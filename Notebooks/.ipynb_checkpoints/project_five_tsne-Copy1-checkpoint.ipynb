# %% [markdown]
# # Project Five
# # Game of Thrones - TSNE

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from textblob import TextBlob
from nltk.corpus import stopwords
import spacy
from nltk import Tree
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph
from nltk.parse import ProjectiveDependencyParser
from nltk.parse import NonprojectiveDependencyParser
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import gensim
from gensim.models import Word2Vec
from nltk.tag import pos_tag
import re
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline
# Out:
# Using Theano backend.

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import scale

from sklearn.datasets import fetch_mldata
from sklearn.cluster import KMeans
from sklearn.utils import shuffle

# %%
import pickle

with open('/Users/zoemarkovits/Metis/project_five_got/total_corpus_texts2.pkl', 'rb') as f:
    total_corpus_texts = pickle.load(f)

# %%
total_corpus_texts
# Out:
# [['well', 'struck'],
#  ['well', 'struck', 'dog'],
#  ['like'],
#  ['well', 'struck', 'grace'],
#  ['already', 'said', 'well', 'struck'],
#  ['yes', 'grace'],
#  ['ser', 'dontos', 'red', 'house', 'hollard'],
#  ['ser', 'dontos', 'red', 'house', 'hollard'],
#  [],
#  ['sorry', 'grace'],
#  ['deepest', u'apology'],
#  ['drunk'],
#  [],
#  ['uh'],
#  ['grace'],
#  ['two', u'cup', 'wine'],
#  ['two', u'cup'],
#  ['thats', 'much'],
#  ['please', 'another', 'cup'],
#  ['sure', 'grace'],
#  ['two'],
#  ['much', 'like'],
#  ['would', 'honored', 'grace'],
#  ['ser', 'meryn', 'help', 'ser', 'dontos', 'celebrate', 'name', 'day'],
#  ['see', u'drink', 'fill'],
#  ['cant'],
#  ['say'],
#  ['say', 'cant'],
#  ['meant', 'would', 'bad', 'luck', 'kill', 'man', 'name', 'day'],
#  ['kind', 'stupid', u'peasant', 'superstition', 'take', 'away'],
#  ['ill', 'killed', 'tomorrow', 'fool'],
#  [],
#  ['fool', 'youre', 'clever', 'see'],
#  ['hell', 'make', 'much', 'better', 'fool', 'knight'],
#  ['doesnt', 'deserve', 'mercy', 'quick', 'death'],
#  ['hear', 'lady', 'ser', 'dontos'],
#  ['day', 'youll', 'new', 'fool'],
#  ['thank', 'grace'],
#  ['lady', 'thank'],
#  ['looked', 'battlefield'],
#  ['nowhere', 'found'],
#  ['ive', 'ruling', u'kingdom'],
#  ['fine', 'job', 'youve', 'done'],
#  ['look'],
#  ['beautiful', 'ever'],
#  [],
#  ['youre', 'going', 'bigger', 'hound', 'much', 'better', 'looking'],
#  ['one', 'doesnt', 'like'],
#  ['cant', 'imagine'],
#  ['heard', 'dead'],
#  ['im', 'glad', 'youre', 'dead'],
#  ['dear'],
#  ['death', 'boring', 'especially', 'much', 'excitement', 'world'],
#  ['lady', 'im', 'sorry', 'loss'],
#  ['loss'],
#  ['father', 'confessed', 'traitor'],
#  ['still', 'father'],
#  ['surely', 'recently', 'lost', 'beloved', 'father', 'sympathize'],
#  ['father', 'traitor'],
#  ['mother', 'brother', u'traitor'],
#  ['loyal', 'beloved', 'joffrey'],
#  ['course'],
#  ['well', 'enjoy', 'name', 'day', 'grace'],
#  ['wish', 'could', 'stay', 'celebrate', 'work', 'done'],
#  ['work'],
#  [],
#  ['raven', 'arrived', 'citadel', 'morning', 'grace'],
#  ['conclave',
#   'met',
#   'considered',
#   u'report',
#   'maesters',
#   'seven',
#   u'kingdom',
#   'done',
#   'last'],
#  ['longest', 'summer', 'living', 'memory'],
#  [u'peasant',
#   'say',
#   'long',
#   'summer',
#   u'mean',
#   u'last',
#   'longer',
#   'well',
#   'fewer',
#   u'peasant'],
#  [u'city', 'drowning', u'refugee', 'grace', 'fleeing', 'war'],
#  ['nowhere', 'house'],
#  ['winter', 'coming', 'itll', 'get', 'worse'],
#  ['command', 'city', 'watch', 'lord', 'slynt'],
#  ['lord', 'command'],
#  ['owe', 'title', u'land', 'generosity', 'grace'],
#  ['job'],
#  ['shut', u'gate', u'peasant'],
#  ['belong', 'field', 'capital'],
#  ['yes', 'grace'],
#  ['dont', 'get'],
#  ['ravishing', 'ever', 'big', 'sister'],
#  ['war', 'agrees'],
#  ['forgive', 'interruption'],
#  ['carry'],
#  [],
#  ['ah', 'remarkable', 'journey'],
#  ['pissed',
#   'edge',
#   'wall',
#   'fought',
#   'hill',
#   u'tribe',
#   'many',
#   u'adventure',
#   'much',
#   'thankful'],
#  [],
#  ['small', 'council'],
#  ['yes'],
#  ['well',
#   'believe',
#   'hand',
#   'king',
#   'welcome',
#   'small',
#   'council',
#   u'meeting'],
#  ['father', 'hand', 'king'],
#  ['yes', 'absence', 'serve', 'hand', 'stead', u'fight'],
#  [],
#  [],
#  ['would', 'like', 'know', 'tricked', 'father'],
#  ['capable', 'tricking', 'father', 'id', 'emperor', 'world'],
#  ['brought'],
#  ['ive', 'done', 'nothing'],
#  ['quite', 'right', 'nothing', 'son', 'called', 'ned', 'starks', 'head'],
#  ['entire', 'north', 'risen', u'u'],
#  ['tried', 'stop'],
#  [],
#  ['failed'],
#  ['bit', 'theater', 'haunt', 'family', 'generation'],
#  ['robb', 'stark', 'child'],
#  [u'who', 'every', 'battle', u'he', 'fought'],
#  ['understand', 'losing', 'war'],
#  ['know', 'warfare'],
#  ['nothing'],
#  ['know', 'people'],
#  ['know', u'enemy', 'hate', 'almost', 'much', 'hate', u'u'],
#  ['joffrey', 'king'],
#  ['joffrey', 'king'],
#  ['advise'],
#  ['im', 'advise'],
#  ['king', 'listens', 'say', 'king', 'might', 'get', 'uncle', 'jaime', 'back'],
#  [],
#  ['love', u'child'],
#  ['one', 'redeeming', 'quality'],
#  [u'cheekbone'],
#  ['starks', 'love', u'child', 'well'],
#  ['two'],
#  ['one'],
#  ['one'],
#  ['arya', 'little', 'animal', 'disappeared'],
#  ['disappeared'],
#  ['puff', 'smoke'],
#  ['three', 'starks', 'trade'],
#  ['chopped', u'one', 'head', 'let', 'another', 'escape'],
#  ['father', 'furious'],
#  ['must', 'odd', 'disappointing', 'child'],
#  ['lord', 'may', 'old', u'god', 'watch', 'brother', 'northern', u'son'],
#  [u'wall', 'holdfast', 'stand', 'winter'],
#  [u'stone',
#   'last',
#   'mortared',
#   'time',
#   'king',
#   u'aery',
#   'im',
#   'afraid',
#   u'mason',
#   'today',
#   'fit',
#   'carry',
#   u'father',
#   u'hammer'],
#  ['boy',
#   'remember',
#   'seeing',
#   'put',
#   'new',
#   'tower',
#   'torrhens',
#   'square',
#   'summer'],
#  ['men', 'worked', 'back'],
#  ['today', 'holdfast', u'look', 'like', 'built', 'drunk', u'child'],
#  ['night', 'hear', 'wind', 'howling', u'gap'],
#  [u'god', 'forbid', u'rain'],
#  ['might', 'well', 'sleep', 'beneath', 'waterfall'],
#  ['maintenance', 'holdfast', 'generally', u'fall', 'lord', 'holdfast'],
#  ['generally',
#   'yes',
#   'ive',
#   'sent',
#   'young',
#   'men',
#   'fight',
#   'robb',
#   'starks',
#   'war'],
#  ['king', 'robb'],
#  ['war'],
#  ['didnt', 'choose'],
#  ['maybe', 'lord', 'called', u'banner', 'took', 'men'],
#  ['joffrey', 'killed', 'father', 'liege', 'lord'],
#  ['remember', u'vow', 'ser'],
#  ['course', 'remember'],
#  ['spare', 'four', u'mason', 'week', 'lord'],
#  ['sufficient', 'repair', u'wall'],
#  ['believe'],
#  ['didnt', 'want', 'day'],
#  ['didnt', 'like', 'way', 'talking', 'robb'],
#  ['listening',
#   'people',
#   'youd',
#   'rather',
#   'listen',
#   'one',
#   u'responsibility',
#   'lord',
#   'winterfell'],
#  ['lord', 'portan'],
#  ['lord', 'may', 'old', u'god', 'watch', 'brother', 'northern', u'son'],
#  ['boil', 'hour', 'drink', 'tea'],
#  [u'make', 'pain', 'go', 'away'],
#  ['dont', 'pain'],
#  ['lucky'],
#  ['way'],
#  ['youve', u'dream'],
#  ['dont', 'dream'],
#  ['everyone', u'dream'],
#  ['dont'],
#  ['heard', 'men', 'talking', 'comet'],
#  ['say', 'omen'],
#  ['say', u'mean', 'robb', 'win', 'great', 'victory', 'south'],
#  [],
#  ['heard', u'fool', 'say', 'lannister', 'red'],
#  [u'mean', 'lannisters', 'rule', 'seven', u'kingdom', 'long'],
#  ['heard', 'stableboy', 'say', 'color', 'blood', 'mark', 'death', 'father'],
#  [u'star', 'dont', 'fall', 'men'],
#  ['red', 'comet', u'mean', 'one', 'thing', 'boy', u'dragon'],
#  [u'dragon', 'dead'],
#  ['theyve', 'dead', u'century'],
#  ['mmm'],
#  ['mmm'],
#  ['mmm'],
#  ['brother', 'say', 'khaleesi'],
#  ['said', 'ate', 'meat'],
#  ['didnt', 'tell', 'kind', 'meat'],
#  ['brother', 'didnt', 'know', 'anything', u'dragon'],
#  ['didnt', 'know', 'anything', 'anything'],
#  ['eh'],
#  ['drogos', 'first', 'gift'],
#  ['remember'],
#  ['promised', 'protect'],
#  ['promised', u'enemy', 'would', 'die', 'screaming'],
#  ['make', 'starvation', 'scream'],
#  ['trick', 'never', 'learned', 'im', 'afraid'],
#  ['ever', 'end'],
#  ['farther', 'east', 'ive', 'ever'],
#  ['yes', 'khaleesi', 'everything', u'end', 'even', 'red', 'waste'],
#  ['youre', 'sure', u'there', 'way'],
#  ['go',
#   'south',
#   'land',
#   'lazarheen',
#   'lamb',
#   'men',
#   'kill',
#   u'u',
#   'take',
#   u'dragon'],
#  ['go',
#   'west',
#   'dothraki',
#   'sea',
#   'first',
#   'khalasar',
#   'meet',
#   'kill',
#   u'u',
#   'take',
#   u'dragon'],
#  ['one', 'take', u'dragon'],
#  ['weak', 'fight', 'people'],
#  ['must', 'strength'],
#  ['mine'],
#  ['rakharo', 'never'],
#  ['bad', 'time', 'start'],
#  ['rough', 'time'],
#  [u'nothing', 'killed', 'yet'],
#  [u'as', 'killed', 'sledge'],
#  ['offered', 'ride'],
#  ['wanted', 'shut', 'damn', u'blister'],
#  ['born', 'place', 'like'],
#  ['later', 'fell', 'hard', u'time'],
#  [u'girl'],
#  ['crasters', u'daughter'],
#  ['havent', 'seen', 'girl', 'six', u'month'],
#  ['id', 'keep', 'seeing'],
#  ['dont', 'like', 'people', 'messing', u'daughter'],
#  ['dont', 'like', 'people', 'messing', u'wife'],
#  ['marries', u'daughter', 'give', u'daughter'],
#  [u'go'],
#  ['thats', 'foul'],
#  ['beyond', 'foul'],
#  ['wildlings', 'hundred', u'league', 'disappeared'],
#  ['crasters', 'still'],
#  ['must', 'something', 'right'],
#  ['happens', u'boy'],
#  ['hmm'],
#  ['marries', u'daughter'],
#  [u'son'],
#  ['said', 'planned', 'stop', 'way', 'frostfangs'],
#  ['people', 'make', u'sort', u'plan'],
#  ['havent', 'seen', 'benjen', 'stark', 'three', u'year'],
#  ['havent', 'missed'],
#  ['always', 'treated', 'like', 'scum'],
#  ['havent', 'good', 'wine', 'long', 'time'],
#  [u'southerner', 'make', 'good', 'wine', 'ill', 'give'],
#  [u'southerner'],
#  [u'who', 'little', 'girl'],
#  ['youre', 'prettier', 'half', u'daughter'],
#  ['got', 'nice', 'wet', 'twat', u'leg'],
#  ['whats', 'name'],
#  ['jon', 'snow'],
#  ['snow', 'eh'],
#  ['listen', 'bastard'],
#  ['lot', 'south', 'wall', 'youre', u'southerner'],
#  ['youre', 'north', 'real', 'north'],
#  ['lad', 'meant', 'harm'],
#  ['catch',
#   'pretty',
#   'little',
#   'bastard',
#   'talking',
#   u'daughter',
#   'one',
#   'talk',
#   u'daughter',
#   'word'],
#  ['sit', 'shut', 'mouth'],
#  ['bring', 'good', 'wine'],
#  [],
#  ['passed', 'six', u'village', 'way'],
#  ['six', 'abandoned'],
#  ['wildlings', 'gone'],
#  ['could', 'tell', 'im', 'thirsty'],
#  [u'there', 'barrel', 'dornish', 'wine', 'sledge'],
#  ['bring'],
#  ['yes', 'commander'],
#  ['want', 'know', 'theyve', 'gone'],
#  ['north', 'join', 'mance', 'rayder', 'old', 'friend'],
#  [u'he', 'friend', 'mine'],
#  ['broke', u'vow', 'betrayed', u'brother'],
#  ['oh', 'aye'],
#  ['poor', 'black', 'crow'],
#  [u'he', 'king', 'beyond', 'wall'],
#  [u'he', 'calling', u'year'],
#  ['whats', 'king'],
#  ['frozen', 'lake', 'somewhere'],
#  ['thats', 'good', 'looking', 'axe'],
#  ['fresh', 'forged'],
#  ['give'],
#  ['youll', 'another', 'one', 'made', 'castle', 'black'],
#  [],
#  ['oh', 'thats', 'lovely', 'steel'],
#  ['want', 'know', 'mance', 'rayder'],
#  ['gathering', 'army'],
#  ['hear', u'he', 'already', 'got', 'men', 'southern', u'king'],
#  ['plan', 'marching', 'army'],
#  ['youre', 'way', 'north', u'there', 'one', 'direction', 'go'],
#  ['bad', u'time', 'living', 'alone', 'wild'],
#  ['cold', u'wind', 'rising'],
#  ['let', 'come'],
#  [u'root', 'sunk', 'deep'],
#  ['wife', 'tell', 'lord', 'crow', 'content'],
#  ['place'],
#  ['husband', u'keep', u'u', 'safe'],
#  ['better', 'live', 'free', 'die', 'slave'],
#  ['dont',
#   'make',
#   'jealous',
#   'old',
#   'man',
#   'see',
#   'young',
#   u'wife',
#   'one',
#   'warm',
#   'bed'],
#  ['chose', 'different', u'path'],
#  ['oh', 'aye', 'chose', 'path', 'one', u'boy'],
#  ['youll', 'wanting', 'sleep', 'beneath', 'roof', 'suppose', 'eat', u'pig'],
#  ['roof', 'would', 'welcome'],
#  ['hard', 'riding'],
#  ['weve', 'brought', 'food', 'good', 'steel'],
#  ['man', u'lay', 'hand', 'one', u'wife', 'loses', 'hand'],
#  ['see', 'one', 'staring', 'long', 'might', 'gouge', u'eye'],
#  ['roof', u'rule'],
#  [],
#  [],
#  ['lord', 'commander'],
#  [],
#  ['jon', 'snow'],
#  [],
#  ['steward'],
#  ['want', 'lead', 'one', 'day'],
#  ['learn', 'follow'],
#  ['lord', 'light', 'come', u'u', 'darkness'],
#  ['offer', 'false', u'god'],
#  ['take', 'cast', 'light', 'upon', u'u', 'night', 'dark', 'full', u'terror'],
#  ['night', 'dark', 'full', u'terror'],
#  ['long', 'summer', 'darkness', 'fall', 'heavy', 'world'],
#  [u'star', 'bleed'],
#  ['need', 'stop'],
#  ['cold', 'breath', 'winter', 'freeze', u'sea'],
#  ['dead', 'shall', 'rise', 'north'],
#  ['men', 'named', 'light', 'seven'],
#  ['treat', u'god', u'father'],
#  ['eager', 'spit', u'ancestor'],
#  ['smell', 'fear', 'fear', 'piss', 'old', u'bone'],
#  ['want', 'stop'],
#  ['stop'],
#  ['ancient',
#   u'book',
#   'written',
#   'warrior',
#   'draw',
#   'burning',
#   'sword',
#   'fire'],
#  ['sword', 'shall', 'lightbringer'],
#  ['stannis', 'baratheon', 'warrior', 'light', 'sword', 'awaits'],
#  ['lord', 'cast', 'light', 'upon', u'u'],
#  ['night', 'dark', 'full', u'terror'],
#  ['night', 'dark', 'full', 'terror'],
#  ['woman', 'lead', 'war', 'cannot', 'win'],
#  ['stannis', 'king'],
#  ['follow', u'lead', 'even', 'dont', 'like', 'path'],
#  ['king'],
#  ['since',
#   'boar',
#   'killed',
#   'brother',
#   'every',
#   'lord',
#   u'want',
#   'coronation'],
#  ['dont', 'serve', 'others'],
#  ['serve', 'stannis'],
#  ['loyal', 'service', u'mean', 'telling', 'hard', u'truth'],
#  [u'he', 'surrounded', u'fool', u'fanatic', u'trust', 'davos'],
#  ['tell', 'truth', 'whats', 'truth'],
#  ['declare',
#   'upon',
#   'honor',
#   'house',
#   'beloved',
#   'brother',
#   'robert',
#   'wasnt',
#   'beloved',
#   'brother'],
#  ['didnt', 'love'],
#  ['didnt', 'love'],
#  ['harmless', 'courtesy', 'grace'],
#  ['lie'],
#  ['take'],
#  ['brother',
#   'robert',
#   'left',
#   'trueborn',
#   u'heir',
#   'boy',
#   'joffrey',
#   'boy',
#   'tommen',
#   'girl',
#   'myrcella',
#   'born',
#   'incest',
#   'cersei',
#   'lannister',
#   'brother',
#   'jaime',
#   'lannister'],
#  ['right', 'birth', 'jaime', 'lannister', 'kingslayer'],
#  ['call'],
#  ['brother', 'jaime', 'lannister', 'kingslayer'],
#  ['right',
#   'birth',
#   'blood',
#   'day',
#   'lay',
#   'claim',
#   'make',
#   'ser',
#   'jaime',
#   'lannister',
#   'kingslayer'],
#  ['whatever', 'else', u'man', 'still', 'knight'],
#  ['ser', 'jaime', 'lannister', 'kingslayer'],
#  ['right',
#   'birth',
#   'blood',
#   'day',
#   'lay',
#   'claim',
#   'iron',
#   'throne',
#   'westeros'],
#  ['let', 'true', 'men', 'declare', 'loyalty'],
#  ['eddard', 'stark', 'learned', 'truth', 'told'],
#  ['ill', 'make', 'mistake'],
#  ['send', u'copy', 'letter', 'every', 'corner', 'realm', 'arbor', 'wall'],
#  ['time', 'come', 'choose'],
#  ['let', 'man', 'claim', 'ignorance', 'excuse'],
#  ['gracethe', 'lannisters', 'true', 'enemy'],
#  ['time',
#   'could',
#   'make',
#   'peace',
#   'brother',
#   'ill',
#   'make',
#   'peace',
#   'renly',
#   u'call',
#   'king'],
#  ['well', 'many', 'already', 'declared', 'mace', 'tyrell', 'randyll', 'tarly'],
#  ['stannis', 'need', 'beg', 'lord', 'lord', 'support'],
#  ['lord', 'light', u'stand', 'behind'],
#  ['many', u'ship', 'lord', 'light', 'got', 'fleet'],
#  ['need', u'ship'],
#  ['im', 'sure', 'doesnt', 'going', 'war'],
#  ['renly', 'grace', 'join', u'force', 'robb', 'stark'],
#  ['would', 'steal', 'northern', 'half', 'kingdom'],
#  ['ive',
#   'always',
#   'served',
#   u'thief',
#   'according',
#   u'dessert',
#   'well',
#   'know',
#   'ser',
#   'davos'],
#  ['joffrey', 'renly', 'robb', 'stark', 'theyre', u'thief'],
#  ['theyll', 'bend', 'knee', 'ill', 'destroy'],
#  ['owe', 'apology', 'king'],
#  ['duty', 'serve'],
#  ['chosen', 'new', 'god', 'old', u'god'],
#  ['may', 'lord', 'light', 'watch', u'u'],
#  ['shall', 'drink', 'together'],
#  ['dont'],
#  ['cup', 'wine', 'honor', 'one', 'true', 'god'],
#  ['night', 'dark', 'full', u'terror', 'old', 'man', 'fire', u'burn', 'away'],
#  ['grace'],
#  ['king', 'north'],
#  ['keep',
#   'expecting',
#   'leave',
#   'one',
#   'castle',
#   'another',
#   'safekeeping',
#   'drag',
#   'along',
#   'camp',
#   'camp'],
#  ['grown', 'fond', 'stark'],
#  [],
#  ['ive', 'never', 'seen', 'girl'],
#  ['left',
#   'one',
#   'bannermen',
#   'father',
#   'would',
#   'know',
#   'within',
#   'fortnight',
#   'bannerman',
#   'would',
#   'receive',
#   'raven',
#   'message',
#   'release',
#   'son',
#   'youll',
#   'rich',
#   'beyond',
#   u'dream'],
#  ['refuse', 'house', 'destroyed', 'root', 'stem'],
#  ['dont', 'trust', 'loyalty', 'men', 'following', 'battle'],
#  ['oh', 'trust', 'life'],
#  ['smart', 'boy'],
#  ['whats', 'wrong'],
#  ['dont', 'like', 'called', 'boy'],
#  ['insulted'],
#  ['insult', 'kingslayer'],
#  ['youve', 'defeated', 'boy'],
#  ['youre', 'held', 'captive', 'boy'],
#  ['perhaps', 'youll', 'killed', 'boy'],
#  ['stannis', 'baratheon', 'sent', u'raven', 'high', u'lord', 'westeros'],
#  ['king',
#   'joffrey',
#   'baratheon',
#   'neither',
#   'true',
#   'king',
#   'true',
#   'baratheon'],
#  [u'he', 'bastard', 'son'],
#  ['thats', 'true', 'stannis', 'rightful', 'king'],
#  ['convenient'],
#  ['father', 'learned', 'truth'],
#  ['thats', 'executed'],
#  ['prisoner', 'ned', 'stark', 'lost', 'head'],
#  ['son', 'killed', 'world', 'wouldnt', 'learn', 'fathered'],
#  ['pushed', 'brother', 'window', 'saw', 'queen'],
#  ['proof'],
#  ['want', 'trade', 'gossip', 'like', 'couple', u'fishwife'],
#  ['im', 'sending', 'one', u'cousin', u'king', 'landing', 'peace', u'term'],
#  ['think', u'father', 'going', 'negotiate'],
#  ['dont', 'know', 'well'],
#  [u'he', 'starting', 'know'],
#  ['three', u'victory', 'dont', 'make', 'conqueror'],
#  ['better', 'three', u'defeat'],
#  ['city', u'stink', 'like', 'dead', u'body'],
#  ['bit', 'corpsey', 'yes'],
#  ['shit'],
#  ['thought', 'wanted', 'come'],
#  ['love'],
#  ['love', 'smell', 'dead', u'body', 'shit'],
#  ['cum', 'garlic', 'rum'],
#  ['smell', 'cum', 'balcony'],
#  ['love', 'stink'],
#  ['love', 'noise'],
#  [u'city', 'make', 'want', 'fuck'],
#  ['country'],
#  ['belong'],
#  ['yes', 'well', 'need', 'careful'],
#  ['one', 'know', 'youre'],
#  ['one', 'know'],
#  ['cant', 'trust', 'anyone', u'king', 'landing'],
#  ['theyre',
#   u'liar',
#   'good',
#   u'liar',
#   'bad',
#   u'liar',
#   'one',
#   'two',
#   'great',
#   u'liar'],
#  [],
#  [],
#  ['im'],
#  ['im', 'slave', 'truth'],
#  ['truth'],
#  ['biggest', 'little', 'liar', 'ever', 'met'],
#  ['think', 'little'],
#  ['im', 'crushed', 'beneath', 'weight', 'truth'],
#  ['oh'],
#  ['ned', 'stark', 'actually', 'slept'],
#  ['poor', 'man', 'didnt', 'suffer', 'enough'],
#  ['one', 'many', u'change', 'well', 'make', 'around'],
#  ['lord', 'baelish'],
#  ['grace'],
#  ['wonder', 'might', 'ask', 'favor'],
#  ['course', 'grace'],
#  ['ned', 'starks', 'youngest', 'daughter', 'arya', 'cant', 'seem', 'locate'],
#  ['shes',
#   'escaped',
#   'capital',
#   'winterfell',
#   'seems',
#   'logical',
#   'destination'],
#  ['yet', u'friend', 'north', 'report', 'sign'],
#  ['curious'],
#  ['choose', 'negotiate', 'starks', 'girl', 'value'],
#  ['whoever', u'find', 'well', 'know', 'say', 'lannisters', u'debt'],
#  ['well', 'could', 'ask', 'varys'],
#  ['hell', 'answer'],
#  ['whether', 'believe', 'always', 'hard', 'time', 'trusting', u'eunuch'],
#  [u'know', 'want'],
#  ['mockingbird'],
#  ['created', 'sigil', 'didnt'],
#  ['yes'],
#  ['appropriate', 'self', 'made', 'man', 'many', u'song', 'sing'],
#  ['im', 'glad', 'like'],
#  ['people', 'fortunate', 'enough', 'born', 'right', 'family'],
#  ['others', 'find', 'way'],
#  ['heard',
#   'song',
#   'boy',
#   'modest',
#   u'mean',
#   'found',
#   'way',
#   'home',
#   'prominent',
#   'family'],
#  ['loved', 'eldest', 'daughter'],
#  ['sadly', u'eye', 'another'],
#  [u'boy', u'girl', 'live', 'home', 'awkward', u'situation', 'arise'],
#  ['sometimes',
#   'ive',
#   'heard',
#   'even',
#   u'brother',
#   u'sister',
#   'develop',
#   'certain',
#   u'affection'],
#  [u'affection',
#   'become',
#   'common',
#   'knowledge',
#   'well',
#   'awkward',
#   'situation',
#   'indeed',
#   'especially',
#   'prominent',
#   'family'],
#  ['prominent',
#   u'family',
#   'often',
#   'forget',
#   'simple',
#   'truth',
#   'ive',
#   'found'],
#  ['truth'],
#  ['knowledge', 'power'],
#  ['seize'],
#  ['cut', 'throat'],
#  ['stop'],
#  ['wait'],
#  ['ive', 'changed', 'mind'],
#  ['let', 'go'],
#  ['step', 'back', 'three', u'pace'],
#  ['turn', 'around'],
#  ['close', u'eye'],
#  ['power', 'power'],
#  ['see', 'take', 'time', 'away', u'coin', u'whore', 'locate', 'stark', 'girl'],
#  ['would', 'much', 'appreciate'],
#  ['youre', 'ser', 'alton', 'lannister'],
#  ['grace'],
#  ['offer', u'cousin', 'peace', 'meet', u'term'],
#  ['first', 'family', 'must', 'release', u'sister'],
#  ['second',
#   u'father',
#   u'bone',
#   'must',
#   'returned',
#   u'u',
#   'may',
#   'rest',
#   'beside',
#   'brother',
#   'sister',
#   u'crypt',
#   'beneath',
#   'winterfell'],
#  ['remains', 'died', 'service', 'must', 'also', 'returned'],
#  [u'family', 'honor', 'proper', u'funeral'],
#  ['honorable', 'request', 'grace'],
#  ['third',
#   'joffrey',
#   'queen',
#   'regent',
#   'must',
#   'renounce',
#   'claim',
#   'dominion',
#   'north'],
#  ['time', 'till', 'end', 'time', 'free', 'independent', 'kingdom'],
#  ['king', 'north'],
#  ['king', 'north'],
#  ['neither', 'joffrey', 'men', 'shall', 'set', 'foot', u'land'],
#  [u'disregard',
#   'command',
#   'shall',
#   'suffer',
#   'fate',
#   'father',
#   'dont',
#   'need',
#   'servant',
#   'beheading'],
#  ['grace', u'term'],
#  ['queen', 'regent', 'son', 'meet', 'ill', 'give', 'peace'],
#  ['litter', 'south', 'lannister', 'dead'],
#  ['king', 'joffrey', 'baratheon', 'grace'],
#  ['oh'],
#  ['youll', 'ride', 'daybreak', 'ser', 'alton'],
#  ['tonight'],
#  ['word', 'grace'],
#  ['dont', 'call', 'grace', u'one', 'around'],
#  ['bad', 'get', 'used'],
#  ['im', 'glad', u'someone', 'gotten', 'used'],
#  ['lannisters', 'going', 'reject', u'term', 'know'],
#  ['course'],
#  ['fight',
#   u'field',
#   'long',
#   'like',
#   'wont',
#   'beat',
#   'take',
#   u'king',
#   'landing'],
#  ['cant', 'take', u'king', 'landing', 'without', u'ship'],
#  ['father', u'ship', 'men', 'know', 'sail'],
#  ['men', 'fought', 'father'],
#  ['men', 'fought', 'king', 'robert', 'free', 'yoke', 'south', 'like', 'youre'],
#  ['im', 'living', 'son'],
#  ['hell', 'listen'],
#  ['know'],
#  ['im', 'stark'],
#  ['know'],
#  ['father', 'raised', 'honorable', 'man'],
#  ['avenge', 'together'],
#  ['dont', 'want', 'balon', 'greyjoy', 'ally'],
#  ['need', u'ship'],
#  ['say'],
#  ['say', 'million', u'rat', 'live', u'sewer', u'king', 'landing'],
#  ['shall', 'rally', 'fight', u'u'],
#  ['understand', 'dont', 'trust', 'lord', 'greyjoy'],
#  ['dont', 'trust', 'lord', 'greyjoy', 'trustworthy'],
#  ['father', 'go', 'war', 'end', 'rebellion'],
#  ['yes'],
#  ['im', 'one', 'rebelling', 'throne'],
#  ['father'],
#  ['married', 'one', 'rebel', 'mothered', 'another'],
#  ['mothered', u'rebel', 'fact', 'seem', 'forgotten'],
#  ['trade', 'kingslayer', 'two', u'girl', 'bannermen', 'string', u'foot'],
#  ['want', 'leave', 'sansa', u'queen', u'hand'],
#  ['arya', 'havent', 'heard', 'word', 'arya'],
#  ['fighting'],
#  ['complicated'],
#  ['know'],
#  ['time', 'go', 'home'],
#  ['havent', 'seen', 'bran', 'rickon', u'month'],
#  ['cant', 'go', 'winterfell'],
#  ['beg', 'pardon'],
#  ['ill',
#   'send',
#   'rodrik',
#   'watch',
#   u'boy',
#   'tomorrow',
#   'youll',
#   'ride',
#   'south',
#   'stormlands'],
#  ['name', u'god', 'need', 'negotiate', 'renly', 'baratheon'],
#  [u'he', 'rallied', 'army'],
#  ['know'],
#  ['know', 'family'],
#  ['havent', 'seen', 'renly', 'baratheon', 'since', 'boy'],
#  ['hundred', u'lord', u'lord', 'trust'],
#  ['renly', u'side', u'u', 'well', 'outnumber', 'two', 'one'],
#  ['feel', u'jaw', 'beginning', 'shut', 'theyll', 'sue', 'peace'],
#  ['well', 'get', u'girl', 'back'],
#  ['well', 'go', 'home', 'good'],
#  ['ride', 'first', 'light'],
#  ['together', 'soon', 'promise'],
#  ['youve', 'done', 'well'],
#  ['father', 'would', 'proud'],
#  ['give', 'lord', 'renly', u'regard'],
#  ['king', 'renly'],
#  [u'there', 'king', 'every', 'corner'],
#  [],
#  ['returning', 'room', 'proper', 'appearance'],
#  ['say', 'targaryens', u'conqueror'],
#  ['seat', 'conqueror'],
#  [u'need', 'room', 'match', u'vine', u'flower'],
#  ['cant', 'find', 'arya', 'stark'],
#  ['luck', 'shes', 'dead', 'ditch', 'somewhere'],
#  ['perhaps'],
#  ['need'],
#  ['theyll', 'never', 'give', 'jaime', 'back', u'u', 'sansa', 'alone'],
#  ['think', 'might'],
#  ['theyre', 'weak'],
#  ['put', 'much', 'value', u'woman'],
#  ['need', 'set', u'army', 'task', 'finding'],
#  ['send', 'many', 'men'],
#  ['im', 'sure', 'asked', 'grandfather', 'king', 'ask', u'command'],
#  [u'grandfather',
#   'stupidity',
#   'field',
#   'battle',
#   'reason',
#   'robb',
#   'stark',
#   'uncle',
#   'jaime',
#   'first',
#   'place'],
#  ['life', 'danger'],
#  ['war'],
#  [u'life', 'danger'],
#  ['heard', 'disgusting', 'lie', 'uncle', 'jaime'],
#  [],
#  [u'enemy', 'say', 'anything', 'weaken', 'claim', 'throne'],
#  ['claim'],
#  ['throne', 'mine'],
#  ['course'],
#  ['one', u'belief', 'foul', 'gossip'],
#  ['someone', u'belief'],
#  ['father', u'child'],
#  ['besides', 'tommen', 'myrcella'],
#  ['asking'],
#  ['im', 'asking', 'fucked', u'woman', 'grew', 'tired'],
#  ['many', u'bastard', 'running', 'punishable', 'death'],
#  ['never'],
#  ['never'],
#  ['mother'],
#  [],
#  ['idea', 'ridiculous', 'sound'],
#  ['ease'],
#  ['slowly', 'passion'],
#  ['oh', 'yeah'],
#  ['go', 'wash'],
#  ['put', 'clothes'],
#  ['working', 'tonight'],
#  [u'thing', 'differently', 'daisy'],
#  ['isnt', 'five', 'copper', 'bawdy', 'house', 'hayseed', 'hall'],
#  ['haystack', 'hall'],
#  ['wherever', 'youre'],
#  ['establishment', 'doesnt', 'cater', u'plowman', 'goat', u'herder'],
#  ['lord', 'olsen'],
#  ['taste', 'everything'],
#  ['littlefingers', 'fancy', 'man'],
#  ['dont', 'call', 'littlefinger'],
#  ['doesnt', 'like'],
#  ['lord', 'baelish'],
#  [u'pretend',
#   'doesnt',
#   'speak',
#   'common',
#   'tongue',
#   'people',
#   'think',
#   'shes',
#   'exotic'],
#  ['grew', 'road', 'flea', 'bottom'],
#  ['shes', 'beautiful'],
#  ['shes', 'dumb', 'slut', 'really', 'lid', 'every', 'pot'],
#  ['lord', 'commander'],
#  ['good', 'see'],
#  ['realize',
#   'establishment',
#   'owned',
#   'lord',
#   'petyr',
#   'baelish',
#   u'king',
#   'master',
#   'coin',
#   'coin',
#   u'go',
#   'many',
#   u'pocket'],
#  [u'order'],
#  ['whose', u'order'],
#  ['someone', 'doesnt', 'care', 'littlefinger', u'think'],
#  ['cant'],
#  [],
#  ['please'],
#  [],
#  ['barra'],
#  ['please'],
#  ['please'],
#  ['enough'],
#  ['get', 'done'],
#  ['kill', 'bastard'],
#  [],
#  ['please'],
#  ['give'],
#  ['please'],
#  ['spread'],
#  ['search', 'every', 'house'],
#  ['every', 'room'],
#  ['look', 'every', 'room'],
#  ['people', 'shouting', 'gendry'],
#  ['name', 'gendry'],
#  ['bastard'],
#  [u'night', 'watch'],
#  ['please', 'stop'],
#  [],
#  ['took', 'kingsroad', 'heading', 'north'],
#  ['know'],
#  [u'he', 'got', u'bull', 'head', 'helmet'],
#  ['made'],
#  ['find'],
#  ['boy'],
#  ['lovely', 'boy'],
#  ['want'],
#  ['man', 'thirst'],
#  ['man', 'drink', 'day', 'night'],
#  ['boy', 'could', 'make', 'friend'],
#  [u'friend'],
#  ['give', u'u', 'beer', 'skin'],
#  ['man', 'choose', u'companion'],
#  ['two', 'courtesy'],
#  ['man', 'must', 'ask', 'forgiveness'],
#  ['youre', 'called', 'arry'],
#  ['man', 'honor', 'jaqen', 'hghar', 'free', 'city', 'beer', 'little', 'shit'],
#  ['get', u'u', 'beer'],
#  ['asked', 'nicely'],
#  ['aah'],
#  ['come', 'closer', 'ill', 'shove', 'stick', 'bunghole', 'fuck', 'bloody'],
#  ['boy', 'courage', 'sense'],
#  ['come'],
#  ['yoren', 'said', 'none', u'u', 'go', 'near', 'three'],
#  ['come'],
#  ['dont', 'scare'],
#  ['hmm'],
#  ['youre', 'stupid'],
#  ['scare'],
#  ['gold', u'cloak', 'far', u'king', 'landing'],
#  [],
#  ['theyre', 'looking'],
#  ['command'],
#  ['youre', 'long', 'way', 'home'],
#  ['asked', 'question'],
#  ['aye'],
#  ['asked', 'without', u'manner', 'chose', 'answer'],
#  ['royal', 'warrant', 'one', 'gutter', u'rat', 'youre', 'transporting'],
#  ['well', 'thing', 'gutter', u'rat', 'belong', u'night', 'watch'],
#  [u'put', 'beyond', 'reach', u'king', u'queen'],
#  [],
#  ['funny',
#   'thing',
#   'people',
#   'worry',
#   'much',
#   u'throat',
#   'forget',
#   'whats',
#   'low'],
#  ['sharpened', 'blade', 'breakfast'],
#  ['could',
#   'shave',
#   u'spider',
#   'arse',
#   'wanted',
#   'could',
#   'nick',
#   'artery',
#   'leg'],
#  ['nicked', u'there', 'one', 'around', u'know', 'unnick'],
#  ['well', 'keep'],
#  ['good', 'steel', 'always', 'needed', 'wall'],
#  ['seems',
#   'choice',
#   'die',
#   u'crossroad',
#   'long',
#   'way',
#   'home',
#   'go',
#   'back',
#   'city',
#   'tell',
#   u'master',
#   'didnt',
#   'find',
#   'looking'],
#  ['looking', 'boy', 'named', 'gendry'],
#  [u'carry', u'bull', 'head', 'helmet'],
#  ['anyone', 'turning', 'earn', u'king', 'reward'],
#  ['well',
#   'back',
#   'men',
#   'ill',
#   'taking',
#   'head',
#   'home',
#   'along',
#   'bastard',
#   'boy'],
#  ['distant', u'seagull', 'lord'],
#  ['make', 'wait', 'long', 'time', 'friend', u'keep', 'company'],
#  ['speaking', 'bravery', 'victory', 'stark', 'auxiliary', u'force'],
#  ['quite', 'battle'],
#  ['heard', 'suffered', 'terrible', 'head', 'wound'],
#  [u'northerner', 'fearsome', u'warrior'],
#  ['tell', 'story', 'meet'],
#  ['find',
#   'lovely',
#   'creature',
#   'working',
#   u'father',
#   u'kitchen',
#   'almost',
#   u'beggar',
#   'belief'],
#  ['strange', u'thing', 'happen'],
#  ['taste', 'fish', 'pie'],
#  ['dont', 'think', 'lord', 'varys', u'like', 'fish', 'pie'],
#  ['tell'],
#  ['always', 'tell'],
#  ['men',
#   'like',
#   'lord',
#   'varys',
#   'cant',
#   'let',
#   u'disadvantage',
#   'get',
#   'best',
#   u'u'],
#  ['well', 'make', 'fisherman', 'yet'],
#  ['glad', 'new', 'friend', 'able', 'accompany', 'capital'],
#  [u'friend', 'important', 'part', 'life'],
#  ['unfortunate', 'father', 'didnt', 'want', 'come'],
#  ['rest', 'easy', 'lord'],
#  ['good', 'keeping', u'secret', 'good', u'friend'],
#  ['discretion', 'legendary', u'friend', 'concerned'],
#  ['unspeakable', 'go', 'want', 'rest'],
#  ['leave'],
#  ['welcome', u'king', 'landing', 'dear'],
#  ['city', 'made', 'brighter', 'presence'],
#  ['council', 'meeting', 'lord'],
#  ['dont', 'like', u'threat'],
#  ['threatened'],
#  ['im', 'ned', 'stark'],
#  ['understand', 'way', 'game', 'played'],
#  ['ned', 'stark', 'man', 'honor'],
#  [],
#  ['threaten', 'ill', 'thrown', 'sea'],
#  ['might', 'disappointed', u'result'],
#  [u'storm',
#   'come',
#   'go',
#   'big',
#   'fish',
#   'eat',
#   'little',
#   'fish',
#   'keep',
#   'paddling'],
#  ['come', 'lord'],
#  ['shouldnt', 'keep', 'queen', 'waiting'],
#  ['time',
#   'end',
#   'time',
#   'part',
#   'realm',
#   'free',
#   'independent',
#   'kingdom',
#   'north'],
#  ['spirit', 'father', 'ill', 'give'],
#  ['youve', 'perfected', 'art', 'tearing', u'paper'],
#  ['give', u'father', u'bone', 'back', 'least', 'gesture', 'good', 'faith'],
#  ['youll', 'give', 'starks', 'reply', 'cousin'],
#  ['grace'],
#  ['see', 'brother', 'starks', 'guest'],
#  [],
#  ['broken', 'spirit', 'grace'],
#  ['speak', 'tell', u'he', 'forgotten'],
#  ['grace'],
#  ['safe', u'travel', 'cousin'],
#  ['deft', 'hand', 'diplomacy'],
#  ['thats', 'everything', 'raven', 'flew', 'morning', 'castle', 'black'],
#  ['trouble', 'wildlings'],
#  ['thats', 'theyre', 'called', 'wildlings'],
#  ['somewhat', u'le', 'wild', u'day'],
#  ['seems',
#   'theyve',
#   'stopped',
#   'killing',
#   'started',
#   'following',
#   'king',
#   'beyond',
#   'wall'],
#  ['another', 'king'],
#  ['many', 'five'],
#  ['ive', 'lost', 'count'],
#  ['lord', 'commander', 'asks', 'send', 'men', 'man', 'wall'],
#  ['perhaps', u'he', 'forgotten', 'fighting', 'war'],
#  ['men', 'spare'],
#  ['cold', u'wind', 'rising', 'dead', 'rise'],
#  [u'northerner', 'superstitious', 'people'],
#  ['according', 'commander', 'one', 'dead', 'men', 'attacked', u'chamber'],
#  ['mormont', 'doesnt', 'lie'],
#  ['kill', 'dead', 'man'],
#  ['apparently', 'burn'],
#  ['one', 'trip', 'wall', 'come', 'back', 'believing', 'grumpkins', 'snarks'],
#  ['dont',
#   'know',
#   'believe',
#   u'here',
#   'fact',
#   u'night',
#   'watch',
#   'thing',
#   u'separate',
#   u'u',
#   u'lie',
#   'beyond',
#   'wall'],
#  ['every', 'confidence', 'brave', 'men', u'night', 'watch', 'protect', u'u'],
#  ['said',
#   u'god',
#   'wanted',
#   u'u',
#   'dignity',
#   'wouldnt',
#   'make',
#   u'u',
#   'fart',
#   'died'],
#  ['fart', 'die'],
#  ['blessed', 'mother', 'holding', 'hand', 'left', 'world'],
#  ['farted', 'hard', 'whole', 'bed', 'shook'],
#  ['seems', 'bit', 'greedy', 'one', 'man', 'many', u'wife'],
#  ['wouldnt', 'two', 'three', 'enough'],
#  ['serious', 'discussion'],
#  ['would', 'look'],
#  ['nothing', 'like', 'sight', 'woman', 'walking', 'away'],
#  ['prefer', 'watching', 'come', 'towards'],
#  ['im', 'sure', 'thats', 'nice'],
#  ['yeah', 'well', 'milkmaid', 'named', 'violet', 'next', 'farm', 'grew'],
#  ['wrestling', 'together', 'time', 'six', u'year', 'old'],
#  ['got', 'older', 'wrestling', 'uh', 'changed'],
#  [],
#  ['many', u'time'],
#  ['well', 'many', u'time', 'could'],
#  ['wish', 'grew', 'farm'],
#  ['need', u'potato'],
#  ['get', 'another', 'sack', 'sledge'],
#  ['get', u'turnip'],
#  [],
#  ['ghost'],
#  [],
#  ['ghost', 'away'],
#  ['shoo', 'shoo'],
#  ['right'],
#  ['frighten'],
#  ['shouldnt', 'touch'],
#  ['oh'],
#  ['oh', 'right'],
#  ['im', 'sorry'],
#  ['wanted', 'make', 'sure', 'werent', 'hurt'],
#  ['youre', 'brave'],
#  [],
#  ['gilly'],
#  ['shes', 'one', 'crasters', u'daughter'],
#  ['hello', 'gilly'],
#  [],
#  ['sam', 'said', 'could', 'help'],
#  ['im', 'sorry', 'sam', u'know', 'supposed', 'shes', 'pregnant'],
#  ['take', u'u', 'leave'],
#  [],
#  ['would', 'know', u'sound', 'bit', 'mad'],
#  ['doesnt', 'sound', 'bit', 'mad', 'impossible'],
#  ['lord', 'commander', 'ordered', u'u', 'sworn', 'protect'],
#  ['sam', 'cant', 'take', 'please', 'ser', 'please'],
#  ['still', 'run'],
#  ['possible'],
#  ['im', 'going', 'baby'],
#  ['boy', 'boy'],
#  ['want', u'u', 'risk', u'life', 'wont', 'even', 'tell', u'u'],
#  ['whyd'],
#  [],
#  ['ask', 'question'],
#  ['cruel'],
#  ['cruel'],
#  ['sam', 'hurry', 'lose', 'hand'],
#  ['didnt', 'touch'],
#  ['want', 'steal'],
#  ['think', 'craster', u'cut'],
#  ['cant', 'steal'],
#  ['shes', 'person', 'goat'],
#  ['heading', 'deeper', 'deeper', 'wildling', 'territory'],
#  ['cant', 'take', 'girl', u'u'],
#  ['mormont', 'wouldnt'],
#  ['even', 'would', 'would'],
#  [u'who', 'going', 'deliver', 'baby'],
#  ['could', 'try'],
#  [],
#  ['ive', 'read'],
#  ['bit'],
#  ['im', 'sorry', 'sam'],
#  ['cant', 'help'],
#  ['khaleesi'],
#  ['dont', 'need', 'see'],
#  ['blood', 'blood'],
#  [],
#  ['khal', 'pono', 'perhaps'],
#  ['khal', 'jhaqo'],
#  ['dont', 'like', 'idea', 'woman', 'leading', 'khalasar'],
#  ['like', 'far', u'le', 'done'],
#  ['remember', 'lord'],
#  [u'look', 'smaller'],
#  ['everything', u'look', 'bigger', 'youre', 'child'],
#  ['remember', u'father', 'cabin', 'felt', 'like', 'palace', 'little'],
#  ['look'],
#  ['theyll', 'waiting', u'dock'],
#  [],
#  ['anyone', u'matter'],
#  ['big', 'day'],
#  ['havent', 'much', 'get', 'excited', 'since', 'left'],
#  ['hard', 'place', 'iron', u'island'],
#  ['always'],
#  ['cold', 'wet'],
#  ['oh', 'love', 'cold', 'wet'],
#  ['say', 'hard', u'place', 'breed', 'hard', 'men'],
#  ['hard', 'men', 'rule', 'world'],
#  ['youll', 'king', 'long'],
#  ['try', 'smiling', u'lip', 'closed'],
#  ['better'],
#  ['father', 'doesnt', 'trust', 'iron', u'islander'],
#  ['dont', 'blame'],
#  [u'say',
#   'youre',
#   'reavers',
#   u'raper',
#   'matter',
#   'many',
#   u'woman',
#   'youll',
#   'never',
#   'sat',
#   'uh'],
#  ['quit', 'talking', 'father'],
#  [u'he', 'right', u'u'],
#  [u'wife', 'iron', u'island', 'theyre', 'breeding'],
#  ['thats', 'enough', u'u'],
#  ['thats', 'take', 'salt', u'wife', u'woman', 'capture'],
#  ['capture'],
#  ['take', 'go', 'ashore'],
#  ['make', 'salt', 'wife'],
#  ['place', 'ship'],
#  ['leave'],
#  ['father', 'punish'],
#  ['hell', 'call', 'whore'],
#  ['havent', 'paid'],
#  ['oh', 'yeah'],
#  ['paid', 'good', 'money', 'im', 'going', 'stand'],
#  ['barely', 'touched'],
#  ['charge', 'twice', 'much', 'every', 'brothel', 'get', u'cry'],
#  ['one', 'moment', 'friend'],
#  ['moment'],
#  ['please', 'accept', 'sincerest', u'apology'],
#  ['aremca', 'take', 'good', 'care'],
#  ['im', 'sorry', 'lord'],
#  ['shh', 'shh'],
#  ['hurt'],
#  ['lord'],
#  ['mhaegen'],
#  [],
#  [u'work'],
#  ['shes', 'one', 'gold', u'cloak', 'killed', 'baby'],
#  ['ah', 'yes'],
#  ['poorly', 'handled'],
#  ['sometimes', 'power', 'least', 'grace'],
#  ['cant', 'stop', 'thinking'],
#  ['cant', 'sleep'],
#  ['poor', 'little', 'baby'],
#  ['know',
#   'remind',
#   'another',
#   'girl',
#   'lovely',
#   'thing',
#   'acquired',
#   'lysene',
#   'pleasure',
#   'house',
#   'beautiful',
#   'like',
#   'intelligent',
#   'like'],
#  ['wasnt', 'happy'],
#  ['cried', 'often'],
#  ['asked', 'didnt', 'kind', 'rapport'],
#  ['yes', 'quite', 'sad'],
#  [u'girl',
#   'lysene',
#   'pleasure',
#   u'house',
#   'expensive',
#   'extremely',
#   'expensive'],
#  ['one', 'wasnt', 'making', 'money'],
#  ['hate', 'bad', u'investment'],
#  ['really'],
#  ['haunt'],
#  ['idea', 'make', 'happy', 'idea', 'mitigate', u'loss'],
#  ['wealthy',
#   'patron',
#   'offered',
#   'tremendous',
#   'amount',
#   'money',
#   'let',
#   'transform',
#   'lovely',
#   'sad',
#   'girl'],
#  ['use', u'way', 'would', 'never', 'occur', 'men'],
#  ['know', 'occurs', 'men'],
#  ['would',
#   'say',
#   'succeeded',
#   'making',
#   'happy',
#   u'loss',
#   'definitely',
#   'mitigated'],
#  ['take', 'tonight', 'mourn', 'mhaegens', 'child'],
#  ['ill', 'see', 'tomorrow'],
#  ['youll', 'happy'],
#  [u'make', 'happy'],
#  ['wine'],
#  ['damn', 'boy'],
#  [u'apology', 'lord'],
#  ['leave', u'u', 'podrick'],
#  ['believe', 'know', 'pour', 'wine'],
#  ['thats', 'new', 'squire'],
#  ['couldve', 'found', 'proper', 'lad'],
#  ['prefer', 'improper', u'one'],
#  ['mm', 'thats', 'good', 'red'],
#  ['dornish'],
#  ['know', u'wine', 'lord'],
#  [],
#  ['fine', 'dinner', 'lord'],
#  ['call', 'tyrion', 'please'],
#  ['im',
#   'sure',
#   'youre',
#   'getting',
#   'used',
#   'fine',
#   u'dinner',
#   'youre',
#   'lord'],
#  ['maybe', 'ill', 'hire', 'cook'],
#  [u'war', 'started', u'le'],
#  ['heard', 'trouble', 'littlefingers', 'brothel', 'night'],
#  ['mm', 'nasty', 'business'],
#  ['done'],
#  ['yes', 'course'],
#  ['city',
#   'watch',
#   'must',
#   'keep',
#   'peace',
#   'hadnt',
#   'realized',
#   'peace',
#   'depended',
#   'killing',
#   u'baby'],
#  [u'order', u'order'],
#  ['quite', 'right'],
#  ['especially', u'queen', u'order'],
#  ['never', 'said', u'queen', u'order'],
#  ['else', 'would', 'want', 'murder', 'king', u'robert', u'bastard'],
#  ['shes', 'always', 'jealous', 'woman'],
#  ['know', 'sister', 'better'],
#  ['youve', 'heard', 'awful', u'rumor', 'brother', 'sister'],
#  ['dont', 'listen', 'filth'],
#  ['thats', 'good', 'heard'],
#  ['suppose',
#   'people',
#   'believe',
#   'filth',
#   'consider',
#   u'robert',
#   u'bastard',
#   'better',
#   u'claimant',
#   'throne',
#   'cerseis',
#   u'child'],
#  ['joffrey', 'king'],
#  ['rest', 'doesnt', 'interest'],
#  ['appreciate', 'loyalty'],
#  ['tell',
#   'men',
#   'slaughtered',
#   'ned',
#   'starks',
#   'men',
#   'throne',
#   'room',
#   'give',
#   'order'],
#  [],
#  ['would'],
#  ['man', 'traitor'],
#  ['tried', 'buy', 'loyalty'],
#  ['fool'],
#  ['idea', 'already', 'bought'],
#  ['drunk'],
#  ['ill', 'honor', 'questioned', 'imp'],
#  ['im', 'questioning', 'honor', 'lord', 'janos'],
#  ['im', 'denying', 'existence'],
#  ['think', 'ill', 'stand', 'take', 'dwarf', 'dwarf'],
#  ['mm', 'stopped', 'imp'],
#  ['yes', 'stand', 'take', 'unless', 'youd', 'like', 'take', 'friend'],
#  ['intend', 'serve', 'hand', 'king', 'father', u'return', 'war'],
#  ['seeing',
#   'betrayed',
#   'last',
#   'hand',
#   'king',
#   'well',
#   'wouldnt',
#   'feel',
#   'safe',
#   'lurking'],
#  [u'friend', 'court', 'allow'],
#  ['queen', 'granted', 'queen', 'regent'],
#  ['youre', 'fool', 'believe', 'friend'],
#  ['shall', 'hear', 'joffrey', 'say'],
#  ['shant'],
#  [u'there', 'ship', 'leaving', 'eastwatch', 'sea', 'tonight'],
#  ['im', 'afraid', 'rather', 'long', 'walk', 'castle', 'black'],
#  ['hope', 'enjoy', 'wall'],
#  ['found',
#   'surprisingly',
#   'beautiful',
#   'brutal',
#   'horribly',
#   'uncomfortable',
#   'sort',
#   'way'],
#  [u'lad', 'escort'],
#  [u'street', 'arent', 'safe', 'night', 'lord'],
#  ...]

# %%
import gensim  
model = gensim.models.Word2Vec(total_corpus_texts, size=100, window=5, min_count=1, workers=2,sg=1)

# %%
model.wv.vocab.items()[:1000]
# Out:
# [('foul', <gensim.models.keyedvectors.Vocab at 0x107a67850>),
#  ('four', <gensim.models.keyedvectors.Vocab at 0x117c16e90>),
#  ('hanging', <gensim.models.keyedvectors.Vocab at 0x117ddddd0>),
#  ('marching', <gensim.models.keyedvectors.Vocab at 0x117dddf10>),
#  (u'increase', <gensim.models.keyedvectors.Vocab at 0x119547d10>),
#  ('midafternoon', <gensim.models.keyedvectors.Vocab at 0x119356050>),
#  ('mutinied', <gensim.models.keyedvectors.Vocab at 0x119356090>),
#  ('lord', <gensim.models.keyedvectors.Vocab at 0x1193560d0>),
#  (u'sinking', <gensim.models.keyedvectors.Vocab at 0x119356110>),
#  ('leisurely', <gensim.models.keyedvectors.Vocab at 0x119356150>),
#  (u'politician', <gensim.models.keyedvectors.Vocab at 0x119356190>),
#  ('stabbed', <gensim.models.keyedvectors.Vocab at 0x1193561d0>),
#  ('bringing', <gensim.models.keyedvectors.Vocab at 0x11935b9d0>),
#  ('disturb', <gensim.models.keyedvectors.Vocab at 0x119356250>),
#  ('prize', <gensim.models.keyedvectors.Vocab at 0x119356290>),
#  ('wooden', <gensim.models.keyedvectors.Vocab at 0x1193562d0>),
#  (u'clientele', <gensim.models.keyedvectors.Vocab at 0x119356310>),
#  ('succession', <gensim.models.keyedvectors.Vocab at 0x119356350>),
#  ('straight', <gensim.models.keyedvectors.Vocab at 0x1193bb390>),
#  ('tired', <gensim.models.keyedvectors.Vocab at 0x1193563d0>),
#  (u'lefford', <gensim.models.keyedvectors.Vocab at 0x119356410>),
#  ('bacon', <gensim.models.keyedvectors.Vocab at 0x119356450>),
#  ('elegant', <gensim.models.keyedvectors.Vocab at 0x119356490>),
#  ('second', <gensim.models.keyedvectors.Vocab at 0x1193564d0>),
#  ('sailed', <gensim.models.keyedvectors.Vocab at 0x119361f50>),
#  (u'ruthless', <gensim.models.keyedvectors.Vocab at 0x119356550>),
#  ('thunder', <gensim.models.keyedvectors.Vocab at 0x119356590>),
#  ('cooking', <gensim.models.keyedvectors.Vocab at 0x1193565d0>),
#  ('contributed', <gensim.models.keyedvectors.Vocab at 0x119356610>),
#  ('resilient', <gensim.models.keyedvectors.Vocab at 0x119356650>),
#  ('succumb', <gensim.models.keyedvectors.Vocab at 0x119356690>),
#  ('hero', <gensim.models.keyedvectors.Vocab at 0x1193566d0>),
#  ('interrupting', <gensim.models.keyedvectors.Vocab at 0x119356710>),
#  (u'here', <gensim.models.keyedvectors.Vocab at 0x119356750>),
#  ('substance', <gensim.models.keyedvectors.Vocab at 0x119356790>),
#  (u'k', <gensim.models.keyedvectors.Vocab at 0x1193567d0>),
#  ('climbed', <gensim.models.keyedvectors.Vocab at 0x119356810>),
#  ('military', <gensim.models.keyedvectors.Vocab at 0x119356850>),
#  (u'climber', <gensim.models.keyedvectors.Vocab at 0x119356890>),
#  ('diplomat', <gensim.models.keyedvectors.Vocab at 0x119670690>),
#  ('appropriately', <gensim.models.keyedvectors.Vocab at 0x119374090>),
#  ('divide', <gensim.models.keyedvectors.Vocab at 0x119356910>),
#  ('explained', <gensim.models.keyedvectors.Vocab at 0x119356950>),
#  ('replace', <gensim.models.keyedvectors.Vocab at 0x119356990>),
#  ('brought', <gensim.models.keyedvectors.Vocab at 0x1193569d0>),
#  ('stern', <gensim.models.keyedvectors.Vocab at 0x119356a10>),
#  ('cheating', <gensim.models.keyedvectors.Vocab at 0x119356a50>),
#  ('spoke', <gensim.models.keyedvectors.Vocab at 0x119356a90>),
#  (u'cannibal', <gensim.models.keyedvectors.Vocab at 0x119356ad0>),
#  ('occupying', <gensim.models.keyedvectors.Vocab at 0x119356b10>),
#  ('untie', <gensim.models.keyedvectors.Vocab at 0x119356b50>),
#  ('strike', <gensim.models.keyedvectors.Vocab at 0x119356b90>),
#  ('sideface', <gensim.models.keyedvectors.Vocab at 0x119356bd0>),
#  ('holy', <gensim.models.keyedvectors.Vocab at 0x119356c10>),
#  ('relax', <gensim.models.keyedvectors.Vocab at 0x119356c50>),
#  ('successful', <gensim.models.keyedvectors.Vocab at 0x119356c90>),
#  ('brings', <gensim.models.keyedvectors.Vocab at 0x119356cd0>),
#  ('hereby', <gensim.models.keyedvectors.Vocab at 0x119356d10>),
#  ('hurt', <gensim.models.keyedvectors.Vocab at 0x119356d50>),
#  (u'glass', <gensim.models.keyedvectors.Vocab at 0x119356d90>),
#  (u'hole', <gensim.models.keyedvectors.Vocab at 0x119379e10>),
#  ('hold', <gensim.models.keyedvectors.Vocab at 0x119356e10>),
#  (u'simper', <gensim.models.keyedvectors.Vocab at 0x119379f50>),
#  (u'benjens', <gensim.models.keyedvectors.Vocab at 0x119356e90>),
#  ('pursue', <gensim.models.keyedvectors.Vocab at 0x119356ed0>),
#  ('zhoan', <gensim.models.keyedvectors.Vocab at 0x119356f10>),
#  ('blade', <gensim.models.keyedvectors.Vocab at 0x11937f250>),
#  ('plunged', <gensim.models.keyedvectors.Vocab at 0x119356f90>),
#  ('sweeter', <gensim.models.keyedvectors.Vocab at 0x119356fd0>),
#  ('rework', <gensim.models.keyedvectors.Vocab at 0x11935b050>),
#  ('example', <gensim.models.keyedvectors.Vocab at 0x11935b090>),
#  ('triple', <gensim.models.keyedvectors.Vocab at 0x1193bb750>),
#  ('organized', <gensim.models.keyedvectors.Vocab at 0x11935b110>),
#  (u'caution', <gensim.models.keyedvectors.Vocab at 0x11935b190>),
#  ('want', <gensim.models.keyedvectors.Vocab at 0x11935b1d0>),
#  ('counseling', <gensim.models.keyedvectors.Vocab at 0x11935b210>),
#  ('mymother', <gensim.models.keyedvectors.Vocab at 0x11935b250>),
#  (u'cocksucker', <gensim.models.keyedvectors.Vocab at 0x11935b290>),
#  ('absolute', <gensim.models.keyedvectors.Vocab at 0x11935b2d0>),
#  ('hog', <gensim.models.keyedvectors.Vocab at 0x11935b310>),
#  ('complaining', <gensim.models.keyedvectors.Vocab at 0x11935b350>),
#  (u'travel', <gensim.models.keyedvectors.Vocab at 0x11935b390>),
#  ('copious', <gensim.models.keyedvectors.Vocab at 0x11935b3d0>),
#  ('undying', <gensim.models.keyedvectors.Vocab at 0x11964f650>),
#  ('hot', <gensim.models.keyedvectors.Vocab at 0x11935b410>),
#  ('retreating', <gensim.models.keyedvectors.Vocab at 0x11960d890>),
#  ('beauty', <gensim.models.keyedvectors.Vocab at 0x11935b490>),
#  ('swing', <gensim.models.keyedvectors.Vocab at 0x11960d8d0>),
#  (u'despondent', <gensim.models.keyedvectors.Vocab at 0x11935b510>),
#  ('outlawed', <gensim.models.keyedvectors.Vocab at 0x11935b550>),
#  ('wrong', <gensim.models.keyedvectors.Vocab at 0x11935b590>),
#  ('barristan', <gensim.models.keyedvectors.Vocab at 0x11935b5d0>),
#  (u'huhuh', <gensim.models.keyedvectors.Vocab at 0x11935b610>),
#  (u'attracts', <gensim.models.keyedvectors.Vocab at 0x11935b650>),
#  (u'revolt', <gensim.models.keyedvectors.Vocab at 0x11935b690>),
#  ('sickening', <gensim.models.keyedvectors.Vocab at 0x11935b6d0>),
#  ('tulip', <gensim.models.keyedvectors.Vocab at 0x11935b710>),
#  ('viserys', <gensim.models.keyedvectors.Vocab at 0x11935b750>),
#  (u'wing', <gensim.models.keyedvectors.Vocab at 0x11935b790>),
#  ('wind', <gensim.models.keyedvectors.Vocab at 0x11935b7d0>),
#  ('wine', <gensim.models.keyedvectors.Vocab at 0x11935b810>),
#  ('dreamed', <gensim.models.keyedvectors.Vocab at 0x11935b850>),
#  ('patricide', <gensim.models.keyedvectors.Vocab at 0x11935b890>),
#  (u'profaned', <gensim.models.keyedvectors.Vocab at 0x11935b8d0>),
#  ('rewarded', <gensim.models.keyedvectors.Vocab at 0x11935b910>),
#  ('fit', <gensim.models.keyedvectors.Vocab at 0x11935b950>),
#  ('allisers', <gensim.models.keyedvectors.Vocab at 0x11935b990>),
#  ('screaming', <gensim.models.keyedvectors.Vocab at 0x119356210>),
#  (u'fix', <gensim.models.keyedvectors.Vocab at 0x11935ba10>),
#  (u'dedicate', <gensim.models.keyedvectors.Vocab at 0x11935ba50>),
#  (u'fig', <gensim.models.keyedvectors.Vocab at 0x11935ba90>),
#  ('mewling', <gensim.models.keyedvectors.Vocab at 0x11935bad0>),
#  ('hidden', <gensim.models.keyedvectors.Vocab at 0x11935bb10>),
#  ('admirable', <gensim.models.keyedvectors.Vocab at 0x11935bb50>),
#  ('easier', <gensim.models.keyedvectors.Vocab at 0x11935bb90>),
#  ('hghar', <gensim.models.keyedvectors.Vocab at 0x11935bbd0>),
#  ('commemorate', <gensim.models.keyedvectors.Vocab at 0x11935bc10>),
#  ('educating', <gensim.models.keyedvectors.Vocab at 0x11935bc50>),
#  ('interrupt', <gensim.models.keyedvectors.Vocab at 0x11935bc90>),
#  ('blink', <gensim.models.keyedvectors.Vocab at 0x11935bcd0>),
#  ('silver', <gensim.models.keyedvectors.Vocab at 0x11935bd10>),
#  ('structural', <gensim.models.keyedvectors.Vocab at 0x11935bd50>),
#  (u'represents', <gensim.models.keyedvectors.Vocab at 0x11935bd90>),
#  ('jaehaerys', <gensim.models.keyedvectors.Vocab at 0x11935bdd0>),
#  ('theons', <gensim.models.keyedvectors.Vocab at 0x11935be10>),
#  (u'arrow', <gensim.models.keyedvectors.Vocab at 0x11935be50>),
#  (u'armourer', <gensim.models.keyedvectors.Vocab at 0x11935be90>),
#  ('burial', <gensim.models.keyedvectors.Vocab at 0x11935bed0>),
#  (u'whim', <gensim.models.keyedvectors.Vocab at 0x11935bf10>),
#  ('financial', <gensim.models.keyedvectors.Vocab at 0x11935bf50>),
#  (u'spider', <gensim.models.keyedvectors.Vocab at 0x11935bf90>),
#  (u'longclaw', <gensim.models.keyedvectors.Vocab at 0x11935bfd0>),
#  (u'turnip', <gensim.models.keyedvectors.Vocab at 0x119361050>),
#  ('fortnight', <gensim.models.keyedvectors.Vocab at 0x119361090>),
#  (u'mutineer', <gensim.models.keyedvectors.Vocab at 0x1193610d0>),
#  (u'wyllis', <gensim.models.keyedvectors.Vocab at 0x119361110>),
#  ('message', <gensim.models.keyedvectors.Vocab at 0x119361150>),
#  ('whip', <gensim.models.keyedvectors.Vocab at 0x119361190>),
#  ('misfortune', <gensim.models.keyedvectors.Vocab at 0x1193611d0>),
#  ('whoosh', <gensim.models.keyedvectors.Vocab at 0x119361210>),
#  (u'mason', <gensim.models.keyedvectors.Vocab at 0x119361250>),
#  (u'rd', <gensim.models.keyedvectors.Vocab at 0x119361290>),
#  ('archmaester', <gensim.models.keyedvectors.Vocab at 0x1193612d0>),
#  (u'ro', <gensim.models.keyedvectors.Vocab at 0x119361310>),
#  (u'outburst', <gensim.models.keyedvectors.Vocab at 0x119361350>),
#  (u'foundation', <gensim.models.keyedvectors.Vocab at 0x119361390>),
#  ('assured', <gensim.models.keyedvectors.Vocab at 0x1193613d0>),
#  ('waddle', <gensim.models.keyedvectors.Vocab at 0x119361410>),
#  ('threatened', <gensim.models.keyedvectors.Vocab at 0x119361450>),
#  ('assures', <gensim.models.keyedvectors.Vocab at 0x1193a5410>),
#  ('aggar', <gensim.models.keyedvectors.Vocab at 0x1193614d0>),
#  ('crowned', <gensim.models.keyedvectors.Vocab at 0x119361510>),
#  ('tobho', <gensim.models.keyedvectors.Vocab at 0x119361550>),
#  ('ate', <gensim.models.keyedvectors.Vocab at 0x119361590>),
#  ('ath', <gensim.models.keyedvectors.Vocab at 0x1193615d0>),
#  ('shipped', <gensim.models.keyedvectors.Vocab at 0x119361610>),
#  (u'disturbed', <gensim.models.keyedvectors.Vocab at 0x119361650>),
#  ('tempting', <gensim.models.keyedvectors.Vocab at 0x119361690>),
#  ('minge', <gensim.models.keyedvectors.Vocab at 0x1193616d0>),
#  (u'subtlety', <gensim.models.keyedvectors.Vocab at 0x119361710>),
#  ('wash', <gensim.models.keyedvectors.Vocab at 0x119361750>),
#  ('instruct', <gensim.models.keyedvectors.Vocab at 0x119361790>),
#  ('bitten', <gensim.models.keyedvectors.Vocab at 0x1193617d0>),
#  ('zala', <gensim.models.keyedvectors.Vocab at 0x119374810>),
#  ('whorehouse', <gensim.models.keyedvectors.Vocab at 0x119361850>),
#  ('timid', <gensim.models.keyedvectors.Vocab at 0x1194ef110>),
#  ('engagement', <gensim.models.keyedvectors.Vocab at 0x119361910>),
#  ('needed', <gensim.models.keyedvectors.Vocab at 0x119361950>),
#  ('master', <gensim.models.keyedvectors.Vocab at 0x119361990>),
#  ('bitter', <gensim.models.keyedvectors.Vocab at 0x1193619d0>),
#  ('ranging', <gensim.models.keyedvectors.Vocab at 0x119361a10>),
#  ('listen', <gensim.models.keyedvectors.Vocab at 0x119361a50>),
#  ('lorch', <gensim.models.keyedvectors.Vocab at 0x119361a90>),
#  (u'collapse', <gensim.models.keyedvectors.Vocab at 0x119361ad0>),
#  ('hows', <gensim.models.keyedvectors.Vocab at 0x119361b10>),
#  ('highgarden', <gensim.models.keyedvectors.Vocab at 0x119361b50>),
#  ('wisdom', <gensim.models.keyedvectors.Vocab at 0x119361b90>),
#  ('predictable', <gensim.models.keyedvectors.Vocab at 0x119361bd0>),
#  ('crawl', <gensim.models.keyedvectors.Vocab at 0x119361c10>),
#  ('positively', <gensim.models.keyedvectors.Vocab at 0x119361c50>),
#  ('showed', <gensim.models.keyedvectors.Vocab at 0x119361c90>),
#  (u'coward', <gensim.models.keyedvectors.Vocab at 0x119361cd0>),
#  ('tree', <gensim.models.keyedvectors.Vocab at 0x119361d10>),
#  (u'whinging', <gensim.models.keyedvectors.Vocab at 0x1193b65d0>),
#  ('shower', <gensim.models.keyedvectors.Vocab at 0x119361d90>),
#  ('idle', <gensim.models.keyedvectors.Vocab at 0x119361dd0>),
#  ('endure', <gensim.models.keyedvectors.Vocab at 0x119361e10>),
#  ('profitable', <gensim.models.keyedvectors.Vocab at 0x119644590>),
#  ('feeling', <gensim.models.keyedvectors.Vocab at 0x119361e50>),
#  ('groaning', <gensim.models.keyedvectors.Vocab at 0x119361e90>),
#  ('longs', <gensim.models.keyedvectors.Vocab at 0x119361ed0>),
#  ('untrained', <gensim.models.keyedvectors.Vocab at 0x119361f10>),
#  ('tether', <gensim.models.keyedvectors.Vocab at 0x119356510>),
#  ('dozen', <gensim.models.keyedvectors.Vocab at 0x119361f90>),
#  ('responsible', <gensim.models.keyedvectors.Vocab at 0x119361fd0>),
#  (u'instructs', <gensim.models.keyedvectors.Vocab at 0x119369090>),
#  ('amusing', <gensim.models.keyedvectors.Vocab at 0x1193690d0>),
#  ('britches', <gensim.models.keyedvectors.Vocab at 0x119369110>),
#  (u'season', <gensim.models.keyedvectors.Vocab at 0x11960ddd0>),
#  ('eastwatch', <gensim.models.keyedvectors.Vocab at 0x119639e90>),
#  (u'horselords', <gensim.models.keyedvectors.Vocab at 0x119369190>),
#  ('howd', <gensim.models.keyedvectors.Vocab at 0x1193691d0>),
#  ('shall', <gensim.models.keyedvectors.Vocab at 0x119369210>),
#  ('huh', <gensim.models.keyedvectors.Vocab at 0x11960de10>),
#  ('aegons', <gensim.models.keyedvectors.Vocab at 0x119369290>),
#  ('toil', <gensim.models.keyedvectors.Vocab at 0x1194ef290>),
#  ('mouth', <gensim.models.keyedvectors.Vocab at 0x119369310>),
#  ('letter', <gensim.models.keyedvectors.Vocab at 0x119369350>),
#  (u'singer', <gensim.models.keyedvectors.Vocab at 0x119369390>),
#  (u'episode', <gensim.models.keyedvectors.Vocab at 0x1193693d0>),
#  ('rayder', <gensim.models.keyedvectors.Vocab at 0x1193c1c90>),
#  ('consummate', <gensim.models.keyedvectors.Vocab at 0x119369450>),
#  ('mating', <gensim.models.keyedvectors.Vocab at 0x1193694d0>),
#  ('tirelessly', <gensim.models.keyedvectors.Vocab at 0x1194c3cd0>),
#  ('came', <gensim.models.keyedvectors.Vocab at 0x119369550>),
#  ('saying', <gensim.models.keyedvectors.Vocab at 0x119369590>),
#  ('fennel', <gensim.models.keyedvectors.Vocab at 0x1193695d0>),
#  (u'tempted', <gensim.models.keyedvectors.Vocab at 0x119369610>),
#  ('abreast', <gensim.models.keyedvectors.Vocab at 0x119369650>),
#  ('busy', <gensim.models.keyedvectors.Vocab at 0x1193c6fd0>),
#  ('theme', <gensim.models.keyedvectors.Vocab at 0x1193696d0>),
#  ('touched', <gensim.models.keyedvectors.Vocab at 0x119369710>),
#  ('rich', <gensim.models.keyedvectors.Vocab at 0x119369750>),
#  (u'plate', <gensim.models.keyedvectors.Vocab at 0x119369790>),
#  ('petrified', <gensim.models.keyedvectors.Vocab at 0x11960df90>),
#  (u'foremost', <gensim.models.keyedvectors.Vocab at 0x119369810>),
#  (u'pocket', <gensim.models.keyedvectors.Vocab at 0x119369850>),
#  (u'reversal', <gensim.models.keyedvectors.Vocab at 0x119369890>),
#  ('altogether', <gensim.models.keyedvectors.Vocab at 0x1193698d0>),
#  ('blistered', <gensim.models.keyedvectors.Vocab at 0x119369910>),
#  (u'spilling', <gensim.models.keyedvectors.Vocab at 0x119369950>),
#  ('nicely', <gensim.models.keyedvectors.Vocab at 0x119369990>),
#  ('dipping', <gensim.models.keyedvectors.Vocab at 0x1193699d0>),
#  ('piggy', <gensim.models.keyedvectors.Vocab at 0x119369a10>),
#  ('release', <gensim.models.keyedvectors.Vocab at 0x119369a50>),
#  (u'respond', <gensim.models.keyedvectors.Vocab at 0x119369a90>),
#  (u'blew', <gensim.models.keyedvectors.Vocab at 0x119369ad0>),
#  ('fair', <gensim.models.keyedvectors.Vocab at 0x119369b10>),
#  ('bled', <gensim.models.keyedvectors.Vocab at 0x119369b50>),
#  (u'result', <gensim.models.keyedvectors.Vocab at 0x119369b90>),
#  ('fail', <gensim.models.keyedvectors.Vocab at 0x119369bd0>),
#  ('nocturnal', <gensim.models.keyedvectors.Vocab at 0x119369c10>),
#  (u'hammer', <gensim.models.keyedvectors.Vocab at 0x119369c50>),
#  ('best', <gensim.models.keyedvectors.Vocab at 0x119369c90>),
#  ('score', <gensim.models.keyedvectors.Vocab at 0x119369cd0>),
#  ('pirate', <gensim.models.keyedvectors.Vocab at 0x119369d10>),
#  (u'wage', <gensim.models.keyedvectors.Vocab at 0x11948c390>),
#  ('men', <gensim.models.keyedvectors.Vocab at 0x119481bd0>),
#  ('khaleesi', <gensim.models.keyedvectors.Vocab at 0x119369dd0>),
#  ('extend', <gensim.models.keyedvectors.Vocab at 0x119369e10>),
#  ('nature', <gensim.models.keyedvectors.Vocab at 0x119369e50>),
#  ('rolled', <gensim.models.keyedvectors.Vocab at 0x119369e90>),
#  ('smelled', <gensim.models.keyedvectors.Vocab at 0x119369ed0>),
#  ('lapping', <gensim.models.keyedvectors.Vocab at 0x119369f10>),
#  (u'souvenir', <gensim.models.keyedvectors.Vocab at 0x119369f50>),
#  (u'extent', <gensim.models.keyedvectors.Vocab at 0x119369fd0>),
#  ('tyrion', <gensim.models.keyedvectors.Vocab at 0x11936e050>),
#  (u'debt', <gensim.models.keyedvectors.Vocab at 0x11936e090>),
#  ('pity', <gensim.models.keyedvectors.Vocab at 0x11936e0d0>),
#  ('accident', <gensim.models.keyedvectors.Vocab at 0x11936e110>),
#  ('weirwood', <gensim.models.keyedvectors.Vocab at 0x11936e150>),
#  ('country', <gensim.models.keyedvectors.Vocab at 0x11936e190>),
#  (u'adventurer', <gensim.models.keyedvectors.Vocab at 0x11936e1d0>),
#  ('demanded', <gensim.models.keyedvectors.Vocab at 0x11936e210>),
#  ('planned', <gensim.models.keyedvectors.Vocab at 0x11936e250>),
#  ('logic', <gensim.models.keyedvectors.Vocab at 0x11936e290>),
#  ('argue', <gensim.models.keyedvectors.Vocab at 0x11936e2d0>),
#  ('asked', <gensim.models.keyedvectors.Vocab at 0x11936e310>),
#  (u'vain', <gensim.models.keyedvectors.Vocab at 0x11936e350>),
#  ('blonde', <gensim.models.keyedvectors.Vocab at 0x11936e390>),
#  ('shouting', <gensim.models.keyedvectors.Vocab at 0x1194ef750>),
#  ('union', <gensim.models.keyedvectors.Vocab at 0x11936e410>),
#  ('slay', <gensim.models.keyedvectors.Vocab at 0x11936e450>),
#  ('muck', <gensim.models.keyedvectors.Vocab at 0x11936e490>),
#  ('much', <gensim.models.keyedvectors.Vocab at 0x11936e4d0>),
#  ('privilege', <gensim.models.keyedvectors.Vocab at 0x11936e510>),
#  ('tallest', <gensim.models.keyedvectors.Vocab at 0x11936e550>),
#  ('life', <gensim.models.keyedvectors.Vocab at 0x11936e590>),
#  (u'lodock', <gensim.models.keyedvectors.Vocab at 0x11936e5d0>),
#  ('spit', <gensim.models.keyedvectors.Vocab at 0x11936e610>),
#  (u'eastern', <gensim.models.keyedvectors.Vocab at 0x11936e650>),
#  ('jeor', <gensim.models.keyedvectors.Vocab at 0x11936e690>),
#  (u'davy', <gensim.models.keyedvectors.Vocab at 0x11936e6d0>),
#  ('wish', <gensim.models.keyedvectors.Vocab at 0x11936e710>),
#  ('lift', <gensim.models.keyedvectors.Vocab at 0x11936e750>),
#  ('direwolf', <gensim.models.keyedvectors.Vocab at 0x11936e790>),
#  ('child', <gensim.models.keyedvectors.Vocab at 0x11936e7d0>),
#  ('worked', <gensim.models.keyedvectors.Vocab at 0x11936e810>),
#  ('cunt', <gensim.models.keyedvectors.Vocab at 0x11936e850>),
#  ('employ', <gensim.models.keyedvectors.Vocab at 0x11936e890>),
#  ('contemplates', <gensim.models.keyedvectors.Vocab at 0x11936e8d0>),
#  (u'flooding', <gensim.models.keyedvectors.Vocab at 0x11936e910>),
#  ('picturing', <gensim.models.keyedvectors.Vocab at 0x11936e950>),
#  ('remembering', <gensim.models.keyedvectors.Vocab at 0x11936e990>),
#  (u'congratulation', <gensim.models.keyedvectors.Vocab at 0x11936e9d0>),
#  ('played', <gensim.models.keyedvectors.Vocab at 0x11936ea10>),
#  ('cersei', <gensim.models.keyedvectors.Vocab at 0x11936ea50>),
#  (u'locksmith', <gensim.models.keyedvectors.Vocab at 0x11936ea90>),
#  (u'obeying', <gensim.models.keyedvectors.Vocab at 0x11936ead0>),
#  (u'player', <gensim.models.keyedvectors.Vocab at 0x11936eb10>),
#  ('trusted', <gensim.models.keyedvectors.Vocab at 0x11936eb50>),
#  ('severity', <gensim.models.keyedvectors.Vocab at 0x11936eb90>),
#  ('tarth', <gensim.models.keyedvectors.Vocab at 0x119612350>),
#  ('yellow', <gensim.models.keyedvectors.Vocab at 0x11936ec10>),
#  ('thievery', <gensim.models.keyedvectors.Vocab at 0x11936ec50>),
#  ('rebellion', <gensim.models.keyedvectors.Vocab at 0x11936ec90>),
#  ('clucking', <gensim.models.keyedvectors.Vocab at 0x11936ecd0>),
#  (u'harmony', <gensim.models.keyedvectors.Vocab at 0x1193f2b50>),
#  ('fairly', <gensim.models.keyedvectors.Vocab at 0x11936ed50>),
#  ('boiled', <gensim.models.keyedvectors.Vocab at 0x11936ed90>),
#  ('marched', <gensim.models.keyedvectors.Vocab at 0x11936edd0>),
#  ('supper', <gensim.models.keyedvectors.Vocab at 0x11936ee10>),
#  ('therell', <gensim.models.keyedvectors.Vocab at 0x11936ee50>),
#  ('metalwork', <gensim.models.keyedvectors.Vocab at 0x11936ee90>),
#  ('tune', <gensim.models.keyedvectors.Vocab at 0x11936eed0>),
#  (u'tarleys', <gensim.models.keyedvectors.Vocab at 0x11936ef10>),
#  ('intrusion', <gensim.models.keyedvectors.Vocab at 0x11936ef50>),
#  ('noblewoman', <gensim.models.keyedvectors.Vocab at 0x11936ef90>),
#  ('eagle', <gensim.models.keyedvectors.Vocab at 0x11960d650>),
#  ('towheaded', <gensim.models.keyedvectors.Vocab at 0x11936efd0>),
#  (u'bellow', <gensim.models.keyedvectors.Vocab at 0x119374050>),
#  ('golden', <gensim.models.keyedvectors.Vocab at 0x1193568d0>),
#  ('forsaken', <gensim.models.keyedvectors.Vocab at 0x1193740d0>),
#  (u'plight', <gensim.models.keyedvectors.Vocab at 0x119374150>),
#  (u'hal', <gensim.models.keyedvectors.Vocab at 0x119374190>),
#  ('ham', <gensim.models.keyedvectors.Vocab at 0x1193741d0>),
#  ('ease', <gensim.models.keyedvectors.Vocab at 0x119374210>),
#  ('hay', <gensim.models.keyedvectors.Vocab at 0x119374250>),
#  ('innocent', <gensim.models.keyedvectors.Vocab at 0x119374290>),
#  ('prison', <gensim.models.keyedvectors.Vocab at 0x1193742d0>),
#  ('east', <gensim.models.keyedvectors.Vocab at 0x119374310>),
#  ('hat', <gensim.models.keyedvectors.Vocab at 0x119374350>),
#  (u'hightower', <gensim.models.keyedvectors.Vocab at 0x119374390>),
#  ('survival', <gensim.models.keyedvectors.Vocab at 0x1193743d0>),
#  ('possible', <gensim.models.keyedvectors.Vocab at 0x119374410>),
#  ('possibly', <gensim.models.keyedvectors.Vocab at 0x119374450>),
#  ('birth', <gensim.models.keyedvectors.Vocab at 0x119374490>),
#  ('shadow', <gensim.models.keyedvectors.Vocab at 0x1193744d0>),
#  ('unique', <gensim.models.keyedvectors.Vocab at 0x119374510>),
#  ('desire', <gensim.models.keyedvectors.Vocab at 0x119374550>),
#  ('remind', <gensim.models.keyedvectors.Vocab at 0x119374590>),
#  ('battlefield', <gensim.models.keyedvectors.Vocab at 0x1193745d0>),
#  ('right', <gensim.models.keyedvectors.Vocab at 0x119374610>),
#  ('old', <gensim.models.keyedvectors.Vocab at 0x119374650>),
#  ('crowd', <gensim.models.keyedvectors.Vocab at 0x119374690>),
#  ('people', <gensim.models.keyedvectors.Vocab at 0x1193746d0>),
#  ('macabre', <gensim.models.keyedvectors.Vocab at 0x119374710>),
#  ('crown', <gensim.models.keyedvectors.Vocab at 0x119374790>),
#  ('captive', <gensim.models.keyedvectors.Vocab at 0x1193747d0>),
#  ('warring', <gensim.models.keyedvectors.Vocab at 0x119374850>),
#  ('bottom', <gensim.models.keyedvectors.Vocab at 0x119374890>),
#  (u'rehearse', <gensim.models.keyedvectors.Vocab at 0x1193748d0>),
#  (u'fox', <gensim.models.keyedvectors.Vocab at 0x119374910>),
#  ('witty', <gensim.models.keyedvectors.Vocab at 0x119374950>),
#  (u'foe', <gensim.models.keyedvectors.Vocab at 0x119374990>),
#  (u'summoned', <gensim.models.keyedvectors.Vocab at 0x1193749d0>),
#  (u'umi', <gensim.models.keyedvectors.Vocab at 0x119374a10>),
#  ('pinched', <gensim.models.keyedvectors.Vocab at 0x119374a50>),
#  ('yoke', <gensim.models.keyedvectors.Vocab at 0x119374a90>),
#  (u'defensive', <gensim.models.keyedvectors.Vocab at 0x119374ad0>),
#  ('losing', <gensim.models.keyedvectors.Vocab at 0x119374b10>),
#  ('memorable', <gensim.models.keyedvectors.Vocab at 0x119374b50>),
#  ('bowing', <gensim.models.keyedvectors.Vocab at 0x119374b90>),
#  (u'grievously', <gensim.models.keyedvectors.Vocab at 0x119374bd0>),
#  (u'o', <gensim.models.keyedvectors.Vocab at 0x119374c10>),
#  ('despair', <gensim.models.keyedvectors.Vocab at 0x119374c50>),
#  (u'slightly', <gensim.models.keyedvectors.Vocab at 0x119374c90>),
#  ('match', <gensim.models.keyedvectors.Vocab at 0x119374cd0>),
#  ('lamprey', <gensim.models.keyedvectors.Vocab at 0x119374d10>),
#  ('raised', <gensim.models.keyedvectors.Vocab at 0x119374d50>),
#  ('watering', <gensim.models.keyedvectors.Vocab at 0x1194872d0>),
#  ('tyrell', <gensim.models.keyedvectors.Vocab at 0x119374dd0>),
#  ('son', <gensim.models.keyedvectors.Vocab at 0x119374e10>),
#  ('thankful', <gensim.models.keyedvectors.Vocab at 0x119374e50>),
#  ('consummated', <gensim.models.keyedvectors.Vocab at 0x119374e90>),
#  ('sow', <gensim.models.keyedvectors.Vocab at 0x119374ed0>),
#  ('wrap', <gensim.models.keyedvectors.Vocab at 0x119374f10>),
#  ('despised', <gensim.models.keyedvectors.Vocab at 0x119374f50>),
#  ('fabric', <gensim.models.keyedvectors.Vocab at 0x119374f90>),
#  ('suffice', <gensim.models.keyedvectors.Vocab at 0x119374fd0>),
#  ('tame', <gensim.models.keyedvectors.Vocab at 0x119379050>),
#  ('grasping', <gensim.models.keyedvectors.Vocab at 0x119379090>),
#  ('despises', <gensim.models.keyedvectors.Vocab at 0x1193790d0>),
#  ('greatness', <gensim.models.keyedvectors.Vocab at 0x119379110>),
#  ('music', <gensim.models.keyedvectors.Vocab at 0x1193b0e50>),
#  ('thoros', <gensim.models.keyedvectors.Vocab at 0x11941ecd0>),
#  ('underestimated', <gensim.models.keyedvectors.Vocab at 0x1193791d0>),
#  ('offer', <gensim.models.keyedvectors.Vocab at 0x119379210>),
#  ('shireen', <gensim.models.keyedvectors.Vocab at 0x119379250>),
#  ('perfumed', <gensim.models.keyedvectors.Vocab at 0x119379290>),
#  ('matthos', <gensim.models.keyedvectors.Vocab at 0x1193792d0>),
#  ('duel', <gensim.models.keyedvectors.Vocab at 0x119379310>),
#  ('inside', <gensim.models.keyedvectors.Vocab at 0x119379350>),
#  ('morning', <gensim.models.keyedvectors.Vocab at 0x1194b3dd0>),
#  ('vanguard', <gensim.models.keyedvectors.Vocab at 0x119379390>),
#  ('pest', <gensim.models.keyedvectors.Vocab at 0x1193793d0>),
#  ('torturing', <gensim.models.keyedvectors.Vocab at 0x119379410>),
#  ('smashed', <gensim.models.keyedvectors.Vocab at 0x119379450>),
#  ('juvenile', <gensim.models.keyedvectors.Vocab at 0x119379490>),
#  ('later', <gensim.models.keyedvectors.Vocab at 0x119612610>),
#  ('proved', <gensim.models.keyedvectors.Vocab at 0x119379510>),
#  ('arwyen', <gensim.models.keyedvectors.Vocab at 0x119379550>),
#  ('tournament', <gensim.models.keyedvectors.Vocab at 0x119379590>),
#  ('proven', <gensim.models.keyedvectors.Vocab at 0x1193795d0>),
#  ('meros', <gensim.models.keyedvectors.Vocab at 0x119379610>),
#  ('soothe', <gensim.models.keyedvectors.Vocab at 0x119379650>),
#  ('exist', <gensim.models.keyedvectors.Vocab at 0x119379690>),
#  ('accounting', <gensim.models.keyedvectors.Vocab at 0x1193796d0>),
#  ('floor', <gensim.models.keyedvectors.Vocab at 0x119379710>),
#  (u'actor', <gensim.models.keyedvectors.Vocab at 0x119379750>),
#  ('uttered', <gensim.models.keyedvectors.Vocab at 0x119379790>),
#  ('flood', <gensim.models.keyedvectors.Vocab at 0x1193797d0>),
#  ('underfed', <gensim.models.keyedvectors.Vocab at 0x119429d90>),
#  ('role', <gensim.models.keyedvectors.Vocab at 0x119379850>),
#  ('ambitious', <gensim.models.keyedvectors.Vocab at 0x119379890>),
#  ('smell', <gensim.models.keyedvectors.Vocab at 0x1193798d0>),
#  ('roll', <gensim.models.keyedvectors.Vocab at 0x119379910>),
#  ('intend', <gensim.models.keyedvectors.Vocab at 0x119379950>),
#  ('corbray', <gensim.models.keyedvectors.Vocab at 0x119379990>),
#  (u'ointment', <gensim.models.keyedvectors.Vocab at 0x1193799d0>),
#  ('scream', <gensim.models.keyedvectors.Vocab at 0x119369510>),
#  ('acquaintance', <gensim.models.keyedvectors.Vocab at 0x119379a10>),
#  ('giantsbane', <gensim.models.keyedvectors.Vocab at 0x119379a50>),
#  ('cleaver', <gensim.models.keyedvectors.Vocab at 0x119379a90>),
#  (u'daugters', <gensim.models.keyedvectors.Vocab at 0x119379ad0>),
#  ('warn', <gensim.models.keyedvectors.Vocab at 0x119487590>),
#  ('pycelle', <gensim.models.keyedvectors.Vocab at 0x119379b50>),
#  ('sniffed', <gensim.models.keyedvectors.Vocab at 0x119379b90>),
#  ('quandary', <gensim.models.keyedvectors.Vocab at 0x119379bd0>),
#  ('time', <gensim.models.keyedvectors.Vocab at 0x119379c10>),
#  ('push', <gensim.models.keyedvectors.Vocab at 0x119379c50>),
#  ('someplace', <gensim.models.keyedvectors.Vocab at 0x11960d590>),
#  ('dotes', <gensim.models.keyedvectors.Vocab at 0x119379c90>),
#  ('gown', <gensim.models.keyedvectors.Vocab at 0x119379cd0>),
#  ('chain', <gensim.models.keyedvectors.Vocab at 0x119379d10>),
#  ('whoever', <gensim.models.keyedvectors.Vocab at 0x119379d50>),
#  ('warg', <gensim.models.keyedvectors.Vocab at 0x119487690>),
#  ('chair', <gensim.models.keyedvectors.Vocab at 0x119379dd0>),
#  ('midst', <gensim.models.keyedvectors.Vocab at 0x119356dd0>),
#  ('quartered', <gensim.models.keyedvectors.Vocab at 0x119379e50>),
#  (u'lothar', <gensim.models.keyedvectors.Vocab at 0x119379e90>),
#  ('choice', <gensim.models.keyedvectors.Vocab at 0x119379ed0>),
#  ('mourn', <gensim.models.keyedvectors.Vocab at 0x119379f10>),
#  ('locked', <gensim.models.keyedvectors.Vocab at 0x119356e50>),
#  (u'exact', <gensim.models.keyedvectors.Vocab at 0x119379f90>),
#  ('minute', <gensim.models.keyedvectors.Vocab at 0x119379fd0>),
#  ('tear', <gensim.models.keyedvectors.Vocab at 0x11937f050>),
#  (u'teat', <gensim.models.keyedvectors.Vocab at 0x11937f090>),
#  (u'pea', <gensim.models.keyedvectors.Vocab at 0x11937f0d0>),
#  ('leave', <gensim.models.keyedvectors.Vocab at 0x11937f110>),
#  ('settle', <gensim.models.keyedvectors.Vocab at 0x11937f150>),
#  ('stockade', <gensim.models.keyedvectors.Vocab at 0x11937f190>),
#  (u'team', <gensim.models.keyedvectors.Vocab at 0x11937f1d0>),
#  ('bonfire', <gensim.models.keyedvectors.Vocab at 0x11937f210>),
#  (u'accomplishment', <gensim.models.keyedvectors.Vocab at 0x119356f50>),
#  (u'sigh', <gensim.models.keyedvectors.Vocab at 0x11937f290>),
#  ('sign', <gensim.models.keyedvectors.Vocab at 0x11937f2d0>),
#  ('chopping', <gensim.models.keyedvectors.Vocab at 0x11937f310>),
#  ('catelyn', <gensim.models.keyedvectors.Vocab at 0x11937f350>),
#  (u'melt', <gensim.models.keyedvectors.Vocab at 0x11937f390>),
#  ('current', <gensim.models.keyedvectors.Vocab at 0x11937f3d0>),
#  ('axel', <gensim.models.keyedvectors.Vocab at 0x11937f410>),
#  ('falling', <gensim.models.keyedvectors.Vocab at 0x11937f450>),
#  ('crashing', <gensim.models.keyedvectors.Vocab at 0x119424610>),
#  ('badge', <gensim.models.keyedvectors.Vocab at 0x11937f4d0>),
#  ('ramming', <gensim.models.keyedvectors.Vocab at 0x11937f510>),
#  (u'funeral', <gensim.models.keyedvectors.Vocab at 0x11937f550>),
#  ('understanding', <gensim.models.keyedvectors.Vocab at 0x11937f590>),
#  ('contemplate', <gensim.models.keyedvectors.Vocab at 0x11937f5d0>),
#  ('address', <gensim.models.keyedvectors.Vocab at 0x11937f610>),
#  ('alone', <gensim.models.keyedvectors.Vocab at 0x11937f650>),
#  ('along', <gensim.models.keyedvectors.Vocab at 0x11937f690>),
#  ('crumbles', <gensim.models.keyedvectors.Vocab at 0x11937f6d0>),
#  (u'summerwine', <gensim.models.keyedvectors.Vocab at 0x11937f710>),
#  ('brilliant', <gensim.models.keyedvectors.Vocab at 0x11937f750>),
#  ('studied', <gensim.models.keyedvectors.Vocab at 0x11937f790>),
#  ('wherever', <gensim.models.keyedvectors.Vocab at 0x11937f7d0>),
#  (u'commonly', <gensim.models.keyedvectors.Vocab at 0x11937f810>),
#  ('accomplished', <gensim.models.keyedvectors.Vocab at 0x11937f850>),
#  ('greizhen', <gensim.models.keyedvectors.Vocab at 0x11937f890>),
#  (u'reclaim', <gensim.models.keyedvectors.Vocab at 0x11937f8d0>),
#  ('nowhere', <gensim.models.keyedvectors.Vocab at 0x11937f910>),
#  ('love', <gensim.models.keyedvectors.Vocab at 0x11937f950>),
#  ('prefer', <gensim.models.keyedvectors.Vocab at 0x11937f990>),
#  ('logical', <gensim.models.keyedvectors.Vocab at 0x11937f9d0>),
#  ('bloody', <gensim.models.keyedvectors.Vocab at 0x11937fa10>),
#  ('marvelous', <gensim.models.keyedvectors.Vocab at 0x11937fa50>),
#  ('betraying', <gensim.models.keyedvectors.Vocab at 0x11937fa90>),
#  (u'sky', <gensim.models.keyedvectors.Vocab at 0x119665ed0>),
#  (u'capsized', <gensim.models.keyedvectors.Vocab at 0x11937fad0>),
#  ('working', <gensim.models.keyedvectors.Vocab at 0x11937fb10>),
#  ('angry', <gensim.models.keyedvectors.Vocab at 0x11937fb50>),
#  ('blackwater', <gensim.models.keyedvectors.Vocab at 0x11937fb90>),
#  (u'cockfighting', <gensim.models.keyedvectors.Vocab at 0x11937fbd0>),
#  ('wondering', <gensim.models.keyedvectors.Vocab at 0x11937fc10>),
#  (u'halfbrother', <gensim.models.keyedvectors.Vocab at 0x11937fc50>),
#  ('wicked', <gensim.models.keyedvectors.Vocab at 0x11937fc90>),
#  (u'introducing', <gensim.models.keyedvectors.Vocab at 0x11937fcd0>),
#  (u'guardsman', <gensim.models.keyedvectors.Vocab at 0x11937fd10>),
#  ('afford', <gensim.models.keyedvectors.Vocab at 0x11937fd50>),
#  ('xaros', <gensim.models.keyedvectors.Vocab at 0x119623fd0>),
#  ('marbled', <gensim.models.keyedvectors.Vocab at 0x11937fd90>),
#  ('everywhere', <gensim.models.keyedvectors.Vocab at 0x11937fdd0>),
#  ('virtue', <gensim.models.keyedvectors.Vocab at 0x11937fe10>),
#  ('behalf', <gensim.models.keyedvectors.Vocab at 0x11937fe50>),
#  ('honey', <gensim.models.keyedvectors.Vocab at 0x119487910>),
#  ('valued', <gensim.models.keyedvectors.Vocab at 0x11937fed0>),
#  ('anything', <gensim.models.keyedvectors.Vocab at 0x1193c1390>),
#  ('originally', <gensim.models.keyedvectors.Vocab at 0x11937ff50>),
#  (u'pretend', <gensim.models.keyedvectors.Vocab at 0x11937ff90>),
#  ('privy', <gensim.models.keyedvectors.Vocab at 0x11937ffd0>),
#  ('believer', <gensim.models.keyedvectors.Vocab at 0x119384050>),
#  (u'impasse', <gensim.models.keyedvectors.Vocab at 0x119384090>),
#  ('believed', <gensim.models.keyedvectors.Vocab at 0x1193840d0>),
#  ('admired', <gensim.models.keyedvectors.Vocab at 0x119384110>),
#  ('locke', <gensim.models.keyedvectors.Vocab at 0x119384150>),
#  (u'unconsummated', <gensim.models.keyedvectors.Vocab at 0x119384190>),
#  ('unveiled', <gensim.models.keyedvectors.Vocab at 0x1193841d0>),
#  ('allowed', <gensim.models.keyedvectors.Vocab at 0x119384210>),
#  ('offense', <gensim.models.keyedvectors.Vocab at 0x119384250>),
#  ('stole', <gensim.models.keyedvectors.Vocab at 0x119384290>),
#  ('evidently', <gensim.models.keyedvectors.Vocab at 0x1193842d0>),
#  ('listens', <gensim.models.keyedvectors.Vocab at 0x119384310>),
#  ('winter', <gensim.models.keyedvectors.Vocab at 0x119384350>),
#  (u'divided', <gensim.models.keyedvectors.Vocab at 0x119384390>),
#  ('thanking', <gensim.models.keyedvectors.Vocab at 0x1193843d0>),
#  ('immune', <gensim.models.keyedvectors.Vocab at 0x119384410>),
#  ('loathe', <gensim.models.keyedvectors.Vocab at 0x1194879d0>),
#  (u'encampment', <gensim.models.keyedvectors.Vocab at 0x119384490>),
#  (u'provincial', <gensim.models.keyedvectors.Vocab at 0x1193844d0>),
#  ('spot', <gensim.models.keyedvectors.Vocab at 0x119384510>),
#  ('suck', <gensim.models.keyedvectors.Vocab at 0x119384550>),
#  ('dove', <gensim.models.keyedvectors.Vocab at 0x119384590>),
#  (u'stress', <gensim.models.keyedvectors.Vocab at 0x1193845d0>),
#  ('natural', <gensim.models.keyedvectors.Vocab at 0x119384610>),
#  ('blackfish', <gensim.models.keyedvectors.Vocab at 0x119612c10>),
#  ('st', <gensim.models.keyedvectors.Vocab at 0x119384690>),
#  ('swollen', <gensim.models.keyedvectors.Vocab at 0x1193846d0>),
#  ('truce', <gensim.models.keyedvectors.Vocab at 0x119384710>),
#  ('pulled', <gensim.models.keyedvectors.Vocab at 0x119384750>),
#  ('drunken', <gensim.models.keyedvectors.Vocab at 0x119384790>),
#  (u'footstep', <gensim.models.keyedvectors.Vocab at 0x1193847d0>),
#  ('unacceptable', <gensim.models.keyedvectors.Vocab at 0x119384810>),
#  ('damage', <gensim.models.keyedvectors.Vocab at 0x119384850>),
#  ('course', <gensim.models.keyedvectors.Vocab at 0x119384890>),
#  ('yearn', <gensim.models.keyedvectors.Vocab at 0x1193848d0>),
#  ('mishear', <gensim.models.keyedvectors.Vocab at 0x119384910>),
#  ('lovelier', <gensim.models.keyedvectors.Vocab at 0x119384950>),
#  (u'tendency', <gensim.models.keyedvectors.Vocab at 0x119384990>),
#  ('tore', <gensim.models.keyedvectors.Vocab at 0x1193849d0>),
#  ('milked', <gensim.models.keyedvectors.Vocab at 0x119384a10>),
#  ('torn', <gensim.models.keyedvectors.Vocab at 0x119384a50>),
#  ('stupidity', <gensim.models.keyedvectors.Vocab at 0x119487a50>),
#  ('aerion', <gensim.models.keyedvectors.Vocab at 0x119384ad0>),
#  ('celebrate', <gensim.models.keyedvectors.Vocab at 0x119384b10>),
#  ('troubled', <gensim.models.keyedvectors.Vocab at 0x119384b50>),
#  (u'deviant', <gensim.models.keyedvectors.Vocab at 0x119384b90>),
#  (u'chaining', <gensim.models.keyedvectors.Vocab at 0x119384bd0>),
#  ('smarter', <gensim.models.keyedvectors.Vocab at 0x119384c10>),
#  ('arriving', <gensim.models.keyedvectors.Vocab at 0x119384c50>),
#  ('reckoning', <gensim.models.keyedvectors.Vocab at 0x119384c90>),
#  (u'shhh', <gensim.models.keyedvectors.Vocab at 0x119384cd0>),
#  ('maintaining', <gensim.models.keyedvectors.Vocab at 0x119384d10>),
#  ('matched', <gensim.models.keyedvectors.Vocab at 0x119384d50>),
#  ('freya', <gensim.models.keyedvectors.Vocab at 0x119384d90>),
#  ('appropriate', <gensim.models.keyedvectors.Vocab at 0x1193c1510>),
#  ('stillborns', <gensim.models.keyedvectors.Vocab at 0x119384e10>),
#  ('fisherman', <gensim.models.keyedvectors.Vocab at 0x119384e50>),
#  ('amnesty', <gensim.models.keyedvectors.Vocab at 0x119384e90>),
#  (u'quarter', <gensim.models.keyedvectors.Vocab at 0x119384ed0>),
#  ('broodmare', <gensim.models.keyedvectors.Vocab at 0x119384f10>),
#  ('square', <gensim.models.keyedvectors.Vocab at 0x119384f50>),
#  ('beloved', <gensim.models.keyedvectors.Vocab at 0x119384f90>),
#  ('entering', <gensim.models.keyedvectors.Vocab at 0x119384fd0>),
#  (u'beetle', <gensim.models.keyedvectors.Vocab at 0x11938a050>),
#  ('troll', <gensim.models.keyedvectors.Vocab at 0x11938a090>),
#  (u'swordsman', <gensim.models.keyedvectors.Vocab at 0x11938a0d0>),
#  ('seriously', <gensim.models.keyedvectors.Vocab at 0x11938a110>),
#  ('investigation', <gensim.models.keyedvectors.Vocab at 0x11938a150>),
#  ('suggesting', <gensim.models.keyedvectors.Vocab at 0x11938a190>),
#  ('facedown', <gensim.models.keyedvectors.Vocab at 0x11938a210>),
#  ('siege', <gensim.models.keyedvectors.Vocab at 0x11938a250>),
#  ('million', <gensim.models.keyedvectors.Vocab at 0x11938a290>),
#  ('seventh', <gensim.models.keyedvectors.Vocab at 0x11938a2d0>),
#  (u'possibility', <gensim.models.keyedvectors.Vocab at 0x11938a310>),
#  ('quite', <gensim.models.keyedvectors.Vocab at 0x11938a350>),
#  ('complicated', <gensim.models.keyedvectors.Vocab at 0x11938a3d0>),
#  ('besides', <gensim.models.keyedvectors.Vocab at 0x11938a410>),
#  (u'grandma', <gensim.models.keyedvectors.Vocab at 0x11938a450>),
#  ('unnamed', <gensim.models.keyedvectors.Vocab at 0x11938a490>),
#  ('patronage', <gensim.models.keyedvectors.Vocab at 0x11938a4d0>),
#  ('training', <gensim.models.keyedvectors.Vocab at 0x11938a510>),
#  ('backside', <gensim.models.keyedvectors.Vocab at 0x11938a550>),
#  ('modest', <gensim.models.keyedvectors.Vocab at 0x11938a590>),
#  (u'nymeria', <gensim.models.keyedvectors.Vocab at 0x11938a5d0>),
#  ('saving', <gensim.models.keyedvectors.Vocab at 0x11938a610>),
#  ('spoken', <gensim.models.keyedvectors.Vocab at 0x11938a650>),
#  ('one', <gensim.models.keyedvectors.Vocab at 0x11938a690>),
#  (u'reopen', <gensim.models.keyedvectors.Vocab at 0x11938a6d0>),
#  ('punishable', <gensim.models.keyedvectors.Vocab at 0x11938a710>),
#  ('vote', <gensim.models.keyedvectors.Vocab at 0x11938a750>),
#  ('open', <gensim.models.keyedvectors.Vocab at 0x11938a790>),
#  ('ripping', <gensim.models.keyedvectors.Vocab at 0x11948c790>),
#  ('partook', <gensim.models.keyedvectors.Vocab at 0x11938a810>),
#  (u'city', <gensim.models.keyedvectors.Vocab at 0x11938a850>),
#  (u'wrath', <gensim.models.keyedvectors.Vocab at 0x11938a890>),
#  ('bite', <gensim.models.keyedvectors.Vocab at 0x11938a8d0>),
#  ('teacher', <gensim.models.keyedvectors.Vocab at 0x11963e810>),
#  (u'shiver', <gensim.models.keyedvectors.Vocab at 0x11938a910>),
#  ('prone', <gensim.models.keyedvectors.Vocab at 0x11938a950>),
#  ('shawl', <gensim.models.keyedvectors.Vocab at 0x11938a990>),
#  ('meddling', <gensim.models.keyedvectors.Vocab at 0x11938a9d0>),
#  (u'padding', <gensim.models.keyedvectors.Vocab at 0x11938aa10>),
#  ('prowling', <gensim.models.keyedvectors.Vocab at 0x1193c1710>),
#  ('ridiculous', <gensim.models.keyedvectors.Vocab at 0x11938aa90>),
#  (u'camello', <gensim.models.keyedvectors.Vocab at 0x11938aad0>),
#  ('third', <gensim.models.keyedvectors.Vocab at 0x119487c50>),
#  ('cower', <gensim.models.keyedvectors.Vocab at 0x119497090>),
#  ('sandor', <gensim.models.keyedvectors.Vocab at 0x11938ab90>),
#  (u'counselor', <gensim.models.keyedvectors.Vocab at 0x11938abd0>),
#  (u'wandering', <gensim.models.keyedvectors.Vocab at 0x11938ac10>),
#  ('damned', <gensim.models.keyedvectors.Vocab at 0x11938ac50>),
#  ('prospect', <gensim.models.keyedvectors.Vocab at 0x11938ac90>),
#  (u'addressing', <gensim.models.keyedvectors.Vocab at 0x11938acd0>),
#  (u'illness', <gensim.models.keyedvectors.Vocab at 0x11938ad10>),
#  ('tasted', <gensim.models.keyedvectors.Vocab at 0x11938ad50>),
#  ('nicer', <gensim.models.keyedvectors.Vocab at 0x11938ad90>),
#  ('turned', <gensim.models.keyedvectors.Vocab at 0x11938add0>),
#  ('alley', <gensim.models.keyedvectors.Vocab at 0x11938ae10>),
#  ('sad', <gensim.models.keyedvectors.Vocab at 0x11938ae50>),
#  ('say', <gensim.models.keyedvectors.Vocab at 0x11938ae90>),
#  ('taster', <gensim.models.keyedvectors.Vocab at 0x11938aed0>),
#  ('buried', <gensim.models.keyedvectors.Vocab at 0x11938af10>),
#  ('lurking', <gensim.models.keyedvectors.Vocab at 0x11938af50>),
#  ('sap', <gensim.models.keyedvectors.Vocab at 0x11938af90>),
#  ('saw', <gensim.models.keyedvectors.Vocab at 0x11938afd0>),
#  ('sat', <gensim.models.keyedvectors.Vocab at 0x11938f050>),
#  ('wink', <gensim.models.keyedvectors.Vocab at 0x11938f090>),
#  (u'downwards', <gensim.models.keyedvectors.Vocab at 0x11938f0d0>),
#  ('aside', <gensim.models.keyedvectors.Vocab at 0x11949db10>),
#  ('instructed', <gensim.models.keyedvectors.Vocab at 0x11938f150>),
#  ('note', <gensim.models.keyedvectors.Vocab at 0x11938f190>),
#  ('take', <gensim.models.keyedvectors.Vocab at 0x11938f1d0>),
#  (u'mazin', <gensim.models.keyedvectors.Vocab at 0x11938f210>),
#  ('wanting', <gensim.models.keyedvectors.Vocab at 0x11949ded0>),
#  (u'opposite', <gensim.models.keyedvectors.Vocab at 0x11938f290>),
#  ('squalor', <gensim.models.keyedvectors.Vocab at 0x11938f2d0>),
#  ('knew', <gensim.models.keyedvectors.Vocab at 0x11938f310>),
#  ('knee', <gensim.models.keyedvectors.Vocab at 0x11938f350>),
#  ('average', <gensim.models.keyedvectors.Vocab at 0x11938f390>),
#  (u'sale', <gensim.models.keyedvectors.Vocab at 0x1194a2d10>),
#  (u'defeating', <gensim.models.keyedvectors.Vocab at 0x11938f410>),
#  ('crooked', <gensim.models.keyedvectors.Vocab at 0x119612f50>),
#  ('gillyflower', <gensim.models.keyedvectors.Vocab at 0x11938f490>),
#  ('squint', <gensim.models.keyedvectors.Vocab at 0x11938f4d0>),
#  ('butchered', <gensim.models.keyedvectors.Vocab at 0x11938f510>),
#  ('salt', <gensim.models.keyedvectors.Vocab at 0x11938f550>),
#  ('walking', <gensim.models.keyedvectors.Vocab at 0x11938f590>),
#  (u'merit', <gensim.models.keyedvectors.Vocab at 0x11938f5d0>),
#  ('bright', <gensim.models.keyedvectors.Vocab at 0x11938f610>),
#  ('imagined', <gensim.models.keyedvectors.Vocab at 0x11938f650>),
#  ('slow', <gensim.models.keyedvectors.Vocab at 0x11938f690>),
#  ('strangled', <gensim.models.keyedvectors.Vocab at 0x1194c9810>),
#  (u'cloak', <gensim.models.keyedvectors.Vocab at 0x11938f6d0>),
#  ('liberation', <gensim.models.keyedvectors.Vocab at 0x11938f710>),
#  ('betrothal', <gensim.models.keyedvectors.Vocab at 0x11938f750>),
#  ('going', <gensim.models.keyedvectors.Vocab at 0x11938f790>),
#  ('dancing', <gensim.models.keyedvectors.Vocab at 0x119644210>),
#  ('outrage', <gensim.models.keyedvectors.Vocab at 0x11938f7d0>),
#  ('robe', <gensim.models.keyedvectors.Vocab at 0x11938f810>),
#  ('clawing', <gensim.models.keyedvectors.Vocab at 0x11938f850>),
#  ('robb', <gensim.models.keyedvectors.Vocab at 0x11938f890>),
#  (u'dispute', <gensim.models.keyedvectors.Vocab at 0x11938f8d0>),
#  ('graceless', <gensim.models.keyedvectors.Vocab at 0x11938f910>),
#  ('guarded', <gensim.models.keyedvectors.Vocab at 0x11938f950>),
#  ('freezing', <gensim.models.keyedvectors.Vocab at 0x11938f990>),
#  (u'clang', <gensim.models.keyedvectors.Vocab at 0x11938f9d0>),
#  ('awaiting', <gensim.models.keyedvectors.Vocab at 0x11938fa10>),
#  ('vhag', <gensim.models.keyedvectors.Vocab at 0x11938fa50>),
#  ('prime', <gensim.models.keyedvectors.Vocab at 0x11938fa90>),
#  (u'resource', <gensim.models.keyedvectors.Vocab at 0x11938fad0>),
#  (u'artist', <gensim.models.keyedvectors.Vocab at 0x11938fb10>),
#  ('absurdly', <gensim.models.keyedvectors.Vocab at 0x11938fb50>),
#  ('worried', <gensim.models.keyedvectors.Vocab at 0x11938fb90>),
#  ('carrion', <gensim.models.keyedvectors.Vocab at 0x11938fbd0>),
#  ('priest', <gensim.models.keyedvectors.Vocab at 0x11938fc10>),
#  (u'primp', <gensim.models.keyedvectors.Vocab at 0x11938fc50>),
#  (u'vision', <gensim.models.keyedvectors.Vocab at 0x11938fc90>),
#  ('gout', <gensim.models.keyedvectors.Vocab at 0x11938fcd0>),
#  ('raged', <gensim.models.keyedvectors.Vocab at 0x11938fd10>),
#  ('notice', <gensim.models.keyedvectors.Vocab at 0x11938fd50>),
#  ('purest', <gensim.models.keyedvectors.Vocab at 0x11938fd90>),
#  ('stannis', <gensim.models.keyedvectors.Vocab at 0x11938fdd0>),
#  ('mutton', <gensim.models.keyedvectors.Vocab at 0x11938fe10>),
#  ('jumped', <gensim.models.keyedvectors.Vocab at 0x1194be0d0>),
#  ('enjoys', <gensim.models.keyedvectors.Vocab at 0x11938fe90>),
#  ('amory', <gensim.models.keyedvectors.Vocab at 0x11938fed0>),
#  ('spare', <gensim.models.keyedvectors.Vocab at 0x11938ff10>),
#  ('umber', <gensim.models.keyedvectors.Vocab at 0x11938ff50>),
#  ('undermine', <gensim.models.keyedvectors.Vocab at 0x11938ff90>),
#  ('mant', <gensim.models.keyedvectors.Vocab at 0x11938ffd0>),
#  ('many', <gensim.models.keyedvectors.Vocab at 0x119395050>),
#  ('loudly', <gensim.models.keyedvectors.Vocab at 0x119395090>),
#  (u'riddle', <gensim.models.keyedvectors.Vocab at 0x1193950d0>),
#  ('drogo', <gensim.models.keyedvectors.Vocab at 0x119395110>),
#  (u'compels', <gensim.models.keyedvectors.Vocab at 0x119395150>),
#  (u'twin', <gensim.models.keyedvectors.Vocab at 0x119395190>),
#  ('boar', <gensim.models.keyedvectors.Vocab at 0x1193951d0>),
#  (u'considers', <gensim.models.keyedvectors.Vocab at 0x1194c9550>),
#  ('boat', <gensim.models.keyedvectors.Vocab at 0x119395250>),
#  (u'stretch', <gensim.models.keyedvectors.Vocab at 0x119395290>),
#  ('west', <gensim.models.keyedvectors.Vocab at 0x1193952d0>),
#  (u'expedition', <gensim.models.keyedvectors.Vocab at 0x119395310>),
#  ('breath', <gensim.models.keyedvectors.Vocab at 0x119395350>),
#  ('combined', <gensim.models.keyedvectors.Vocab at 0x119395390>),
#  ('stripped', <gensim.models.keyedvectors.Vocab at 0x1193953d0>),
#  ('coughing', <gensim.models.keyedvectors.Vocab at 0x1194ce590>),
#  ('centerpiece', <gensim.models.keyedvectors.Vocab at 0x119395450>),
#  ('observe', <gensim.models.keyedvectors.Vocab at 0x119395490>),
#  (u'extant', <gensim.models.keyedvectors.Vocab at 0x1193954d0>),
#  ('former', <gensim.models.keyedvectors.Vocab at 0x119395510>),
#  ('wherewithal', <gensim.models.keyedvectors.Vocab at 0x119395550>),
#  (u'fin', <gensim.models.keyedvectors.Vocab at 0x119395590>),
#  ('straighten', <gensim.models.keyedvectors.Vocab at 0x1194d4110>),
#  ('whatevers', <gensim.models.keyedvectors.Vocab at 0x119618250>),
#  ('squeezed', <gensim.models.keyedvectors.Vocab at 0x119395650>),
#  (u'situation', <gensim.models.keyedvectors.Vocab at 0x119395690>),
#  ('endured', <gensim.models.keyedvectors.Vocab at 0x1193956d0>),
#  ('ive', <gensim.models.keyedvectors.Vocab at 0x119395710>),
#  ('thatll', <gensim.models.keyedvectors.Vocab at 0x119395750>),
#  ('purse', <gensim.models.keyedvectors.Vocab at 0x119395790>),
#  ('shevelathin', <gensim.models.keyedvectors.Vocab at 0x1193957d0>),
#  ('spooked', <gensim.models.keyedvectors.Vocab at 0x119395810>),
#  ('burbling', <gensim.models.keyedvectors.Vocab at 0x119395850>),
#  ('threatens', <gensim.models.keyedvectors.Vocab at 0x119395890>),
#  ('damon', <gensim.models.keyedvectors.Vocab at 0x1193958d0>),
#  ('edged', <gensim.models.keyedvectors.Vocab at 0x119395910>),
#  ('sickness', <gensim.models.keyedvectors.Vocab at 0x1194df350>),
#  ('defy', <gensim.models.keyedvectors.Vocab at 0x119395990>),
# ...
#  ('dark', <gensim.models.keyedvectors.Vocab at 0x119395d50>),
#  ('preference', <gensim.models.keyedvectors.Vocab at 0x119395d90>),
#  ('fringed', <gensim.models.keyedvectors.Vocab at 0x11949d710>),
#  ('vague', <gensim.models.keyedvectors.Vocab at 0x119395e10>),
#  ('bravery', <gensim.models.keyedvectors.Vocab at 0x119395e50>),
#  (u'clan', <gensim.models.keyedvectors.Vocab at 0x119395e90>),
#  (u'clam', <gensim.models.keyedvectors.Vocab at 0x119395ed0>),
#  ('stranger', <gensim.models.keyedvectors.Vocab at 0x119395f10>),
#  ('discarded', <gensim.models.keyedvectors.Vocab at 0x119395f50>),
#  ('superiority', <gensim.models.keyedvectors.Vocab at 0x119395f90>),
#  (u'claw', <gensim.models.keyedvectors.Vocab at 0x119395fd0>),
#  ('sorcerer', <gensim.models.keyedvectors.Vocab at 0x1193c1f90>),
#  (u'kennel', <gensim.models.keyedvectors.Vocab at 0x11939a090>),
#  (u'clap', <gensim.models.keyedvectors.Vocab at 0x11939a0d0>),
#  ('grub', <gensim.models.keyedvectors.Vocab at 0x11939a110>),
#  (u'lobster', <gensim.models.keyedvectors.Vocab at 0x11939a150>),
#  (u'divine', <gensim.models.keyedvectors.Vocab at 0x11939a190>),
#  ('crabber', <gensim.models.keyedvectors.Vocab at 0x11939a1d0>),
#  ('dimpled', <gensim.models.keyedvectors.Vocab at 0x11939a210>),
#  ('refer', <gensim.models.keyedvectors.Vocab at 0x11939a250>),
#  (u'clarenzo', <gensim.models.keyedvectors.Vocab at 0x11939a290>),
#  ('averse', <gensim.models.keyedvectors.Vocab at 0x11939a2d0>),
#  ('power', <gensim.models.keyedvectors.Vocab at 0x11939a310>),
#  ('intimate', <gensim.models.keyedvectors.Vocab at 0x11939a350>),
#  ('hayseed', <gensim.models.keyedvectors.Vocab at 0x11939a390>),
#  ('leadership', <gensim.models.keyedvectors.Vocab at 0x11939a3d0>),
#  (u'stone', <gensim.models.keyedvectors.Vocab at 0x11939a410>),
#  ('yunkai', <gensim.models.keyedvectors.Vocab at 0x11939a450>),
#  ('favorite', <gensim.models.keyedvectors.Vocab at 0x11939a490>),
#  (u'side', <gensim.models.keyedvectors.Vocab at 0x11948c410>),
#  (u'apostate', <gensim.models.keyedvectors.Vocab at 0x11939a510>),
#  (u'neighbor', <gensim.models.keyedvectors.Vocab at 0x11939a550>),
#  ('act', <gensim.models.keyedvectors.Vocab at 0x11939a590>),
#  (u'mean', <gensim.models.keyedvectors.Vocab at 0x1194ea410>),
#  ('stony', <gensim.models.keyedvectors.Vocab at 0x11939a610>),
#  (u'widowed', <gensim.models.keyedvectors.Vocab at 0x11939a650>),
#  ('chivalry', <gensim.models.keyedvectors.Vocab at 0x11939a690>),
#  ('shapely', <gensim.models.keyedvectors.Vocab at 0x11939a6d0>),
#  ('burning', <gensim.models.keyedvectors.Vocab at 0x11939a710>),
#  ('interruption', <gensim.models.keyedvectors.Vocab at 0x11948c4d0>),
#  (u'antidote', <gensim.models.keyedvectors.Vocab at 0x11939a790>),
#  ('apologize', <gensim.models.keyedvectors.Vocab at 0x11939a7d0>),
#  (u'pivot', <gensim.models.keyedvectors.Vocab at 0x119505390>),
#  ('trussed', <gensim.models.keyedvectors.Vocab at 0x11939a850>),
#  ('hey', <gensim.models.keyedvectors.Vocab at 0x11939a890>),
#  ('hed', <gensim.models.keyedvectors.Vocab at 0x11939a8d0>),
#  (u'lhazareen', <gensim.models.keyedvectors.Vocab at 0x11939a910>),
#  ('mindless', <gensim.models.keyedvectors.Vocab at 0x11939a950>),
#  ('sealed', <gensim.models.keyedvectors.Vocab at 0x11939a990>),
#  (u'hen', <gensim.models.keyedvectors.Vocab at 0x11939a9d0>),
#  ('survives', <gensim.models.keyedvectors.Vocab at 0x11939aa10>),
#  ('recommends', <gensim.models.keyedvectors.Vocab at 0x11939aa50>),
#  ('complete', <gensim.models.keyedvectors.Vocab at 0x11939aa90>),
#  ('survived', <gensim.models.keyedvectors.Vocab at 0x11939aad0>),
#  (u'whinny', <gensim.models.keyedvectors.Vocab at 0x11939ab10>),
#  ('buying', <gensim.models.keyedvectors.Vocab at 0x11939ab50>),
#  ('handsome', <gensim.models.keyedvectors.Vocab at 0x11939ab90>),
#  ('abused', <gensim.models.keyedvectors.Vocab at 0x11939abd0>),
#  ('pull', <gensim.models.keyedvectors.Vocab at 0x11939ac10>),
#  (u'rush', <gensim.models.keyedvectors.Vocab at 0x11939ac50>),
#  ('rage', <gensim.models.keyedvectors.Vocab at 0x11939ac90>),
#  ('browbeaten', <gensim.models.keyedvectors.Vocab at 0x11939acd0>),
#  ('balons', <gensim.models.keyedvectors.Vocab at 0x11948c550>),
#  ('dirty', <gensim.models.keyedvectors.Vocab at 0x11939ad50>),
#  ('agree', <gensim.models.keyedvectors.Vocab at 0x11939ad90>),
#  ('darker', <gensim.models.keyedvectors.Vocab at 0x11939add0>),
#  (u'detailed', <gensim.models.keyedvectors.Vocab at 0x11939ae10>),
#  ('gone', <gensim.models.keyedvectors.Vocab at 0x11939ae50>),
#  ('fright', <gensim.models.keyedvectors.Vocab at 0x11939ae90>),
#  (u'exhausted', <gensim.models.keyedvectors.Vocab at 0x11939aed0>),
#  ('ah', <gensim.models.keyedvectors.Vocab at 0x11939af10>),
#  ('stealing', <gensim.models.keyedvectors.Vocab at 0x11948c5d0>),
#  ('al', <gensim.models.keyedvectors.Vocab at 0x11939af90>),
#  ('wartime', <gensim.models.keyedvectors.Vocab at 0x11939afd0>),
#  (u'watcher', <gensim.models.keyedvectors.Vocab at 0x1193a0050>),
#  ('behest', <gensim.models.keyedvectors.Vocab at 0x1193a0090>),
#  (u'as', <gensim.models.keyedvectors.Vocab at 0x1193a00d0>),
#  ('carved', <gensim.models.keyedvectors.Vocab at 0x1193a0110>),
#  (u'midwife', <gensim.models.keyedvectors.Vocab at 0x1193a0150>),
#  ('laboratory', <gensim.models.keyedvectors.Vocab at 0x1193a0190>),
#  ('ax', <gensim.models.keyedvectors.Vocab at 0x1193a01d0>),
#  (u'johnna', <gensim.models.keyedvectors.Vocab at 0x1193a0210>),
#  ('cream', <gensim.models.keyedvectors.Vocab at 0x1193a0250>),
#  (u'ideally', <gensim.models.keyedvectors.Vocab at 0x1193a0290>),
#  ('tight', <gensim.models.keyedvectors.Vocab at 0x1193a02d0>),
#  ('httpsubttfreeorg', <gensim.models.keyedvectors.Vocab at 0x1193a0310>),
#  (u'puppy', <gensim.models.keyedvectors.Vocab at 0x1193a0350>),
#  ('disgraceful', <gensim.models.keyedvectors.Vocab at 0x1193a03d0>),
#  (u'congress', <gensim.models.keyedvectors.Vocab at 0x1193a0410>),
#  ('waving', <gensim.models.keyedvectors.Vocab at 0x1193a0450>),
#  (u'middling', <gensim.models.keyedvectors.Vocab at 0x1193a0490>),
#  (u'midget', <gensim.models.keyedvectors.Vocab at 0x1193a04d0>),
#  ('brotherhood', <gensim.models.keyedvectors.Vocab at 0x1193a0510>),
#  ('tricky', <gensim.models.keyedvectors.Vocab at 0x1193a0550>),
#  ('disdained', <gensim.models.keyedvectors.Vocab at 0x1193a0590>),
#  ('infanticide', <gensim.models.keyedvectors.Vocab at 0x1193a05d0>),
#  ('sobbing', <gensim.models.keyedvectors.Vocab at 0x1193a0610>),
#  (u'thorn', <gensim.models.keyedvectors.Vocab at 0x1193a0650>),
#  ('groom', <gensim.models.keyedvectors.Vocab at 0x1193a0690>),
#  (u'mask', <gensim.models.keyedvectors.Vocab at 0x1193a06d0>),
#  (u'dyed', <gensim.models.keyedvectors.Vocab at 0x1193a0710>),
#  (u'mast', <gensim.models.keyedvectors.Vocab at 0x1193a0750>),
#  (u'mass', <gensim.models.keyedvectors.Vocab at 0x1193a0790>),
#  ('sawing', <gensim.models.keyedvectors.Vocab at 0x1193a07d0>),
#  (u'dyer', <gensim.models.keyedvectors.Vocab at 0x1193a0810>),
#  ('original', <gensim.models.keyedvectors.Vocab at 0x1193a0850>),
#  ('consider', <gensim.models.keyedvectors.Vocab at 0x1193a0890>),
#  ('beware', <gensim.models.keyedvectors.Vocab at 0x1193a08d0>),
#  (u'neigh', <gensim.models.keyedvectors.Vocab at 0x1193a0910>),
#  ('welfare', <gensim.models.keyedvectors.Vocab at 0x1193a0950>),
#  ('hunting', <gensim.models.keyedvectors.Vocab at 0x1193a0990>),
#  ('tail', <gensim.models.keyedvectors.Vocab at 0x1193a09d0>),
#  ('chewing', <gensim.models.keyedvectors.Vocab at 0x1193a0a10>),
#  ('dockworker', <gensim.models.keyedvectors.Vocab at 0x1193a0a50>),
#  ('th', <gensim.models.keyedvectors.Vocab at 0x1193a0a90>),
#  (u'ti', <gensim.models.keyedvectors.Vocab at 0x1193a0ad0>),
#  ('smile', <gensim.models.keyedvectors.Vocab at 0x1193a0b10>),
#  (u'shipload', <gensim.models.keyedvectors.Vocab at 0x1193a0b50>),
#  ('paying', <gensim.models.keyedvectors.Vocab at 0x119618910>),
#  ('appointment', <gensim.models.keyedvectors.Vocab at 0x1193a0bd0>),
#  ('returned', <gensim.models.keyedvectors.Vocab at 0x1193a0c10>),
#  ('squiring', <gensim.models.keyedvectors.Vocab at 0x1193a0c50>),
#  ('eyrie', <gensim.models.keyedvectors.Vocab at 0x1193a0c90>),
#  ('condition', <gensim.models.keyedvectors.Vocab at 0x1193a0cd0>),
#  ('harrenhal', <gensim.models.keyedvectors.Vocab at 0x1193a0d10>),
#  ('overprotective', <gensim.models.keyedvectors.Vocab at 0x1193a0d50>),
#  (u'laying', <gensim.models.keyedvectors.Vocab at 0x1193a0d90>),
#  ('joined', <gensim.models.keyedvectors.Vocab at 0x1193a0dd0>),
#  ('underclothes', <gensim.models.keyedvectors.Vocab at 0x1193a0e10>),
#  ('large', <gensim.models.keyedvectors.Vocab at 0x1193a0e50>),
#  ('sang', <gensim.models.keyedvectors.Vocab at 0x1193a0e90>),
#  ('sand', <gensim.models.keyedvectors.Vocab at 0x1193a0ed0>),
#  (u'adjust', <gensim.models.keyedvectors.Vocab at 0x1193a0f10>),
#  ('small', <gensim.models.keyedvectors.Vocab at 0x1193a0f50>),
#  ('quicker', <gensim.models.keyedvectors.Vocab at 0x1193a0f90>),
#  (u'healed', <gensim.models.keyedvectors.Vocab at 0x1193a0fd0>),
#  ('past', <gensim.models.keyedvectors.Vocab at 0x1193a5050>),
#  ('podrick', <gensim.models.keyedvectors.Vocab at 0x11948c890>),
#  (u'pass', <gensim.models.keyedvectors.Vocab at 0x1193a50d0>),
#  ('turning', <gensim.models.keyedvectors.Vocab at 0x11948c8d0>),
#  (u'investment', <gensim.models.keyedvectors.Vocab at 0x1193a5150>),
#  ('poisonous', <gensim.models.keyedvectors.Vocab at 0x1193a5190>),
#  ('prevailed', <gensim.models.keyedvectors.Vocab at 0x1193a51d0>),
#  ('nurse', <gensim.models.keyedvectors.Vocab at 0x1193a5210>),
#  ('full', <gensim.models.keyedvectors.Vocab at 0x1193a5250>),
#  ('escaping', <gensim.models.keyedvectors.Vocab at 0x1193a5290>),
#  ('vomiting', <gensim.models.keyedvectors.Vocab at 0x1193a52d0>),
#  ('smartest', <gensim.models.keyedvectors.Vocab at 0x1193a5310>),
#  ('buzzing', <gensim.models.keyedvectors.Vocab at 0x1193a5350>),
#  ('legend', <gensim.models.keyedvectors.Vocab at 0x1193a5390>),
#  ('slynt', <gensim.models.keyedvectors.Vocab at 0x1193a53d0>),
#  ('kayla', <gensim.models.keyedvectors.Vocab at 0x119361490>),
#  ('experience', <gensim.models.keyedvectors.Vocab at 0x1193a5450>),
#  ('pick', <gensim.models.keyedvectors.Vocab at 0x1193a5490>),
#  (u'action', <gensim.models.keyedvectors.Vocab at 0x1193a54d0>),
#  ('murdering', <gensim.models.keyedvectors.Vocab at 0x1193a5510>),
#  ('luck', <gensim.models.keyedvectors.Vocab at 0x11948c490>),
#  ('smuggle', <gensim.models.keyedvectors.Vocab at 0x1193a5550>),
#  ('gawking', <gensim.models.keyedvectors.Vocab at 0x1193a5590>),
#  ('followed', <gensim.models.keyedvectors.Vocab at 0x1193a55d0>),
#  (u'follower', <gensim.models.keyedvectors.Vocab at 0x1193a5610>),
#  (u'indoors', <gensim.models.keyedvectors.Vocab at 0x1193a5650>),
#  (u'captor', <gensim.models.keyedvectors.Vocab at 0x1193a5690>),
#  ('darkens', <gensim.models.keyedvectors.Vocab at 0x1193a56d0>),
#  (u'moro', <gensim.models.keyedvectors.Vocab at 0x1193a5710>),
#  (u'gorgeous', <gensim.models.keyedvectors.Vocab at 0x1193a5750>),
#  (u'mord', <gensim.models.keyedvectors.Vocab at 0x1193a5790>),
#  ('restraint', <gensim.models.keyedvectors.Vocab at 0x11963eed0>),
#  ('door', <gensim.models.keyedvectors.Vocab at 0x1193a57d0>),
#  ('company', <gensim.models.keyedvectors.Vocab at 0x1193a5810>),
#  ('tested', <gensim.models.keyedvectors.Vocab at 0x1193a5850>),
#  ('doom', <gensim.models.keyedvectors.Vocab at 0x1193a5890>),
#  ('riverbank', <gensim.models.keyedvectors.Vocab at 0x1193a58d0>),
#  ('cunning', <gensim.models.keyedvectors.Vocab at 0x1193a5910>),
#  ('keeping', <gensim.models.keyedvectors.Vocab at 0x1193a5950>),
#  ('pleasing', <gensim.models.keyedvectors.Vocab at 0x1193a5990>),
#  ('farted', <gensim.models.keyedvectors.Vocab at 0x1193a59d0>),
#  ('thickest', <gensim.models.keyedvectors.Vocab at 0x1193a5a10>),
#  ('learn', <gensim.models.keyedvectors.Vocab at 0x1193a5a50>),
#  ('knocked', <gensim.models.keyedvectors.Vocab at 0x1193a5a90>),
#  ('sunspear', <gensim.models.keyedvectors.Vocab at 0x1193a5ad0>),
#  (u'seagull', <gensim.models.keyedvectors.Vocab at 0x1193a5b10>),
#  (u'male', <gensim.models.keyedvectors.Vocab at 0x1193a5b50>),
#  ('beautiful', <gensim.models.keyedvectors.Vocab at 0x1193a5b90>),
#  ('brightflame', <gensim.models.keyedvectors.Vocab at 0x1193a5bd0>),
#  ('accept', <gensim.models.keyedvectors.Vocab at 0x1193a5c10>),
#  ('fiercely', <gensim.models.keyedvectors.Vocab at 0x1193a5c50>),
#  ('sense', <gensim.models.keyedvectors.Vocab at 0x1193a5c90>),
#  ('scar', <gensim.models.keyedvectors.Vocab at 0x1193a5d10>),
#  ('dress', <gensim.models.keyedvectors.Vocab at 0x1193a5d50>),
#  ('condemn', <gensim.models.keyedvectors.Vocab at 0x1193a5d90>),
#  ('information', <gensim.models.keyedvectors.Vocab at 0x1193a5dd0>),
#  ('impulse', <gensim.models.keyedvectors.Vocab at 0x11943a710>),
#  ('imminent', <gensim.models.keyedvectors.Vocab at 0x1193a5e10>),
#  (u'hugh', <gensim.models.keyedvectors.Vocab at 0x1193a5e50>),
#  ('dismissed', <gensim.models.keyedvectors.Vocab at 0x1193a5e90>),
#  (u'glowing', <gensim.models.keyedvectors.Vocab at 0x1193a5ed0>),
#  ('freshly', <gensim.models.keyedvectors.Vocab at 0x1193a5f10>),
#  (u'clink', <gensim.models.keyedvectors.Vocab at 0x1193a5f50>),
#  ('unattended', <gensim.models.keyedvectors.Vocab at 0x1193a5f90>),
#  ('creature', <gensim.models.keyedvectors.Vocab at 0x1193a5fd0>),
#  ('sprinkle', <gensim.models.keyedvectors.Vocab at 0x1193ab050>),
#  ('intended', <gensim.models.keyedvectors.Vocab at 0x1193ab090>),
#  ('countryside', <gensim.models.keyedvectors.Vocab at 0x1193ab0d0>),
#  ('disgraced', <gensim.models.keyedvectors.Vocab at 0x1193ab110>),
#  ('sympathize', <gensim.models.keyedvectors.Vocab at 0x1193ab150>),
#  ('zuriff', <gensim.models.keyedvectors.Vocab at 0x1193ab190>),
#  (u'pleaded', <gensim.models.keyedvectors.Vocab at 0x1193ab1d0>),
#  ('plank', <gensim.models.keyedvectors.Vocab at 0x1193ab210>),
#  ('refuse', <gensim.models.keyedvectors.Vocab at 0x1193ab250>),
#  ('replied', <gensim.models.keyedvectors.Vocab at 0x1193ab290>),
#  ('eddark', <gensim.models.keyedvectors.Vocab at 0x1193ab2d0>),
#  (u'pant', <gensim.models.keyedvectors.Vocab at 0x1193ab310>),
#  ('reminded', <gensim.models.keyedvectors.Vocab at 0x119618c50>),
#  ('eddard', <gensim.models.keyedvectors.Vocab at 0x1193ab390>),
#  ('installed', <gensim.models.keyedvectors.Vocab at 0x1193ab3d0>),
#  (u'paper', <gensim.models.keyedvectors.Vocab at 0x1193ab410>),
#  (u'brim', <gensim.models.keyedvectors.Vocab at 0x1193ab450>),
#  ('smiling', <gensim.models.keyedvectors.Vocab at 0x1193ab490>),
#  ('aemon', <gensim.models.keyedvectors.Vocab at 0x1193ab4d0>),
#  ('mistreated', <gensim.models.keyedvectors.Vocab at 0x1193ab510>),
#  (u'mummer', <gensim.models.keyedvectors.Vocab at 0x1193ab550>),
#  ('ruining', <gensim.models.keyedvectors.Vocab at 0x1193ab590>),
#  (u'travelling', <gensim.models.keyedvectors.Vocab at 0x1193ab5d0>),
#  ('ally', <gensim.models.keyedvectors.Vocab at 0x1193ab610>),
#  ('colleague', <gensim.models.keyedvectors.Vocab at 0x1193ab650>),
#  ('lowell', <gensim.models.keyedvectors.Vocab at 0x1193ab690>),
#  ('propose', <gensim.models.keyedvectors.Vocab at 0x1193ab6d0>),
#  ('martells', <gensim.models.keyedvectors.Vocab at 0x1193ab710>),
#  (u'easterner', <gensim.models.keyedvectors.Vocab at 0x1193ab750>),
#  (u'qyburns', <gensim.models.keyedvectors.Vocab at 0x1193ab790>),
#  ('always', <gensim.models.keyedvectors.Vocab at 0x1193ab7d0>),
#  ('repayment', <gensim.models.keyedvectors.Vocab at 0x1193ab810>),
#  ('found', <gensim.models.keyedvectors.Vocab at 0x1193ab850>),
#  ('shocking', <gensim.models.keyedvectors.Vocab at 0x1193ab890>),
#  ('begged', <gensim.models.keyedvectors.Vocab at 0x1193ab8d0>),
#  (u'stevron', <gensim.models.keyedvectors.Vocab at 0x1193ab910>),
#  ('varys', <gensim.models.keyedvectors.Vocab at 0x1193c6b10>),
#  (u'measurement', <gensim.models.keyedvectors.Vocab at 0x1193ab990>),
#  ('bluer', <gensim.models.keyedvectors.Vocab at 0x1193ab9d0>),
#  ('really', <gensim.models.keyedvectors.Vocab at 0x1193aba10>),
#  ('missed', <gensim.models.keyedvectors.Vocab at 0x1193aba50>),
#  (u'research', <gensim.models.keyedvectors.Vocab at 0x1193aba90>),
#  ('hood', <gensim.models.keyedvectors.Vocab at 0x11948cd10>),
#  ('darling', <gensim.models.keyedvectors.Vocab at 0x1193abb10>),
#  ('nastiness', <gensim.models.keyedvectors.Vocab at 0x11948cd50>)]

# %%
model.wv.vocab.keys()[:1000]
# Out:
# ['foul',
#  'four',
#  'hanging',
#  'marching',
#  u'increase',
#  'midafternoon',
#  'mutinied',
#  'lord',
#  u'sinking',
#  'leisurely',
#  u'politician',
#  'stabbed',
#  'bringing',
#  'disturb',
#  'prize',
#  'wooden',
#  u'clientele',
#  'succession',
#  'straight',
#  'tired',
#  u'lefford',
#  'bacon',
#  'elegant',
#  'second',
#  'sailed',
#  u'ruthless',
#  'thunder',
#  'cooking',
#  'contributed',
#  'resilient',
#  'succumb',
#  'hero',
#  'interrupting',
#  u'here',
#  'substance',
#  u'k',
#  'climbed',
#  'military',
#  u'climber',
#  'diplomat',
#  'appropriately',
#  'divide',
#  'explained',
#  'replace',
#  'brought',
#  'stern',
#  'cheating',
#  'spoke',
#  u'cannibal',
#  'occupying',
#  'untie',
#  'strike',
#  'sideface',
#  'holy',
#  'relax',
#  'successful',
#  'brings',
#  'hereby',
#  'hurt',
#  u'glass',
#  u'hole',
#  'hold',
#  u'simper',
#  u'benjens',
#  'pursue',
#  'zhoan',
#  'blade',
#  'plunged',
#  'sweeter',
#  'rework',
#  'example',
#  'triple',
#  'organized',
#  u'caution',
#  'want',
#  'counseling',
#  'mymother',
#  u'cocksucker',
#  'absolute',
#  'hog',
#  'complaining',
#  u'travel',
#  'copious',
#  'undying',
#  'hot',
#  'retreating',
#  'beauty',
#  'swing',
#  u'despondent',
#  'outlawed',
#  'wrong',
#  'barristan',
#  u'huhuh',
#  u'attracts',
#  u'revolt',
#  'sickening',
#  'tulip',
#  'viserys',
#  u'wing',
#  'wind',
#  'wine',
#  'dreamed',
#  'patricide',
#  u'profaned',
#  'rewarded',
#  'fit',
#  'allisers',
#  'screaming',
#  u'fix',
#  u'dedicate',
#  u'fig',
#  'mewling',
#  'hidden',
#  'admirable',
#  'easier',
#  'hghar',
#  'commemorate',
#  'educating',
#  'interrupt',
#  'blink',
#  'silver',
#  'structural',
#  u'represents',
#  'jaehaerys',
#  'theons',
#  u'arrow',
#  u'armourer',
#  'burial',
#  u'whim',
#  'financial',
#  u'spider',
#  u'longclaw',
#  u'turnip',
#  'fortnight',
#  u'mutineer',
#  u'wyllis',
#  'message',
#  'whip',
#  'misfortune',
#  'whoosh',
#  u'mason',
#  u'rd',
#  'archmaester',
#  u'ro',
#  u'outburst',
#  u'foundation',
#  'assured',
#  'waddle',
#  'threatened',
#  'assures',
#  'aggar',
#  'crowned',
#  'tobho',
#  'ate',
#  'ath',
#  'shipped',
#  u'disturbed',
#  'tempting',
#  'minge',
#  u'subtlety',
#  'wash',
#  'instruct',
#  'bitten',
#  'zala',
#  'whorehouse',
#  'timid',
#  'engagement',
#  'needed',
#  'master',
#  'bitter',
#  'ranging',
#  'listen',
#  'lorch',
#  u'collapse',
#  'hows',
#  'highgarden',
#  'wisdom',
#  'predictable',
#  'crawl',
#  'positively',
#  'showed',
#  u'coward',
#  'tree',
#  u'whinging',
#  'shower',
#  'idle',
#  'endure',
#  'profitable',
#  'feeling',
#  'groaning',
#  'longs',
#  'untrained',
#  'tether',
#  'dozen',
#  'responsible',
#  u'instructs',
#  'amusing',
#  'britches',
#  u'season',
#  'eastwatch',
#  u'horselords',
#  'howd',
#  'shall',
#  'huh',
#  'aegons',
#  'toil',
#  'mouth',
#  'letter',
#  u'singer',
#  u'episode',
#  'rayder',
#  'consummate',
#  'mating',
#  'tirelessly',
#  'came',
#  'saying',
#  'fennel',
#  u'tempted',
#  'abreast',
#  'busy',
#  'theme',
#  'touched',
#  'rich',
#  u'plate',
#  'petrified',
#  u'foremost',
#  u'pocket',
#  u'reversal',
#  'altogether',
#  'blistered',
#  u'spilling',
#  'nicely',
#  'dipping',
#  'piggy',
#  'release',
#  u'respond',
#  u'blew',
#  'fair',
#  'bled',
#  u'result',
#  'fail',
#  'nocturnal',
#  u'hammer',
#  'best',
#  'score',
#  'pirate',
#  u'wage',
#  'men',
#  'khaleesi',
#  'extend',
#  'nature',
#  'rolled',
#  'smelled',
#  'lapping',
#  u'souvenir',
#  u'extent',
#  'tyrion',
#  u'debt',
#  'pity',
#  'accident',
#  'weirwood',
#  'country',
#  u'adventurer',
#  'demanded',
#  'planned',
#  'logic',
#  'argue',
#  'asked',
#  u'vain',
#  'blonde',
#  'shouting',
#  'union',
#  'slay',
#  'muck',
#  'much',
#  'privilege',
#  'tallest',
#  'life',
#  u'lodock',
#  'spit',
#  u'eastern',
#  'jeor',
#  u'davy',
#  'wish',
#  'lift',
#  'direwolf',
#  'child',
#  'worked',
#  'cunt',
#  'employ',
#  'contemplates',
#  u'flooding',
#  'picturing',
#  'remembering',
#  u'congratulation',
#  'played',
#  'cersei',
#  u'locksmith',
#  u'obeying',
#  u'player',
#  'trusted',
#  'severity',
#  'tarth',
#  'yellow',
#  'thievery',
#  'rebellion',
#  'clucking',
#  u'harmony',
#  'fairly',
#  'boiled',
#  'marched',
#  'supper',
#  'therell',
#  'metalwork',
#  'tune',
#  u'tarleys',
#  'intrusion',
#  'noblewoman',
#  'eagle',
#  'towheaded',
#  u'bellow',
#  'golden',
#  'forsaken',
#  u'plight',
#  u'hal',
#  'ham',
#  'ease',
#  'hay',
#  'innocent',
#  'prison',
#  'east',
#  'hat',
#  u'hightower',
#  'survival',
#  'possible',
#  'possibly',
#  'birth',
#  'shadow',
#  'unique',
#  'desire',
#  'remind',
#  'battlefield',
#  'right',
#  'old',
#  'crowd',
#  'people',
#  'macabre',
#  'crown',
#  'captive',
#  'warring',
#  'bottom',
#  u'rehearse',
#  u'fox',
#  'witty',
#  u'foe',
#  u'summoned',
#  u'umi',
#  'pinched',
#  'yoke',
#  u'defensive',
#  'losing',
#  'memorable',
#  'bowing',
#  u'grievously',
#  u'o',
#  'despair',
#  u'slightly',
#  'match',
#  'lamprey',
#  'raised',
#  'watering',
#  'tyrell',
#  'son',
#  'thankful',
#  'consummated',
#  'sow',
#  'wrap',
#  'despised',
#  'fabric',
#  'suffice',
#  'tame',
#  'grasping',
#  'despises',
#  'greatness',
#  'music',
#  'thoros',
#  'underestimated',
#  'offer',
#  'shireen',
#  'perfumed',
#  'matthos',
#  'duel',
#  'inside',
#  'morning',
#  'vanguard',
#  'pest',
#  'torturing',
#  'smashed',
#  'juvenile',
#  'later',
#  'proved',
#  'arwyen',
#  'tournament',
#  'proven',
#  'meros',
#  'soothe',
#  'exist',
#  'accounting',
#  'floor',
#  u'actor',
#  'uttered',
#  'flood',
#  'underfed',
#  'role',
#  'ambitious',
#  'smell',
#  'roll',
#  'intend',
#  'corbray',
#  u'ointment',
#  'scream',
#  'acquaintance',
#  'giantsbane',
#  'cleaver',
#  u'daugters',
#  'warn',
#  'pycelle',
#  'sniffed',
#  'quandary',
#  'time',
#  'push',
#  'someplace',
#  'dotes',
#  'gown',
#  'chain',
#  'whoever',
#  'warg',
#  'chair',
#  'midst',
#  'quartered',
#  u'lothar',
#  'choice',
#  'mourn',
#  'locked',
#  u'exact',
#  'minute',
#  'tear',
#  u'teat',
#  u'pea',
#  'leave',
#  'settle',
#  'stockade',
#  u'team',
#  'bonfire',
#  u'accomplishment',
#  u'sigh',
#  'sign',
#  'chopping',
#  'catelyn',
#  u'melt',
#  'current',
#  'axel',
#  'falling',
#  'crashing',
#  'badge',
#  'ramming',
#  u'funeral',
#  'understanding',
#  'contemplate',
#  'address',
#  'alone',
#  'along',
#  'crumbles',
#  u'summerwine',
#  'brilliant',
#  'studied',
#  'wherever',
#  u'commonly',
#  'accomplished',
#  'greizhen',
#  u'reclaim',
#  'nowhere',
#  'love',
#  'prefer',
#  'logical',
#  'bloody',
#  'marvelous',
#  'betraying',
#  u'sky',
#  u'capsized',
#  'working',
#  'angry',
#  'blackwater',
#  u'cockfighting',
#  'wondering',
#  u'halfbrother',
#  'wicked',
#  u'introducing',
#  u'guardsman',
#  'afford',
#  'xaros',
#  'marbled',
#  'everywhere',
#  'virtue',
#  'behalf',
#  'honey',
#  'valued',
#  'anything',
#  'originally',
#  u'pretend',
#  'privy',
#  'believer',
#  u'impasse',
#  'believed',
#  'admired',
#  'locke',
#  u'unconsummated',
#  'unveiled',
#  'allowed',
#  'offense',
#  'stole',
#  'evidently',
#  'listens',
#  'winter',
#  u'divided',
#  'thanking',
#  'immune',
#  'loathe',
#  u'encampment',
#  u'provincial',
#  'spot',
#  'suck',
#  'dove',
#  u'stress',
#  'natural',
#  'blackfish',
#  'st',
#  'swollen',
#  'truce',
#  'pulled',
#  'drunken',
#  u'footstep',
#  'unacceptable',
#  'damage',
#  'course',
#  'yearn',
#  'mishear',
#  'lovelier',
#  u'tendency',
#  'tore',
#  'milked',
#  'torn',
#  'stupidity',
#  'aerion',
#  'celebrate',
#  'troubled',
#  u'deviant',
#  u'chaining',
#  'smarter',
#  'arriving',
#  'reckoning',
#  u'shhh',
#  'maintaining',
#  'matched',
#  'freya',
#  'appropriate',
#  'stillborns',
#  'fisherman',
#  'amnesty',
#  u'quarter',
#  'broodmare',
#  'square',
#  'beloved',
#  'entering',
#  u'beetle',
#  'troll',
#  u'swordsman',
#  'seriously',
#  'investigation',
#  'suggesting',
#  'facedown',
#  'siege',
#  'million',
#  'seventh',
#  u'possibility',
#  'quite',
#  'complicated',
#  'besides',
#  u'grandma',
#  'unnamed',
#  'patronage',
#  'training',
#  'backside',
#  'modest',
#  u'nymeria',
#  'saving',
#  'spoken',
#  'one',
#  u'reopen',
#  'punishable',
#  'vote',
#  'open',
#  'ripping',
#  'partook',
#  u'city',
#  u'wrath',
#  'bite',
#  'teacher',
#  u'shiver',
#  'prone',
#  'shawl',
#  'meddling',
#  u'padding',
#  'prowling',
#  'ridiculous',
#  u'camello',
#  'third',
#  'cower',
#  'sandor',
#  u'counselor',
#  u'wandering',
#  'damned',
#  'prospect',
#  u'addressing',
#  u'illness',
#  'tasted',
#  'nicer',
#  'turned',
#  'alley',
#  'sad',
#  'say',
#  'taster',
#  'buried',
#  'lurking',
#  'sap',
#  'saw',
#  'sat',
#  'wink',
#  u'downwards',
#  'aside',
#  'instructed',
#  'note',
#  'take',
#  u'mazin',
#  'wanting',
#  u'opposite',
#  'squalor',
#  'knew',
#  'knee',
#  'average',
#  u'sale',
#  u'defeating',
#  'crooked',
#  'gillyflower',
#  'squint',
#  'butchered',
#  'salt',
#  'walking',
#  u'merit',
#  'bright',
#  'imagined',
#  'slow',
#  'strangled',
#  u'cloak',
#  'liberation',
#  'betrothal',
#  'going',
#  'dancing',
#  'outrage',
#  'robe',
#  'clawing',
#  'robb',
#  u'dispute',
#  'graceless',
#  'guarded',
#  'freezing',
#  u'clang',
#  'awaiting',
#  'vhag',
#  'prime',
#  u'resource',
#  u'artist',
#  'absurdly',
#  'worried',
#  'carrion',
#  'priest',
#  u'primp',
#  u'vision',
#  'gout',
#  'raged',
#  'notice',
#  'purest',
#  'stannis',
#  'mutton',
#  'jumped',
#  'enjoys',
#  'amory',
#  'spare',
#  'umber',
#  'undermine',
#  'mant',
#  'many',
#  'loudly',
#  u'riddle',
#  'drogo',
#  u'compels',
#  u'twin',
#  'boar',
#  u'considers',
#  'boat',
#  u'stretch',
#  'west',
#  u'expedition',
#  'breath',
#  'combined',
#  'stripped',
#  'coughing',
#  'centerpiece',
#  'observe',
#  u'extant',
#  'former',
#  'wherewithal',
#  u'fin',
#  'straighten',
#  'whatevers',
#  'squeezed',
#  u'situation',
#  'endured',
#  'ive',
#  'thatll',
#  'purse',
#  'shevelathin',
#  'spooked',
#  'burbling',
#  'threatens',
#  'damon',
#  'edged',
#  'sickness',
#  'defy',
#  'disown',
#  'recapture',
#  'polliver',
#  'summer',
#  u'being',
#  'rest',
#  u'overconfident',
#  'afterwards',
#  u'khalar',
#  u'sixteen',
#  'befalling',
#  'overthrow',
#  'haystack',
#  'starving',
#  'around',
#  'dark',
#  'preference',
#  'fringed',
#  'vague',
#  'bravery',
#  u'clan',
#  u'clam',
#  'stranger',
#  'discarded',
#  'superiority',
#  u'claw',
#  'sorcerer',
#  u'kennel',
#  u'clap',
#  'grub',
#  u'lobster',
#  u'divine',
#  'crabber',
#  'dimpled',
#  'refer',
#  u'clarenzo',
#  'averse',
#  'power',
#  'intimate',
#  'hayseed',
#  'leadership',
#  u'stone',
#  'yunkai',
#  'favorite',
#  u'side',
#  u'apostate',
#  u'neighbor',
#  'act',
#  u'mean',
#  'stony',
#  u'widowed',
#  'chivalry',
#  'shapely',
#  'burning',
#  'interruption',
#  u'antidote',
#  'apologize',
#  u'pivot',
#  'trussed',
#  'hey',
#  'hed',
#  u'lhazareen',
#  'mindless',
#  'sealed',
#  u'hen',
#  'survives',
#  'recommends',
#  'complete',
#  'survived',
#  u'whinny',
#  'buying',
#  'handsome',
#  'abused',
#  'pull',
#  u'rush',
#  'rage',
#  'browbeaten',
#  'balons',
#  'dirty',
#  'agree',
#  'darker',
#  u'detailed',
#  'gone',
#  'fright',
#  u'exhausted',
#  'ah',
#  'stealing',
#  'al',
#  'wartime',
#  u'watcher',
#  'behest',
#  u'as',
#  'carved',
#  u'midwife',
#  'laboratory',
#  'ax',
#  u'johnna',
#  'cream',
#  u'ideally',
#  'tight',
#  'httpsubttfreeorg',
#  u'puppy',
#  'disgraceful',
#  u'congress',
#  'waving',
#  u'middling',
#  u'midget',
#  'brotherhood',
#  'tricky',
#  'disdained',
#  'infanticide',
#  'sobbing',
#  u'thorn',
#  'groom',
#  u'mask',
#  u'dyed',
#  u'mast',
#  u'mass',
#  'sawing',
#  u'dyer',
#  'original',
#  'consider',
#  'beware',
#  u'neigh',
#  'welfare',
#  'hunting',
#  'tail',
#  'chewing',
#  'dockworker',
#  'th',
#  u'ti',
#  'smile',
#  u'shipload',
#  'paying',
#  'appointment',
#  'returned',
#  'squiring',
#  'eyrie',
#  'condition',
#  'harrenhal',
#  'overprotective',
#  u'laying',
#  'joined',
#  'underclothes',
#  'large',
#  'sang',
#  'sand',
#  u'adjust',
#  'small',
#  'quicker',
#  u'healed',
#  'past',
#  'podrick',
#  u'pass',
#  'turning',
#  u'investment',
#  'poisonous',
#  'prevailed',
#  'nurse',
#  'full',
#  'escaping',
#  'vomiting',
#  'smartest',
#  'buzzing',
#  'legend',
#  'slynt',
#  'kayla',
#  'experience',
#  'pick',
#  u'action',
#  'murdering',
#  'luck',
#  'smuggle',
#  'gawking',
#  'followed',
#  u'follower',
#  u'indoors',
#  u'captor',
#  'darkens',
#  u'moro',
#  u'gorgeous',
#  u'mord',
#  'restraint',
#  'door',
#  'company',
#  'tested',
#  'doom',
#  'riverbank',
#  'cunning',
#  'keeping',
#  'pleasing',
#  'farted',
#  'thickest',
#  'learn',
#  'knocked',
#  'sunspear',
#  u'seagull',
#  u'male',
#  'beautiful',
#  'brightflame',
#  'accept',
#  'fiercely',
#  'sense',
#  'scar',
#  'dress',
#  'condemn',
#  'information',
#  'impulse',
#  'imminent',
#  u'hugh',
#  'dismissed',
#  u'glowing',
#  'freshly',
#  u'clink',
#  'unattended',
#  'creature',
#  'sprinkle',
#  'intended',
#  'countryside',
#  'disgraced',
#  'sympathize',
#  'zuriff',
#  u'pleaded',
#  'plank',
#  'refuse',
#  'replied',
#  'eddark',
#  u'pant',
#  'reminded',
#  'eddard',
#  'installed',
#  u'paper',
#  u'brim',
#  'smiling',
#  'aemon',
#  'mistreated',
#  u'mummer',
#  'ruining',
#  u'travelling',
#  'ally',
#  'colleague',
#  'lowell',
#  'propose',
#  'martells',
#  u'easterner',
#  u'qyburns',
#  'always',
#  'repayment',
#  'found',
#  'shocking',
#  'begged',
#  u'stevron',
#  'varys',
#  u'measurement',
#  'bluer',
#  'really',
#  'missed',
#  u'research',
#  'hood',
#  'darling',
#  'nastiness']

# %%
keys = model.wv.vocab.keys()[:1000]

# %%
len(keys)
# Out:
# 1000

# %%
model_list = []

for i in model.wv.vocab.keys()[:1000]:
    model_list.append(model.wv[i])

# %%
model_list
# Out:
# [array([-0.2201032 , -0.02837961, -0.02490109, -0.13356975, -0.11383844,
#         -0.08560812, -0.11283692, -0.17773542, -0.0163451 , -0.16739868,
#          0.02727871, -0.10160653,  0.13535702, -0.11560764, -0.00087528,
#          0.17586975,  0.07832502, -0.08430013, -0.11605735, -0.01392592,
#         -0.24020572, -0.16266282,  0.01878661,  0.18701701,  0.16823702,
#         -0.140855  , -0.01697922, -0.09108484, -0.07105353, -0.09729636,
#         -0.28552878,  0.03437837, -0.00653471, -0.10382082,  0.0441023 ,
#         -0.04415965, -0.18583868, -0.0705314 ,  0.07401858,  0.17081675,
#         -0.12037672,  0.00949856, -0.02894573, -0.13325515,  0.12302099,
#         -0.22372763,  0.11746498, -0.00353795, -0.01476935,  0.16778667,
#          0.21529925,  0.0694027 , -0.12880202, -0.05060088, -0.12820126,
#         -0.14918911,  0.0060474 ,  0.05711462, -0.17657067, -0.16329244,
#          0.09818585, -0.08111268,  0.1701913 , -0.14485508,  0.03456515,
#         -0.10599979, -0.03306227,  0.0340928 ,  0.09054012, -0.02598176,
#          0.02001245, -0.13669835,  0.05641529, -0.22952965, -0.05711254,
#         -0.10288958, -0.16767968,  0.07713268,  0.14725173,  0.08101269,
#         -0.06121428, -0.01503089,  0.09219155, -0.00400142, -0.11347001,
#         -0.10191435,  0.00830288,  0.06007345,  0.13997717,  0.13824818,
#          0.05367783,  0.02201632, -0.18634385, -0.14177614, -0.05865874,
#          0.09816483, -0.20817007,  0.00600718, -0.14747705,  0.02282279], dtype=float32),
#          0.03322562,  0.0209996 , -0.13539952, -0.10350679, -0.04579292,
#          0.07113928, -0.16625749,  0.00586936, -0.10808374,  0.014888  ], dtype=float32),
#  array([-0.03132363, -0.0038488 , -0.00882573, -0.01814995, -0.01956821,
#         -0.01427456, -0.01373062, -0.02882054,  0.00039971, -0.02282829,
#          0.00612452, -0.01629854,  0.02130379, -0.02006578, -0.00151901,
#          0.02055537,  0.0067399 , -0.01366385, -0.01818341, -0.00427759,
#         -0.0303246 , -0.01973793, -0.00102683,  0.02581298,  0.02569248,
#         -0.01636002, -0.00567772, -0.01695751, -0.01564322, -0.0172298 ,
#         -0.03841752,  0.0044465 , -0.00164266, -0.01827009,  0.00876806,
#         -0.00084502, -0.03041421, -0.0068494 ,  0.01328998,  0.02772131,
#         -0.01843206,  0.00289601, -0.00122592, -0.02417033,  0.01778794,
#         -0.03524785,  0.01705764,  0.0034769 , -0.00763724,  0.02085481,
#          0.02838863,  0.00457326, -0.01461252, -0.00797327, -0.01540193,
#         -0.0241972 ,  0.00298055,  0.01060717, -0.02268683, -0.01893698,
#          0.01607807, -0.00937725,  0.02314175, -0.02039747,  0.00478233,
#         -0.01727902, -0.00492392,  0.00352611,  0.0144369 , -0.0073785 ,
#          0.00705087, -0.02096831,  0.01264835, -0.03257457, -0.00600984,
#         -0.01827168, -0.02562566,  0.00796044,  0.02607673,  0.01145091,
#         -0.00811165,  0.00093495,  0.01483097, -0.00579752, -0.01122752,
#         -0.01374829, -0.00188804,  0.00305275,  0.01497993,  0.01544487,
#          0.00431906,  0.00622496, -0.02261107, -0.0151714 , -0.00891399,
#          0.01483561, -0.03365059,  0.00489924, -0.02303187,  0.00692213], dtype=float32)]

# %%
type(model_list)
# Out:
# list

# %%
model_vectors = pd.DataFrame(model_list)
model_vectors.shape
# Out:
# (1000, 100)

# %%
model_vectors = model_vectors.reset_index()

# %%
model_vectors['index'] = model.wv.vocab.keys()[:1000]

# %%
model_vectors = model_vectors.set_index('index')

# %%
model_vectors.head()
# Out:
#                 0         1         2         3         4         5   \
# index
# foul     -0.220103 -0.028380 -0.024901 -0.133570 -0.113838 -0.085608
# four     -0.297167 -0.038520 -0.033580 -0.188524 -0.143326 -0.108931
# hanging  -0.149179 -0.024699 -0.018099 -0.091869 -0.070343 -0.059248
# marching -0.276062 -0.028115 -0.030908 -0.167234 -0.137653 -0.104539
# increase -0.053131 -0.002141 -0.009760 -0.034136 -0.026318 -0.019984
#
#                 6         7         8         9     ...           90  \
# index                                               ...
# foul     -0.112837 -0.177735 -0.016345 -0.167399    ...     0.053678
# four     -0.160364 -0.244877 -0.033657 -0.221645    ...     0.072253
# hanging  -0.082069 -0.119663 -0.016709 -0.105277    ...     0.039494
# marching -0.149709 -0.239572 -0.034453 -0.205653    ...     0.068669
# increase -0.031060 -0.051461 -0.008208 -0.041638    ...     0.017360
#
#                 91        92        93        94        95        96  \
# index
# foul      0.022016 -0.186344 -0.141776 -0.058659  0.098165 -0.208170
# four      0.025593 -0.253804 -0.187361 -0.076680  0.135796 -0.287399
# hanging   0.016379 -0.129442 -0.091595 -0.046732  0.070702 -0.147137
# marching  0.030033 -0.231684 -0.180742 -0.081611  0.125562 -0.267287
# increase  0.001552 -0.042716 -0.038436 -0.019355  0.022150 -0.049959
#
#                 97        98        99
# index
# foul      0.006007 -0.147477  0.022823
# four      0.017764 -0.190886  0.025354
# hanging   0.005779 -0.093536  0.008911
# marching  0.007875 -0.178907  0.025474
# increase  0.006524 -0.039858  0.005928
#
# [5 rows x 100 columns]

# %%
model_vectors.index
# Out:
# Index([        u'foul',         u'four',      u'hanging',     u'marching',
#            u'increase', u'midafternoon',     u'mutinied',         u'lord',
#             u'sinking',    u'leisurely',
#        ...
#             u'stevron',        u'varys',  u'measurement',        u'bluer',
#              u'really',       u'missed',     u'research',         u'hood',
#             u'darling',    u'nastiness'],
#       dtype='object', name=u'index', length=1000)

# %%
pca20 = PCA(n_components=20)

pca_results20 = pca20.fit_transform(model_vectors)

# %%
pca_results_20 = pd.DataFrame(pca_results20)

# %%
pca_results_20 = pca_results_20.reset_index()

# %%
pca_results_20['index'] = model.wv.vocab.keys()[:1000]

# %%
pca_results_20 = pca_results_20.set_index('index')

# %%
pca_results_20.head()
# Out:
#                 0         1         2         3         4         5   \
# index
# foul      0.446863 -0.023647 -0.011113 -0.005200  0.002261  0.012376
# four      0.840662 -0.024916 -0.017842  0.007714 -0.018131 -0.002235
# hanging   0.062891 -0.012707 -0.005567  0.001538 -0.005764 -0.000691
# marching  0.749064  0.006683 -0.022743  0.014987 -0.016229 -0.003189
# increase -0.433067 -0.001041  0.005321  0.001381 -0.001274 -0.003111
#
#                 6         7         8         9         10        11  \
# index
# foul     -0.000807 -0.001670 -0.000161 -0.001108 -0.002533 -0.000669
# four     -0.005610  0.008322  0.006826  0.011446 -0.000579 -0.002865
# hanging   0.001232  0.005922 -0.008095 -0.000554 -0.002266  0.001391
# marching -0.003144  0.009422 -0.003990 -0.001316 -0.002512 -0.003785
# increase -0.001158 -0.002485  0.004001 -0.002513 -0.005495  0.002581
#
#                 12        13        14        15        16        17  \
# index
# foul     -0.006948 -0.001957 -0.002941  0.002991  0.005119 -0.001716
# four     -0.005222 -0.000228  0.000757  0.005776  0.000721  0.001320
# hanging   0.001563  0.000171 -0.002395 -0.005128 -0.004143 -0.007017
# marching  0.004086 -0.004461 -0.005145 -0.000205 -0.000590  0.005554
# increase  0.003784  0.002494 -0.002303 -0.004337  0.002833  0.002959
#
#                 18        19
# index
# foul     -0.003890  0.006059
# four     -0.000719 -0.000844
# hanging  -0.005267 -0.001681
# marching -0.002085 -0.008618
# increase -0.000315 -0.001776

# %%
pca_results20.shape
# Out:
# (1000, 20)

# %%
pca_results20
# Out:
# array([[  4.46862782e-01,  -2.36467600e-02,  -1.11131390e-02, ...,
#          -1.71618657e-03,  -3.89016879e-03,   6.05894440e-03],
#        [  8.40662449e-01,  -2.49164583e-02,  -1.78416449e-02, ...,
#           1.32034027e-03,  -7.19364326e-04,  -8.43804778e-04],
#        [  6.28913616e-02,  -1.27065307e-02,  -5.56716986e-03, ...,
#          -7.01675518e-03,  -5.26715607e-03,  -1.68110341e-03],
#        ...,
#        [ -2.67452698e-01,  -9.40722136e-04,   7.96261972e-04, ...,
#           2.86154000e-03,  -7.81439740e-04,  -2.93528924e-03],
#        [  1.63493934e-01,   2.88870355e-03,   9.20812485e-04, ...,
#           2.46782573e-03,  -9.03000458e-03,   3.11360449e-03],
#        [ -5.63901169e-01,   9.76092728e-03,   3.30734609e-03, ...,
#           3.31539009e-03,  -1.43706837e-03,   4.65432043e-03]])

# %%
tsne = TSNE(n_components=2)

tsne_pca_results20 = tsne.fit_transform(pca_results_20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-1d450527d4f9> in <module>()
#       1 tsne = TSNE(n_components=2)
#       2
# ----> 3 tsne_pca_results20 = tsne.fit_transform(pca_results_20)
#
# /Users/zoemarkovits/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in fit_transform(self, X, y)
#     882             Embedding of the training data in low-dimensional space.
#     883         """
# --> 884         embedding = self._fit(X)
#     885         self.embedding_ = embedding
#     886         return self.embedding_
#
# /Users/zoemarkovits/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _fit(self, X, skip_num_points)
#     787                           X_embedded=X_embedded,
#     788                           neighbors=neighbors_nn,
# --> 789                           skip_num_points=skip_num_points)
#     790
#     791     def _tsne(self, P, degrees_of_freedom, n_samples, random_state,
#
# /Users/zoemarkovits/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _tsne(self, P, degrees_of_freedom, n_samples, random_state, X_embedded, neighbors, skip_num_points)
#     856         opt_args['n_iter'] = self.n_iter
#     857         opt_args['it'] = it + 1
# --> 858         params, error, it = _gradient_descent(obj_func, params, **opt_args)
#     859
#     860         if self.verbose:
#
# /Users/zoemarkovits/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _gradient_descent(objective, p0, it, n_iter, objective_error, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, min_error_diff, verbose, args, kwargs)
#     386     for i in range(it, n_iter):
#     387         new_error, grad = objective(p, *args, **kwargs)
# --> 388         grad_norm = linalg.norm(grad)
#     389
#     390         inc = update * grad >= 0.0
#
# /Users/zoemarkovits/anaconda/lib/python2.7/site-packages/scipy/linalg/misc.pyc in norm(a, ord, axis, keepdims)
#     127     """
#     128     # Differs from numpy only in non-finite handling and the use of blas.
# --> 129     a = np.asarray_chkfinite(a)
#     130
#     131     # Only use optimized norms if axis and keepdims are not specified.
#
# /Users/zoemarkovits/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in asarray_chkfinite(a, dtype, order)
#    1213     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#    1214         raise ValueError(
# -> 1215             "array must not contain infs or NaNs")
#    1216     return a
#    1217
#
# ValueError: array must not contain infs or NaNs

# %%
tsne_pca_results_20 = pd.DataFrame(tsne_pca_results20)

# %%
tsne_pca_results_20 = tsne_pca_results_20.reset_index()

# %%
tsne_pca_results_20['index'] = model.wv.vocab.keys()

# %%
tsne_pca_results_20 = tsne_pca_results_20.set_index('index')

# %%
tsne_pca_results_20.shape
# Out:
# (6913, 2)

# %%
tsne_pca_results_20.head(10)
# Out:
#                          0             1
# index
# foul         -3.625123e+16 -2.161681e+16
# four         -9.084463e+16  8.768620e+16
# hanging       8.068193e+14  1.081339e+15
# marching     -5.278399e+16  2.309692e+16
# increase      5.925796e+16  7.973523e+15
# midafternoon  1.475672e+16  1.842794e+16
# mutinied      1.402947e+16  1.219439e+16
# lord         -4.730225e+16  8.740347e+16
# sinking       7.180056e+17  3.342843e+17
# leisurely    -7.647436e+16 -1.485316e+17

# %%
tsne_pca_results_20['index_name'] = tsne_pca_results_20.index

# %%
tsne_pca_results_20.columns
# Out:
# Index([0, 1, u'index_name'], dtype='object')

# %%
tsne_pca_results_20.head()
# Out:
#                      0             1 index_name
# index
# foul     -3.625123e+16 -2.161681e+16       foul
# four     -9.084463e+16  8.768620e+16       four
# hanging   8.068193e+14  1.081339e+15    hanging
# marching -5.278399e+16  2.309692e+16   marching
# increase  5.925796e+16  7.973523e+15   increase

# %%
tsne_pca_results_20 = tsne_pca_results_20[[u'index_name', 0, 1]]

# %%
tsne_pca_results_20.head()
# Out:
#          index_name             0             1
# index
# foul           foul -3.625123e+16 -2.161681e+16
# four           four -9.084463e+16  8.768620e+16
# hanging     hanging  8.068193e+14  1.081339e+15
# marching   marching -5.278399e+16  2.309692e+16
# increase   increase  5.925796e+16  7.973523e+15

# %%
tsne_pca_results_20.to_csv('tsne.csv', index=False)

# %%
tsne_pca_results_20.shape
# Out:
# (6913, 3)

# %%
tsne_pca_results20
# Out:
# array([[ -3.62512349e+16,  -2.16168129e+16],
#        [ -9.08446308e+16,   8.76862005e+16],
#        [  8.06819259e+14,   1.08133874e+15],
#        ...,
#        [ -6.37758208e+16,   3.80275648e+16],
#        [  2.37607896e+17,  -1.83630568e+17],
#        [ -4.70821141e+16,   3.05877748e+16]])

# %%
tsne_pca_results_20.index
# Out:
# Index([        u'foul',         u'four',      u'hanging',     u'marching',
#            u'increase', u'midafternoon',     u'mutinied',         u'lord',
#             u'sinking',    u'leisurely',
#        ...
#               u'lance',       u'risked',       u'squeak',       u'oberyn',
#               u'cliff',    u'auxiliary',        u'wylla',    u'firestorm',
#          u'baratheons',  u'furthermore'],
#       dtype='object', name=u'index', length=6913)

# %%
import numpy as Math
import pylab as Plot
import matplotlib.pyplot as plt

rows = tsne_pca_results_20.index
# %matplotlib notebook
plt.ion()

Plot.figure(figsize=(20, 10))
max_x = Math.amax(tsne_pca_results20, axis=0)[0]
max_y = Math.amax(tsne_pca_results20, axis=0)[1]
#Plot.xlim((-.125e+20,.25e+20))
#Plot.ylim((-.125+e20,.1e20))

Plot.scatter(tsne_pca_results20[:, 0], tsne_pca_results20[:, 1], 20);

for row_id in range(0, len(rows)):
    target_word = rows[row_id]
    x = tsne_pca_results20[row_id, 0]
    y = tsne_pca_results20[row_id, 1]
    Plot.annotate(target_word, (x,y))

Plot.savefig("tsne_200.png");
# Out:
# <img src="data:image/png;base64,..." width="1440">
