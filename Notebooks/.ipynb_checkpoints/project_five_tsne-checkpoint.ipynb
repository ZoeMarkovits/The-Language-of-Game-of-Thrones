# %% [markdown]
# # Project Five
# # Game of Thrones - TSNE

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from textblob import TextBlob
from nltk.corpus import stopwords
import spacy
from nltk import Tree
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph
from nltk.parse import ProjectiveDependencyParser
from nltk.parse import NonprojectiveDependencyParser
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import gensim
from gensim.models import Word2Vec
from nltk.tag import pos_tag
import re
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline
# Out:
# Using Theano backend.

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import scale

from sklearn.datasets import fetch_mldata
from sklearn.cluster import KMeans
from sklearn.utils import shuffle

# %%
import pickle

with open('/Users/zoemarkovits/Metis/project_five_got/total_corpus_texts2.pkl', 'rb') as f:
    total_corpus_texts = pickle.load(f)

# %%
total_corpus_texts
# Out:
# [['well', 'struck'],
#  ['well', 'struck', 'dog'],
#  ['like'],
#  ['well', 'struck', 'grace'],
#  ['already', 'said', 'well', 'struck'],
#  ['yes', 'grace'],
#  ['ser', 'dontos', 'red', 'house', 'hollard'],
#  ['ser', 'dontos', 'red', 'house', 'hollard'],
#  [],
#  ['sorry', 'grace'],
#  ['deepest', u'apology'],
#  ['drunk'],
#  [],
#  ['uh'],
#  ['grace'],
#  ['two', u'cup', 'wine'],
#  ['two', u'cup'],
#  ['thats', 'much'],
#  ['please', 'another', 'cup'],
#  ['sure', 'grace'],
#  ['two'],
#  ['much', 'like'],
#  ['would', 'honored', 'grace'],
#  ['ser', 'meryn', 'help', 'ser', 'dontos', 'celebrate', 'name', 'day'],
#  ['see', u'drink', 'fill'],
#  ['cant'],
#  ['say'],
#  ['say', 'cant'],
#  ['meant', 'would', 'bad', 'luck', 'kill', 'man', 'name', 'day'],
#  ['kind', 'stupid', u'peasant', 'superstition', 'take', 'away'],
#  ['ill', 'killed', 'tomorrow', 'fool'],
#  [],
#  ['fool', 'youre', 'clever', 'see'],
#  ['hell', 'make', 'much', 'better', 'fool', 'knight'],
#  ['doesnt', 'deserve', 'mercy', 'quick', 'death'],
#  ['hear', 'lady', 'ser', 'dontos'],
#  ['day', 'youll', 'new', 'fool'],
#  ['thank', 'grace'],
#  ['lady', 'thank'],
#  ['looked', 'battlefield'],
#  ['nowhere', 'found'],
#  ['ive', 'ruling', u'kingdom'],
#  ['fine', 'job', 'youve', 'done'],
#  ['look'],
#  ['beautiful', 'ever'],
#  [],
#  ['youre', 'going', 'bigger', 'hound', 'much', 'better', 'looking'],
#  ['one', 'doesnt', 'like'],
#  ['cant', 'imagine'],
#  ['heard', 'dead'],
#  ['im', 'glad', 'youre', 'dead'],
#  ['dear'],
#  ['death', 'boring', 'especially', 'much', 'excitement', 'world'],
#  ['lady', 'im', 'sorry', 'loss'],
#  ['loss'],
#  ['father', 'confessed', 'traitor'],
#  ['still', 'father'],
#  ['surely', 'recently', 'lost', 'beloved', 'father', 'sympathize'],
#  ['father', 'traitor'],
#  ['mother', 'brother', u'traitor'],
#  ['loyal', 'beloved', 'joffrey'],
#  ['course'],
#  ['well', 'enjoy', 'name', 'day', 'grace'],
#  ['wish', 'could', 'stay', 'celebrate', 'work', 'done'],
#  ['work'],
#  [],
#  ['raven', 'arrived', 'citadel', 'morning', 'grace'],
#  ['conclave',
#   'met',
#   'considered',
#   u'report',
#   'maesters',
#   'seven',
#   u'kingdom',
#   'done',
#   'last'],
#  ['longest', 'summer', 'living', 'memory'],
#  [u'peasant',
#   'say',
#   'long',
#   'summer',
#   u'mean',
#   u'last',
#   'longer',
#   'well',
#   'fewer',
#   u'peasant'],
#  [u'city', 'drowning', u'refugee', 'grace', 'fleeing', 'war'],
#  ['nowhere', 'house'],
#  ['winter', 'coming', 'itll', 'get', 'worse'],
#  ['command', 'city', 'watch', 'lord', 'slynt'],
#  ['lord', 'command'],
#  ['owe', 'title', u'land', 'generosity', 'grace'],
#  ['job'],
#  ['shut', u'gate', u'peasant'],
#  ['belong', 'field', 'capital'],
#  ['yes', 'grace'],
#  ['dont', 'get'],
#  ['ravishing', 'ever', 'big', 'sister'],
#  ['war', 'agrees'],
#  ['forgive', 'interruption'],
#  ['carry'],
#  [],
#  ['ah', 'remarkable', 'journey'],
#  ['pissed',
#   'edge',
#   'wall',
#   'fought',
#   'hill',
#   u'tribe',
#   'many',
#   u'adventure',
#   'much',
#   'thankful'],
#  [],
#  ['small', 'council'],
#  ['yes'],
#  ['well',
#   'believe',
#   'hand',
#   'king',
#   'welcome',
#   'small',
#   'council',
#   u'meeting'],
#  ['father', 'hand', 'king'],
#  ['yes', 'absence', 'serve', 'hand', 'stead', u'fight'],
#  [],
#  [],
#  ['would', 'like', 'know', 'tricked', 'father'],
#  ['capable', 'tricking', 'father', 'id', 'emperor', 'world'],
#  ['brought'],
#  ['ive', 'done', 'nothing'],
#  ['quite', 'right', 'nothing', 'son', 'called', 'ned', 'starks', 'head'],
#  ['entire', 'north', 'risen', u'u'],
#  ['tried', 'stop'],
#  [],
#  ['failed'],
#  ['bit', 'theater', 'haunt', 'family', 'generation'],
#  ['robb', 'stark', 'child'],
#  [u'who', 'every', 'battle', u'he', 'fought'],
#  ['understand', 'losing', 'war'],
#  ['know', 'warfare'],
#  ['nothing'],
#  ['know', 'people'],
#  ['know', u'enemy', 'hate', 'almost', 'much', 'hate', u'u'],
#  ['joffrey', 'king'],
#  ['joffrey', 'king'],
#  ['advise'],
#  ['im', 'advise'],
#  ['king', 'listens', 'say', 'king', 'might', 'get', 'uncle', 'jaime', 'back'],
#  [],
#  ['love', u'child'],
#  ['one', 'redeeming', 'quality'],
#  [u'cheekbone'],
#  ['starks', 'love', u'child', 'well'],
#  ['two'],
#  ['one'],
#  ['one'],
#  ['arya', 'little', 'animal', 'disappeared'],
#  ['disappeared'],
#  ['puff', 'smoke'],
#  ['three', 'starks', 'trade'],
#  ['chopped', u'one', 'head', 'let', 'another', 'escape'],
#  ['father', 'furious'],
#  ['must', 'odd', 'disappointing', 'child'],
#  ['lord', 'may', 'old', u'god', 'watch', 'brother', 'northern', u'son'],
#  [u'wall', 'holdfast', 'stand', 'winter'],
#  [u'stone',
#   'last',
#   'mortared',
#   'time',
#   'king',
#   u'aery',
#   'im',
#   'afraid',
#   u'mason',
#   'today',
#   'fit',
#   'carry',
#   u'father',
#   u'hammer'],
#  ['boy',
#   'remember',
#   'seeing',
#   'put',
#   'new',
#   'tower',
#   'torrhens',
#   'square',
#   'summer'],
#  ['men', 'worked', 'back'],
#  ['today', 'holdfast', u'look', 'like', 'built', 'drunk', u'child'],
#  ['night', 'hear', 'wind', 'howling', u'gap'],
#  [u'god', 'forbid', u'rain'],
#  ['might', 'well', 'sleep', 'beneath', 'waterfall'],
#  ['maintenance', 'holdfast', 'generally', u'fall', 'lord', 'holdfast'],
#  ['generally',
#   'yes',
#   'ive',
#   'sent',
#   'young',
#   'men',
#   'fight',
#   'robb',
#   'starks',
#   'war'],
#  ['king', 'robb'],
#  ['war'],
#  ['didnt', 'choose'],
#  ['maybe', 'lord', 'called', u'banner', 'took', 'men'],
#  ['joffrey', 'killed', 'father', 'liege', 'lord'],
#  ['remember', u'vow', 'ser'],
#  ['course', 'remember'],
#  ['spare', 'four', u'mason', 'week', 'lord'],
#  ['sufficient', 'repair', u'wall'],
#  ['believe'],
#  ['didnt', 'want', 'day'],
#  ['didnt', 'like', 'way', 'talking', 'robb'],
#  ['listening',
#   'people',
#   'youd',
#   'rather',
#   'listen',
#   'one',
#   u'responsibility',
#   'lord',
#   'winterfell'],
#  ['lord', 'portan'],
#  ['lord', 'may', 'old', u'god', 'watch', 'brother', 'northern', u'son'],
#  ['boil', 'hour', 'drink', 'tea'],
#  [u'make', 'pain', 'go', 'away'],
#  ['dont', 'pain'],
#  ['lucky'],
#  ['way'],
#  ['youve', u'dream'],
#  ['dont', 'dream'],
#  ['everyone', u'dream'],
#  ['dont'],
#  ['heard', 'men', 'talking', 'comet'],
#  ['say', 'omen'],
#  ['say', u'mean', 'robb', 'win', 'great', 'victory', 'south'],
#  [],
#  ['heard', u'fool', 'say', 'lannister', 'red'],
#  [u'mean', 'lannisters', 'rule', 'seven', u'kingdom', 'long'],
#  ['heard', 'stableboy', 'say', 'color', 'blood', 'mark', 'death', 'father'],
#  [u'star', 'dont', 'fall', 'men'],
#  ['red', 'comet', u'mean', 'one', 'thing', 'boy', u'dragon'],
#  [u'dragon', 'dead'],
#  ['theyve', 'dead', u'century'],
#  ['mmm'],
#  ['mmm'],
#  ['mmm'],
#  ['brother', 'say', 'khaleesi'],
#  ['said', 'ate', 'meat'],
#  ['didnt', 'tell', 'kind', 'meat'],
#  ['brother', 'didnt', 'know', 'anything', u'dragon'],
#  ['didnt', 'know', 'anything', 'anything'],
#  ['eh'],
#  ['drogos', 'first', 'gift'],
#  ['remember'],
#  ['promised', 'protect'],
#  ['promised', u'enemy', 'would', 'die', 'screaming'],
#  ['make', 'starvation', 'scream'],
#  ['trick', 'never', 'learned', 'im', 'afraid'],
#  ['ever', 'end'],
#  ['farther', 'east', 'ive', 'ever'],
#  ['yes', 'khaleesi', 'everything', u'end', 'even', 'red', 'waste'],
#  ['youre', 'sure', u'there', 'way'],
#  ['go',
#   'south',
#   'land',
#   'lazarheen',
#   'lamb',
#   'men',
#   'kill',
#   u'u',
#   'take',
#   u'dragon'],
#  ['go',
#   'west',
#   'dothraki',
#   'sea',
#   'first',
#   'khalasar',
#   'meet',
#   'kill',
#   u'u',
#   'take',
#   u'dragon'],
#  ['one', 'take', u'dragon'],
#  ['weak', 'fight', 'people'],
#  ['must', 'strength'],
#  ['mine'],
#  ['rakharo', 'never'],
#  ['bad', 'time', 'start'],
#  ['rough', 'time'],
#  [u'nothing', 'killed', 'yet'],
#  [u'as', 'killed', 'sledge'],
#  ['offered', 'ride'],
#  ['wanted', 'shut', 'damn', u'blister'],
#  ['born', 'place', 'like'],
#  ['later', 'fell', 'hard', u'time'],
#  [u'girl'],
#  ['crasters', u'daughter'],
#  ['havent', 'seen', 'girl', 'six', u'month'],
#  ['id', 'keep', 'seeing'],
#  ['dont', 'like', 'people', 'messing', u'daughter'],
#  ['dont', 'like', 'people', 'messing', u'wife'],
#  ['marries', u'daughter', 'give', u'daughter'],
#  [u'go'],
#  ['thats', 'foul'],
#  ['beyond', 'foul'],
#  ['wildlings', 'hundred', u'league', 'disappeared'],
#  ['crasters', 'still'],
#  ['must', 'something', 'right'],
#  ['happens', u'boy'],
#  ['hmm'],
#  ['marries', u'daughter'],
#  [u'son'],
#  ['said', 'planned', 'stop', 'way', 'frostfangs'],
#  ['people', 'make', u'sort', u'plan'],
#  ['havent', 'seen', 'benjen', 'stark', 'three', u'year'],
#  ['havent', 'missed'],
#  ['always', 'treated', 'like', 'scum'],
#  ['havent', 'good', 'wine', 'long', 'time'],
#  [u'southerner', 'make', 'good', 'wine', 'ill', 'give'],
#  [u'southerner'],
#  [u'who', 'little', 'girl'],
#  ['youre', 'prettier', 'half', u'daughter'],
#  ['got', 'nice', 'wet', 'twat', u'leg'],
#  ['whats', 'name'],
#  ['jon', 'snow'],
#  ['snow', 'eh'],
#  ['listen', 'bastard'],
#  ['lot', 'south', 'wall', 'youre', u'southerner'],
#  ['youre', 'north', 'real', 'north'],
#  ['lad', 'meant', 'harm'],
#  ['catch',
#   'pretty',
#   'little',
#   'bastard',
#   'talking',
#   u'daughter',
#   'one',
#   'talk',
#   u'daughter',
#   'word'],
#  ['sit', 'shut', 'mouth'],
#  ['bring', 'good', 'wine'],
#  [],
#  ['passed', 'six', u'village', 'way'],
#  ['six', 'abandoned'],
#  ['wildlings', 'gone'],
#  ['could', 'tell', 'im', 'thirsty'],
#  [u'there', 'barrel', 'dornish', 'wine', 'sledge'],
#  ['bring'],
#  ['yes', 'commander'],
#  ['want', 'know', 'theyve', 'gone'],
#  ['north', 'join', 'mance', 'rayder', 'old', 'friend'],
#  [u'he', 'friend', 'mine'],
#  ['broke', u'vow', 'betrayed', u'brother'],
#  ['oh', 'aye'],
#  ['poor', 'black', 'crow'],
#  [u'he', 'king', 'beyond', 'wall'],
#  [u'he', 'calling', u'year'],
#  ['whats', 'king'],
#  ['frozen', 'lake', 'somewhere'],
#  ['thats', 'good', 'looking', 'axe'],
#  ['fresh', 'forged'],
#  ['give'],
#  ['youll', 'another', 'one', 'made', 'castle', 'black'],
#  [],
#  ['oh', 'thats', 'lovely', 'steel'],
#  ['want', 'know', 'mance', 'rayder'],
#  ['gathering', 'army'],
#  ['hear', u'he', 'already', 'got', 'men', 'southern', u'king'],
#  ['plan', 'marching', 'army'],
#  ['youre', 'way', 'north', u'there', 'one', 'direction', 'go'],
#  ['bad', u'time', 'living', 'alone', 'wild'],
#  ['cold', u'wind', 'rising'],
#  ['let', 'come'],
#  [u'root', 'sunk', 'deep'],
#  ['wife', 'tell', 'lord', 'crow', 'content'],
#  ['place'],
#  ['husband', u'keep', u'u', 'safe'],
#  ['better', 'live', 'free', 'die', 'slave'],
#  ['dont',
#   'make',
#   'jealous',
#   'old',
#   'man',
#   'see',
#   'young',
#   u'wife',
#   'one',
#   'warm',
#   'bed'],
#  ['chose', 'different', u'path'],
#  ['oh', 'aye', 'chose', 'path', 'one', u'boy'],
#  ['youll', 'wanting', 'sleep', 'beneath', 'roof', 'suppose', 'eat', u'pig'],
#  ['roof', 'would', 'welcome'],
#  ['hard', 'riding'],
#  ['weve', 'brought', 'food', 'good', 'steel'],
#  ['man', u'lay', 'hand', 'one', u'wife', 'loses', 'hand'],
#  ['see', 'one', 'staring', 'long', 'might', 'gouge', u'eye'],
#  ['roof', u'rule'],
#  [],
#  [],
#  ['lord', 'commander'],
#  [],
#  ['jon', 'snow'],
#  [],
#  ['steward'],
#  ['want', 'lead', 'one', 'day'],
#  ['learn', 'follow'],
#  ['lord', 'light', 'come', u'u', 'darkness'],
#  ['offer', 'false', u'god'],
#  ['take', 'cast', 'light', 'upon', u'u', 'night', 'dark', 'full', u'terror'],
#  ['night', 'dark', 'full', u'terror'],
#  ['long', 'summer', 'darkness', 'fall', 'heavy', 'world'],
#  [u'star', 'bleed'],
#  ['need', 'stop'],
#  ['cold', 'breath', 'winter', 'freeze', u'sea'],
#  ['dead', 'shall', 'rise', 'north'],
#  ['men', 'named', 'light', 'seven'],
#  ['treat', u'god', u'father'],
#  ['eager', 'spit', u'ancestor'],
#  ['smell', 'fear', 'fear', 'piss', 'old', u'bone'],
#  ['want', 'stop'],
#  ['stop'],
#  ['ancient',
#   u'book',
#   'written',
#   'warrior',
#   'draw',
#   'burning',
#   'sword',
#   'fire'],
#  ['sword', 'shall', 'lightbringer'],
#  ['stannis', 'baratheon', 'warrior', 'light', 'sword', 'awaits'],
#  ['lord', 'cast', 'light', 'upon', u'u'],
#  ['night', 'dark', 'full', u'terror'],
#  ['night', 'dark', 'full', 'terror'],
#  ['woman', 'lead', 'war', 'cannot', 'win'],
#  ['stannis', 'king'],
#  ['follow', u'lead', 'even', 'dont', 'like', 'path'],
#  ['king'],
#  ['since',
#   'boar',
#   'killed',
#   'brother',
#   'every',
#   'lord',
#   u'want',
#   'coronation'],
#  ['dont', 'serve', 'others'],
#  ['serve', 'stannis'],
#  ['loyal', 'service', u'mean', 'telling', 'hard', u'truth'],
#  [u'he', 'surrounded', u'fool', u'fanatic', u'trust', 'davos'],
#  ['tell', 'truth', 'whats', 'truth'],
#  ['declare',
#   'upon',
#   'honor',
#   'house',
#   'beloved',
#   'brother',
#   'robert',
#   'wasnt',
#   'beloved',
#   'brother'],
#  ['didnt', 'love'],
#  ['didnt', 'love'],
#  ['harmless', 'courtesy', 'grace'],
#  ['lie'],
#  ['take'],
#  ['brother',
#   'robert',
#   'left',
#   'trueborn',
#   u'heir',
#   'boy',
#   'joffrey',
#   'boy',
#   'tommen',
#   'girl',
#   'myrcella',
#   'born',
#   'incest',
#   'cersei',
#   'lannister',
#   'brother',
#   'jaime',
#   'lannister'],
#  ['right', 'birth', 'jaime', 'lannister', 'kingslayer'],
#  ['call'],
#  ['brother', 'jaime', 'lannister', 'kingslayer'],
#  ['right',
#   'birth',
#   'blood',
#   'day',
#   'lay',
#   'claim',
#   'make',
#   'ser',
#   'jaime',
#   'lannister',
#   'kingslayer'],
#  ['whatever', 'else', u'man', 'still', 'knight'],
#  ['ser', 'jaime', 'lannister', 'kingslayer'],
#  ['right',
#   'birth',
#   'blood',
#   'day',
#   'lay',
#   'claim',
#   'iron',
#   'throne',
#   'westeros'],
#  ['let', 'true', 'men', 'declare', 'loyalty'],
#  ['eddard', 'stark', 'learned', 'truth', 'told'],
#  ['ill', 'make', 'mistake'],
#  ['send', u'copy', 'letter', 'every', 'corner', 'realm', 'arbor', 'wall'],
#  ['time', 'come', 'choose'],
#  ['let', 'man', 'claim', 'ignorance', 'excuse'],
#  ['gracethe', 'lannisters', 'true', 'enemy'],
#  ['time',
#   'could',
#   'make',
#   'peace',
#   'brother',
#   'ill',
#   'make',
#   'peace',
#   'renly',
#   u'call',
#   'king'],
#  ['well', 'many', 'already', 'declared', 'mace', 'tyrell', 'randyll', 'tarly'],
#  ['stannis', 'need', 'beg', 'lord', 'lord', 'support'],
#  ['lord', 'light', u'stand', 'behind'],
#  ['many', u'ship', 'lord', 'light', 'got', 'fleet'],
#  ['need', u'ship'],
#  ['im', 'sure', 'doesnt', 'going', 'war'],
#  ['renly', 'grace', 'join', u'force', 'robb', 'stark'],
#  ['would', 'steal', 'northern', 'half', 'kingdom'],
#  ['ive',
#   'always',
#   'served',
#   u'thief',
#   'according',
#   u'dessert',
#   'well',
#   'know',
#   'ser',
#   'davos'],
#  ['joffrey', 'renly', 'robb', 'stark', 'theyre', u'thief'],
#  ['theyll', 'bend', 'knee', 'ill', 'destroy'],
#  ['owe', 'apology', 'king'],
#  ['duty', 'serve'],
#  ['chosen', 'new', 'god', 'old', u'god'],
#  ['may', 'lord', 'light', 'watch', u'u'],
#  ['shall', 'drink', 'together'],
#  ['dont'],
#  ['cup', 'wine', 'honor', 'one', 'true', 'god'],
#  ['night', 'dark', 'full', u'terror', 'old', 'man', 'fire', u'burn', 'away'],
#  ['grace'],
#  ['king', 'north'],
#  ['keep',
#   'expecting',
#   'leave',
#   'one',
#   'castle',
#   'another',
#   'safekeeping',
#   'drag',
#   'along',
#   'camp',
#   'camp'],
#  ['grown', 'fond', 'stark'],
#  [],
#  ['ive', 'never', 'seen', 'girl'],
#  ['left',
#   'one',
#   'bannermen',
#   'father',
#   'would',
#   'know',
#   'within',
#   'fortnight',
#   'bannerman',
#   'would',
#   'receive',
#   'raven',
#   'message',
#   'release',
#   'son',
#   'youll',
#   'rich',
#   'beyond',
#   u'dream'],
#  ['refuse', 'house', 'destroyed', 'root', 'stem'],
#  ['dont', 'trust', 'loyalty', 'men', 'following', 'battle'],
#  ['oh', 'trust', 'life'],
#  ['smart', 'boy'],
#  ['whats', 'wrong'],
#  ['dont', 'like', 'called', 'boy'],
#  ['insulted'],
#  ['insult', 'kingslayer'],
#  ['youve', 'defeated', 'boy'],
#  ['youre', 'held', 'captive', 'boy'],
#  ['perhaps', 'youll', 'killed', 'boy'],
#  ['stannis', 'baratheon', 'sent', u'raven', 'high', u'lord', 'westeros'],
#  ['king',
#   'joffrey',
#   'baratheon',
#   'neither',
#   'true',
#   'king',
#   'true',
#   'baratheon'],
#  [u'he', 'bastard', 'son'],
#  ['thats', 'true', 'stannis', 'rightful', 'king'],
#  ['convenient'],
#  ['father', 'learned', 'truth'],
#  ['thats', 'executed'],
#  ['prisoner', 'ned', 'stark', 'lost', 'head'],
#  ['son', 'killed', 'world', 'wouldnt', 'learn', 'fathered'],
#  ['pushed', 'brother', 'window', 'saw', 'queen'],
#  ['proof'],
#  ['want', 'trade', 'gossip', 'like', 'couple', u'fishwife'],
#  ['im', 'sending', 'one', u'cousin', u'king', 'landing', 'peace', u'term'],
#  ['think', u'father', 'going', 'negotiate'],
#  ['dont', 'know', 'well'],
#  [u'he', 'starting', 'know'],
#  ['three', u'victory', 'dont', 'make', 'conqueror'],
#  ['better', 'three', u'defeat'],
#  ['city', u'stink', 'like', 'dead', u'body'],
#  ['bit', 'corpsey', 'yes'],
#  ['shit'],
#  ['thought', 'wanted', 'come'],
#  ['love'],
#  ['love', 'smell', 'dead', u'body', 'shit'],
#  ['cum', 'garlic', 'rum'],
#  ['smell', 'cum', 'balcony'],
#  ['love', 'stink'],
#  ['love', 'noise'],
#  [u'city', 'make', 'want', 'fuck'],
#  ['country'],
#  ['belong'],
#  ['yes', 'well', 'need', 'careful'],
#  ['one', 'know', 'youre'],
#  ['one', 'know'],
#  ['cant', 'trust', 'anyone', u'king', 'landing'],
#  ['theyre',
#   u'liar',
#   'good',
#   u'liar',
#   'bad',
#   u'liar',
#   'one',
#   'two',
#   'great',
#   u'liar'],
#  [],
#  [],
#  ['im'],
#  ['im', 'slave', 'truth'],
#  ['truth'],
#  ['biggest', 'little', 'liar', 'ever', 'met'],
#  ['think', 'little'],
#  ['im', 'crushed', 'beneath', 'weight', 'truth'],
#  ['oh'],
#  ['ned', 'stark', 'actually', 'slept'],
#  ['poor', 'man', 'didnt', 'suffer', 'enough'],
#  ['one', 'many', u'change', 'well', 'make', 'around'],
#  ['lord', 'baelish'],
#  ['grace'],
#  ['wonder', 'might', 'ask', 'favor'],
#  ['course', 'grace'],
#  ['ned', 'starks', 'youngest', 'daughter', 'arya', 'cant', 'seem', 'locate'],
#  ['shes',
#   'escaped',
#   'capital',
#   'winterfell',
#   'seems',
#   'logical',
#   'destination'],
#  ['yet', u'friend', 'north', 'report', 'sign'],
#  ['curious'],
#  ['choose', 'negotiate', 'starks', 'girl', 'value'],
#  ['whoever', u'find', 'well', 'know', 'say', 'lannisters', u'debt'],
#  ['well', 'could', 'ask', 'varys'],
#  ['hell', 'answer'],
#  ['whether', 'believe', 'always', 'hard', 'time', 'trusting', u'eunuch'],
#  [u'know', 'want'],
#  ['mockingbird'],
#  ['created', 'sigil', 'didnt'],
#  ['yes'],
#  ['appropriate', 'self', 'made', 'man', 'many', u'song', 'sing'],
#  ['im', 'glad', 'like'],
#  ['people', 'fortunate', 'enough', 'born', 'right', 'family'],
#  ['others', 'find', 'way'],
#  ['heard',
#   'song',
#   'boy',
#   'modest',
#   u'mean',
#   'found',
#   'way',
#   'home',
#   'prominent',
#   'family'],
#  ['loved', 'eldest', 'daughter'],
#  ['sadly', u'eye', 'another'],
#  [u'boy', u'girl', 'live', 'home', 'awkward', u'situation', 'arise'],
#  ['sometimes',
#   'ive',
#   'heard',
#   'even',
#   u'brother',
#   u'sister',
#   'develop',
#   'certain',
#   u'affection'],
#  [u'affection',
#   'become',
#   'common',
#   'knowledge',
#   'well',
#   'awkward',
#   'situation',
#   'indeed',
#   'especially',
#   'prominent',
#   'family'],
#  ['prominent',
#   u'family',
#   'often',
#   'forget',
#   'simple',
#   'truth',
#   'ive',
#   'found'],
#  ['truth'],
#  ['knowledge', 'power'],
#  ['seize'],
#  ['cut', 'throat'],
#  ['stop'],
#  ['wait'],
#  ['ive', 'changed', 'mind'],
#  ['let', 'go'],
#  ['step', 'back', 'three', u'pace'],
#  ['turn', 'around'],
#  ['close', u'eye'],
#  ['power', 'power'],
#  ['see', 'take', 'time', 'away', u'coin', u'whore', 'locate', 'stark', 'girl'],
#  ['would', 'much', 'appreciate'],
#  ['youre', 'ser', 'alton', 'lannister'],
#  ['grace'],
#  ['offer', u'cousin', 'peace', 'meet', u'term'],
#  ['first', 'family', 'must', 'release', u'sister'],
#  ['second',
#   u'father',
#   u'bone',
#   'must',
#   'returned',
#   u'u',
#   'may',
#   'rest',
#   'beside',
#   'brother',
#   'sister',
#   u'crypt',
#   'beneath',
#   'winterfell'],
#  ['remains', 'died', 'service', 'must', 'also', 'returned'],
#  [u'family', 'honor', 'proper', u'funeral'],
#  ['honorable', 'request', 'grace'],
#  ['third',
#   'joffrey',
#   'queen',
#   'regent',
#   'must',
#   'renounce',
#   'claim',
#   'dominion',
#   'north'],
#  ['time', 'till', 'end', 'time', 'free', 'independent', 'kingdom'],
#  ['king', 'north'],
#  ['king', 'north'],
#  ['neither', 'joffrey', 'men', 'shall', 'set', 'foot', u'land'],
#  [u'disregard',
#   'command',
#   'shall',
#   'suffer',
#   'fate',
#   'father',
#   'dont',
#   'need',
#   'servant',
#   'beheading'],
#  ['grace', u'term'],
#  ['queen', 'regent', 'son', 'meet', 'ill', 'give', 'peace'],
#  ['litter', 'south', 'lannister', 'dead'],
#  ['king', 'joffrey', 'baratheon', 'grace'],
#  ['oh'],
#  ['youll', 'ride', 'daybreak', 'ser', 'alton'],
#  ['tonight'],
#  ['word', 'grace'],
#  ['dont', 'call', 'grace', u'one', 'around'],
#  ['bad', 'get', 'used'],
#  ['im', 'glad', u'someone', 'gotten', 'used'],
#  ['lannisters', 'going', 'reject', u'term', 'know'],
#  ['course'],
#  ['fight',
#   u'field',
#   'long',
#   'like',
#   'wont',
#   'beat',
#   'take',
#   u'king',
#   'landing'],
#  ['cant', 'take', u'king', 'landing', 'without', u'ship'],
#  ['father', u'ship', 'men', 'know', 'sail'],
#  ['men', 'fought', 'father'],
#  ['men', 'fought', 'king', 'robert', 'free', 'yoke', 'south', 'like', 'youre'],
#  ['im', 'living', 'son'],
#  ['hell', 'listen'],
#  ['know'],
#  ['im', 'stark'],
#  ['know'],
#  ['father', 'raised', 'honorable', 'man'],
#  ['avenge', 'together'],
#  ['dont', 'want', 'balon', 'greyjoy', 'ally'],
#  ['need', u'ship'],
#  ['say'],
#  ['say', 'million', u'rat', 'live', u'sewer', u'king', 'landing'],
#  ['shall', 'rally', 'fight', u'u'],
#  ['understand', 'dont', 'trust', 'lord', 'greyjoy'],
#  ['dont', 'trust', 'lord', 'greyjoy', 'trustworthy'],
#  ['father', 'go', 'war', 'end', 'rebellion'],
#  ['yes'],
#  ['im', 'one', 'rebelling', 'throne'],
#  ['father'],
#  ['married', 'one', 'rebel', 'mothered', 'another'],
#  ['mothered', u'rebel', 'fact', 'seem', 'forgotten'],
#  ['trade', 'kingslayer', 'two', u'girl', 'bannermen', 'string', u'foot'],
#  ['want', 'leave', 'sansa', u'queen', u'hand'],
#  ['arya', 'havent', 'heard', 'word', 'arya'],
#  ['fighting'],
#  ['complicated'],
#  ['know'],
#  ['time', 'go', 'home'],
#  ['havent', 'seen', 'bran', 'rickon', u'month'],
#  ['cant', 'go', 'winterfell'],
#  ['beg', 'pardon'],
#  ['ill',
#   'send',
#   'rodrik',
#   'watch',
#   u'boy',
#   'tomorrow',
#   'youll',
#   'ride',
#   'south',
#   'stormlands'],
#  ['name', u'god', 'need', 'negotiate', 'renly', 'baratheon'],
#  [u'he', 'rallied', 'army'],
#  ['know'],
#  ['know', 'family'],
#  ['havent', 'seen', 'renly', 'baratheon', 'since', 'boy'],
#  ['hundred', u'lord', u'lord', 'trust'],
#  ['renly', u'side', u'u', 'well', 'outnumber', 'two', 'one'],
#  ['feel', u'jaw', 'beginning', 'shut', 'theyll', 'sue', 'peace'],
#  ['well', 'get', u'girl', 'back'],
#  ['well', 'go', 'home', 'good'],
#  ['ride', 'first', 'light'],
#  ['together', 'soon', 'promise'],
#  ['youve', 'done', 'well'],
#  ['father', 'would', 'proud'],
#  ['give', 'lord', 'renly', u'regard'],
#  ['king', 'renly'],
#  [u'there', 'king', 'every', 'corner'],
#  [],
#  ['returning', 'room', 'proper', 'appearance'],
#  ['say', 'targaryens', u'conqueror'],
#  ['seat', 'conqueror'],
#  [u'need', 'room', 'match', u'vine', u'flower'],
#  ['cant', 'find', 'arya', 'stark'],
#  ['luck', 'shes', 'dead', 'ditch', 'somewhere'],
#  ['perhaps'],
#  ['need'],
#  ['theyll', 'never', 'give', 'jaime', 'back', u'u', 'sansa', 'alone'],
#  ['think', 'might'],
#  ['theyre', 'weak'],
#  ['put', 'much', 'value', u'woman'],
#  ['need', 'set', u'army', 'task', 'finding'],
#  ['send', 'many', 'men'],
#  ['im', 'sure', 'asked', 'grandfather', 'king', 'ask', u'command'],
#  [u'grandfather',
#   'stupidity',
#   'field',
#   'battle',
#   'reason',
#   'robb',
#   'stark',
#   'uncle',
#   'jaime',
#   'first',
#   'place'],
#  ['life', 'danger'],
#  ['war'],
#  [u'life', 'danger'],
#  ['heard', 'disgusting', 'lie', 'uncle', 'jaime'],
#  [],
#  [u'enemy', 'say', 'anything', 'weaken', 'claim', 'throne'],
#  ['claim'],
#  ['throne', 'mine'],
#  ['course'],
#  ['one', u'belief', 'foul', 'gossip'],
#  ['someone', u'belief'],
#  ['father', u'child'],
#  ['besides', 'tommen', 'myrcella'],
#  ['asking'],
#  ['im', 'asking', 'fucked', u'woman', 'grew', 'tired'],
#  ['many', u'bastard', 'running', 'punishable', 'death'],
#  ['never'],
#  ['never'],
#  ['mother'],
#  [],
#  ['idea', 'ridiculous', 'sound'],
#  ['ease'],
#  ['slowly', 'passion'],
#  ['oh', 'yeah'],
#  ['go', 'wash'],
#  ['put', 'clothes'],
#  ['working', 'tonight'],
#  [u'thing', 'differently', 'daisy'],
#  ['isnt', 'five', 'copper', 'bawdy', 'house', 'hayseed', 'hall'],
#  ['haystack', 'hall'],
#  ['wherever', 'youre'],
#  ['establishment', 'doesnt', 'cater', u'plowman', 'goat', u'herder'],
#  ['lord', 'olsen'],
#  ['taste', 'everything'],
#  ['littlefingers', 'fancy', 'man'],
#  ['dont', 'call', 'littlefinger'],
#  ['doesnt', 'like'],
#  ['lord', 'baelish'],
#  [u'pretend',
#   'doesnt',
#   'speak',
#   'common',
#   'tongue',
#   'people',
#   'think',
#   'shes',
#   'exotic'],
#  ['grew', 'road', 'flea', 'bottom'],
#  ['shes', 'beautiful'],
#  ['shes', 'dumb', 'slut', 'really', 'lid', 'every', 'pot'],
#  ['lord', 'commander'],
#  ['good', 'see'],
#  ['realize',
#   'establishment',
#   'owned',
#   'lord',
#   'petyr',
#   'baelish',
#   u'king',
#   'master',
#   'coin',
#   'coin',
#   u'go',
#   'many',
#   u'pocket'],
#  [u'order'],
#  ['whose', u'order'],
#  ['someone', 'doesnt', 'care', 'littlefinger', u'think'],
#  ['cant'],
#  [],
#  ['please'],
#  [],
#  ['barra'],
#  ['please'],
#  ['please'],
#  ['enough'],
#  ['get', 'done'],
#  ['kill', 'bastard'],
#  [],
#  ['please'],
#  ['give'],
#  ['please'],
#  ['spread'],
#  ['search', 'every', 'house'],
#  ['every', 'room'],
#  ['look', 'every', 'room'],
#  ['people', 'shouting', 'gendry'],
#  ['name', 'gendry'],
#  ['bastard'],
#  [u'night', 'watch'],
#  ['please', 'stop'],
#  [],
#  ['took', 'kingsroad', 'heading', 'north'],
#  ['know'],
#  [u'he', 'got', u'bull', 'head', 'helmet'],
#  ['made'],
#  ['find'],
#  ['boy'],
#  ['lovely', 'boy'],
#  ['want'],
#  ['man', 'thirst'],
#  ['man', 'drink', 'day', 'night'],
#  ['boy', 'could', 'make', 'friend'],
#  [u'friend'],
#  ['give', u'u', 'beer', 'skin'],
#  ['man', 'choose', u'companion'],
#  ['two', 'courtesy'],
#  ['man', 'must', 'ask', 'forgiveness'],
#  ['youre', 'called', 'arry'],
#  ['man', 'honor', 'jaqen', 'hghar', 'free', 'city', 'beer', 'little', 'shit'],
#  ['get', u'u', 'beer'],
#  ['asked', 'nicely'],
#  ['aah'],
#  ['come', 'closer', 'ill', 'shove', 'stick', 'bunghole', 'fuck', 'bloody'],
#  ['boy', 'courage', 'sense'],
#  ['come'],
#  ['yoren', 'said', 'none', u'u', 'go', 'near', 'three'],
#  ['come'],
#  ['dont', 'scare'],
#  ['hmm'],
#  ['youre', 'stupid'],
#  ['scare'],
#  ['gold', u'cloak', 'far', u'king', 'landing'],
#  [],
#  ['theyre', 'looking'],
#  ['command'],
#  ['youre', 'long', 'way', 'home'],
#  ['asked', 'question'],
#  ['aye'],
#  ['asked', 'without', u'manner', 'chose', 'answer'],
#  ['royal', 'warrant', 'one', 'gutter', u'rat', 'youre', 'transporting'],
#  ['well', 'thing', 'gutter', u'rat', 'belong', u'night', 'watch'],
#  [u'put', 'beyond', 'reach', u'king', u'queen'],
#  [],
#  ['funny',
#   'thing',
#   'people',
#   'worry',
#   'much',
#   u'throat',
#   'forget',
#   'whats',
#   'low'],
#  ['sharpened', 'blade', 'breakfast'],
#  ['could',
#   'shave',
#   u'spider',
#   'arse',
#   'wanted',
#   'could',
#   'nick',
#   'artery',
#   'leg'],
#  ['nicked', u'there', 'one', 'around', u'know', 'unnick'],
#  ['well', 'keep'],
#  ['good', 'steel', 'always', 'needed', 'wall'],
#  ['seems',
#   'choice',
#   'die',
#   u'crossroad',
#   'long',
#   'way',
#   'home',
#   'go',
#   'back',
#   'city',
#   'tell',
#   u'master',
#   'didnt',
#   'find',
#   'looking'],
#  ['looking', 'boy', 'named', 'gendry'],
#  [u'carry', u'bull', 'head', 'helmet'],
#  ['anyone', 'turning', 'earn', u'king', 'reward'],
#  ['well',
#   'back',
#   'men',
#   'ill',
#   'taking',
#   'head',
#   'home',
#   'along',
#   'bastard',
#   'boy'],
#  ['distant', u'seagull', 'lord'],
#  ['make', 'wait', 'long', 'time', 'friend', u'keep', 'company'],
#  ['speaking', 'bravery', 'victory', 'stark', 'auxiliary', u'force'],
#  ['quite', 'battle'],
#  ['heard', 'suffered', 'terrible', 'head', 'wound'],
#  [u'northerner', 'fearsome', u'warrior'],
#  ['tell', 'story', 'meet'],
#  ['find',
#   'lovely',
#   'creature',
#   'working',
#   u'father',
#   u'kitchen',
#   'almost',
#   u'beggar',
#   'belief'],
#  ['strange', u'thing', 'happen'],
#  ['taste', 'fish', 'pie'],
#  ['dont', 'think', 'lord', 'varys', u'like', 'fish', 'pie'],
#  ['tell'],
#  ['always', 'tell'],
#  ['men',
#   'like',
#   'lord',
#   'varys',
#   'cant',
#   'let',
#   u'disadvantage',
#   'get',
#   'best',
#   u'u'],
#  ['well', 'make', 'fisherman', 'yet'],
#  ['glad', 'new', 'friend', 'able', 'accompany', 'capital'],
#  [u'friend', 'important', 'part', 'life'],
#  ['unfortunate', 'father', 'didnt', 'want', 'come'],
#  ['rest', 'easy', 'lord'],
#  ['good', 'keeping', u'secret', 'good', u'friend'],
#  ['discretion', 'legendary', u'friend', 'concerned'],
#  ['unspeakable', 'go', 'want', 'rest'],
#  ['leave'],
#  ['welcome', u'king', 'landing', 'dear'],
#  ['city', 'made', 'brighter', 'presence'],
#  ['council', 'meeting', 'lord'],
#  ['dont', 'like', u'threat'],
#  ['threatened'],
#  ['im', 'ned', 'stark'],
#  ['understand', 'way', 'game', 'played'],
#  ['ned', 'stark', 'man', 'honor'],
#  [],
#  ['threaten', 'ill', 'thrown', 'sea'],
#  ['might', 'disappointed', u'result'],
#  [u'storm',
#   'come',
#   'go',
#   'big',
#   'fish',
#   'eat',
#   'little',
#   'fish',
#   'keep',
#   'paddling'],
#  ['come', 'lord'],
#  ['shouldnt', 'keep', 'queen', 'waiting'],
#  ['time',
#   'end',
#   'time',
#   'part',
#   'realm',
#   'free',
#   'independent',
#   'kingdom',
#   'north'],
#  ['spirit', 'father', 'ill', 'give'],
#  ['youve', 'perfected', 'art', 'tearing', u'paper'],
#  ['give', u'father', u'bone', 'back', 'least', 'gesture', 'good', 'faith'],
#  ['youll', 'give', 'starks', 'reply', 'cousin'],
#  ['grace'],
#  ['see', 'brother', 'starks', 'guest'],
#  [],
#  ['broken', 'spirit', 'grace'],
#  ['speak', 'tell', u'he', 'forgotten'],
#  ['grace'],
#  ['safe', u'travel', 'cousin'],
#  ['deft', 'hand', 'diplomacy'],
#  ['thats', 'everything', 'raven', 'flew', 'morning', 'castle', 'black'],
#  ['trouble', 'wildlings'],
#  ['thats', 'theyre', 'called', 'wildlings'],
#  ['somewhat', u'le', 'wild', u'day'],
#  ['seems',
#   'theyve',
#   'stopped',
#   'killing',
#   'started',
#   'following',
#   'king',
#   'beyond',
#   'wall'],
#  ['another', 'king'],
#  ['many', 'five'],
#  ['ive', 'lost', 'count'],
#  ['lord', 'commander', 'asks', 'send', 'men', 'man', 'wall'],
#  ['perhaps', u'he', 'forgotten', 'fighting', 'war'],
#  ['men', 'spare'],
#  ['cold', u'wind', 'rising', 'dead', 'rise'],
#  [u'northerner', 'superstitious', 'people'],
#  ['according', 'commander', 'one', 'dead', 'men', 'attacked', u'chamber'],
#  ['mormont', 'doesnt', 'lie'],
#  ['kill', 'dead', 'man'],
#  ['apparently', 'burn'],
#  ['one', 'trip', 'wall', 'come', 'back', 'believing', 'grumpkins', 'snarks'],
#  ['dont',
#   'know',
#   'believe',
#   u'here',
#   'fact',
#   u'night',
#   'watch',
#   'thing',
#   u'separate',
#   u'u',
#   u'lie',
#   'beyond',
#   'wall'],
#  ['every', 'confidence', 'brave', 'men', u'night', 'watch', 'protect', u'u'],
#  ['said',
#   u'god',
#   'wanted',
#   u'u',
#   'dignity',
#   'wouldnt',
#   'make',
#   u'u',
#   'fart',
#   'died'],
#  ['fart', 'die'],
#  ['blessed', 'mother', 'holding', 'hand', 'left', 'world'],
#  ['farted', 'hard', 'whole', 'bed', 'shook'],
#  ['seems', 'bit', 'greedy', 'one', 'man', 'many', u'wife'],
#  ['wouldnt', 'two', 'three', 'enough'],
#  ['serious', 'discussion'],
#  ['would', 'look'],
#  ['nothing', 'like', 'sight', 'woman', 'walking', 'away'],
#  ['prefer', 'watching', 'come', 'towards'],
#  ['im', 'sure', 'thats', 'nice'],
#  ['yeah', 'well', 'milkmaid', 'named', 'violet', 'next', 'farm', 'grew'],
#  ['wrestling', 'together', 'time', 'six', u'year', 'old'],
#  ['got', 'older', 'wrestling', 'uh', 'changed'],
#  [],
#  ['many', u'time'],
#  ['well', 'many', u'time', 'could'],
#  ['wish', 'grew', 'farm'],
#  ['need', u'potato'],
#  ['get', 'another', 'sack', 'sledge'],
#  ['get', u'turnip'],
#  [],
#  ['ghost'],
#  [],
#  ['ghost', 'away'],
#  ['shoo', 'shoo'],
#  ['right'],
#  ['frighten'],
#  ['shouldnt', 'touch'],
#  ['oh'],
#  ['oh', 'right'],
#  ['im', 'sorry'],
#  ['wanted', 'make', 'sure', 'werent', 'hurt'],
#  ['youre', 'brave'],
#  [],
#  ['gilly'],
#  ['shes', 'one', 'crasters', u'daughter'],
#  ['hello', 'gilly'],
#  [],
#  ['sam', 'said', 'could', 'help'],
#  ['im', 'sorry', 'sam', u'know', 'supposed', 'shes', 'pregnant'],
#  ['take', u'u', 'leave'],
#  [],
#  ['would', 'know', u'sound', 'bit', 'mad'],
#  ['doesnt', 'sound', 'bit', 'mad', 'impossible'],
#  ['lord', 'commander', 'ordered', u'u', 'sworn', 'protect'],
#  ['sam', 'cant', 'take', 'please', 'ser', 'please'],
#  ['still', 'run'],
#  ['possible'],
#  ['im', 'going', 'baby'],
#  ['boy', 'boy'],
#  ['want', u'u', 'risk', u'life', 'wont', 'even', 'tell', u'u'],
#  ['whyd'],
#  [],
#  ['ask', 'question'],
#  ['cruel'],
#  ['cruel'],
#  ['sam', 'hurry', 'lose', 'hand'],
#  ['didnt', 'touch'],
#  ['want', 'steal'],
#  ['think', 'craster', u'cut'],
#  ['cant', 'steal'],
#  ['shes', 'person', 'goat'],
#  ['heading', 'deeper', 'deeper', 'wildling', 'territory'],
#  ['cant', 'take', 'girl', u'u'],
#  ['mormont', 'wouldnt'],
#  ['even', 'would', 'would'],
#  [u'who', 'going', 'deliver', 'baby'],
#  ['could', 'try'],
#  [],
#  ['ive', 'read'],
#  ['bit'],
#  ['im', 'sorry', 'sam'],
#  ['cant', 'help'],
#  ['khaleesi'],
#  ['dont', 'need', 'see'],
#  ['blood', 'blood'],
#  [],
#  ['khal', 'pono', 'perhaps'],
#  ['khal', 'jhaqo'],
#  ['dont', 'like', 'idea', 'woman', 'leading', 'khalasar'],
#  ['like', 'far', u'le', 'done'],
#  ['remember', 'lord'],
#  [u'look', 'smaller'],
#  ['everything', u'look', 'bigger', 'youre', 'child'],
#  ['remember', u'father', 'cabin', 'felt', 'like', 'palace', 'little'],
#  ['look'],
#  ['theyll', 'waiting', u'dock'],
#  [],
#  ['anyone', u'matter'],
#  ['big', 'day'],
#  ['havent', 'much', 'get', 'excited', 'since', 'left'],
#  ['hard', 'place', 'iron', u'island'],
#  ['always'],
#  ['cold', 'wet'],
#  ['oh', 'love', 'cold', 'wet'],
#  ['say', 'hard', u'place', 'breed', 'hard', 'men'],
#  ['hard', 'men', 'rule', 'world'],
#  ['youll', 'king', 'long'],
#  ['try', 'smiling', u'lip', 'closed'],
#  ['better'],
#  ['father', 'doesnt', 'trust', 'iron', u'islander'],
#  ['dont', 'blame'],
#  [u'say',
#   'youre',
#   'reavers',
#   u'raper',
#   'matter',
#   'many',
#   u'woman',
#   'youll',
#   'never',
#   'sat',
#   'uh'],
#  ['quit', 'talking', 'father'],
#  [u'he', 'right', u'u'],
#  [u'wife', 'iron', u'island', 'theyre', 'breeding'],
#  ['thats', 'enough', u'u'],
#  ['thats', 'take', 'salt', u'wife', u'woman', 'capture'],
#  ['capture'],
#  ['take', 'go', 'ashore'],
#  ['make', 'salt', 'wife'],
#  ['place', 'ship'],
#  ['leave'],
#  ['father', 'punish'],
#  ['hell', 'call', 'whore'],
#  ['havent', 'paid'],
#  ['oh', 'yeah'],
#  ['paid', 'good', 'money', 'im', 'going', 'stand'],
#  ['barely', 'touched'],
#  ['charge', 'twice', 'much', 'every', 'brothel', 'get', u'cry'],
#  ['one', 'moment', 'friend'],
#  ['moment'],
#  ['please', 'accept', 'sincerest', u'apology'],
#  ['aremca', 'take', 'good', 'care'],
#  ['im', 'sorry', 'lord'],
#  ['shh', 'shh'],
#  ['hurt'],
#  ['lord'],
#  ['mhaegen'],
#  [],
#  [u'work'],
#  ['shes', 'one', 'gold', u'cloak', 'killed', 'baby'],
#  ['ah', 'yes'],
#  ['poorly', 'handled'],
#  ['sometimes', 'power', 'least', 'grace'],
#  ['cant', 'stop', 'thinking'],
#  ['cant', 'sleep'],
#  ['poor', 'little', 'baby'],
#  ['know',
#   'remind',
#   'another',
#   'girl',
#   'lovely',
#   'thing',
#   'acquired',
#   'lysene',
#   'pleasure',
#   'house',
#   'beautiful',
#   'like',
#   'intelligent',
#   'like'],
#  ['wasnt', 'happy'],
#  ['cried', 'often'],
#  ['asked', 'didnt', 'kind', 'rapport'],
#  ['yes', 'quite', 'sad'],
#  [u'girl',
#   'lysene',
#   'pleasure',
#   u'house',
#   'expensive',
#   'extremely',
#   'expensive'],
#  ['one', 'wasnt', 'making', 'money'],
#  ['hate', 'bad', u'investment'],
#  ['really'],
#  ['haunt'],
#  ['idea', 'make', 'happy', 'idea', 'mitigate', u'loss'],
#  ['wealthy',
#   'patron',
#   'offered',
#   'tremendous',
#   'amount',
#   'money',
#   'let',
#   'transform',
#   'lovely',
#   'sad',
#   'girl'],
#  ['use', u'way', 'would', 'never', 'occur', 'men'],
#  ['know', 'occurs', 'men'],
#  ['would',
#   'say',
#   'succeeded',
#   'making',
#   'happy',
#   u'loss',
#   'definitely',
#   'mitigated'],
#  ['take', 'tonight', 'mourn', 'mhaegens', 'child'],
#  ['ill', 'see', 'tomorrow'],
#  ['youll', 'happy'],
#  [u'make', 'happy'],
#  ['wine'],
#  ['damn', 'boy'],
#  [u'apology', 'lord'],
#  ['leave', u'u', 'podrick'],
#  ['believe', 'know', 'pour', 'wine'],
#  ['thats', 'new', 'squire'],
#  ['couldve', 'found', 'proper', 'lad'],
#  ['prefer', 'improper', u'one'],
#  ['mm', 'thats', 'good', 'red'],
#  ['dornish'],
#  ['know', u'wine', 'lord'],
#  [],
#  ['fine', 'dinner', 'lord'],
#  ['call', 'tyrion', 'please'],
#  ['im',
#   'sure',
#   'youre',
#   'getting',
#   'used',
#   'fine',
#   u'dinner',
#   'youre',
#   'lord'],
#  ['maybe', 'ill', 'hire', 'cook'],
#  [u'war', 'started', u'le'],
#  ['heard', 'trouble', 'littlefingers', 'brothel', 'night'],
#  ['mm', 'nasty', 'business'],
#  ['done'],
#  ['yes', 'course'],
#  ['city',
#   'watch',
#   'must',
#   'keep',
#   'peace',
#   'hadnt',
#   'realized',
#   'peace',
#   'depended',
#   'killing',
#   u'baby'],
#  [u'order', u'order'],
#  ['quite', 'right'],
#  ['especially', u'queen', u'order'],
#  ['never', 'said', u'queen', u'order'],
#  ['else', 'would', 'want', 'murder', 'king', u'robert', u'bastard'],
#  ['shes', 'always', 'jealous', 'woman'],
#  ['know', 'sister', 'better'],
#  ['youve', 'heard', 'awful', u'rumor', 'brother', 'sister'],
#  ['dont', 'listen', 'filth'],
#  ['thats', 'good', 'heard'],
#  ['suppose',
#   'people',
#   'believe',
#   'filth',
#   'consider',
#   u'robert',
#   u'bastard',
#   'better',
#   u'claimant',
#   'throne',
#   'cerseis',
#   u'child'],
#  ['joffrey', 'king'],
#  ['rest', 'doesnt', 'interest'],
#  ['appreciate', 'loyalty'],
#  ['tell',
#   'men',
#   'slaughtered',
#   'ned',
#   'starks',
#   'men',
#   'throne',
#   'room',
#   'give',
#   'order'],
#  [],
#  ['would'],
#  ['man', 'traitor'],
#  ['tried', 'buy', 'loyalty'],
#  ['fool'],
#  ['idea', 'already', 'bought'],
#  ['drunk'],
#  ['ill', 'honor', 'questioned', 'imp'],
#  ['im', 'questioning', 'honor', 'lord', 'janos'],
#  ['im', 'denying', 'existence'],
#  ['think', 'ill', 'stand', 'take', 'dwarf', 'dwarf'],
#  ['mm', 'stopped', 'imp'],
#  ['yes', 'stand', 'take', 'unless', 'youd', 'like', 'take', 'friend'],
#  ['intend', 'serve', 'hand', 'king', 'father', u'return', 'war'],
#  ['seeing',
#   'betrayed',
#   'last',
#   'hand',
#   'king',
#   'well',
#   'wouldnt',
#   'feel',
#   'safe',
#   'lurking'],
#  [u'friend', 'court', 'allow'],
#  ['queen', 'granted', 'queen', 'regent'],
#  ['youre', 'fool', 'believe', 'friend'],
#  ['shall', 'hear', 'joffrey', 'say'],
#  ['shant'],
#  [u'there', 'ship', 'leaving', 'eastwatch', 'sea', 'tonight'],
#  ['im', 'afraid', 'rather', 'long', 'walk', 'castle', 'black'],
#  ['hope', 'enjoy', 'wall'],
#  ['found',
#   'surprisingly',
#   'beautiful',
#   'brutal',
#   'horribly',
#   'uncomfortable',
#   'sort',
#   'way'],
#  [u'lad', 'escort'],
#  [u'street', 'arent', 'safe', 'night', 'lord'],
#  ...]

# %%
import gensim  
model = gensim.models.Word2Vec(total_corpus_texts, size=100, window=5, min_count=1, workers=2,sg=1)

# %%
model.wv.vocab.items()
# Out:
# [('foul', <gensim.models.keyedvectors.Vocab at 0x106f5fe90>),
#  ('four', <gensim.models.keyedvectors.Vocab at 0x11525ce50>),
#  ('hanging', <gensim.models.keyedvectors.Vocab at 0x11525cf90>),
#  ('marching', <gensim.models.keyedvectors.Vocab at 0x1167d6050>),
#  (u'increase', <gensim.models.keyedvectors.Vocab at 0x1169c6d90>),
#  ('midafternoon', <gensim.models.keyedvectors.Vocab at 0x1167d60d0>),
#  ('mutinied', <gensim.models.keyedvectors.Vocab at 0x1167d6110>),
#  ('lord', <gensim.models.keyedvectors.Vocab at 0x1167d6150>),
#  (u'sinking', <gensim.models.keyedvectors.Vocab at 0x1167d6190>),
#  ('leisurely', <gensim.models.keyedvectors.Vocab at 0x1167d61d0>),
#  (u'politician', <gensim.models.keyedvectors.Vocab at 0x1167d6210>),
#  ('stabbed', <gensim.models.keyedvectors.Vocab at 0x1167d6250>),
#  ('bringing', <gensim.models.keyedvectors.Vocab at 0x1167dba50>),
#  ('disturb', <gensim.models.keyedvectors.Vocab at 0x1167d62d0>),
#  ('prize', <gensim.models.keyedvectors.Vocab at 0x1167d6310>),
#  ('wooden', <gensim.models.keyedvectors.Vocab at 0x1167d6350>),
#  (u'clientele', <gensim.models.keyedvectors.Vocab at 0x1167d6390>),
#  ('succession', <gensim.models.keyedvectors.Vocab at 0x1167d63d0>),
#  ('straight', <gensim.models.keyedvectors.Vocab at 0x11683a410>),
#  ('tired', <gensim.models.keyedvectors.Vocab at 0x1167d6450>),
#  (u'lefford', <gensim.models.keyedvectors.Vocab at 0x1167d6490>),
#  ('bacon', <gensim.models.keyedvectors.Vocab at 0x1167d64d0>),
#  ('elegant', <gensim.models.keyedvectors.Vocab at 0x1167d6510>),
#  ('second', <gensim.models.keyedvectors.Vocab at 0x1167d6550>),
#  ('sailed', <gensim.models.keyedvectors.Vocab at 0x1167e0fd0>),
#  (u'ruthless', <gensim.models.keyedvectors.Vocab at 0x1167d65d0>),
#  ('thunder', <gensim.models.keyedvectors.Vocab at 0x1167d6610>),
#  ('cooking', <gensim.models.keyedvectors.Vocab at 0x1167d6650>),
#  ('contributed', <gensim.models.keyedvectors.Vocab at 0x1167d6690>),
#  ('resilient', <gensim.models.keyedvectors.Vocab at 0x1167d66d0>),
#  ('succumb', <gensim.models.keyedvectors.Vocab at 0x1167d6710>),
#  ('hero', <gensim.models.keyedvectors.Vocab at 0x1167d6750>),
#  ('interrupting', <gensim.models.keyedvectors.Vocab at 0x1167d6790>),
#  (u'here', <gensim.models.keyedvectors.Vocab at 0x1167d67d0>),
#  ('substance', <gensim.models.keyedvectors.Vocab at 0x1167d6810>),
#  (u'k', <gensim.models.keyedvectors.Vocab at 0x1167d6850>),
#  ('climbed', <gensim.models.keyedvectors.Vocab at 0x1167d6890>),
#  ('military', <gensim.models.keyedvectors.Vocab at 0x1167d68d0>),
#  (u'climber', <gensim.models.keyedvectors.Vocab at 0x1167d6910>),
#  ('diplomat', <gensim.models.keyedvectors.Vocab at 0x116aef710>),
#  ('appropriately', <gensim.models.keyedvectors.Vocab at 0x1167f3110>),
#  ('divide', <gensim.models.keyedvectors.Vocab at 0x1167d6990>),
#  ('explained', <gensim.models.keyedvectors.Vocab at 0x1167d69d0>),
#  ('replace', <gensim.models.keyedvectors.Vocab at 0x1167d6a10>),
#  ('brought', <gensim.models.keyedvectors.Vocab at 0x1167d6a50>),
#  ('stern', <gensim.models.keyedvectors.Vocab at 0x1167d6a90>),
#  ('cheating', <gensim.models.keyedvectors.Vocab at 0x1167d6ad0>),
#  ('spoke', <gensim.models.keyedvectors.Vocab at 0x1167d6b10>),
#  (u'cannibal', <gensim.models.keyedvectors.Vocab at 0x1167d6b50>),
#  ('occupying', <gensim.models.keyedvectors.Vocab at 0x1167d6b90>),
#  ('untie', <gensim.models.keyedvectors.Vocab at 0x1167d6bd0>),
#  ('strike', <gensim.models.keyedvectors.Vocab at 0x1167d6c10>),
#  ('sideface', <gensim.models.keyedvectors.Vocab at 0x1167d6c50>),
#  ('holy', <gensim.models.keyedvectors.Vocab at 0x1167d6c90>),
#  ('relax', <gensim.models.keyedvectors.Vocab at 0x1167d6cd0>),
#  ('successful', <gensim.models.keyedvectors.Vocab at 0x1167d6d10>),
#  ('brings', <gensim.models.keyedvectors.Vocab at 0x1167d6d50>),
#  ('hereby', <gensim.models.keyedvectors.Vocab at 0x1167d6d90>),
#  ('hurt', <gensim.models.keyedvectors.Vocab at 0x1167d6dd0>),
#  (u'glass', <gensim.models.keyedvectors.Vocab at 0x1167d6e10>),
#  (u'hole', <gensim.models.keyedvectors.Vocab at 0x1167f8e90>),
#  ('hold', <gensim.models.keyedvectors.Vocab at 0x1167d6e90>),
#  (u'simper', <gensim.models.keyedvectors.Vocab at 0x1167f8fd0>),
#  (u'benjens', <gensim.models.keyedvectors.Vocab at 0x1167d6f10>),
#  ('pursue', <gensim.models.keyedvectors.Vocab at 0x1167d6f50>),
#  ('zhoan', <gensim.models.keyedvectors.Vocab at 0x1167d6f90>),
#  ('blade', <gensim.models.keyedvectors.Vocab at 0x1167fe2d0>),
#  ('plunged', <gensim.models.keyedvectors.Vocab at 0x1167db050>),
#  ('sweeter', <gensim.models.keyedvectors.Vocab at 0x1167db090>),
#  ('rework', <gensim.models.keyedvectors.Vocab at 0x1167db0d0>),
#  ('example', <gensim.models.keyedvectors.Vocab at 0x1167db110>),
#  ('triple', <gensim.models.keyedvectors.Vocab at 0x11683a7d0>),
#  ('organized', <gensim.models.keyedvectors.Vocab at 0x1167db190>),
#  (u'caution', <gensim.models.keyedvectors.Vocab at 0x1167db210>),
#  ('want', <gensim.models.keyedvectors.Vocab at 0x1167db250>),
#  ('counseling', <gensim.models.keyedvectors.Vocab at 0x1167db290>),
#  ('mymother', <gensim.models.keyedvectors.Vocab at 0x1167db2d0>),
#  (u'cocksucker', <gensim.models.keyedvectors.Vocab at 0x1167db310>),
#  ('absolute', <gensim.models.keyedvectors.Vocab at 0x1167db350>),
#  ('hog', <gensim.models.keyedvectors.Vocab at 0x1167db390>),
#  ('complaining', <gensim.models.keyedvectors.Vocab at 0x1167db3d0>),
#  (u'travel', <gensim.models.keyedvectors.Vocab at 0x1167db410>),
#  ('copious', <gensim.models.keyedvectors.Vocab at 0x1167db450>),
#  ('undying', <gensim.models.keyedvectors.Vocab at 0x116ace6d0>),
#  ('hot', <gensim.models.keyedvectors.Vocab at 0x1167db490>),
#  ('retreating', <gensim.models.keyedvectors.Vocab at 0x116a8c910>),
#  ('beauty', <gensim.models.keyedvectors.Vocab at 0x1167db510>),
#  ('swing', <gensim.models.keyedvectors.Vocab at 0x116a8c950>),
#  (u'despondent', <gensim.models.keyedvectors.Vocab at 0x1167db590>),
#  ('outlawed', <gensim.models.keyedvectors.Vocab at 0x1167db5d0>),
#  ('wrong', <gensim.models.keyedvectors.Vocab at 0x1167db610>),
#  ('barristan', <gensim.models.keyedvectors.Vocab at 0x1167db650>),
#  (u'huhuh', <gensim.models.keyedvectors.Vocab at 0x1167db690>),
#  (u'attracts', <gensim.models.keyedvectors.Vocab at 0x1167db6d0>),
#  (u'revolt', <gensim.models.keyedvectors.Vocab at 0x1167db710>),
#  ('sickening', <gensim.models.keyedvectors.Vocab at 0x1167db750>),
#  ('tulip', <gensim.models.keyedvectors.Vocab at 0x1167db790>),
#  ('viserys', <gensim.models.keyedvectors.Vocab at 0x1167db7d0>),
#  (u'wing', <gensim.models.keyedvectors.Vocab at 0x1167db810>),
#  ('wind', <gensim.models.keyedvectors.Vocab at 0x1167db850>),
#  ('wine', <gensim.models.keyedvectors.Vocab at 0x1167db890>),
#  ('dreamed', <gensim.models.keyedvectors.Vocab at 0x1167db8d0>),
#  ('patricide', <gensim.models.keyedvectors.Vocab at 0x1167db910>),
#  (u'profaned', <gensim.models.keyedvectors.Vocab at 0x1167db950>),
#  ('rewarded', <gensim.models.keyedvectors.Vocab at 0x1167db990>),
#  ('fit', <gensim.models.keyedvectors.Vocab at 0x1167db9d0>),
#  ('allisers', <gensim.models.keyedvectors.Vocab at 0x1167dba10>),
#  ('screaming', <gensim.models.keyedvectors.Vocab at 0x1167d6290>),
#  (u'fix', <gensim.models.keyedvectors.Vocab at 0x1167dba90>),
#  (u'dedicate', <gensim.models.keyedvectors.Vocab at 0x1167dbad0>),
#  (u'fig', <gensim.models.keyedvectors.Vocab at 0x1167dbb10>),
#  ('mewling', <gensim.models.keyedvectors.Vocab at 0x1167dbb50>),
#  ('hidden', <gensim.models.keyedvectors.Vocab at 0x1167dbb90>),
#  ('admirable', <gensim.models.keyedvectors.Vocab at 0x1167dbbd0>),
#  ('easier', <gensim.models.keyedvectors.Vocab at 0x1167dbc10>),
#  ('hghar', <gensim.models.keyedvectors.Vocab at 0x1167dbc50>),
#  ('commemorate', <gensim.models.keyedvectors.Vocab at 0x1167dbc90>),
#  ('educating', <gensim.models.keyedvectors.Vocab at 0x1167dbcd0>),
#  ('interrupt', <gensim.models.keyedvectors.Vocab at 0x1167dbd10>),
#  ('blink', <gensim.models.keyedvectors.Vocab at 0x1167dbd50>),
#  ('silver', <gensim.models.keyedvectors.Vocab at 0x1167dbd90>),
#  ('structural', <gensim.models.keyedvectors.Vocab at 0x1167dbdd0>),
#  (u'represents', <gensim.models.keyedvectors.Vocab at 0x1167dbe10>),
#  ('jaehaerys', <gensim.models.keyedvectors.Vocab at 0x1167dbe50>),
#  ('theons', <gensim.models.keyedvectors.Vocab at 0x1167dbe90>),
#  (u'arrow', <gensim.models.keyedvectors.Vocab at 0x1167dbed0>),
#  (u'armourer', <gensim.models.keyedvectors.Vocab at 0x1167dbf10>),
#  ('burial', <gensim.models.keyedvectors.Vocab at 0x1167dbf50>),
#  (u'whim', <gensim.models.keyedvectors.Vocab at 0x1167dbf90>),
#  ('financial', <gensim.models.keyedvectors.Vocab at 0x1167dbfd0>),
#  (u'spider', <gensim.models.keyedvectors.Vocab at 0x1167e0050>),
#  (u'longclaw', <gensim.models.keyedvectors.Vocab at 0x1167e0090>),
#  (u'turnip', <gensim.models.keyedvectors.Vocab at 0x1167e00d0>),
#  ('fortnight', <gensim.models.keyedvectors.Vocab at 0x1167e0110>),
#  (u'mutineer', <gensim.models.keyedvectors.Vocab at 0x1167e0150>),
#  (u'wyllis', <gensim.models.keyedvectors.Vocab at 0x1167e0190>),
#  ('message', <gensim.models.keyedvectors.Vocab at 0x1167e01d0>),
#  ('whip', <gensim.models.keyedvectors.Vocab at 0x1167e0210>),
#  ('misfortune', <gensim.models.keyedvectors.Vocab at 0x1167e0250>),
#  ('whoosh', <gensim.models.keyedvectors.Vocab at 0x1167e0290>),
#  (u'mason', <gensim.models.keyedvectors.Vocab at 0x1167e02d0>),
#  (u'rd', <gensim.models.keyedvectors.Vocab at 0x1167e0310>),
#  ('archmaester', <gensim.models.keyedvectors.Vocab at 0x1167e0350>),
#  (u'ro', <gensim.models.keyedvectors.Vocab at 0x1167e0390>),
#  (u'outburst', <gensim.models.keyedvectors.Vocab at 0x1167e03d0>),
#  (u'foundation', <gensim.models.keyedvectors.Vocab at 0x1167e0410>),
#  ('assured', <gensim.models.keyedvectors.Vocab at 0x1167e0450>),
#  ('waddle', <gensim.models.keyedvectors.Vocab at 0x1167e0490>),
#  ('threatened', <gensim.models.keyedvectors.Vocab at 0x1167e04d0>),
#  ('assures', <gensim.models.keyedvectors.Vocab at 0x116824490>),
#  ('aggar', <gensim.models.keyedvectors.Vocab at 0x1167e0550>),
#  ('crowned', <gensim.models.keyedvectors.Vocab at 0x1167e0590>),
#  ('tobho', <gensim.models.keyedvectors.Vocab at 0x1167e05d0>),
#  ('ate', <gensim.models.keyedvectors.Vocab at 0x1167e0610>),
#  ('ath', <gensim.models.keyedvectors.Vocab at 0x1167e0650>),
#  ('shipped', <gensim.models.keyedvectors.Vocab at 0x1167e0690>),
#  (u'disturbed', <gensim.models.keyedvectors.Vocab at 0x1167e06d0>),
#  ('tempting', <gensim.models.keyedvectors.Vocab at 0x1167e0710>),
#  ('minge', <gensim.models.keyedvectors.Vocab at 0x1167e0750>),
#  (u'subtlety', <gensim.models.keyedvectors.Vocab at 0x1167e0790>),
#  ('wash', <gensim.models.keyedvectors.Vocab at 0x1167e07d0>),
#  ('instruct', <gensim.models.keyedvectors.Vocab at 0x1167e0810>),
#  ('bitten', <gensim.models.keyedvectors.Vocab at 0x1167e0850>),
#  ('zala', <gensim.models.keyedvectors.Vocab at 0x1167f3890>),
#  ('whorehouse', <gensim.models.keyedvectors.Vocab at 0x1167e08d0>),
#  ('timid', <gensim.models.keyedvectors.Vocab at 0x11696e190>),
#  ('engagement', <gensim.models.keyedvectors.Vocab at 0x1167e0990>),
#  ('needed', <gensim.models.keyedvectors.Vocab at 0x1167e09d0>),
#  ('master', <gensim.models.keyedvectors.Vocab at 0x1167e0a10>),
#  ('bitter', <gensim.models.keyedvectors.Vocab at 0x1167e0a50>),
#  ('ranging', <gensim.models.keyedvectors.Vocab at 0x1167e0a90>),
#  ('listen', <gensim.models.keyedvectors.Vocab at 0x1167e0ad0>),
#  ('lorch', <gensim.models.keyedvectors.Vocab at 0x1167e0b10>),
#  (u'collapse', <gensim.models.keyedvectors.Vocab at 0x1167e0b50>),
#  ('hows', <gensim.models.keyedvectors.Vocab at 0x1167e0b90>),
#  ('highgarden', <gensim.models.keyedvectors.Vocab at 0x1167e0bd0>),
#  ('wisdom', <gensim.models.keyedvectors.Vocab at 0x1167e0c10>),
#  ('predictable', <gensim.models.keyedvectors.Vocab at 0x1167e0c50>),
#  ('crawl', <gensim.models.keyedvectors.Vocab at 0x1167e0c90>),
#  ('positively', <gensim.models.keyedvectors.Vocab at 0x1167e0cd0>),
#  ('showed', <gensim.models.keyedvectors.Vocab at 0x1167e0d10>),
#  (u'coward', <gensim.models.keyedvectors.Vocab at 0x1167e0d50>),
#  ('tree', <gensim.models.keyedvectors.Vocab at 0x1167e0d90>),
#  (u'whinging', <gensim.models.keyedvectors.Vocab at 0x116835650>),
#  ('shower', <gensim.models.keyedvectors.Vocab at 0x1167e0e10>),
#  ('idle', <gensim.models.keyedvectors.Vocab at 0x1167e0e50>),
#  ('endure', <gensim.models.keyedvectors.Vocab at 0x1167e0e90>),
#  ('profitable', <gensim.models.keyedvectors.Vocab at 0x116ac3610>),
#  ('feeling', <gensim.models.keyedvectors.Vocab at 0x1167e0ed0>),
#  ('groaning', <gensim.models.keyedvectors.Vocab at 0x1167e0f10>),
#  ('longs', <gensim.models.keyedvectors.Vocab at 0x1167e0f50>),
#  ('untrained', <gensim.models.keyedvectors.Vocab at 0x1167e0f90>),
#  ('tether', <gensim.models.keyedvectors.Vocab at 0x1167d6590>),
#  ('dozen', <gensim.models.keyedvectors.Vocab at 0x1167e8050>),
#  ('responsible', <gensim.models.keyedvectors.Vocab at 0x1167e8090>),
#  (u'instructs', <gensim.models.keyedvectors.Vocab at 0x1167e8110>),
#  ('amusing', <gensim.models.keyedvectors.Vocab at 0x1167e8150>),
#  ('britches', <gensim.models.keyedvectors.Vocab at 0x1167e8190>),
#  (u'season', <gensim.models.keyedvectors.Vocab at 0x116a8ce50>),
#  ('eastwatch', <gensim.models.keyedvectors.Vocab at 0x116ab8f10>),
#  (u'horselords', <gensim.models.keyedvectors.Vocab at 0x1167e8210>),
#  ('howd', <gensim.models.keyedvectors.Vocab at 0x1167e8250>),
#  ('shall', <gensim.models.keyedvectors.Vocab at 0x1167e8290>),
#  ('huh', <gensim.models.keyedvectors.Vocab at 0x116a8ce90>),
#  ('aegons', <gensim.models.keyedvectors.Vocab at 0x1167e8310>),
#  ('toil', <gensim.models.keyedvectors.Vocab at 0x11696e310>),
#  ('mouth', <gensim.models.keyedvectors.Vocab at 0x1167e8390>),
#  ('letter', <gensim.models.keyedvectors.Vocab at 0x1167e83d0>),
#  (u'singer', <gensim.models.keyedvectors.Vocab at 0x1167e8410>),
#  (u'episode', <gensim.models.keyedvectors.Vocab at 0x1167e8450>),
#  ('rayder', <gensim.models.keyedvectors.Vocab at 0x116840d10>),
#  ('consummate', <gensim.models.keyedvectors.Vocab at 0x1167e84d0>),
#  ('mating', <gensim.models.keyedvectors.Vocab at 0x1167e8550>),
#  ('tirelessly', <gensim.models.keyedvectors.Vocab at 0x116942d50>),
#  ('came', <gensim.models.keyedvectors.Vocab at 0x1167e85d0>),
#  ('saying', <gensim.models.keyedvectors.Vocab at 0x1167e8610>),
#  ('fennel', <gensim.models.keyedvectors.Vocab at 0x1167e8650>),
#  (u'tempted', <gensim.models.keyedvectors.Vocab at 0x1167e8690>),
#  ('abreast', <gensim.models.keyedvectors.Vocab at 0x1167e86d0>),
#  ('busy', <gensim.models.keyedvectors.Vocab at 0x11684b090>),
#  ('theme', <gensim.models.keyedvectors.Vocab at 0x1167e8750>),
#  ('touched', <gensim.models.keyedvectors.Vocab at 0x1167e8790>),
#  ('rich', <gensim.models.keyedvectors.Vocab at 0x1167e87d0>),
#  (u'plate', <gensim.models.keyedvectors.Vocab at 0x1167e8810>),
#  ('petrified', <gensim.models.keyedvectors.Vocab at 0x116a91050>),
#  (u'foremost', <gensim.models.keyedvectors.Vocab at 0x1167e8890>),
#  (u'pocket', <gensim.models.keyedvectors.Vocab at 0x1167e88d0>),
#  (u'reversal', <gensim.models.keyedvectors.Vocab at 0x1167e8910>),
#  ('altogether', <gensim.models.keyedvectors.Vocab at 0x1167e8950>),
#  ('blistered', <gensim.models.keyedvectors.Vocab at 0x1167e8990>),
#  (u'spilling', <gensim.models.keyedvectors.Vocab at 0x1167e89d0>),
#  ('nicely', <gensim.models.keyedvectors.Vocab at 0x1167e8a10>),
#  ('dipping', <gensim.models.keyedvectors.Vocab at 0x1167e8a50>),
#  ('piggy', <gensim.models.keyedvectors.Vocab at 0x1167e8a90>),
#  ('release', <gensim.models.keyedvectors.Vocab at 0x1167e8ad0>),
#  (u'respond', <gensim.models.keyedvectors.Vocab at 0x1167e8b10>),
#  (u'blew', <gensim.models.keyedvectors.Vocab at 0x1167e8b50>),
#  ('fair', <gensim.models.keyedvectors.Vocab at 0x1167e8b90>),
#  ('bled', <gensim.models.keyedvectors.Vocab at 0x1167e8bd0>),
#  (u'result', <gensim.models.keyedvectors.Vocab at 0x1167e8c10>),
#  ('fail', <gensim.models.keyedvectors.Vocab at 0x1167e8c50>),
#  ('nocturnal', <gensim.models.keyedvectors.Vocab at 0x1167e8c90>),
#  (u'hammer', <gensim.models.keyedvectors.Vocab at 0x1167e8cd0>),
#  ('best', <gensim.models.keyedvectors.Vocab at 0x1167e8d10>),
#  ('score', <gensim.models.keyedvectors.Vocab at 0x1167e8d50>),
#  ('pirate', <gensim.models.keyedvectors.Vocab at 0x1167e8d90>),
#  (u'wage', <gensim.models.keyedvectors.Vocab at 0x11690b410>),
#  ('men', <gensim.models.keyedvectors.Vocab at 0x116900c50>),
#  ('khaleesi', <gensim.models.keyedvectors.Vocab at 0x1167e8e50>),
#  ('extend', <gensim.models.keyedvectors.Vocab at 0x1167e8e90>),
#  ('nature', <gensim.models.keyedvectors.Vocab at 0x1167e8ed0>),
#  ('rolled', <gensim.models.keyedvectors.Vocab at 0x1167e8f10>),
#  ('smelled', <gensim.models.keyedvectors.Vocab at 0x1167e8f50>),
#  ('lapping', <gensim.models.keyedvectors.Vocab at 0x1167e8f90>),
#  (u'souvenir', <gensim.models.keyedvectors.Vocab at 0x1167e8fd0>),
#  (u'extent', <gensim.models.keyedvectors.Vocab at 0x1167ed090>),
#  ('tyrion', <gensim.models.keyedvectors.Vocab at 0x1167ed0d0>),
#  (u'debt', <gensim.models.keyedvectors.Vocab at 0x1167ed110>),
#  ('pity', <gensim.models.keyedvectors.Vocab at 0x1167ed150>),
#  ('accident', <gensim.models.keyedvectors.Vocab at 0x1167ed190>),
#  ('weirwood', <gensim.models.keyedvectors.Vocab at 0x1167ed1d0>),
#  ('country', <gensim.models.keyedvectors.Vocab at 0x1167ed210>),
#  (u'adventurer', <gensim.models.keyedvectors.Vocab at 0x1167ed250>),
#  ('demanded', <gensim.models.keyedvectors.Vocab at 0x1167ed290>),
#  ('planned', <gensim.models.keyedvectors.Vocab at 0x1167ed2d0>),
#  ('logic', <gensim.models.keyedvectors.Vocab at 0x1167ed310>),
#  ('argue', <gensim.models.keyedvectors.Vocab at 0x1167ed350>),
#  ('asked', <gensim.models.keyedvectors.Vocab at 0x1167ed390>),
#  (u'vain', <gensim.models.keyedvectors.Vocab at 0x1167ed3d0>),
#  ('blonde', <gensim.models.keyedvectors.Vocab at 0x1167ed410>),
#  ('shouting', <gensim.models.keyedvectors.Vocab at 0x11696e7d0>),
#  ('union', <gensim.models.keyedvectors.Vocab at 0x1167ed490>),
#  ('slay', <gensim.models.keyedvectors.Vocab at 0x1167ed4d0>),
#  ('muck', <gensim.models.keyedvectors.Vocab at 0x1167ed510>),
#  ('much', <gensim.models.keyedvectors.Vocab at 0x1167ed550>),
#  ('privilege', <gensim.models.keyedvectors.Vocab at 0x1167ed590>),
#  ('tallest', <gensim.models.keyedvectors.Vocab at 0x1167ed5d0>),
#  ('life', <gensim.models.keyedvectors.Vocab at 0x1167ed610>),
#  (u'lodock', <gensim.models.keyedvectors.Vocab at 0x1167ed650>),
#  ('spit', <gensim.models.keyedvectors.Vocab at 0x1167ed690>),
#  (u'eastern', <gensim.models.keyedvectors.Vocab at 0x1167ed6d0>),
#  ('jeor', <gensim.models.keyedvectors.Vocab at 0x1167ed710>),
#  (u'davy', <gensim.models.keyedvectors.Vocab at 0x1167ed750>),
#  ('wish', <gensim.models.keyedvectors.Vocab at 0x1167ed790>),
#  ('lift', <gensim.models.keyedvectors.Vocab at 0x1167ed7d0>),
#  ('direwolf', <gensim.models.keyedvectors.Vocab at 0x1167ed810>),
#  ('child', <gensim.models.keyedvectors.Vocab at 0x1167ed850>),
#  ('worked', <gensim.models.keyedvectors.Vocab at 0x1167ed890>),
#  ('cunt', <gensim.models.keyedvectors.Vocab at 0x1167ed8d0>),
#  ('employ', <gensim.models.keyedvectors.Vocab at 0x1167ed910>),
#  ('contemplates', <gensim.models.keyedvectors.Vocab at 0x1167ed950>),
#  (u'flooding', <gensim.models.keyedvectors.Vocab at 0x1167ed990>),
#  ('picturing', <gensim.models.keyedvectors.Vocab at 0x1167ed9d0>),
#  ('remembering', <gensim.models.keyedvectors.Vocab at 0x1167eda10>),
#  (u'congratulation', <gensim.models.keyedvectors.Vocab at 0x1167eda50>),
#  ('played', <gensim.models.keyedvectors.Vocab at 0x1167eda90>),
#  ('cersei', <gensim.models.keyedvectors.Vocab at 0x1167edad0>),
#  (u'locksmith', <gensim.models.keyedvectors.Vocab at 0x1167edb10>),
#  (u'obeying', <gensim.models.keyedvectors.Vocab at 0x1167edb50>),
#  (u'player', <gensim.models.keyedvectors.Vocab at 0x1167edb90>),
#  ('trusted', <gensim.models.keyedvectors.Vocab at 0x1167edbd0>),
#  ('severity', <gensim.models.keyedvectors.Vocab at 0x1167edc10>),
#  ('tarth', <gensim.models.keyedvectors.Vocab at 0x116a913d0>),
#  ('yellow', <gensim.models.keyedvectors.Vocab at 0x1167edc90>),
#  ('thievery', <gensim.models.keyedvectors.Vocab at 0x1167edcd0>),
#  ('rebellion', <gensim.models.keyedvectors.Vocab at 0x1167edd10>),
#  ('clucking', <gensim.models.keyedvectors.Vocab at 0x1167edd50>),
#  (u'harmony', <gensim.models.keyedvectors.Vocab at 0x116871bd0>),
#  ('fairly', <gensim.models.keyedvectors.Vocab at 0x1167eddd0>),
#  ('boiled', <gensim.models.keyedvectors.Vocab at 0x1167ede10>),
#  ('marched', <gensim.models.keyedvectors.Vocab at 0x1167ede50>),
#  ('supper', <gensim.models.keyedvectors.Vocab at 0x1167ede90>),
#  ('therell', <gensim.models.keyedvectors.Vocab at 0x1167eded0>),
#  ('metalwork', <gensim.models.keyedvectors.Vocab at 0x1167edf10>),
#  ('tune', <gensim.models.keyedvectors.Vocab at 0x1167edf50>),
#  (u'tarleys', <gensim.models.keyedvectors.Vocab at 0x1167edf90>),
#  ('intrusion', <gensim.models.keyedvectors.Vocab at 0x1167edfd0>),
#  ('noblewoman', <gensim.models.keyedvectors.Vocab at 0x1167f3050>),
#  ('eagle', <gensim.models.keyedvectors.Vocab at 0x116a8c6d0>),
#  ('towheaded', <gensim.models.keyedvectors.Vocab at 0x1167f3090>),
#  (u'bellow', <gensim.models.keyedvectors.Vocab at 0x1167f30d0>),
#  ('golden', <gensim.models.keyedvectors.Vocab at 0x1167d6950>),
#  ('forsaken', <gensim.models.keyedvectors.Vocab at 0x1167f3150>),
#  (u'plight', <gensim.models.keyedvectors.Vocab at 0x1167f31d0>),
#  (u'hal', <gensim.models.keyedvectors.Vocab at 0x1167f3210>),
#  ('ham', <gensim.models.keyedvectors.Vocab at 0x1167f3250>),
#  ('ease', <gensim.models.keyedvectors.Vocab at 0x1167f3290>),
#  ('hay', <gensim.models.keyedvectors.Vocab at 0x1167f32d0>),
#  ('innocent', <gensim.models.keyedvectors.Vocab at 0x1167f3310>),
#  ('prison', <gensim.models.keyedvectors.Vocab at 0x1167f3350>),
#  ('east', <gensim.models.keyedvectors.Vocab at 0x1167f3390>),
#  ('hat', <gensim.models.keyedvectors.Vocab at 0x1167f33d0>),
#  (u'hightower', <gensim.models.keyedvectors.Vocab at 0x1167f3410>),
#  ('survival', <gensim.models.keyedvectors.Vocab at 0x1167f3450>),
#  ('possible', <gensim.models.keyedvectors.Vocab at 0x1167f3490>),
#  ('possibly', <gensim.models.keyedvectors.Vocab at 0x1167f34d0>),
#  ('birth', <gensim.models.keyedvectors.Vocab at 0x1167f3510>),
#  ('shadow', <gensim.models.keyedvectors.Vocab at 0x1167f3550>),
#  ('unique', <gensim.models.keyedvectors.Vocab at 0x1167f3590>),
#  ('desire', <gensim.models.keyedvectors.Vocab at 0x1167f35d0>),
#  ('remind', <gensim.models.keyedvectors.Vocab at 0x1167f3610>),
#  ('battlefield', <gensim.models.keyedvectors.Vocab at 0x1167f3650>),
#  ('right', <gensim.models.keyedvectors.Vocab at 0x1167f3690>),
#  ('old', <gensim.models.keyedvectors.Vocab at 0x1167f36d0>),
#  ('crowd', <gensim.models.keyedvectors.Vocab at 0x1167f3710>),
#  ('people', <gensim.models.keyedvectors.Vocab at 0x1167f3750>),
#  ('macabre', <gensim.models.keyedvectors.Vocab at 0x1167f3790>),
#  ('crown', <gensim.models.keyedvectors.Vocab at 0x1167f3810>),
#  ('captive', <gensim.models.keyedvectors.Vocab at 0x1167f3850>),
#  ('warring', <gensim.models.keyedvectors.Vocab at 0x1167f38d0>),
#  ('bottom', <gensim.models.keyedvectors.Vocab at 0x1167f3910>),
#  (u'rehearse', <gensim.models.keyedvectors.Vocab at 0x1167f3950>),
#  (u'fox', <gensim.models.keyedvectors.Vocab at 0x1167f3990>),
#  ('witty', <gensim.models.keyedvectors.Vocab at 0x1167f39d0>),
#  (u'foe', <gensim.models.keyedvectors.Vocab at 0x1167f3a10>),
#  (u'summoned', <gensim.models.keyedvectors.Vocab at 0x1167f3a50>),
#  (u'umi', <gensim.models.keyedvectors.Vocab at 0x1167f3a90>),
#  ('pinched', <gensim.models.keyedvectors.Vocab at 0x1167f3ad0>),
#  ('yoke', <gensim.models.keyedvectors.Vocab at 0x1167f3b10>),
#  (u'defensive', <gensim.models.keyedvectors.Vocab at 0x1167f3b50>),
#  ('losing', <gensim.models.keyedvectors.Vocab at 0x1167f3b90>),
#  ('memorable', <gensim.models.keyedvectors.Vocab at 0x1167f3bd0>),
#  ('bowing', <gensim.models.keyedvectors.Vocab at 0x1167f3c10>),
#  (u'grievously', <gensim.models.keyedvectors.Vocab at 0x1167f3c50>),
#  (u'o', <gensim.models.keyedvectors.Vocab at 0x1167f3c90>),
#  ('despair', <gensim.models.keyedvectors.Vocab at 0x1167f3cd0>),
#  (u'slightly', <gensim.models.keyedvectors.Vocab at 0x1167f3d10>),
#  ('match', <gensim.models.keyedvectors.Vocab at 0x1167f3d50>),
#  ('lamprey', <gensim.models.keyedvectors.Vocab at 0x1167f3d90>),
#  ('raised', <gensim.models.keyedvectors.Vocab at 0x1167f3dd0>),
#  ('watering', <gensim.models.keyedvectors.Vocab at 0x116906350>),
#  ('tyrell', <gensim.models.keyedvectors.Vocab at 0x1167f3e50>),
#  ('son', <gensim.models.keyedvectors.Vocab at 0x1167f3e90>),
#  ('thankful', <gensim.models.keyedvectors.Vocab at 0x1167f3ed0>),
#  ('consummated', <gensim.models.keyedvectors.Vocab at 0x1167f3f10>),
#  ('sow', <gensim.models.keyedvectors.Vocab at 0x1167f3f50>),
#  ('wrap', <gensim.models.keyedvectors.Vocab at 0x1167f3f90>),
#  ('despised', <gensim.models.keyedvectors.Vocab at 0x1167f3fd0>),
#  ('fabric', <gensim.models.keyedvectors.Vocab at 0x1167f8050>),
#  ('suffice', <gensim.models.keyedvectors.Vocab at 0x1167f8090>),
#  ('tame', <gensim.models.keyedvectors.Vocab at 0x1167f80d0>),
#  ('grasping', <gensim.models.keyedvectors.Vocab at 0x1167f8110>),
#  ('despises', <gensim.models.keyedvectors.Vocab at 0x1167f8150>),
#  ('greatness', <gensim.models.keyedvectors.Vocab at 0x1167f8190>),
#  ('music', <gensim.models.keyedvectors.Vocab at 0x11682fed0>),
#  ('thoros', <gensim.models.keyedvectors.Vocab at 0x11689dd50>),
#  ('underestimated', <gensim.models.keyedvectors.Vocab at 0x1167f8250>),
#  ('offer', <gensim.models.keyedvectors.Vocab at 0x1167f8290>),
#  ('shireen', <gensim.models.keyedvectors.Vocab at 0x1167f82d0>),
#  ('perfumed', <gensim.models.keyedvectors.Vocab at 0x1167f8310>),
#  ('matthos', <gensim.models.keyedvectors.Vocab at 0x1167f8350>),
#  ('duel', <gensim.models.keyedvectors.Vocab at 0x1167f8390>),
#  ('inside', <gensim.models.keyedvectors.Vocab at 0x1167f83d0>),
#  ('morning', <gensim.models.keyedvectors.Vocab at 0x116932e50>),
#  ('vanguard', <gensim.models.keyedvectors.Vocab at 0x1167f8410>),
#  ('pest', <gensim.models.keyedvectors.Vocab at 0x1167f8450>),
#  ('torturing', <gensim.models.keyedvectors.Vocab at 0x1167f8490>),
#  ('smashed', <gensim.models.keyedvectors.Vocab at 0x1167f84d0>),
#  ('juvenile', <gensim.models.keyedvectors.Vocab at 0x1167f8510>),
#  ('later', <gensim.models.keyedvectors.Vocab at 0x116a91690>),
#  ('proved', <gensim.models.keyedvectors.Vocab at 0x1167f8590>),
#  ('arwyen', <gensim.models.keyedvectors.Vocab at 0x1167f85d0>),
#  ('tournament', <gensim.models.keyedvectors.Vocab at 0x1167f8610>),
#  ('proven', <gensim.models.keyedvectors.Vocab at 0x1167f8650>),
#  ('meros', <gensim.models.keyedvectors.Vocab at 0x1167f8690>),
#  ('soothe', <gensim.models.keyedvectors.Vocab at 0x1167f86d0>),
#  ('exist', <gensim.models.keyedvectors.Vocab at 0x1167f8710>),
#  ('accounting', <gensim.models.keyedvectors.Vocab at 0x1167f8750>),
#  ('floor', <gensim.models.keyedvectors.Vocab at 0x1167f8790>),
#  (u'actor', <gensim.models.keyedvectors.Vocab at 0x1167f87d0>),
#  ('uttered', <gensim.models.keyedvectors.Vocab at 0x1167f8810>),
#  ('flood', <gensim.models.keyedvectors.Vocab at 0x1167f8850>),
#  ('underfed', <gensim.models.keyedvectors.Vocab at 0x1168a8e10>),
#  ('role', <gensim.models.keyedvectors.Vocab at 0x1167f88d0>),
#  ('ambitious', <gensim.models.keyedvectors.Vocab at 0x1167f8910>),
#  ('smell', <gensim.models.keyedvectors.Vocab at 0x1167f8950>),
#  ('roll', <gensim.models.keyedvectors.Vocab at 0x1167f8990>),
#  ('intend', <gensim.models.keyedvectors.Vocab at 0x1167f89d0>),
#  ('corbray', <gensim.models.keyedvectors.Vocab at 0x1167f8a10>),
#  (u'ointment', <gensim.models.keyedvectors.Vocab at 0x1167f8a50>),
#  ('scream', <gensim.models.keyedvectors.Vocab at 0x1167e8590>),
#  ('acquaintance', <gensim.models.keyedvectors.Vocab at 0x1167f8a90>),
#  ('giantsbane', <gensim.models.keyedvectors.Vocab at 0x1167f8ad0>),
#  ('cleaver', <gensim.models.keyedvectors.Vocab at 0x1167f8b10>),
#  (u'daugters', <gensim.models.keyedvectors.Vocab at 0x1167f8b50>),
#  ('warn', <gensim.models.keyedvectors.Vocab at 0x116906610>),
#  ('pycelle', <gensim.models.keyedvectors.Vocab at 0x1167f8bd0>),
#  ('sniffed', <gensim.models.keyedvectors.Vocab at 0x1167f8c10>),
#  ('quandary', <gensim.models.keyedvectors.Vocab at 0x1167f8c50>),
#  ('time', <gensim.models.keyedvectors.Vocab at 0x1167f8c90>),
#  ('push', <gensim.models.keyedvectors.Vocab at 0x1167f8cd0>),
#  ('someplace', <gensim.models.keyedvectors.Vocab at 0x116a8c610>),
#  ('dotes', <gensim.models.keyedvectors.Vocab at 0x1167f8d10>),
#  ('gown', <gensim.models.keyedvectors.Vocab at 0x1167f8d50>),
#  ('chain', <gensim.models.keyedvectors.Vocab at 0x1167f8d90>),
#  ('whoever', <gensim.models.keyedvectors.Vocab at 0x1167f8dd0>),
#  ('warg', <gensim.models.keyedvectors.Vocab at 0x116906710>),
#  ('chair', <gensim.models.keyedvectors.Vocab at 0x1167f8e50>),
#  ('midst', <gensim.models.keyedvectors.Vocab at 0x1167d6e50>),
#  ('quartered', <gensim.models.keyedvectors.Vocab at 0x1167f8ed0>),
#  (u'lothar', <gensim.models.keyedvectors.Vocab at 0x1167f8f10>),
#  ('choice', <gensim.models.keyedvectors.Vocab at 0x1167f8f50>),
#  ('mourn', <gensim.models.keyedvectors.Vocab at 0x1167f8f90>),
#  ('locked', <gensim.models.keyedvectors.Vocab at 0x1167d6ed0>),
#  (u'exact', <gensim.models.keyedvectors.Vocab at 0x1167fe050>),
#  ('minute', <gensim.models.keyedvectors.Vocab at 0x1167fe090>),
#  ('tear', <gensim.models.keyedvectors.Vocab at 0x1167fe0d0>),
#  (u'teat', <gensim.models.keyedvectors.Vocab at 0x1167fe110>),
#  (u'pea', <gensim.models.keyedvectors.Vocab at 0x1167fe150>),
#  ('leave', <gensim.models.keyedvectors.Vocab at 0x1167fe190>),
#  ('settle', <gensim.models.keyedvectors.Vocab at 0x1167fe1d0>),
#  ('stockade', <gensim.models.keyedvectors.Vocab at 0x1167fe210>),
#  (u'team', <gensim.models.keyedvectors.Vocab at 0x1167fe250>),
#  ('bonfire', <gensim.models.keyedvectors.Vocab at 0x1167fe290>),
#  (u'accomplishment', <gensim.models.keyedvectors.Vocab at 0x1167d6fd0>),
#  (u'sigh', <gensim.models.keyedvectors.Vocab at 0x1167fe310>),
#  ('sign', <gensim.models.keyedvectors.Vocab at 0x1167fe350>),
#  ('chopping', <gensim.models.keyedvectors.Vocab at 0x1167fe390>),
#  ('catelyn', <gensim.models.keyedvectors.Vocab at 0x1167fe3d0>),
#  (u'melt', <gensim.models.keyedvectors.Vocab at 0x1167fe410>),
#  ('current', <gensim.models.keyedvectors.Vocab at 0x1167fe450>),
#  ('axel', <gensim.models.keyedvectors.Vocab at 0x1167fe490>),
#  ('falling', <gensim.models.keyedvectors.Vocab at 0x1167fe4d0>),
#  ('crashing', <gensim.models.keyedvectors.Vocab at 0x1168a3690>),
#  ('badge', <gensim.models.keyedvectors.Vocab at 0x1167fe550>),
#  ('ramming', <gensim.models.keyedvectors.Vocab at 0x1167fe590>),
#  (u'funeral', <gensim.models.keyedvectors.Vocab at 0x1167fe5d0>),
#  ('understanding', <gensim.models.keyedvectors.Vocab at 0x1167fe610>),
#  ('contemplate', <gensim.models.keyedvectors.Vocab at 0x1167fe650>),
#  ('address', <gensim.models.keyedvectors.Vocab at 0x1167fe690>),
#  ('alone', <gensim.models.keyedvectors.Vocab at 0x1167fe6d0>),
#  ('along', <gensim.models.keyedvectors.Vocab at 0x1167fe710>),
#  ('crumbles', <gensim.models.keyedvectors.Vocab at 0x1167fe750>),
#  (u'summerwine', <gensim.models.keyedvectors.Vocab at 0x1167fe790>),
#  ('brilliant', <gensim.models.keyedvectors.Vocab at 0x1167fe7d0>),
#  ('studied', <gensim.models.keyedvectors.Vocab at 0x1167fe810>),
#  ('wherever', <gensim.models.keyedvectors.Vocab at 0x1167fe850>),
#  (u'commonly', <gensim.models.keyedvectors.Vocab at 0x1167fe890>),
#  ('accomplished', <gensim.models.keyedvectors.Vocab at 0x1167fe8d0>),
#  ('greizhen', <gensim.models.keyedvectors.Vocab at 0x1167fe910>),
#  (u'reclaim', <gensim.models.keyedvectors.Vocab at 0x1167fe950>),
#  ('nowhere', <gensim.models.keyedvectors.Vocab at 0x1167fe990>),
#  ('love', <gensim.models.keyedvectors.Vocab at 0x1167fe9d0>),
#  ('prefer', <gensim.models.keyedvectors.Vocab at 0x1167fea10>),
#  ('logical', <gensim.models.keyedvectors.Vocab at 0x1167fea50>),
#  ('bloody', <gensim.models.keyedvectors.Vocab at 0x1167fea90>),
#  ('marvelous', <gensim.models.keyedvectors.Vocab at 0x1167fead0>),
#  ('betraying', <gensim.models.keyedvectors.Vocab at 0x1167feb10>),
#  (u'sky', <gensim.models.keyedvectors.Vocab at 0x116ae4f50>),
#  (u'capsized', <gensim.models.keyedvectors.Vocab at 0x1167feb50>),
#  ('working', <gensim.models.keyedvectors.Vocab at 0x1167feb90>),
#  ('angry', <gensim.models.keyedvectors.Vocab at 0x1167febd0>),
#  ('blackwater', <gensim.models.keyedvectors.Vocab at 0x1167fec10>),
#  (u'cockfighting', <gensim.models.keyedvectors.Vocab at 0x1167fec50>),
#  ('wondering', <gensim.models.keyedvectors.Vocab at 0x1167fec90>),
#  (u'halfbrother', <gensim.models.keyedvectors.Vocab at 0x1167fecd0>),
#  ('wicked', <gensim.models.keyedvectors.Vocab at 0x1167fed10>),
#  (u'introducing', <gensim.models.keyedvectors.Vocab at 0x1167fed50>),
#  (u'guardsman', <gensim.models.keyedvectors.Vocab at 0x1167fed90>),
#  ('afford', <gensim.models.keyedvectors.Vocab at 0x1167fedd0>),
#  ('xaros', <gensim.models.keyedvectors.Vocab at 0x116aa7090>),
#  ('marbled', <gensim.models.keyedvectors.Vocab at 0x1167fee10>),
#  ('everywhere', <gensim.models.keyedvectors.Vocab at 0x1167fee50>),
#  ('virtue', <gensim.models.keyedvectors.Vocab at 0x1167fee90>),
#  ('behalf', <gensim.models.keyedvectors.Vocab at 0x1167feed0>),
#  ('honey', <gensim.models.keyedvectors.Vocab at 0x116906990>),
#  ('valued', <gensim.models.keyedvectors.Vocab at 0x1167fef50>),
#  ('anything', <gensim.models.keyedvectors.Vocab at 0x116840410>),
#  ('originally', <gensim.models.keyedvectors.Vocab at 0x1167fefd0>),
#  (u'pretend', <gensim.models.keyedvectors.Vocab at 0x116803050>),
#  ('privy', <gensim.models.keyedvectors.Vocab at 0x116803090>),
#  ('believer', <gensim.models.keyedvectors.Vocab at 0x1168030d0>),
#  (u'impasse', <gensim.models.keyedvectors.Vocab at 0x116803110>),
#  ('believed', <gensim.models.keyedvectors.Vocab at 0x116803150>),
#  ('admired', <gensim.models.keyedvectors.Vocab at 0x116803190>),
#  ('locke', <gensim.models.keyedvectors.Vocab at 0x1168031d0>),
#  (u'unconsummated', <gensim.models.keyedvectors.Vocab at 0x116803210>),
#  ('unveiled', <gensim.models.keyedvectors.Vocab at 0x116803250>),
#  ('allowed', <gensim.models.keyedvectors.Vocab at 0x116803290>),
#  ('offense', <gensim.models.keyedvectors.Vocab at 0x1168032d0>),
#  ('stole', <gensim.models.keyedvectors.Vocab at 0x116803310>),
#  ('evidently', <gensim.models.keyedvectors.Vocab at 0x116803350>),
#  ('listens', <gensim.models.keyedvectors.Vocab at 0x116803390>),
#  ('winter', <gensim.models.keyedvectors.Vocab at 0x1168033d0>),
#  (u'divided', <gensim.models.keyedvectors.Vocab at 0x116803410>),
#  ('thanking', <gensim.models.keyedvectors.Vocab at 0x116803450>),
#  ('immune', <gensim.models.keyedvectors.Vocab at 0x116803490>),
#  ('loathe', <gensim.models.keyedvectors.Vocab at 0x116906a50>),
#  (u'encampment', <gensim.models.keyedvectors.Vocab at 0x116803510>),
#  (u'provincial', <gensim.models.keyedvectors.Vocab at 0x116803550>),
#  ('spot', <gensim.models.keyedvectors.Vocab at 0x116803590>),
#  ('suck', <gensim.models.keyedvectors.Vocab at 0x1168035d0>),
#  ('dove', <gensim.models.keyedvectors.Vocab at 0x116803610>),
#  (u'stress', <gensim.models.keyedvectors.Vocab at 0x116803650>),
#  ('natural', <gensim.models.keyedvectors.Vocab at 0x116803690>),
#  ('blackfish', <gensim.models.keyedvectors.Vocab at 0x116a91c90>),
#  ('st', <gensim.models.keyedvectors.Vocab at 0x116803710>),
#  ('swollen', <gensim.models.keyedvectors.Vocab at 0x116803750>),
#  ('truce', <gensim.models.keyedvectors.Vocab at 0x116803790>),
#  ('pulled', <gensim.models.keyedvectors.Vocab at 0x1168037d0>),
#  ('drunken', <gensim.models.keyedvectors.Vocab at 0x116803810>),
#  (u'footstep', <gensim.models.keyedvectors.Vocab at 0x116803850>),
#  ('unacceptable', <gensim.models.keyedvectors.Vocab at 0x116803890>),
#  ('damage', <gensim.models.keyedvectors.Vocab at 0x1168038d0>),
#  ('course', <gensim.models.keyedvectors.Vocab at 0x116803910>),
#  ('yearn', <gensim.models.keyedvectors.Vocab at 0x116803950>),
#  ('mishear', <gensim.models.keyedvectors.Vocab at 0x116803990>),
#  ('lovelier', <gensim.models.keyedvectors.Vocab at 0x1168039d0>),
#  (u'tendency', <gensim.models.keyedvectors.Vocab at 0x116803a10>),
#  ('tore', <gensim.models.keyedvectors.Vocab at 0x116803a50>),
#  ('milked', <gensim.models.keyedvectors.Vocab at 0x116803a90>),
#  ('torn', <gensim.models.keyedvectors.Vocab at 0x116803ad0>),
#  ('stupidity', <gensim.models.keyedvectors.Vocab at 0x116906ad0>),
#  ('aerion', <gensim.models.keyedvectors.Vocab at 0x116803b50>),
#  ('celebrate', <gensim.models.keyedvectors.Vocab at 0x116803b90>),
#  ('troubled', <gensim.models.keyedvectors.Vocab at 0x116803bd0>),
#  (u'deviant', <gensim.models.keyedvectors.Vocab at 0x116803c10>),
#  (u'chaining', <gensim.models.keyedvectors.Vocab at 0x116803c50>),
#  ('smarter', <gensim.models.keyedvectors.Vocab at 0x116803c90>),
#  ('arriving', <gensim.models.keyedvectors.Vocab at 0x116803cd0>),
#  ('reckoning', <gensim.models.keyedvectors.Vocab at 0x116803d10>),
#  (u'shhh', <gensim.models.keyedvectors.Vocab at 0x116803d50>),
#  ('maintaining', <gensim.models.keyedvectors.Vocab at 0x116803d90>),
#  ('matched', <gensim.models.keyedvectors.Vocab at 0x116803dd0>),
#  ('freya', <gensim.models.keyedvectors.Vocab at 0x116803e10>),
#  ('appropriate', <gensim.models.keyedvectors.Vocab at 0x116840590>),
#  ('stillborns', <gensim.models.keyedvectors.Vocab at 0x116803e90>),
#  ('fisherman', <gensim.models.keyedvectors.Vocab at 0x116803ed0>),
#  ('amnesty', <gensim.models.keyedvectors.Vocab at 0x116803f10>),
#  (u'quarter', <gensim.models.keyedvectors.Vocab at 0x116803f50>),
#  ('broodmare', <gensim.models.keyedvectors.Vocab at 0x116803f90>),
#  ('square', <gensim.models.keyedvectors.Vocab at 0x116803fd0>),
#  ('beloved', <gensim.models.keyedvectors.Vocab at 0x116809050>),
#  ('entering', <gensim.models.keyedvectors.Vocab at 0x116809090>),
#  (u'beetle', <gensim.models.keyedvectors.Vocab at 0x1168090d0>),
#  ('troll', <gensim.models.keyedvectors.Vocab at 0x116809110>),
#  (u'swordsman', <gensim.models.keyedvectors.Vocab at 0x116809150>),
#  ('seriously', <gensim.models.keyedvectors.Vocab at 0x116809190>),
#  ('investigation', <gensim.models.keyedvectors.Vocab at 0x1168091d0>),
#  ('suggesting', <gensim.models.keyedvectors.Vocab at 0x116809210>),
#  ('facedown', <gensim.models.keyedvectors.Vocab at 0x116809290>),
#  ('siege', <gensim.models.keyedvectors.Vocab at 0x1168092d0>),
#  ('million', <gensim.models.keyedvectors.Vocab at 0x116809310>),
#  ('seventh', <gensim.models.keyedvectors.Vocab at 0x116809350>),
#  (u'possibility', <gensim.models.keyedvectors.Vocab at 0x116809390>),
#  ('quite', <gensim.models.keyedvectors.Vocab at 0x1168093d0>),
#  ('complicated', <gensim.models.keyedvectors.Vocab at 0x116809450>),
#  ('besides', <gensim.models.keyedvectors.Vocab at 0x116809490>),
#  (u'grandma', <gensim.models.keyedvectors.Vocab at 0x1168094d0>),
#  ('unnamed', <gensim.models.keyedvectors.Vocab at 0x116809510>),
#  ('patronage', <gensim.models.keyedvectors.Vocab at 0x116809550>),
#  ('training', <gensim.models.keyedvectors.Vocab at 0x116809590>),
#  ('backside', <gensim.models.keyedvectors.Vocab at 0x1168095d0>),
#  ('modest', <gensim.models.keyedvectors.Vocab at 0x116809610>),
#  (u'nymeria', <gensim.models.keyedvectors.Vocab at 0x116809650>),
#  ('saving', <gensim.models.keyedvectors.Vocab at 0x116809690>),
#  ('spoken', <gensim.models.keyedvectors.Vocab at 0x1168096d0>),
#  ('one', <gensim.models.keyedvectors.Vocab at 0x116809710>),
#  (u'reopen', <gensim.models.keyedvectors.Vocab at 0x116809750>),
#  ('punishable', <gensim.models.keyedvectors.Vocab at 0x116809790>),
#  ('vote', <gensim.models.keyedvectors.Vocab at 0x1168097d0>),
#  ('open', <gensim.models.keyedvectors.Vocab at 0x116809810>),
#  ('ripping', <gensim.models.keyedvectors.Vocab at 0x11690b810>),
#  ('partook', <gensim.models.keyedvectors.Vocab at 0x116809890>),
#  (u'city', <gensim.models.keyedvectors.Vocab at 0x1168098d0>),
#  (u'wrath', <gensim.models.keyedvectors.Vocab at 0x116809910>),
#  ('bite', <gensim.models.keyedvectors.Vocab at 0x116809950>),
#  ('teacher', <gensim.models.keyedvectors.Vocab at 0x116abd890>),
#  (u'shiver', <gensim.models.keyedvectors.Vocab at 0x116809990>),
#  ('prone', <gensim.models.keyedvectors.Vocab at 0x1168099d0>),
#  ('shawl', <gensim.models.keyedvectors.Vocab at 0x116809a10>),
#  ('meddling', <gensim.models.keyedvectors.Vocab at 0x116809a50>),
#  (u'padding', <gensim.models.keyedvectors.Vocab at 0x116809a90>),
#  ('prowling', <gensim.models.keyedvectors.Vocab at 0x116840790>),
#  ('ridiculous', <gensim.models.keyedvectors.Vocab at 0x116809b10>),
#  (u'camello', <gensim.models.keyedvectors.Vocab at 0x116809b50>),
#  ('third', <gensim.models.keyedvectors.Vocab at 0x116906cd0>),
#  ('cower', <gensim.models.keyedvectors.Vocab at 0x116916110>),
#  ('sandor', <gensim.models.keyedvectors.Vocab at 0x116809c10>),
#  (u'counselor', <gensim.models.keyedvectors.Vocab at 0x116809c50>),
#  (u'wandering', <gensim.models.keyedvectors.Vocab at 0x116809c90>),
#  ('damned', <gensim.models.keyedvectors.Vocab at 0x116809cd0>),
#  ('prospect', <gensim.models.keyedvectors.Vocab at 0x116809d10>),
#  (u'addressing', <gensim.models.keyedvectors.Vocab at 0x116809d50>),
#  (u'illness', <gensim.models.keyedvectors.Vocab at 0x116809d90>),
#  ('tasted', <gensim.models.keyedvectors.Vocab at 0x116809dd0>),
#  ('nicer', <gensim.models.keyedvectors.Vocab at 0x116809e10>),
#  ('turned', <gensim.models.keyedvectors.Vocab at 0x116809e50>),
#  ('alley', <gensim.models.keyedvectors.Vocab at 0x116809e90>),
#  ('sad', <gensim.models.keyedvectors.Vocab at 0x116809ed0>),
#  ('say', <gensim.models.keyedvectors.Vocab at 0x116809f10>),
#  ('taster', <gensim.models.keyedvectors.Vocab at 0x116809f50>),
#  ('buried', <gensim.models.keyedvectors.Vocab at 0x116809f90>),
#  ('lurking', <gensim.models.keyedvectors.Vocab at 0x116809fd0>),
#  ('sap', <gensim.models.keyedvectors.Vocab at 0x11680e050>),
#  ('saw', <gensim.models.keyedvectors.Vocab at 0x11680e090>),
#  ('sat', <gensim.models.keyedvectors.Vocab at 0x11680e0d0>),
#  ('wink', <gensim.models.keyedvectors.Vocab at 0x11680e110>),
#  (u'downwards', <gensim.models.keyedvectors.Vocab at 0x11680e150>),
#  ('aside', <gensim.models.keyedvectors.Vocab at 0x11691cb90>),
#  ('instructed', <gensim.models.keyedvectors.Vocab at 0x11680e1d0>),
#  ('note', <gensim.models.keyedvectors.Vocab at 0x11680e210>),
#  ('take', <gensim.models.keyedvectors.Vocab at 0x11680e250>),
#  (u'mazin', <gensim.models.keyedvectors.Vocab at 0x11680e290>),
#  ('wanting', <gensim.models.keyedvectors.Vocab at 0x11691cf50>),
#  (u'opposite', <gensim.models.keyedvectors.Vocab at 0x11680e310>),
#  ('squalor', <gensim.models.keyedvectors.Vocab at 0x11680e350>),
#  ('knew', <gensim.models.keyedvectors.Vocab at 0x11680e390>),
#  ('knee', <gensim.models.keyedvectors.Vocab at 0x11680e3d0>),
#  ('average', <gensim.models.keyedvectors.Vocab at 0x11680e410>),
#  (u'sale', <gensim.models.keyedvectors.Vocab at 0x116921d90>),
#  (u'defeating', <gensim.models.keyedvectors.Vocab at 0x11680e490>),
#  ('crooked', <gensim.models.keyedvectors.Vocab at 0x116a91fd0>),
#  ('gillyflower', <gensim.models.keyedvectors.Vocab at 0x11680e510>),
#  ('squint', <gensim.models.keyedvectors.Vocab at 0x11680e550>),
#  ('butchered', <gensim.models.keyedvectors.Vocab at 0x11680e590>),
#  ('salt', <gensim.models.keyedvectors.Vocab at 0x11680e5d0>),
#  ('walking', <gensim.models.keyedvectors.Vocab at 0x11680e610>),
#  (u'merit', <gensim.models.keyedvectors.Vocab at 0x11680e650>),
#  ('bright', <gensim.models.keyedvectors.Vocab at 0x11680e690>),
#  ('imagined', <gensim.models.keyedvectors.Vocab at 0x11680e6d0>),
#  ('slow', <gensim.models.keyedvectors.Vocab at 0x11680e710>),
#  ('strangled', <gensim.models.keyedvectors.Vocab at 0x116948890>),
#  (u'cloak', <gensim.models.keyedvectors.Vocab at 0x11680e750>),
#  ('liberation', <gensim.models.keyedvectors.Vocab at 0x11680e790>),
#  ('betrothal', <gensim.models.keyedvectors.Vocab at 0x11680e7d0>),
#  ('going', <gensim.models.keyedvectors.Vocab at 0x11680e810>),
#  ('dancing', <gensim.models.keyedvectors.Vocab at 0x116ac3290>),
#  ('outrage', <gensim.models.keyedvectors.Vocab at 0x11680e850>),
#  ('robe', <gensim.models.keyedvectors.Vocab at 0x11680e890>),
#  ('clawing', <gensim.models.keyedvectors.Vocab at 0x11680e8d0>),
#  ('robb', <gensim.models.keyedvectors.Vocab at 0x11680e910>),
#  (u'dispute', <gensim.models.keyedvectors.Vocab at 0x11680e950>),
#  ('graceless', <gensim.models.keyedvectors.Vocab at 0x11680e990>),
#  ('guarded', <gensim.models.keyedvectors.Vocab at 0x11680e9d0>),
#  ('freezing', <gensim.models.keyedvectors.Vocab at 0x11680ea10>),
#  (u'clang', <gensim.models.keyedvectors.Vocab at 0x11680ea50>),
#  ('awaiting', <gensim.models.keyedvectors.Vocab at 0x11680ea90>),
#  ('vhag', <gensim.models.keyedvectors.Vocab at 0x11680ead0>),
#  ('prime', <gensim.models.keyedvectors.Vocab at 0x11680eb10>),
#  (u'resource', <gensim.models.keyedvectors.Vocab at 0x11680eb50>),
#  (u'artist', <gensim.models.keyedvectors.Vocab at 0x11680eb90>),
#  ('absurdly', <gensim.models.keyedvectors.Vocab at 0x11680ebd0>),
#  ('worried', <gensim.models.keyedvectors.Vocab at 0x11680ec10>),
#  ('carrion', <gensim.models.keyedvectors.Vocab at 0x11680ec50>),
#  ('priest', <gensim.models.keyedvectors.Vocab at 0x11680ec90>),
#  (u'primp', <gensim.models.keyedvectors.Vocab at 0x11680ecd0>),
#  (u'vision', <gensim.models.keyedvectors.Vocab at 0x11680ed10>),
#  ('gout', <gensim.models.keyedvectors.Vocab at 0x11680ed50>),
#  ('raged', <gensim.models.keyedvectors.Vocab at 0x11680ed90>),
#  ('notice', <gensim.models.keyedvectors.Vocab at 0x11680edd0>),
#  ('purest', <gensim.models.keyedvectors.Vocab at 0x11680ee10>),
#  ('stannis', <gensim.models.keyedvectors.Vocab at 0x11680ee50>),
#  ('mutton', <gensim.models.keyedvectors.Vocab at 0x11680ee90>),
#  ('jumped', <gensim.models.keyedvectors.Vocab at 0x11693d150>),
#  ('enjoys', <gensim.models.keyedvectors.Vocab at 0x11680ef10>),
#  ('amory', <gensim.models.keyedvectors.Vocab at 0x11680ef50>),
#  ('spare', <gensim.models.keyedvectors.Vocab at 0x11680ef90>),
#  ('umber', <gensim.models.keyedvectors.Vocab at 0x11680efd0>),
#  ('undermine', <gensim.models.keyedvectors.Vocab at 0x116814050>),
#  ('mant', <gensim.models.keyedvectors.Vocab at 0x116814090>),
#  ('many', <gensim.models.keyedvectors.Vocab at 0x1168140d0>),
#  ('loudly', <gensim.models.keyedvectors.Vocab at 0x116814110>),
#  (u'riddle', <gensim.models.keyedvectors.Vocab at 0x116814150>),
#  ('drogo', <gensim.models.keyedvectors.Vocab at 0x116814190>),
#  (u'compels', <gensim.models.keyedvectors.Vocab at 0x1168141d0>),
#  (u'twin', <gensim.models.keyedvectors.Vocab at 0x116814210>),
#  ('boar', <gensim.models.keyedvectors.Vocab at 0x116814250>),
#  (u'considers', <gensim.models.keyedvectors.Vocab at 0x1169485d0>),
#  ('boat', <gensim.models.keyedvectors.Vocab at 0x1168142d0>),
#  (u'stretch', <gensim.models.keyedvectors.Vocab at 0x116814310>),
#  ('west', <gensim.models.keyedvectors.Vocab at 0x116814350>),
#  (u'expedition', <gensim.models.keyedvectors.Vocab at 0x116814390>),
#  ('breath', <gensim.models.keyedvectors.Vocab at 0x1168143d0>),
#  ('combined', <gensim.models.keyedvectors.Vocab at 0x116814410>),
#  ('stripped', <gensim.models.keyedvectors.Vocab at 0x116814450>),
#  ('coughing', <gensim.models.keyedvectors.Vocab at 0x11694d610>),
#  ('centerpiece', <gensim.models.keyedvectors.Vocab at 0x1168144d0>),
#  ('observe', <gensim.models.keyedvectors.Vocab at 0x116814510>),
#  (u'extant', <gensim.models.keyedvectors.Vocab at 0x116814550>),
#  ('former', <gensim.models.keyedvectors.Vocab at 0x116814590>),
#  ('wherewithal', <gensim.models.keyedvectors.Vocab at 0x1168145d0>),
#  (u'fin', <gensim.models.keyedvectors.Vocab at 0x116814610>),
#  ('straighten', <gensim.models.keyedvectors.Vocab at 0x116953190>),
#  ('whatevers', <gensim.models.keyedvectors.Vocab at 0x116a972d0>),
#  ('squeezed', <gensim.models.keyedvectors.Vocab at 0x1168146d0>),
#  (u'situation', <gensim.models.keyedvectors.Vocab at 0x116814710>),
#  ('endured', <gensim.models.keyedvectors.Vocab at 0x116814750>),
#  ('ive', <gensim.models.keyedvectors.Vocab at 0x116814790>),
#  ('thatll', <gensim.models.keyedvectors.Vocab at 0x1168147d0>),
#  ('purse', <gensim.models.keyedvectors.Vocab at 0x116814810>),
#  ('shevelathin', <gensim.models.keyedvectors.Vocab at 0x116814850>),
#  ('spooked', <gensim.models.keyedvectors.Vocab at 0x116814890>),
#  ('burbling', <gensim.models.keyedvectors.Vocab at 0x1168148d0>),
#  ('threatens', <gensim.models.keyedvectors.Vocab at 0x116814910>),
#  ('damon', <gensim.models.keyedvectors.Vocab at 0x116814950>),
#  ('edged', <gensim.models.keyedvectors.Vocab at 0x116814990>),
#  ('sickness', <gensim.models.keyedvectors.Vocab at 0x11695e3d0>),
#  ('defy', <gensim.models.keyedvectors.Vocab at 0x116814a10>),
# ...
#  ('dark', <gensim.models.keyedvectors.Vocab at 0x116814dd0>),
#  ('preference', <gensim.models.keyedvectors.Vocab at 0x116814e10>),
#  ('fringed', <gensim.models.keyedvectors.Vocab at 0x11691c790>),
#  ('vague', <gensim.models.keyedvectors.Vocab at 0x116814e90>),
#  ('bravery', <gensim.models.keyedvectors.Vocab at 0x116814ed0>),
#  (u'clan', <gensim.models.keyedvectors.Vocab at 0x116814f10>),
#  (u'clam', <gensim.models.keyedvectors.Vocab at 0x116814f50>),
#  ('stranger', <gensim.models.keyedvectors.Vocab at 0x116814f90>),
#  ('discarded', <gensim.models.keyedvectors.Vocab at 0x116814fd0>),
#  ('superiority', <gensim.models.keyedvectors.Vocab at 0x116819050>),
#  (u'claw', <gensim.models.keyedvectors.Vocab at 0x116819090>),
#  ('sorcerer', <gensim.models.keyedvectors.Vocab at 0x116845050>),
#  (u'kennel', <gensim.models.keyedvectors.Vocab at 0x116819110>),
#  (u'clap', <gensim.models.keyedvectors.Vocab at 0x116819150>),
#  ('grub', <gensim.models.keyedvectors.Vocab at 0x116819190>),
#  (u'lobster', <gensim.models.keyedvectors.Vocab at 0x1168191d0>),
#  (u'divine', <gensim.models.keyedvectors.Vocab at 0x116819210>),
#  ('crabber', <gensim.models.keyedvectors.Vocab at 0x116819250>),
#  ('dimpled', <gensim.models.keyedvectors.Vocab at 0x116819290>),
#  ('refer', <gensim.models.keyedvectors.Vocab at 0x1168192d0>),
#  (u'clarenzo', <gensim.models.keyedvectors.Vocab at 0x116819310>),
#  ('averse', <gensim.models.keyedvectors.Vocab at 0x116819350>),
#  ('power', <gensim.models.keyedvectors.Vocab at 0x116819390>),
#  ('intimate', <gensim.models.keyedvectors.Vocab at 0x1168193d0>),
#  ('hayseed', <gensim.models.keyedvectors.Vocab at 0x116819410>),
#  ('leadership', <gensim.models.keyedvectors.Vocab at 0x116819450>),
#  (u'stone', <gensim.models.keyedvectors.Vocab at 0x116819490>),
#  ('yunkai', <gensim.models.keyedvectors.Vocab at 0x1168194d0>),
#  ('favorite', <gensim.models.keyedvectors.Vocab at 0x116819510>),
#  (u'side', <gensim.models.keyedvectors.Vocab at 0x11690b490>),
#  (u'apostate', <gensim.models.keyedvectors.Vocab at 0x116819590>),
#  (u'neighbor', <gensim.models.keyedvectors.Vocab at 0x1168195d0>),
#  ('act', <gensim.models.keyedvectors.Vocab at 0x116819610>),
#  (u'mean', <gensim.models.keyedvectors.Vocab at 0x116969490>),
#  ('stony', <gensim.models.keyedvectors.Vocab at 0x116819690>),
#  (u'widowed', <gensim.models.keyedvectors.Vocab at 0x1168196d0>),
#  ('chivalry', <gensim.models.keyedvectors.Vocab at 0x116819710>),
#  ('shapely', <gensim.models.keyedvectors.Vocab at 0x116819750>),
#  ('burning', <gensim.models.keyedvectors.Vocab at 0x116819790>),
#  ('interruption', <gensim.models.keyedvectors.Vocab at 0x11690b550>),
#  (u'antidote', <gensim.models.keyedvectors.Vocab at 0x116819810>),
#  ('apologize', <gensim.models.keyedvectors.Vocab at 0x116819850>),
#  (u'pivot', <gensim.models.keyedvectors.Vocab at 0x116984410>),
#  ('trussed', <gensim.models.keyedvectors.Vocab at 0x1168198d0>),
#  ('hey', <gensim.models.keyedvectors.Vocab at 0x116819910>),
#  ('hed', <gensim.models.keyedvectors.Vocab at 0x116819950>),
#  (u'lhazareen', <gensim.models.keyedvectors.Vocab at 0x116819990>),
#  ('mindless', <gensim.models.keyedvectors.Vocab at 0x1168199d0>),
#  ('sealed', <gensim.models.keyedvectors.Vocab at 0x116819a10>),
#  (u'hen', <gensim.models.keyedvectors.Vocab at 0x116819a50>),
#  ('survives', <gensim.models.keyedvectors.Vocab at 0x116819a90>),
#  ('recommends', <gensim.models.keyedvectors.Vocab at 0x116819ad0>),
#  ('complete', <gensim.models.keyedvectors.Vocab at 0x116819b10>),
#  ('survived', <gensim.models.keyedvectors.Vocab at 0x116819b50>),
#  (u'whinny', <gensim.models.keyedvectors.Vocab at 0x116819b90>),
#  ('buying', <gensim.models.keyedvectors.Vocab at 0x116819bd0>),
#  ('handsome', <gensim.models.keyedvectors.Vocab at 0x116819c10>),
#  ('abused', <gensim.models.keyedvectors.Vocab at 0x116819c50>),
#  ('pull', <gensim.models.keyedvectors.Vocab at 0x116819c90>),
#  (u'rush', <gensim.models.keyedvectors.Vocab at 0x116819cd0>),
#  ('rage', <gensim.models.keyedvectors.Vocab at 0x116819d10>),
#  ('browbeaten', <gensim.models.keyedvectors.Vocab at 0x116819d50>),
#  ('balons', <gensim.models.keyedvectors.Vocab at 0x11690b5d0>),
#  ('dirty', <gensim.models.keyedvectors.Vocab at 0x116819dd0>),
#  ('agree', <gensim.models.keyedvectors.Vocab at 0x116819e10>),
#  ('darker', <gensim.models.keyedvectors.Vocab at 0x116819e50>),
#  (u'detailed', <gensim.models.keyedvectors.Vocab at 0x116819e90>),
#  ('gone', <gensim.models.keyedvectors.Vocab at 0x116819ed0>),
#  ('fright', <gensim.models.keyedvectors.Vocab at 0x116819f10>),
#  (u'exhausted', <gensim.models.keyedvectors.Vocab at 0x116819f50>),
#  ('ah', <gensim.models.keyedvectors.Vocab at 0x116819f90>),
#  ('stealing', <gensim.models.keyedvectors.Vocab at 0x11690b650>),
#  ('al', <gensim.models.keyedvectors.Vocab at 0x11681f050>),
#  ('wartime', <gensim.models.keyedvectors.Vocab at 0x11681f090>),
#  (u'watcher', <gensim.models.keyedvectors.Vocab at 0x11681f0d0>),
#  ('behest', <gensim.models.keyedvectors.Vocab at 0x11681f110>),
#  (u'as', <gensim.models.keyedvectors.Vocab at 0x11681f150>),
#  ('carved', <gensim.models.keyedvectors.Vocab at 0x11681f190>),
#  (u'midwife', <gensim.models.keyedvectors.Vocab at 0x11681f1d0>),
#  ('laboratory', <gensim.models.keyedvectors.Vocab at 0x11681f210>),
#  ('ax', <gensim.models.keyedvectors.Vocab at 0x11681f250>),
#  (u'johnna', <gensim.models.keyedvectors.Vocab at 0x11681f290>),
#  ('cream', <gensim.models.keyedvectors.Vocab at 0x11681f2d0>),
#  (u'ideally', <gensim.models.keyedvectors.Vocab at 0x11681f310>),
#  ('tight', <gensim.models.keyedvectors.Vocab at 0x11681f350>),
#  ('httpsubttfreeorg', <gensim.models.keyedvectors.Vocab at 0x11681f390>),
#  (u'puppy', <gensim.models.keyedvectors.Vocab at 0x11681f3d0>),
#  ('disgraceful', <gensim.models.keyedvectors.Vocab at 0x11681f450>),
#  (u'congress', <gensim.models.keyedvectors.Vocab at 0x11681f490>),
#  ('waving', <gensim.models.keyedvectors.Vocab at 0x11681f4d0>),
#  (u'middling', <gensim.models.keyedvectors.Vocab at 0x11681f510>),
#  (u'midget', <gensim.models.keyedvectors.Vocab at 0x11681f550>),
#  ('brotherhood', <gensim.models.keyedvectors.Vocab at 0x11681f590>),
#  ('tricky', <gensim.models.keyedvectors.Vocab at 0x11681f5d0>),
#  ('disdained', <gensim.models.keyedvectors.Vocab at 0x11681f610>),
#  ('infanticide', <gensim.models.keyedvectors.Vocab at 0x11681f650>),
#  ('sobbing', <gensim.models.keyedvectors.Vocab at 0x11681f690>),
#  (u'thorn', <gensim.models.keyedvectors.Vocab at 0x11681f6d0>),
#  ('groom', <gensim.models.keyedvectors.Vocab at 0x11681f710>),
#  (u'mask', <gensim.models.keyedvectors.Vocab at 0x11681f750>),
#  (u'dyed', <gensim.models.keyedvectors.Vocab at 0x11681f790>),
#  (u'mast', <gensim.models.keyedvectors.Vocab at 0x11681f7d0>),
#  (u'mass', <gensim.models.keyedvectors.Vocab at 0x11681f810>),
#  ('sawing', <gensim.models.keyedvectors.Vocab at 0x11681f850>),
#  (u'dyer', <gensim.models.keyedvectors.Vocab at 0x11681f890>),
#  ('original', <gensim.models.keyedvectors.Vocab at 0x11681f8d0>),
#  ('consider', <gensim.models.keyedvectors.Vocab at 0x11681f910>),
#  ('beware', <gensim.models.keyedvectors.Vocab at 0x11681f950>),
#  (u'neigh', <gensim.models.keyedvectors.Vocab at 0x11681f990>),
#  ('welfare', <gensim.models.keyedvectors.Vocab at 0x11681f9d0>),
#  ('hunting', <gensim.models.keyedvectors.Vocab at 0x11681fa10>),
#  ('tail', <gensim.models.keyedvectors.Vocab at 0x11681fa50>),
#  ('chewing', <gensim.models.keyedvectors.Vocab at 0x11681fa90>),
#  ('dockworker', <gensim.models.keyedvectors.Vocab at 0x11681fad0>),
#  ('th', <gensim.models.keyedvectors.Vocab at 0x11681fb10>),
#  (u'ti', <gensim.models.keyedvectors.Vocab at 0x11681fb50>),
#  ('smile', <gensim.models.keyedvectors.Vocab at 0x11681fb90>),
#  (u'shipload', <gensim.models.keyedvectors.Vocab at 0x11681fbd0>),
#  ('paying', <gensim.models.keyedvectors.Vocab at 0x116a97990>),
#  ('appointment', <gensim.models.keyedvectors.Vocab at 0x11681fc50>),
#  ('returned', <gensim.models.keyedvectors.Vocab at 0x11681fc90>),
#  ('squiring', <gensim.models.keyedvectors.Vocab at 0x11681fcd0>),
#  ('eyrie', <gensim.models.keyedvectors.Vocab at 0x11681fd10>),
#  ('condition', <gensim.models.keyedvectors.Vocab at 0x11681fd50>),
#  ('harrenhal', <gensim.models.keyedvectors.Vocab at 0x11681fd90>),
#  ('overprotective', <gensim.models.keyedvectors.Vocab at 0x11681fdd0>),
#  (u'laying', <gensim.models.keyedvectors.Vocab at 0x11681fe10>),
#  ('joined', <gensim.models.keyedvectors.Vocab at 0x11681fe50>),
#  ('underclothes', <gensim.models.keyedvectors.Vocab at 0x11681fe90>),
#  ('large', <gensim.models.keyedvectors.Vocab at 0x11681fed0>),
#  ('sang', <gensim.models.keyedvectors.Vocab at 0x11681ff10>),
#  ('sand', <gensim.models.keyedvectors.Vocab at 0x11681ff50>),
#  (u'adjust', <gensim.models.keyedvectors.Vocab at 0x11681ff90>),
#  ('small', <gensim.models.keyedvectors.Vocab at 0x11681ffd0>),
#  ('quicker', <gensim.models.keyedvectors.Vocab at 0x116824050>),
#  (u'healed', <gensim.models.keyedvectors.Vocab at 0x116824090>),
#  ('past', <gensim.models.keyedvectors.Vocab at 0x1168240d0>),
#  ('podrick', <gensim.models.keyedvectors.Vocab at 0x11690b910>),
#  (u'pass', <gensim.models.keyedvectors.Vocab at 0x116824150>),
#  ('turning', <gensim.models.keyedvectors.Vocab at 0x11690b950>),
#  (u'investment', <gensim.models.keyedvectors.Vocab at 0x1168241d0>),
#  ('poisonous', <gensim.models.keyedvectors.Vocab at 0x116824210>),
#  ('prevailed', <gensim.models.keyedvectors.Vocab at 0x116824250>),
#  ('nurse', <gensim.models.keyedvectors.Vocab at 0x116824290>),
#  ('full', <gensim.models.keyedvectors.Vocab at 0x1168242d0>),
#  ('escaping', <gensim.models.keyedvectors.Vocab at 0x116824310>),
#  ('vomiting', <gensim.models.keyedvectors.Vocab at 0x116824350>),
#  ('smartest', <gensim.models.keyedvectors.Vocab at 0x116824390>),
#  ('buzzing', <gensim.models.keyedvectors.Vocab at 0x1168243d0>),
#  ('legend', <gensim.models.keyedvectors.Vocab at 0x116824410>),
#  ('slynt', <gensim.models.keyedvectors.Vocab at 0x116824450>),
#  ('kayla', <gensim.models.keyedvectors.Vocab at 0x1167e0510>),
#  ('experience', <gensim.models.keyedvectors.Vocab at 0x1168244d0>),
#  ('pick', <gensim.models.keyedvectors.Vocab at 0x116824510>),
#  (u'action', <gensim.models.keyedvectors.Vocab at 0x116824550>),
#  ('murdering', <gensim.models.keyedvectors.Vocab at 0x116824590>),
#  ('luck', <gensim.models.keyedvectors.Vocab at 0x11690b510>),
#  ('smuggle', <gensim.models.keyedvectors.Vocab at 0x1168245d0>),
#  ('gawking', <gensim.models.keyedvectors.Vocab at 0x116824610>),
#  ('followed', <gensim.models.keyedvectors.Vocab at 0x116824650>),
#  (u'follower', <gensim.models.keyedvectors.Vocab at 0x116824690>),
#  (u'indoors', <gensim.models.keyedvectors.Vocab at 0x1168246d0>),
#  (u'captor', <gensim.models.keyedvectors.Vocab at 0x116824710>),
#  ('darkens', <gensim.models.keyedvectors.Vocab at 0x116824750>),
#  (u'moro', <gensim.models.keyedvectors.Vocab at 0x116824790>),
#  (u'gorgeous', <gensim.models.keyedvectors.Vocab at 0x1168247d0>),
#  (u'mord', <gensim.models.keyedvectors.Vocab at 0x116824810>),
#  ('restraint', <gensim.models.keyedvectors.Vocab at 0x116abdf50>),
#  ('door', <gensim.models.keyedvectors.Vocab at 0x116824850>),
#  ('company', <gensim.models.keyedvectors.Vocab at 0x116824890>),
#  ('tested', <gensim.models.keyedvectors.Vocab at 0x1168248d0>),
#  ('doom', <gensim.models.keyedvectors.Vocab at 0x116824910>),
#  ('riverbank', <gensim.models.keyedvectors.Vocab at 0x116824950>),
#  ('cunning', <gensim.models.keyedvectors.Vocab at 0x116824990>),
#  ('keeping', <gensim.models.keyedvectors.Vocab at 0x1168249d0>),
#  ('pleasing', <gensim.models.keyedvectors.Vocab at 0x116824a10>),
#  ('farted', <gensim.models.keyedvectors.Vocab at 0x116824a50>),
#  ('thickest', <gensim.models.keyedvectors.Vocab at 0x116824a90>),
#  ('learn', <gensim.models.keyedvectors.Vocab at 0x116824ad0>),
#  ('knocked', <gensim.models.keyedvectors.Vocab at 0x116824b10>),
#  ('sunspear', <gensim.models.keyedvectors.Vocab at 0x116824b50>),
#  (u'seagull', <gensim.models.keyedvectors.Vocab at 0x116824b90>),
#  (u'male', <gensim.models.keyedvectors.Vocab at 0x116824bd0>),
#  ('beautiful', <gensim.models.keyedvectors.Vocab at 0x116824c10>),
#  ('brightflame', <gensim.models.keyedvectors.Vocab at 0x116824c50>),
#  ('accept', <gensim.models.keyedvectors.Vocab at 0x116824c90>),
#  ('fiercely', <gensim.models.keyedvectors.Vocab at 0x116824cd0>),
#  ('sense', <gensim.models.keyedvectors.Vocab at 0x116824d10>),
#  ('scar', <gensim.models.keyedvectors.Vocab at 0x116824d90>),
#  ('dress', <gensim.models.keyedvectors.Vocab at 0x116824dd0>),
#  ('condemn', <gensim.models.keyedvectors.Vocab at 0x116824e10>),
#  ('information', <gensim.models.keyedvectors.Vocab at 0x116824e50>),
#  ('impulse', <gensim.models.keyedvectors.Vocab at 0x1168b9790>),
#  ('imminent', <gensim.models.keyedvectors.Vocab at 0x116824e90>),
#  (u'hugh', <gensim.models.keyedvectors.Vocab at 0x116824ed0>),
#  ('dismissed', <gensim.models.keyedvectors.Vocab at 0x116824f10>),
#  (u'glowing', <gensim.models.keyedvectors.Vocab at 0x116824f50>),
#  ('freshly', <gensim.models.keyedvectors.Vocab at 0x116824f90>),
#  (u'clink', <gensim.models.keyedvectors.Vocab at 0x116824fd0>),
#  ('unattended', <gensim.models.keyedvectors.Vocab at 0x11682a050>),
#  ('creature', <gensim.models.keyedvectors.Vocab at 0x11682a090>),
#  ('sprinkle', <gensim.models.keyedvectors.Vocab at 0x11682a0d0>),
#  ('intended', <gensim.models.keyedvectors.Vocab at 0x11682a110>),
#  ('countryside', <gensim.models.keyedvectors.Vocab at 0x11682a150>),
#  ('disgraced', <gensim.models.keyedvectors.Vocab at 0x11682a190>),
#  ('sympathize', <gensim.models.keyedvectors.Vocab at 0x11682a1d0>),
#  ('zuriff', <gensim.models.keyedvectors.Vocab at 0x11682a210>),
#  (u'pleaded', <gensim.models.keyedvectors.Vocab at 0x11682a250>),
#  ('plank', <gensim.models.keyedvectors.Vocab at 0x11682a290>),
#  ('refuse', <gensim.models.keyedvectors.Vocab at 0x11682a2d0>),
#  ('replied', <gensim.models.keyedvectors.Vocab at 0x11682a310>),
#  ('eddark', <gensim.models.keyedvectors.Vocab at 0x11682a350>),
#  (u'pant', <gensim.models.keyedvectors.Vocab at 0x11682a390>),
#  ('reminded', <gensim.models.keyedvectors.Vocab at 0x116a97cd0>),
#  ('eddard', <gensim.models.keyedvectors.Vocab at 0x11682a410>),
#  ('installed', <gensim.models.keyedvectors.Vocab at 0x11682a450>),
#  (u'paper', <gensim.models.keyedvectors.Vocab at 0x11682a490>),
#  (u'brim', <gensim.models.keyedvectors.Vocab at 0x11682a4d0>),
#  ('smiling', <gensim.models.keyedvectors.Vocab at 0x11682a510>),
#  ('aemon', <gensim.models.keyedvectors.Vocab at 0x11682a550>),
#  ('mistreated', <gensim.models.keyedvectors.Vocab at 0x11682a590>),
#  (u'mummer', <gensim.models.keyedvectors.Vocab at 0x11682a5d0>),
#  ('ruining', <gensim.models.keyedvectors.Vocab at 0x11682a610>),
#  (u'travelling', <gensim.models.keyedvectors.Vocab at 0x11682a650>),
#  ('ally', <gensim.models.keyedvectors.Vocab at 0x11682a690>),
#  ('colleague', <gensim.models.keyedvectors.Vocab at 0x11682a6d0>),
#  ('lowell', <gensim.models.keyedvectors.Vocab at 0x11682a710>),
#  ('propose', <gensim.models.keyedvectors.Vocab at 0x11682a750>),
#  ('martells', <gensim.models.keyedvectors.Vocab at 0x11682a790>),
#  (u'easterner', <gensim.models.keyedvectors.Vocab at 0x11682a7d0>),
#  (u'qyburns', <gensim.models.keyedvectors.Vocab at 0x11682a810>),
#  ('always', <gensim.models.keyedvectors.Vocab at 0x11682a850>),
#  ('repayment', <gensim.models.keyedvectors.Vocab at 0x11682a890>),
#  ('found', <gensim.models.keyedvectors.Vocab at 0x11682a8d0>),
#  ('shocking', <gensim.models.keyedvectors.Vocab at 0x11682a910>),
#  ('begged', <gensim.models.keyedvectors.Vocab at 0x11682a950>),
#  (u'stevron', <gensim.models.keyedvectors.Vocab at 0x11682a990>),
#  ('varys', <gensim.models.keyedvectors.Vocab at 0x116845b90>),
#  (u'measurement', <gensim.models.keyedvectors.Vocab at 0x11682aa10>),
#  ('bluer', <gensim.models.keyedvectors.Vocab at 0x11682aa50>),
#  ('really', <gensim.models.keyedvectors.Vocab at 0x11682aa90>),
#  ('missed', <gensim.models.keyedvectors.Vocab at 0x11682aad0>),
#  (u'research', <gensim.models.keyedvectors.Vocab at 0x11682ab10>),
#  ('hood', <gensim.models.keyedvectors.Vocab at 0x11690bd90>),
#  ('darling', <gensim.models.keyedvectors.Vocab at 0x11682ab90>),
#  ('nastiness', <gensim.models.keyedvectors.Vocab at 0x11690bdd0>),
#  ...]

# %%
keys = model.wv.vocab.keys()

# %%
len(keys)
# Out:
# 6913

# %%
model_list = []

for i in model.wv.vocab.keys():
    model_list.append(model.wv[i])

# %%
model_list
# Out:
# [array([-0.22376278, -0.02872269, -0.02884169, -0.13852729, -0.10908575,
#         -0.09059495, -0.10303082, -0.18324159, -0.01464033, -0.17107914,
#          0.03584175, -0.10879163,  0.13107596, -0.10880311,  0.00426053,
#          0.17559682,  0.08271719, -0.0837829 , -0.11370994, -0.01475961,
#         -0.23856805, -0.15408367,  0.0040189 ,  0.18536162,  0.16116762,
#         -0.14047369, -0.0288725 , -0.09842048, -0.06744577, -0.09924854,
#         -0.27871603,  0.0260792 , -0.00055787, -0.10405756,  0.04722917,
#         -0.04971896, -0.17617296, -0.07015444,  0.07551545,  0.17233972,
#         -0.12381607,  0.01121468, -0.02532187, -0.14582539,  0.12648505,
#         -0.23243997,  0.10935027, -0.00507858, -0.01617946,  0.16234636,
#          0.21953857,  0.07109509, -0.13217871, -0.05112288, -0.13051277,
#         -0.14993665,  0.00779412,  0.04892343, -0.17880924, -0.16841882,
#          0.10723458, -0.06776533,  0.18188369, -0.13874528,  0.03867292,
#         -0.11311741, -0.03735886,  0.02994094,  0.08542707, -0.03123507,
#          0.01848751, -0.13658139,  0.05254735, -0.22596677, -0.05402031,
#         -0.10632221, -0.15990195,  0.06821056,  0.13953461,  0.09248964,
#         -0.05442227, -0.01474358,  0.0845262 , -0.00145673, -0.12087471,
#         -0.10932285,  0.00983544,  0.05972183,  0.1444695 ,  0.13093677,
#          0.04867502,  0.00881354, -0.17871004, -0.1359892 , -0.05944286,
#          0.10267095, -0.20231608,  0.00109483, -0.15022787,  0.024837  ], dtype=float32),
#  array([-0.30067533, -0.03868769, -0.0386788 , -0.19469179, -0.13664429,
#         -0.11519067, -0.14735205, -0.25182092, -0.03130583, -0.22545448,
#         -0.08968572,  0.00617895,  0.04677539,  0.10924187,  0.10379937,
#          0.02902071,  0.0110303 , -0.12846966, -0.09831501, -0.04632896,
#          0.07420182, -0.16049835,  0.00197765, -0.10982881,  0.01642236], dtype=float32),
#  array([-0.03242898, -0.00397786, -0.00944386, -0.01926112, -0.01930738,
#         -0.01519178, -0.01269677, -0.03017143,  0.00059029, -0.02388066,
#          0.00744276, -0.01761628,  0.02107977, -0.01945916, -0.00082437,
#          0.02102858,  0.00767189, -0.01393822, -0.01823156, -0.00445956,
#         -0.03082336, -0.01900925, -0.00312771,  0.02614978,  0.0251588 ,
#         -0.01674098, -0.00744953, -0.01821882, -0.01535715, -0.01782222,
#         -0.03831538,  0.00341721, -0.00079503, -0.01859488,  0.00933985,
#         -0.00179617, -0.02960452, -0.00699033,  0.01372415,  0.02848221,
#         -0.0192673 ,  0.00306926, -0.0007387 , -0.02637844,  0.01871238,
#         -0.03715451,  0.01628755,  0.00324296, -0.00788763,  0.02052582,
#          0.02955192,  0.00493318, -0.01540674, -0.00815192, -0.01608295,
#         -0.02473717,  0.00328855,  0.00964866, -0.02353559, -0.02011816,
#          0.01760784, -0.0077261 ,  0.02529977, -0.01994235,  0.00550184,
#         -0.01861188, -0.00562357,  0.00303472,  0.01395271, -0.00821013,
#          0.00683356, -0.02130867,  0.01229094, -0.03276518, -0.00574493,
#         -0.01916618, -0.02502789,  0.00693478,  0.02538901,  0.01326426,
#         -0.00737982,  0.00096178,  0.01402513, -0.00545571, -0.01264738,
#         -0.01512376, -0.00167148,  0.00312668,  0.016025  ,  0.01476677,
#          0.00377021,  0.00449538, -0.02207942, -0.01483006, -0.00918865,
#          0.01574262, -0.03339581,  0.00418573, -0.02385822,  0.00733176], dtype=float32),
#  ...]

# %%
type(model_list)
# Out:
# list

# %%
model_vectors = pd.DataFrame(model_list)
model_vectors.shape
# Out:
# (6913, 100)

# %%
model_vectors = model_vectors.reset_index()

# %%
model_vectors['index'] = model.wv.vocab.keys()

# %%
model_vectors = model_vectors.set_index('index')

# %%
model_vectors.head()
# Out:
#                 0         1         2         3         4         5   \
# index
# foul     -0.223763 -0.028723 -0.028842 -0.138527 -0.109086 -0.090595
# four     -0.300675 -0.038688 -0.038679 -0.194692 -0.136644 -0.115191
# hanging  -0.149231 -0.024683 -0.020389 -0.093670 -0.066091 -0.061924
# marching -0.278668 -0.028508 -0.036134 -0.173791 -0.131981 -0.110273
# increase -0.052680 -0.002060 -0.010599 -0.034631 -0.024483 -0.020824
#
#                 6         7         8         9     ...           90  \
# index                                               ...
# foul     -0.103031 -0.183242 -0.014640 -0.171079    ...     0.048675
# four     -0.147352 -0.251821 -0.031306 -0.225454    ...     0.065593
# hanging  -0.074482 -0.121463 -0.015311 -0.106075    ...     0.035812
# marching -0.137984 -0.246331 -0.032305 -0.210208    ...     0.062213
# increase -0.027974 -0.051805 -0.007654 -0.041661    ...     0.015827
#
#                 91        92        93        94        95        96  \
# index
# foul      0.008814 -0.178710 -0.135989 -0.059443  0.102671 -0.202316
# four      0.008234 -0.242825 -0.179177 -0.077777  0.141316 -0.278841
# hanging   0.007456 -0.122735 -0.086237 -0.046715  0.072785 -0.141090
# marching  0.013903 -0.222403 -0.172924 -0.083528  0.131210 -0.260200
# increase -0.001859 -0.039856 -0.036232 -0.019226  0.022830 -0.047325
#
#                 97        98        99
# index
# foul      0.001095 -0.150228  0.024837
# four      0.011297 -0.194583  0.028036
# hanging   0.002686 -0.094094  0.010044
# marching  0.001749 -0.183669  0.028350
# increase  0.005241 -0.039863  0.006344
#
# [5 rows x 100 columns]

# %%
model_vectors.index
# Out:
# Index([        u'foul',         u'four',      u'hanging',     u'marching',
#            u'increase', u'midafternoon',     u'mutinied',         u'lord',
#             u'sinking',    u'leisurely',
#        ...
#               u'lance',       u'risked',       u'squeak',       u'oberyn',
#               u'cliff',    u'auxiliary',        u'wylla',    u'firestorm',
#          u'baratheons',  u'furthermore'],
#       dtype='object', name=u'index', length=6913)

# %%
pca20 = PCA(n_components=20)

pca_results20 = pca20.fit_transform(model_vectors)

# %%
pca_results_20 = pd.DataFrame(pca_results20)

# %%
pca_results_20 = pca_results_20.reset_index()

# %%
pca_results_20['index'] = model.wv.vocab.keys()

# %%
pca_results_20 = pca_results_20.set_index('index')

# %%
pca_results_20.head()
# Out:
#                 0         1         2         3         4         5   \
# index
# foul      0.467647 -0.014334 -0.026153  0.001959  0.008908 -0.006659
# four      0.857013 -0.018887 -0.014639  0.027772  0.006600  0.000064
# hanging   0.073550 -0.007433 -0.010237  0.009123  0.000454  0.000615
# marching  0.769884 -0.001557 -0.002889  0.028507 -0.006912 -0.009819
# increase -0.416789  0.002963  0.001901 -0.001240 -0.001894  0.007262
#
#                 6         7         8         9         10        11  \
# index
# foul      0.003164  0.003577 -0.000055 -0.002291 -0.000950 -0.005422
# four     -0.000069  0.013742 -0.002338  0.008833 -0.008369 -0.003136
# hanging   0.005964 -0.003025 -0.005726 -0.002516 -0.006506 -0.000812
# marching -0.014108 -0.004524 -0.007684 -0.003106  0.000303  0.000469
# increase  0.000998  0.001125 -0.003840 -0.000058 -0.000617  0.003261
#
#                 12        13        14        15        16        17  \
# index
# foul     -0.004610 -0.005913 -0.001350 -0.001498 -0.001902 -0.001455
# four     -0.000913 -0.001376  0.002562  0.002916  0.000558  0.003521
# hanging  -0.005215 -0.001793 -0.002190 -0.003235  0.004846  0.000164
# marching -0.001402  0.008261  0.003649  0.001374 -0.002129 -0.001949
# increase  0.004684 -0.000277 -0.002677  0.000950 -0.006967  0.003510
#
#                 18        19
# index
# foul     -0.002228 -0.001400
# four      0.003161  0.007202
# hanging   0.003384 -0.005926
# marching -0.002234  0.004815
# increase -0.000703  0.001766

# %%
tsne = TSNE(n_components=2)

tsne_pca_results20 = tsne.fit_transform(pca_results20)

# %%
tsne_pca_results_20 = pd.DataFrame(tsne_pca_results20)

# %%
tsne_pca_results_20 = tsne_pca_results_20.reset_index()

# %%
tsne_pca_results_20['index'] = model.wv.vocab.keys()

# %%
tsne_pca_results_20 = tsne_pca_results_20.set_index('index')

# %%
tsne_pca_results_20.shape
# Out:
# (6913, 2)

# %%
tsne_pca_results_20.head(10)
# Out:
#                          0             1
# index
# foul         -3.625123e+16 -2.161681e+16
# four         -9.084463e+16  8.768620e+16
# hanging       8.068193e+14  1.081339e+15
# marching     -5.278399e+16  2.309692e+16
# increase      5.925796e+16  7.973523e+15
# midafternoon  1.475672e+16  1.842794e+16
# mutinied      1.402947e+16  1.219439e+16
# lord         -4.730225e+16  8.740347e+16
# sinking       7.180056e+17  3.342843e+17
# leisurely    -7.647436e+16 -1.485316e+17

# %%
tsne_pca_results_20['index_name'] = tsne_pca_results_20.index

# %%
tsne_pca_results_20.columns
# Out:
# Index([0, 1, u'index_name'], dtype='object')

# %%
tsne_pca_results_20.head()
# Out:
#                      0             1 index_name
# index
# foul     -3.625123e+16 -2.161681e+16       foul
# four     -9.084463e+16  8.768620e+16       four
# hanging   8.068193e+14  1.081339e+15    hanging
# marching -5.278399e+16  2.309692e+16   marching
# increase  5.925796e+16  7.973523e+15   increase

# %%
tsne_pca_results_20 = tsne_pca_results_20[[u'index_name', 0, 1]]

# %%
tsne_pca_results_20.head()
# Out:
#          index_name             0             1
# index
# foul           foul -3.625123e+16 -2.161681e+16
# four           four -9.084463e+16  8.768620e+16
# hanging     hanging  8.068193e+14  1.081339e+15
# marching   marching -5.278399e+16  2.309692e+16
# increase   increase  5.925796e+16  7.973523e+15

# %%
tsne_pca_results_20.to_csv('tsne.csv', index=False)

# %%
tsne_pca_results_20.shape
# Out:
# (6913, 3)

# %%
tsne_pca_results20
# Out:
# array([[ -3.62512349e+16,  -2.16168129e+16],
#        [ -9.08446308e+16,   8.76862005e+16],
#        [  8.06819259e+14,   1.08133874e+15],
#        ...,
#        [ -6.37758208e+16,   3.80275648e+16],
#        [  2.37607896e+17,  -1.83630568e+17],
#        [ -4.70821141e+16,   3.05877748e+16]])

# %%
tsne_pca_results_20.index
# Out:
# Index([        u'foul',         u'four',      u'hanging',     u'marching',
#            u'increase', u'midafternoon',     u'mutinied',         u'lord',
#             u'sinking',    u'leisurely',
#        ...
#               u'lance',       u'risked',       u'squeak',       u'oberyn',
#               u'cliff',    u'auxiliary',        u'wylla',    u'firestorm',
#          u'baratheons',  u'furthermore'],
#       dtype='object', name=u'index', length=6913)

# %%
import numpy as Math
import pylab as Plot
import matplotlib.pyplot as plt

rows = tsne_pca_results_20.index
# %matplotlib notebook
plt.ion()

Plot.figure(figsize=(20, 10))
max_x = Math.amax(tsne_pca_results20, axis=0)[0]
max_y = Math.amax(tsne_pca_results20, axis=0)[1]
#Plot.xlim((-.125e+20,.25e+20))
#Plot.ylim((-.125+e20,.1e20))

Plot.scatter(tsne_pca_results20[:, 0], tsne_pca_results20[:, 1], 20);

for row_id in range(0, len(rows)):
    target_word = rows[row_id]
    x = tsne_pca_results20[row_id, 0]
    y = tsne_pca_results20[row_id, 1]
    Plot.annotate(target_word, (x,y))

Plot.savefig("tsne_200.png");
# Out:
# <img src="data:image/png;base64,..." width="1440">
