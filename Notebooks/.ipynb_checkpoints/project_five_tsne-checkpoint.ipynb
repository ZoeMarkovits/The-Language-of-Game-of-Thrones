# %% [markdown]
# # Project Five
# # Game of Thrones - TSNE

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from textblob import TextBlob
from nltk.corpus import stopwords
import spacy
from nltk import Tree
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph
from nltk.parse import ProjectiveDependencyParser
from nltk.parse import NonprojectiveDependencyParser
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import gensim
from gensim.models import Word2Vec
from nltk.tag import pos_tag
import re
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline
# Out:
# Using Theano backend.

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import scale

from sklearn.datasets import fetch_mldata
from sklearn.cluster import KMeans
from sklearn.utils import shuffle

# %%
import pickle

with open('/Users/zoemarkovits/Metis/project_five_got/total_corpus_texts2.pkl', 'rb') as f:
    total_corpus_texts = pickle.load(f)

# %%
total_corpus_texts
# Out:
# [['well', 'struck'],
#  ['well', 'struck', 'dog'],
#  ['like'],
#  ['well', 'struck', 'grace'],
#  ['already', 'said', 'well', 'struck'],
#  ['yes', 'grace'],
#  ['ser', 'dontos', 'red', 'house', 'hollard'],
#  ['ser', 'dontos', 'red', 'house', 'hollard'],
#  [],
#  ['sorry', 'grace'],
#  ['deepest', u'apology'],
#  ['drunk'],
#  [],
#  ['uh'],
#  ['grace'],
#  ['two', u'cup', 'wine'],
#  ['two', u'cup'],
#  ['thats', 'much'],
#  ['please', 'another', 'cup'],
#  ['sure', 'grace'],
#  ['two'],
#  ['much', 'like'],
#  ['would', 'honored', 'grace'],
#  ['ser', 'meryn', 'help', 'ser', 'dontos', 'celebrate', 'name', 'day'],
#  ['see', u'drink', 'fill'],
#  ['cant'],
#  ['say'],
#  ['say', 'cant'],
#  ['meant', 'would', 'bad', 'luck', 'kill', 'man', 'name', 'day'],
#  ['kind', 'stupid', u'peasant', 'superstition', 'take', 'away'],
#  ['ill', 'killed', 'tomorrow', 'fool'],
#  [],
#  ['fool', 'youre', 'clever', 'see'],
#  ['hell', 'make', 'much', 'better', 'fool', 'knight'],
#  ['doesnt', 'deserve', 'mercy', 'quick', 'death'],
#  ['hear', 'lady', 'ser', 'dontos'],
#  ['day', 'youll', 'new', 'fool'],
#  ['thank', 'grace'],
#  ['lady', 'thank'],
#  ['looked', 'battlefield'],
#  ['nowhere', 'found'],
#  ['ive', 'ruling', u'kingdom'],
#  ['fine', 'job', 'youve', 'done'],
#  ['look'],
#  ['beautiful', 'ever'],
#  [],
#  ['youre', 'going', 'bigger', 'hound', 'much', 'better', 'looking'],
#  ['one', 'doesnt', 'like'],
#  ['cant', 'imagine'],
#  ['heard', 'dead'],
#  ['im', 'glad', 'youre', 'dead'],
#  ['dear'],
#  ['death', 'boring', 'especially', 'much', 'excitement', 'world'],
#  ['lady', 'im', 'sorry', 'loss'],
#  ['loss'],
#  ['father', 'confessed', 'traitor'],
#  ['still', 'father'],
#  ['surely', 'recently', 'lost', 'beloved', 'father', 'sympathize'],
#  ['father', 'traitor'],
#  ['mother', 'brother', u'traitor'],
#  ['loyal', 'beloved', 'joffrey'],
#  ['course'],
#  ['well', 'enjoy', 'name', 'day', 'grace'],
#  ['wish', 'could', 'stay', 'celebrate', 'work', 'done'],
#  ['work'],
#  [],
#  ['raven', 'arrived', 'citadel', 'morning', 'grace'],
#  ['conclave',
#   'met',
#   'considered',
#   u'report',
#   'maesters',
#   'seven',
#   u'kingdom',
#   'done',
#   'last'],
#  ['longest', 'summer', 'living', 'memory'],
#  [u'peasant',
#   'say',
#   'long',
#   'summer',
#   u'mean',
#   u'last',
#   'longer',
#   'well',
#   'fewer',
#   u'peasant'],
#  [u'city', 'drowning', u'refugee', 'grace', 'fleeing', 'war'],
#  ['nowhere', 'house'],
#  ['winter', 'coming', 'itll', 'get', 'worse'],
#  ['command', 'city', 'watch', 'lord', 'slynt'],
#  ['lord', 'command'],
#  ['owe', 'title', u'land', 'generosity', 'grace'],
#  ['job'],
#  ['shut', u'gate', u'peasant'],
#  ['belong', 'field', 'capital'],
#  ['yes', 'grace'],
#  ['dont', 'get'],
#  ['ravishing', 'ever', 'big', 'sister'],
#  ['war', 'agrees'],
#  ['forgive', 'interruption'],
#  ['carry'],
#  [],
#  ['ah', 'remarkable', 'journey'],
#  ['pissed',
#   'edge',
#   'wall',
#   'fought',
#   'hill',
#   u'tribe',
#   'many',
#   u'adventure',
#   'much',
#   'thankful'],
#  [],
#  ['small', 'council'],
#  ['yes'],
#  ['well',
#   'believe',
#   'hand',
#   'king',
#   'welcome',
#   'small',
#   'council',
#   u'meeting'],
#  ['father', 'hand', 'king'],
#  ['yes', 'absence', 'serve', 'hand', 'stead', u'fight'],
#  [],
#  [],
#  ['would', 'like', 'know', 'tricked', 'father'],
#  ['capable', 'tricking', 'father', 'id', 'emperor', 'world'],
#  ['brought'],
#  ['ive', 'done', 'nothing'],
#  ['quite', 'right', 'nothing', 'son', 'called', 'ned', 'starks', 'head'],
#  ['entire', 'north', 'risen', u'u'],
#  ['tried', 'stop'],
#  [],
#  ['failed'],
#  ['bit', 'theater', 'haunt', 'family', 'generation'],
#  ['robb', 'stark', 'child'],
#  [u'who', 'every', 'battle', u'he', 'fought'],
#  ['understand', 'losing', 'war'],
#  ['know', 'warfare'],
#  ['nothing'],
#  ['know', 'people'],
#  ['know', u'enemy', 'hate', 'almost', 'much', 'hate', u'u'],
#  ['joffrey', 'king'],
#  ['joffrey', 'king'],
#  ['advise'],
#  ['im', 'advise'],
#  ['king', 'listens', 'say', 'king', 'might', 'get', 'uncle', 'jaime', 'back'],
#  [],
#  ['love', u'child'],
#  ['one', 'redeeming', 'quality'],
#  [u'cheekbone'],
#  ['starks', 'love', u'child', 'well'],
#  ['two'],
#  ['one'],
#  ['one'],
#  ['arya', 'little', 'animal', 'disappeared'],
#  ['disappeared'],
#  ['puff', 'smoke'],
#  ['three', 'starks', 'trade'],
#  ['chopped', u'one', 'head', 'let', 'another', 'escape'],
#  ['father', 'furious'],
#  ['must', 'odd', 'disappointing', 'child'],
#  ['lord', 'may', 'old', u'god', 'watch', 'brother', 'northern', u'son'],
#  [u'wall', 'holdfast', 'stand', 'winter'],
#  [u'stone',
#   'last',
#   'mortared',
#   'time',
#   'king',
#   u'aery',
#   'im',
#   'afraid',
#   u'mason',
#   'today',
#   'fit',
#   'carry',
#   u'father',
#   u'hammer'],
#  ['boy',
#   'remember',
#   'seeing',
#   'put',
#   'new',
#   'tower',
#   'torrhens',
#   'square',
#   'summer'],
#  ['men', 'worked', 'back'],
#  ['today', 'holdfast', u'look', 'like', 'built', 'drunk', u'child'],
#  ['night', 'hear', 'wind', 'howling', u'gap'],
#  [u'god', 'forbid', u'rain'],
#  ['might', 'well', 'sleep', 'beneath', 'waterfall'],
#  ['maintenance', 'holdfast', 'generally', u'fall', 'lord', 'holdfast'],
#  ['generally',
#   'yes',
#   'ive',
#   'sent',
#   'young',
#   'men',
#   'fight',
#   'robb',
#   'starks',
#   'war'],
#  ['king', 'robb'],
#  ['war'],
#  ['didnt', 'choose'],
#  ['maybe', 'lord', 'called', u'banner', 'took', 'men'],
#  ['joffrey', 'killed', 'father', 'liege', 'lord'],
#  ['remember', u'vow', 'ser'],
#  ['course', 'remember'],
#  ['spare', 'four', u'mason', 'week', 'lord'],
#  ['sufficient', 'repair', u'wall'],
#  ['believe'],
#  ['didnt', 'want', 'day'],
#  ['didnt', 'like', 'way', 'talking', 'robb'],
#  ['listening',
#   'people',
#   'youd',
#   'rather',
#   'listen',
#   'one',
#   u'responsibility',
#   'lord',
#   'winterfell'],
#  ['lord', 'portan'],
#  ['lord', 'may', 'old', u'god', 'watch', 'brother', 'northern', u'son'],
#  ['boil', 'hour', 'drink', 'tea'],
#  [u'make', 'pain', 'go', 'away'],
#  ['dont', 'pain'],
#  ['lucky'],
#  ['way'],
#  ['youve', u'dream'],
#  ['dont', 'dream'],
#  ['everyone', u'dream'],
#  ['dont'],
#  ['heard', 'men', 'talking', 'comet'],
#  ['say', 'omen'],
#  ['say', u'mean', 'robb', 'win', 'great', 'victory', 'south'],
#  [],
#  ['heard', u'fool', 'say', 'lannister', 'red'],
#  [u'mean', 'lannisters', 'rule', 'seven', u'kingdom', 'long'],
#  ['heard', 'stableboy', 'say', 'color', 'blood', 'mark', 'death', 'father'],
#  [u'star', 'dont', 'fall', 'men'],
#  ['red', 'comet', u'mean', 'one', 'thing', 'boy', u'dragon'],
#  [u'dragon', 'dead'],
#  ['theyve', 'dead', u'century'],
#  ['mmm'],
#  ['mmm'],
#  ['mmm'],
#  ['brother', 'say', 'khaleesi'],
#  ['said', 'ate', 'meat'],
#  ['didnt', 'tell', 'kind', 'meat'],
#  ['brother', 'didnt', 'know', 'anything', u'dragon'],
#  ['didnt', 'know', 'anything', 'anything'],
#  ['eh'],
#  ['drogos', 'first', 'gift'],
#  ['remember'],
#  ['promised', 'protect'],
#  ['promised', u'enemy', 'would', 'die', 'screaming'],
#  ['make', 'starvation', 'scream'],
#  ['trick', 'never', 'learned', 'im', 'afraid'],
#  ['ever', 'end'],
#  ['farther', 'east', 'ive', 'ever'],
#  ['yes', 'khaleesi', 'everything', u'end', 'even', 'red', 'waste'],
#  ['youre', 'sure', u'there', 'way'],
#  ['go',
#   'south',
#   'land',
#   'lazarheen',
#   'lamb',
#   'men',
#   'kill',
#   u'u',
#   'take',
#   u'dragon'],
#  ['go',
#   'west',
#   'dothraki',
#   'sea',
#   'first',
#   'khalasar',
#   'meet',
#   'kill',
#   u'u',
#   'take',
#   u'dragon'],
#  ['one', 'take', u'dragon'],
#  ['weak', 'fight', 'people'],
#  ['must', 'strength'],
#  ['mine'],
#  ['rakharo', 'never'],
#  ['bad', 'time', 'start'],
#  ['rough', 'time'],
#  [u'nothing', 'killed', 'yet'],
#  [u'as', 'killed', 'sledge'],
#  ['offered', 'ride'],
#  ['wanted', 'shut', 'damn', u'blister'],
#  ['born', 'place', 'like'],
#  ['later', 'fell', 'hard', u'time'],
#  [u'girl'],
#  ['crasters', u'daughter'],
#  ['havent', 'seen', 'girl', 'six', u'month'],
#  ['id', 'keep', 'seeing'],
#  ['dont', 'like', 'people', 'messing', u'daughter'],
#  ['dont', 'like', 'people', 'messing', u'wife'],
#  ['marries', u'daughter', 'give', u'daughter'],
#  [u'go'],
#  ['thats', 'foul'],
#  ['beyond', 'foul'],
#  ['wildlings', 'hundred', u'league', 'disappeared'],
#  ['crasters', 'still'],
#  ['must', 'something', 'right'],
#  ['happens', u'boy'],
#  ['hmm'],
#  ['marries', u'daughter'],
#  [u'son'],
#  ['said', 'planned', 'stop', 'way', 'frostfangs'],
#  ['people', 'make', u'sort', u'plan'],
#  ['havent', 'seen', 'benjen', 'stark', 'three', u'year'],
#  ['havent', 'missed'],
#  ['always', 'treated', 'like', 'scum'],
#  ['havent', 'good', 'wine', 'long', 'time'],
#  [u'southerner', 'make', 'good', 'wine', 'ill', 'give'],
#  [u'southerner'],
#  [u'who', 'little', 'girl'],
#  ['youre', 'prettier', 'half', u'daughter'],
#  ['got', 'nice', 'wet', 'twat', u'leg'],
#  ['whats', 'name'],
#  ['jon', 'snow'],
#  ['snow', 'eh'],
#  ['listen', 'bastard'],
#  ['lot', 'south', 'wall', 'youre', u'southerner'],
#  ['youre', 'north', 'real', 'north'],
#  ['lad', 'meant', 'harm'],
#  ['catch',
#   'pretty',
#   'little',
#   'bastard',
#   'talking',
#   u'daughter',
#   'one',
#   'talk',
#   u'daughter',
#   'word'],
#  ['sit', 'shut', 'mouth'],
#  ['bring', 'good', 'wine'],
#  [],
#  ['passed', 'six', u'village', 'way'],
#  ['six', 'abandoned'],
#  ['wildlings', 'gone'],
#  ['could', 'tell', 'im', 'thirsty'],
#  [u'there', 'barrel', 'dornish', 'wine', 'sledge'],
#  ['bring'],
#  ['yes', 'commander'],
#  ['want', 'know', 'theyve', 'gone'],
#  ['north', 'join', 'mance', 'rayder', 'old', 'friend'],
#  [u'he', 'friend', 'mine'],
#  ['broke', u'vow', 'betrayed', u'brother'],
#  ['oh', 'aye'],
#  ['poor', 'black', 'crow'],
#  [u'he', 'king', 'beyond', 'wall'],
#  [u'he', 'calling', u'year'],
#  ['whats', 'king'],
#  ['frozen', 'lake', 'somewhere'],
#  ['thats', 'good', 'looking', 'axe'],
#  ['fresh', 'forged'],
#  ['give'],
#  ['youll', 'another', 'one', 'made', 'castle', 'black'],
#  [],
#  ['oh', 'thats', 'lovely', 'steel'],
#  ['want', 'know', 'mance', 'rayder'],
#  ['gathering', 'army'],
#  ['hear', u'he', 'already', 'got', 'men', 'southern', u'king'],
#  ['plan', 'marching', 'army'],
#  ['youre', 'way', 'north', u'there', 'one', 'direction', 'go'],
#  ['bad', u'time', 'living', 'alone', 'wild'],
#  ['cold', u'wind', 'rising'],
#  ['let', 'come'],
#  [u'root', 'sunk', 'deep'],
#  ['wife', 'tell', 'lord', 'crow', 'content'],
#  ['place'],
#  ['husband', u'keep', u'u', 'safe'],
#  ['better', 'live', 'free', 'die', 'slave'],
#  ['dont',
#   'make',
#   'jealous',
#   'old',
#   'man',
#   'see',
#   'young',
#   u'wife',
#   'one',
#   'warm',
#   'bed'],
#  ['chose', 'different', u'path'],
#  ['oh', 'aye', 'chose', 'path', 'one', u'boy'],
#  ['youll', 'wanting', 'sleep', 'beneath', 'roof', 'suppose', 'eat', u'pig'],
#  ['roof', 'would', 'welcome'],
#  ['hard', 'riding'],
#  ['weve', 'brought', 'food', 'good', 'steel'],
#  ['man', u'lay', 'hand', 'one', u'wife', 'loses', 'hand'],
#  ['see', 'one', 'staring', 'long', 'might', 'gouge', u'eye'],
#  ['roof', u'rule'],
#  [],
#  [],
#  ['lord', 'commander'],
#  [],
#  ['jon', 'snow'],
#  [],
#  ['steward'],
#  ['want', 'lead', 'one', 'day'],
#  ['learn', 'follow'],
#  ['lord', 'light', 'come', u'u', 'darkness'],
#  ['offer', 'false', u'god'],
#  ['take', 'cast', 'light', 'upon', u'u', 'night', 'dark', 'full', u'terror'],
#  ['night', 'dark', 'full', u'terror'],
#  ['long', 'summer', 'darkness', 'fall', 'heavy', 'world'],
#  [u'star', 'bleed'],
#  ['need', 'stop'],
#  ['cold', 'breath', 'winter', 'freeze', u'sea'],
#  ['dead', 'shall', 'rise', 'north'],
#  ['men', 'named', 'light', 'seven'],
#  ['treat', u'god', u'father'],
#  ['eager', 'spit', u'ancestor'],
#  ['smell', 'fear', 'fear', 'piss', 'old', u'bone'],
#  ['want', 'stop'],
#  ['stop'],
#  ['ancient',
#   u'book',
#   'written',
#   'warrior',
#   'draw',
#   'burning',
#   'sword',
#   'fire'],
#  ['sword', 'shall', 'lightbringer'],
#  ['stannis', 'baratheon', 'warrior', 'light', 'sword', 'awaits'],
#  ['lord', 'cast', 'light', 'upon', u'u'],
#  ['night', 'dark', 'full', u'terror'],
#  ['night', 'dark', 'full', 'terror'],
#  ['woman', 'lead', 'war', 'cannot', 'win'],
#  ['stannis', 'king'],
#  ['follow', u'lead', 'even', 'dont', 'like', 'path'],
#  ['king'],
#  ['since',
#   'boar',
#   'killed',
#   'brother',
#   'every',
#   'lord',
#   u'want',
#   'coronation'],
#  ['dont', 'serve', 'others'],
#  ['serve', 'stannis'],
#  ['loyal', 'service', u'mean', 'telling', 'hard', u'truth'],
#  [u'he', 'surrounded', u'fool', u'fanatic', u'trust', 'davos'],
#  ['tell', 'truth', 'whats', 'truth'],
#  ['declare',
#   'upon',
#   'honor',
#   'house',
#   'beloved',
#   'brother',
#   'robert',
#   'wasnt',
#   'beloved',
#   'brother'],
#  ['didnt', 'love'],
#  ['didnt', 'love'],
#  ['harmless', 'courtesy', 'grace'],
#  ['lie'],
#  ['take'],
#  ['brother',
#   'robert',
#   'left',
#   'trueborn',
#   u'heir',
#   'boy',
#   'joffrey',
#   'boy',
#   'tommen',
#   'girl',
#   'myrcella',
#   'born',
#   'incest',
#   'cersei',
#   'lannister',
#   'brother',
#   'jaime',
#   'lannister'],
#  ['right', 'birth', 'jaime', 'lannister', 'kingslayer'],
#  ['call'],
#  ['brother', 'jaime', 'lannister', 'kingslayer'],
#  ['right',
#   'birth',
#   'blood',
#   'day',
#   'lay',
#   'claim',
#   'make',
#   'ser',
#   'jaime',
#   'lannister',
#   'kingslayer'],
#  ['whatever', 'else', u'man', 'still', 'knight'],
#  ['ser', 'jaime', 'lannister', 'kingslayer'],
#  ['right',
#   'birth',
#   'blood',
#   'day',
#   'lay',
#   'claim',
#   'iron',
#   'throne',
#   'westeros'],
#  ['let', 'true', 'men', 'declare', 'loyalty'],
#  ['eddard', 'stark', 'learned', 'truth', 'told'],
#  ['ill', 'make', 'mistake'],
#  ['send', u'copy', 'letter', 'every', 'corner', 'realm', 'arbor', 'wall'],
#  ['time', 'come', 'choose'],
#  ['let', 'man', 'claim', 'ignorance', 'excuse'],
#  ['gracethe', 'lannisters', 'true', 'enemy'],
#  ['time',
#   'could',
#   'make',
#   'peace',
#   'brother',
#   'ill',
#   'make',
#   'peace',
#   'renly',
#   u'call',
#   'king'],
#  ['well', 'many', 'already', 'declared', 'mace', 'tyrell', 'randyll', 'tarly'],
#  ['stannis', 'need', 'beg', 'lord', 'lord', 'support'],
#  ['lord', 'light', u'stand', 'behind'],
#  ['many', u'ship', 'lord', 'light', 'got', 'fleet'],
#  ['need', u'ship'],
#  ['im', 'sure', 'doesnt', 'going', 'war'],
#  ['renly', 'grace', 'join', u'force', 'robb', 'stark'],
#  ['would', 'steal', 'northern', 'half', 'kingdom'],
#  ['ive',
#   'always',
#   'served',
#   u'thief',
#   'according',
#   u'dessert',
#   'well',
#   'know',
#   'ser',
#   'davos'],
#  ['joffrey', 'renly', 'robb', 'stark', 'theyre', u'thief'],
#  ['theyll', 'bend', 'knee', 'ill', 'destroy'],
#  ['owe', 'apology', 'king'],
#  ['duty', 'serve'],
#  ['chosen', 'new', 'god', 'old', u'god'],
#  ['may', 'lord', 'light', 'watch', u'u'],
#  ['shall', 'drink', 'together'],
#  ['dont'],
#  ['cup', 'wine', 'honor', 'one', 'true', 'god'],
#  ['night', 'dark', 'full', u'terror', 'old', 'man', 'fire', u'burn', 'away'],
#  ['grace'],
#  ['king', 'north'],
#  ['keep',
#   'expecting',
#   'leave',
#   'one',
#   'castle',
#   'another',
#   'safekeeping',
#   'drag',
#   'along',
#   'camp',
#   'camp'],
#  ['grown', 'fond', 'stark'],
#  [],
#  ['ive', 'never', 'seen', 'girl'],
#  ['left',
#   'one',
#   'bannermen',
#   'father',
#   'would',
#   'know',
#   'within',
#   'fortnight',
#   'bannerman',
#   'would',
#   'receive',
#   'raven',
#   'message',
#   'release',
#   'son',
#   'youll',
#   'rich',
#   'beyond',
#   u'dream'],
#  ['refuse', 'house', 'destroyed', 'root', 'stem'],
#  ['dont', 'trust', 'loyalty', 'men', 'following', 'battle'],
#  ['oh', 'trust', 'life'],
#  ['smart', 'boy'],
#  ['whats', 'wrong'],
#  ['dont', 'like', 'called', 'boy'],
#  ['insulted'],
#  ['insult', 'kingslayer'],
#  ['youve', 'defeated', 'boy'],
#  ['youre', 'held', 'captive', 'boy'],
#  ['perhaps', 'youll', 'killed', 'boy'],
#  ['stannis', 'baratheon', 'sent', u'raven', 'high', u'lord', 'westeros'],
#  ['king',
#   'joffrey',
#   'baratheon',
#   'neither',
#   'true',
#   'king',
#   'true',
#   'baratheon'],
#  [u'he', 'bastard', 'son'],
#  ['thats', 'true', 'stannis', 'rightful', 'king'],
#  ['convenient'],
#  ['father', 'learned', 'truth'],
#  ['thats', 'executed'],
#  ['prisoner', 'ned', 'stark', 'lost', 'head'],
#  ['son', 'killed', 'world', 'wouldnt', 'learn', 'fathered'],
#  ['pushed', 'brother', 'window', 'saw', 'queen'],
#  ['proof'],
#  ['want', 'trade', 'gossip', 'like', 'couple', u'fishwife'],
#  ['im', 'sending', 'one', u'cousin', u'king', 'landing', 'peace', u'term'],
#  ['think', u'father', 'going', 'negotiate'],
#  ['dont', 'know', 'well'],
#  [u'he', 'starting', 'know'],
#  ['three', u'victory', 'dont', 'make', 'conqueror'],
#  ['better', 'three', u'defeat'],
#  ['city', u'stink', 'like', 'dead', u'body'],
#  ['bit', 'corpsey', 'yes'],
#  ['shit'],
#  ['thought', 'wanted', 'come'],
#  ['love'],
#  ['love', 'smell', 'dead', u'body', 'shit'],
#  ['cum', 'garlic', 'rum'],
#  ['smell', 'cum', 'balcony'],
#  ['love', 'stink'],
#  ['love', 'noise'],
#  [u'city', 'make', 'want', 'fuck'],
#  ['country'],
#  ['belong'],
#  ['yes', 'well', 'need', 'careful'],
#  ['one', 'know', 'youre'],
#  ['one', 'know'],
#  ['cant', 'trust', 'anyone', u'king', 'landing'],
#  ['theyre',
#   u'liar',
#   'good',
#   u'liar',
#   'bad',
#   u'liar',
#   'one',
#   'two',
#   'great',
#   u'liar'],
#  [],
#  [],
#  ['im'],
#  ['im', 'slave', 'truth'],
#  ['truth'],
#  ['biggest', 'little', 'liar', 'ever', 'met'],
#  ['think', 'little'],
#  ['im', 'crushed', 'beneath', 'weight', 'truth'],
#  ['oh'],
#  ['ned', 'stark', 'actually', 'slept'],
#  ['poor', 'man', 'didnt', 'suffer', 'enough'],
#  ['one', 'many', u'change', 'well', 'make', 'around'],
#  ['lord', 'baelish'],
#  ['grace'],
#  ['wonder', 'might', 'ask', 'favor'],
#  ['course', 'grace'],
#  ['ned', 'starks', 'youngest', 'daughter', 'arya', 'cant', 'seem', 'locate'],
#  ['shes',
#   'escaped',
#   'capital',
#   'winterfell',
#   'seems',
#   'logical',
#   'destination'],
#  ['yet', u'friend', 'north', 'report', 'sign'],
#  ['curious'],
#  ['choose', 'negotiate', 'starks', 'girl', 'value'],
#  ['whoever', u'find', 'well', 'know', 'say', 'lannisters', u'debt'],
#  ['well', 'could', 'ask', 'varys'],
#  ['hell', 'answer'],
#  ['whether', 'believe', 'always', 'hard', 'time', 'trusting', u'eunuch'],
#  [u'know', 'want'],
#  ['mockingbird'],
#  ['created', 'sigil', 'didnt'],
#  ['yes'],
#  ['appropriate', 'self', 'made', 'man', 'many', u'song', 'sing'],
#  ['im', 'glad', 'like'],
#  ['people', 'fortunate', 'enough', 'born', 'right', 'family'],
#  ['others', 'find', 'way'],
#  ['heard',
#   'song',
#   'boy',
#   'modest',
#   u'mean',
#   'found',
#   'way',
#   'home',
#   'prominent',
#   'family'],
#  ['loved', 'eldest', 'daughter'],
#  ['sadly', u'eye', 'another'],
#  [u'boy', u'girl', 'live', 'home', 'awkward', u'situation', 'arise'],
#  ['sometimes',
#   'ive',
#   'heard',
#   'even',
#   u'brother',
#   u'sister',
#   'develop',
#   'certain',
#   u'affection'],
#  [u'affection',
#   'become',
#   'common',
#   'knowledge',
#   'well',
#   'awkward',
#   'situation',
#   'indeed',
#   'especially',
#   'prominent',
#   'family'],
#  ['prominent',
#   u'family',
#   'often',
#   'forget',
#   'simple',
#   'truth',
#   'ive',
#   'found'],
#  ['truth'],
#  ['knowledge', 'power'],
#  ['seize'],
#  ['cut', 'throat'],
#  ['stop'],
#  ['wait'],
#  ['ive', 'changed', 'mind'],
#  ['let', 'go'],
#  ['step', 'back', 'three', u'pace'],
#  ['turn', 'around'],
#  ['close', u'eye'],
#  ['power', 'power'],
#  ['see', 'take', 'time', 'away', u'coin', u'whore', 'locate', 'stark', 'girl'],
#  ['would', 'much', 'appreciate'],
#  ['youre', 'ser', 'alton', 'lannister'],
#  ['grace'],
#  ['offer', u'cousin', 'peace', 'meet', u'term'],
#  ['first', 'family', 'must', 'release', u'sister'],
#  ['second',
#   u'father',
#   u'bone',
#   'must',
#   'returned',
#   u'u',
#   'may',
#   'rest',
#   'beside',
#   'brother',
#   'sister',
#   u'crypt',
#   'beneath',
#   'winterfell'],
#  ['remains', 'died', 'service', 'must', 'also', 'returned'],
#  [u'family', 'honor', 'proper', u'funeral'],
#  ['honorable', 'request', 'grace'],
#  ['third',
#   'joffrey',
#   'queen',
#   'regent',
#   'must',
#   'renounce',
#   'claim',
#   'dominion',
#   'north'],
#  ['time', 'till', 'end', 'time', 'free', 'independent', 'kingdom'],
#  ['king', 'north'],
#  ['king', 'north'],
#  ['neither', 'joffrey', 'men', 'shall', 'set', 'foot', u'land'],
#  [u'disregard',
#   'command',
#   'shall',
#   'suffer',
#   'fate',
#   'father',
#   'dont',
#   'need',
#   'servant',
#   'beheading'],
#  ['grace', u'term'],
#  ['queen', 'regent', 'son', 'meet', 'ill', 'give', 'peace'],
#  ['litter', 'south', 'lannister', 'dead'],
#  ['king', 'joffrey', 'baratheon', 'grace'],
#  ['oh'],
#  ['youll', 'ride', 'daybreak', 'ser', 'alton'],
#  ['tonight'],
#  ['word', 'grace'],
#  ['dont', 'call', 'grace', u'one', 'around'],
#  ['bad', 'get', 'used'],
#  ['im', 'glad', u'someone', 'gotten', 'used'],
#  ['lannisters', 'going', 'reject', u'term', 'know'],
#  ['course'],
#  ['fight',
#   u'field',
#   'long',
#   'like',
#   'wont',
#   'beat',
#   'take',
#   u'king',
#   'landing'],
#  ['cant', 'take', u'king', 'landing', 'without', u'ship'],
#  ['father', u'ship', 'men', 'know', 'sail'],
#  ['men', 'fought', 'father'],
#  ['men', 'fought', 'king', 'robert', 'free', 'yoke', 'south', 'like', 'youre'],
#  ['im', 'living', 'son'],
#  ['hell', 'listen'],
#  ['know'],
#  ['im', 'stark'],
#  ['know'],
#  ['father', 'raised', 'honorable', 'man'],
#  ['avenge', 'together'],
#  ['dont', 'want', 'balon', 'greyjoy', 'ally'],
#  ['need', u'ship'],
#  ['say'],
#  ['say', 'million', u'rat', 'live', u'sewer', u'king', 'landing'],
#  ['shall', 'rally', 'fight', u'u'],
#  ['understand', 'dont', 'trust', 'lord', 'greyjoy'],
#  ['dont', 'trust', 'lord', 'greyjoy', 'trustworthy'],
#  ['father', 'go', 'war', 'end', 'rebellion'],
#  ['yes'],
#  ['im', 'one', 'rebelling', 'throne'],
#  ['father'],
#  ['married', 'one', 'rebel', 'mothered', 'another'],
#  ['mothered', u'rebel', 'fact', 'seem', 'forgotten'],
#  ['trade', 'kingslayer', 'two', u'girl', 'bannermen', 'string', u'foot'],
#  ['want', 'leave', 'sansa', u'queen', u'hand'],
#  ['arya', 'havent', 'heard', 'word', 'arya'],
#  ['fighting'],
#  ['complicated'],
#  ['know'],
#  ['time', 'go', 'home'],
#  ['havent', 'seen', 'bran', 'rickon', u'month'],
#  ['cant', 'go', 'winterfell'],
#  ['beg', 'pardon'],
#  ['ill',
#   'send',
#   'rodrik',
#   'watch',
#   u'boy',
#   'tomorrow',
#   'youll',
#   'ride',
#   'south',
#   'stormlands'],
#  ['name', u'god', 'need', 'negotiate', 'renly', 'baratheon'],
#  [u'he', 'rallied', 'army'],
#  ['know'],
#  ['know', 'family'],
#  ['havent', 'seen', 'renly', 'baratheon', 'since', 'boy'],
#  ['hundred', u'lord', u'lord', 'trust'],
#  ['renly', u'side', u'u', 'well', 'outnumber', 'two', 'one'],
#  ['feel', u'jaw', 'beginning', 'shut', 'theyll', 'sue', 'peace'],
#  ['well', 'get', u'girl', 'back'],
#  ['well', 'go', 'home', 'good'],
#  ['ride', 'first', 'light'],
#  ['together', 'soon', 'promise'],
#  ['youve', 'done', 'well'],
#  ['father', 'would', 'proud'],
#  ['give', 'lord', 'renly', u'regard'],
#  ['king', 'renly'],
#  [u'there', 'king', 'every', 'corner'],
#  [],
#  ['returning', 'room', 'proper', 'appearance'],
#  ['say', 'targaryens', u'conqueror'],
#  ['seat', 'conqueror'],
#  [u'need', 'room', 'match', u'vine', u'flower'],
#  ['cant', 'find', 'arya', 'stark'],
#  ['luck', 'shes', 'dead', 'ditch', 'somewhere'],
#  ['perhaps'],
#  ['need'],
#  ['theyll', 'never', 'give', 'jaime', 'back', u'u', 'sansa', 'alone'],
#  ['think', 'might'],
#  ['theyre', 'weak'],
#  ['put', 'much', 'value', u'woman'],
#  ['need', 'set', u'army', 'task', 'finding'],
#  ['send', 'many', 'men'],
#  ['im', 'sure', 'asked', 'grandfather', 'king', 'ask', u'command'],
#  [u'grandfather',
#   'stupidity',
#   'field',
#   'battle',
#   'reason',
#   'robb',
#   'stark',
#   'uncle',
#   'jaime',
#   'first',
#   'place'],
#  ['life', 'danger'],
#  ['war'],
#  [u'life', 'danger'],
#  ['heard', 'disgusting', 'lie', 'uncle', 'jaime'],
#  [],
#  [u'enemy', 'say', 'anything', 'weaken', 'claim', 'throne'],
#  ['claim'],
#  ['throne', 'mine'],
#  ['course'],
#  ['one', u'belief', 'foul', 'gossip'],
#  ['someone', u'belief'],
#  ['father', u'child'],
#  ['besides', 'tommen', 'myrcella'],
#  ['asking'],
#  ['im', 'asking', 'fucked', u'woman', 'grew', 'tired'],
#  ['many', u'bastard', 'running', 'punishable', 'death'],
#  ['never'],
#  ['never'],
#  ['mother'],
#  [],
#  ['idea', 'ridiculous', 'sound'],
#  ['ease'],
#  ['slowly', 'passion'],
#  ['oh', 'yeah'],
#  ['go', 'wash'],
#  ['put', 'clothes'],
#  ['working', 'tonight'],
#  [u'thing', 'differently', 'daisy'],
#  ['isnt', 'five', 'copper', 'bawdy', 'house', 'hayseed', 'hall'],
#  ['haystack', 'hall'],
#  ['wherever', 'youre'],
#  ['establishment', 'doesnt', 'cater', u'plowman', 'goat', u'herder'],
#  ['lord', 'olsen'],
#  ['taste', 'everything'],
#  ['littlefingers', 'fancy', 'man'],
#  ['dont', 'call', 'littlefinger'],
#  ['doesnt', 'like'],
#  ['lord', 'baelish'],
#  [u'pretend',
#   'doesnt',
#   'speak',
#   'common',
#   'tongue',
#   'people',
#   'think',
#   'shes',
#   'exotic'],
#  ['grew', 'road', 'flea', 'bottom'],
#  ['shes', 'beautiful'],
#  ['shes', 'dumb', 'slut', 'really', 'lid', 'every', 'pot'],
#  ['lord', 'commander'],
#  ['good', 'see'],
#  ['realize',
#   'establishment',
#   'owned',
#   'lord',
#   'petyr',
#   'baelish',
#   u'king',
#   'master',
#   'coin',
#   'coin',
#   u'go',
#   'many',
#   u'pocket'],
#  [u'order'],
#  ['whose', u'order'],
#  ['someone', 'doesnt', 'care', 'littlefinger', u'think'],
#  ['cant'],
#  [],
#  ['please'],
#  [],
#  ['barra'],
#  ['please'],
#  ['please'],
#  ['enough'],
#  ['get', 'done'],
#  ['kill', 'bastard'],
#  [],
#  ['please'],
#  ['give'],
#  ['please'],
#  ['spread'],
#  ['search', 'every', 'house'],
#  ['every', 'room'],
#  ['look', 'every', 'room'],
#  ['people', 'shouting', 'gendry'],
#  ['name', 'gendry'],
#  ['bastard'],
#  [u'night', 'watch'],
#  ['please', 'stop'],
#  [],
#  ['took', 'kingsroad', 'heading', 'north'],
#  ['know'],
#  [u'he', 'got', u'bull', 'head', 'helmet'],
#  ['made'],
#  ['find'],
#  ['boy'],
#  ['lovely', 'boy'],
#  ['want'],
#  ['man', 'thirst'],
#  ['man', 'drink', 'day', 'night'],
#  ['boy', 'could', 'make', 'friend'],
#  [u'friend'],
#  ['give', u'u', 'beer', 'skin'],
#  ['man', 'choose', u'companion'],
#  ['two', 'courtesy'],
#  ['man', 'must', 'ask', 'forgiveness'],
#  ['youre', 'called', 'arry'],
#  ['man', 'honor', 'jaqen', 'hghar', 'free', 'city', 'beer', 'little', 'shit'],
#  ['get', u'u', 'beer'],
#  ['asked', 'nicely'],
#  ['aah'],
#  ['come', 'closer', 'ill', 'shove', 'stick', 'bunghole', 'fuck', 'bloody'],
#  ['boy', 'courage', 'sense'],
#  ['come'],
#  ['yoren', 'said', 'none', u'u', 'go', 'near', 'three'],
#  ['come'],
#  ['dont', 'scare'],
#  ['hmm'],
#  ['youre', 'stupid'],
#  ['scare'],
#  ['gold', u'cloak', 'far', u'king', 'landing'],
#  [],
#  ['theyre', 'looking'],
#  ['command'],
#  ['youre', 'long', 'way', 'home'],
#  ['asked', 'question'],
#  ['aye'],
#  ['asked', 'without', u'manner', 'chose', 'answer'],
#  ['royal', 'warrant', 'one', 'gutter', u'rat', 'youre', 'transporting'],
#  ['well', 'thing', 'gutter', u'rat', 'belong', u'night', 'watch'],
#  [u'put', 'beyond', 'reach', u'king', u'queen'],
#  [],
#  ['funny',
#   'thing',
#   'people',
#   'worry',
#   'much',
#   u'throat',
#   'forget',
#   'whats',
#   'low'],
#  ['sharpened', 'blade', 'breakfast'],
#  ['could',
#   'shave',
#   u'spider',
#   'arse',
#   'wanted',
#   'could',
#   'nick',
#   'artery',
#   'leg'],
#  ['nicked', u'there', 'one', 'around', u'know', 'unnick'],
#  ['well', 'keep'],
#  ['good', 'steel', 'always', 'needed', 'wall'],
#  ['seems',
#   'choice',
#   'die',
#   u'crossroad',
#   'long',
#   'way',
#   'home',
#   'go',
#   'back',
#   'city',
#   'tell',
#   u'master',
#   'didnt',
#   'find',
#   'looking'],
#  ['looking', 'boy', 'named', 'gendry'],
#  [u'carry', u'bull', 'head', 'helmet'],
#  ['anyone', 'turning', 'earn', u'king', 'reward'],
#  ['well',
#   'back',
#   'men',
#   'ill',
#   'taking',
#   'head',
#   'home',
#   'along',
#   'bastard',
#   'boy'],
#  ['distant', u'seagull', 'lord'],
#  ['make', 'wait', 'long', 'time', 'friend', u'keep', 'company'],
#  ['speaking', 'bravery', 'victory', 'stark', 'auxiliary', u'force'],
#  ['quite', 'battle'],
#  ['heard', 'suffered', 'terrible', 'head', 'wound'],
#  [u'northerner', 'fearsome', u'warrior'],
#  ['tell', 'story', 'meet'],
#  ['find',
#   'lovely',
#   'creature',
#   'working',
#   u'father',
#   u'kitchen',
#   'almost',
#   u'beggar',
#   'belief'],
#  ['strange', u'thing', 'happen'],
#  ['taste', 'fish', 'pie'],
#  ['dont', 'think', 'lord', 'varys', u'like', 'fish', 'pie'],
#  ['tell'],
#  ['always', 'tell'],
#  ['men',
#   'like',
#   'lord',
#   'varys',
#   'cant',
#   'let',
#   u'disadvantage',
#   'get',
#   'best',
#   u'u'],
#  ['well', 'make', 'fisherman', 'yet'],
#  ['glad', 'new', 'friend', 'able', 'accompany', 'capital'],
#  [u'friend', 'important', 'part', 'life'],
#  ['unfortunate', 'father', 'didnt', 'want', 'come'],
#  ['rest', 'easy', 'lord'],
#  ['good', 'keeping', u'secret', 'good', u'friend'],
#  ['discretion', 'legendary', u'friend', 'concerned'],
#  ['unspeakable', 'go', 'want', 'rest'],
#  ['leave'],
#  ['welcome', u'king', 'landing', 'dear'],
#  ['city', 'made', 'brighter', 'presence'],
#  ['council', 'meeting', 'lord'],
#  ['dont', 'like', u'threat'],
#  ['threatened'],
#  ['im', 'ned', 'stark'],
#  ['understand', 'way', 'game', 'played'],
#  ['ned', 'stark', 'man', 'honor'],
#  [],
#  ['threaten', 'ill', 'thrown', 'sea'],
#  ['might', 'disappointed', u'result'],
#  [u'storm',
#   'come',
#   'go',
#   'big',
#   'fish',
#   'eat',
#   'little',
#   'fish',
#   'keep',
#   'paddling'],
#  ['come', 'lord'],
#  ['shouldnt', 'keep', 'queen', 'waiting'],
#  ['time',
#   'end',
#   'time',
#   'part',
#   'realm',
#   'free',
#   'independent',
#   'kingdom',
#   'north'],
#  ['spirit', 'father', 'ill', 'give'],
#  ['youve', 'perfected', 'art', 'tearing', u'paper'],
#  ['give', u'father', u'bone', 'back', 'least', 'gesture', 'good', 'faith'],
#  ['youll', 'give', 'starks', 'reply', 'cousin'],
#  ['grace'],
#  ['see', 'brother', 'starks', 'guest'],
#  [],
#  ['broken', 'spirit', 'grace'],
#  ['speak', 'tell', u'he', 'forgotten'],
#  ['grace'],
#  ['safe', u'travel', 'cousin'],
#  ['deft', 'hand', 'diplomacy'],
#  ['thats', 'everything', 'raven', 'flew', 'morning', 'castle', 'black'],
#  ['trouble', 'wildlings'],
#  ['thats', 'theyre', 'called', 'wildlings'],
#  ['somewhat', u'le', 'wild', u'day'],
#  ['seems',
#   'theyve',
#   'stopped',
#   'killing',
#   'started',
#   'following',
#   'king',
#   'beyond',
#   'wall'],
#  ['another', 'king'],
#  ['many', 'five'],
#  ['ive', 'lost', 'count'],
#  ['lord', 'commander', 'asks', 'send', 'men', 'man', 'wall'],
#  ['perhaps', u'he', 'forgotten', 'fighting', 'war'],
#  ['men', 'spare'],
#  ['cold', u'wind', 'rising', 'dead', 'rise'],
#  [u'northerner', 'superstitious', 'people'],
#  ['according', 'commander', 'one', 'dead', 'men', 'attacked', u'chamber'],
#  ['mormont', 'doesnt', 'lie'],
#  ['kill', 'dead', 'man'],
#  ['apparently', 'burn'],
#  ['one', 'trip', 'wall', 'come', 'back', 'believing', 'grumpkins', 'snarks'],
#  ['dont',
#   'know',
#   'believe',
#   u'here',
#   'fact',
#   u'night',
#   'watch',
#   'thing',
#   u'separate',
#   u'u',
#   u'lie',
#   'beyond',
#   'wall'],
#  ['every', 'confidence', 'brave', 'men', u'night', 'watch', 'protect', u'u'],
#  ['said',
#   u'god',
#   'wanted',
#   u'u',
#   'dignity',
#   'wouldnt',
#   'make',
#   u'u',
#   'fart',
#   'died'],
#  ['fart', 'die'],
#  ['blessed', 'mother', 'holding', 'hand', 'left', 'world'],
#  ['farted', 'hard', 'whole', 'bed', 'shook'],
#  ['seems', 'bit', 'greedy', 'one', 'man', 'many', u'wife'],
#  ['wouldnt', 'two', 'three', 'enough'],
#  ['serious', 'discussion'],
#  ['would', 'look'],
#  ['nothing', 'like', 'sight', 'woman', 'walking', 'away'],
#  ['prefer', 'watching', 'come', 'towards'],
#  ['im', 'sure', 'thats', 'nice'],
#  ['yeah', 'well', 'milkmaid', 'named', 'violet', 'next', 'farm', 'grew'],
#  ['wrestling', 'together', 'time', 'six', u'year', 'old'],
#  ['got', 'older', 'wrestling', 'uh', 'changed'],
#  [],
#  ['many', u'time'],
#  ['well', 'many', u'time', 'could'],
#  ['wish', 'grew', 'farm'],
#  ['need', u'potato'],
#  ['get', 'another', 'sack', 'sledge'],
#  ['get', u'turnip'],
#  [],
#  ['ghost'],
#  [],
#  ['ghost', 'away'],
#  ['shoo', 'shoo'],
#  ['right'],
#  ['frighten'],
#  ['shouldnt', 'touch'],
#  ['oh'],
#  ['oh', 'right'],
#  ['im', 'sorry'],
#  ['wanted', 'make', 'sure', 'werent', 'hurt'],
#  ['youre', 'brave'],
#  [],
#  ['gilly'],
#  ['shes', 'one', 'crasters', u'daughter'],
#  ['hello', 'gilly'],
#  [],
#  ['sam', 'said', 'could', 'help'],
#  ['im', 'sorry', 'sam', u'know', 'supposed', 'shes', 'pregnant'],
#  ['take', u'u', 'leave'],
#  [],
#  ['would', 'know', u'sound', 'bit', 'mad'],
#  ['doesnt', 'sound', 'bit', 'mad', 'impossible'],
#  ['lord', 'commander', 'ordered', u'u', 'sworn', 'protect'],
#  ['sam', 'cant', 'take', 'please', 'ser', 'please'],
#  ['still', 'run'],
#  ['possible'],
#  ['im', 'going', 'baby'],
#  ['boy', 'boy'],
#  ['want', u'u', 'risk', u'life', 'wont', 'even', 'tell', u'u'],
#  ['whyd'],
#  [],
#  ['ask', 'question'],
#  ['cruel'],
#  ['cruel'],
#  ['sam', 'hurry', 'lose', 'hand'],
#  ['didnt', 'touch'],
#  ['want', 'steal'],
#  ['think', 'craster', u'cut'],
#  ['cant', 'steal'],
#  ['shes', 'person', 'goat'],
#  ['heading', 'deeper', 'deeper', 'wildling', 'territory'],
#  ['cant', 'take', 'girl', u'u'],
#  ['mormont', 'wouldnt'],
#  ['even', 'would', 'would'],
#  [u'who', 'going', 'deliver', 'baby'],
#  ['could', 'try'],
#  [],
#  ['ive', 'read'],
#  ['bit'],
#  ['im', 'sorry', 'sam'],
#  ['cant', 'help'],
#  ['khaleesi'],
#  ['dont', 'need', 'see'],
#  ['blood', 'blood'],
#  [],
#  ['khal', 'pono', 'perhaps'],
#  ['khal', 'jhaqo'],
#  ['dont', 'like', 'idea', 'woman', 'leading', 'khalasar'],
#  ['like', 'far', u'le', 'done'],
#  ['remember', 'lord'],
#  [u'look', 'smaller'],
#  ['everything', u'look', 'bigger', 'youre', 'child'],
#  ['remember', u'father', 'cabin', 'felt', 'like', 'palace', 'little'],
#  ['look'],
#  ['theyll', 'waiting', u'dock'],
#  [],
#  ['anyone', u'matter'],
#  ['big', 'day'],
#  ['havent', 'much', 'get', 'excited', 'since', 'left'],
#  ['hard', 'place', 'iron', u'island'],
#  ['always'],
#  ['cold', 'wet'],
#  ['oh', 'love', 'cold', 'wet'],
#  ['say', 'hard', u'place', 'breed', 'hard', 'men'],
#  ['hard', 'men', 'rule', 'world'],
#  ['youll', 'king', 'long'],
#  ['try', 'smiling', u'lip', 'closed'],
#  ['better'],
#  ['father', 'doesnt', 'trust', 'iron', u'islander'],
#  ['dont', 'blame'],
#  [u'say',
#   'youre',
#   'reavers',
#   u'raper',
#   'matter',
#   'many',
#   u'woman',
#   'youll',
#   'never',
#   'sat',
#   'uh'],
#  ['quit', 'talking', 'father'],
#  [u'he', 'right', u'u'],
#  [u'wife', 'iron', u'island', 'theyre', 'breeding'],
#  ['thats', 'enough', u'u'],
#  ['thats', 'take', 'salt', u'wife', u'woman', 'capture'],
#  ['capture'],
#  ['take', 'go', 'ashore'],
#  ['make', 'salt', 'wife'],
#  ['place', 'ship'],
#  ['leave'],
#  ['father', 'punish'],
#  ['hell', 'call', 'whore'],
#  ['havent', 'paid'],
#  ['oh', 'yeah'],
#  ['paid', 'good', 'money', 'im', 'going', 'stand'],
#  ['barely', 'touched'],
#  ['charge', 'twice', 'much', 'every', 'brothel', 'get', u'cry'],
#  ['one', 'moment', 'friend'],
#  ['moment'],
#  ['please', 'accept', 'sincerest', u'apology'],
#  ['aremca', 'take', 'good', 'care'],
#  ['im', 'sorry', 'lord'],
#  ['shh', 'shh'],
#  ['hurt'],
#  ['lord'],
#  ['mhaegen'],
#  [],
#  [u'work'],
#  ['shes', 'one', 'gold', u'cloak', 'killed', 'baby'],
#  ['ah', 'yes'],
#  ['poorly', 'handled'],
#  ['sometimes', 'power', 'least', 'grace'],
#  ['cant', 'stop', 'thinking'],
#  ['cant', 'sleep'],
#  ['poor', 'little', 'baby'],
#  ['know',
#   'remind',
#   'another',
#   'girl',
#   'lovely',
#   'thing',
#   'acquired',
#   'lysene',
#   'pleasure',
#   'house',
#   'beautiful',
#   'like',
#   'intelligent',
#   'like'],
#  ['wasnt', 'happy'],
#  ['cried', 'often'],
#  ['asked', 'didnt', 'kind', 'rapport'],
#  ['yes', 'quite', 'sad'],
#  [u'girl',
#   'lysene',
#   'pleasure',
#   u'house',
#   'expensive',
#   'extremely',
#   'expensive'],
#  ['one', 'wasnt', 'making', 'money'],
#  ['hate', 'bad', u'investment'],
#  ['really'],
#  ['haunt'],
#  ['idea', 'make', 'happy', 'idea', 'mitigate', u'loss'],
#  ['wealthy',
#   'patron',
#   'offered',
#   'tremendous',
#   'amount',
#   'money',
#   'let',
#   'transform',
#   'lovely',
#   'sad',
#   'girl'],
#  ['use', u'way', 'would', 'never', 'occur', 'men'],
#  ['know', 'occurs', 'men'],
#  ['would',
#   'say',
#   'succeeded',
#   'making',
#   'happy',
#   u'loss',
#   'definitely',
#   'mitigated'],
#  ['take', 'tonight', 'mourn', 'mhaegens', 'child'],
#  ['ill', 'see', 'tomorrow'],
#  ['youll', 'happy'],
#  [u'make', 'happy'],
#  ['wine'],
#  ['damn', 'boy'],
#  [u'apology', 'lord'],
#  ['leave', u'u', 'podrick'],
#  ['believe', 'know', 'pour', 'wine'],
#  ['thats', 'new', 'squire'],
#  ['couldve', 'found', 'proper', 'lad'],
#  ['prefer', 'improper', u'one'],
#  ['mm', 'thats', 'good', 'red'],
#  ['dornish'],
#  ['know', u'wine', 'lord'],
#  [],
#  ['fine', 'dinner', 'lord'],
#  ['call', 'tyrion', 'please'],
#  ['im',
#   'sure',
#   'youre',
#   'getting',
#   'used',
#   'fine',
#   u'dinner',
#   'youre',
#   'lord'],
#  ['maybe', 'ill', 'hire', 'cook'],
#  [u'war', 'started', u'le'],
#  ['heard', 'trouble', 'littlefingers', 'brothel', 'night'],
#  ['mm', 'nasty', 'business'],
#  ['done'],
#  ['yes', 'course'],
#  ['city',
#   'watch',
#   'must',
#   'keep',
#   'peace',
#   'hadnt',
#   'realized',
#   'peace',
#   'depended',
#   'killing',
#   u'baby'],
#  [u'order', u'order'],
#  ['quite', 'right'],
#  ['especially', u'queen', u'order'],
#  ['never', 'said', u'queen', u'order'],
#  ['else', 'would', 'want', 'murder', 'king', u'robert', u'bastard'],
#  ['shes', 'always', 'jealous', 'woman'],
#  ['know', 'sister', 'better'],
#  ['youve', 'heard', 'awful', u'rumor', 'brother', 'sister'],
#  ['dont', 'listen', 'filth'],
#  ['thats', 'good', 'heard'],
#  ['suppose',
#   'people',
#   'believe',
#   'filth',
#   'consider',
#   u'robert',
#   u'bastard',
#   'better',
#   u'claimant',
#   'throne',
#   'cerseis',
#   u'child'],
#  ['joffrey', 'king'],
#  ['rest', 'doesnt', 'interest'],
#  ['appreciate', 'loyalty'],
#  ['tell',
#   'men',
#   'slaughtered',
#   'ned',
#   'starks',
#   'men',
#   'throne',
#   'room',
#   'give',
#   'order'],
#  [],
#  ['would'],
#  ['man', 'traitor'],
#  ['tried', 'buy', 'loyalty'],
#  ['fool'],
#  ['idea', 'already', 'bought'],
#  ['drunk'],
#  ['ill', 'honor', 'questioned', 'imp'],
#  ['im', 'questioning', 'honor', 'lord', 'janos'],
#  ['im', 'denying', 'existence'],
#  ['think', 'ill', 'stand', 'take', 'dwarf', 'dwarf'],
#  ['mm', 'stopped', 'imp'],
#  ['yes', 'stand', 'take', 'unless', 'youd', 'like', 'take', 'friend'],
#  ['intend', 'serve', 'hand', 'king', 'father', u'return', 'war'],
#  ['seeing',
#   'betrayed',
#   'last',
#   'hand',
#   'king',
#   'well',
#   'wouldnt',
#   'feel',
#   'safe',
#   'lurking'],
#  [u'friend', 'court', 'allow'],
#  ['queen', 'granted', 'queen', 'regent'],
#  ['youre', 'fool', 'believe', 'friend'],
#  ['shall', 'hear', 'joffrey', 'say'],
#  ['shant'],
#  [u'there', 'ship', 'leaving', 'eastwatch', 'sea', 'tonight'],
#  ['im', 'afraid', 'rather', 'long', 'walk', 'castle', 'black'],
#  ['hope', 'enjoy', 'wall'],
#  ['found',
#   'surprisingly',
#   'beautiful',
#   'brutal',
#   'horribly',
#   'uncomfortable',
#   'sort',
#   'way'],
#  [u'lad', 'escort'],
#  [u'street', 'arent', 'safe', 'night', 'lord'],
#  ...]

# %%
import gensim  
model = gensim.models.Word2Vec(total_corpus_texts, size=100, window=5, min_count=1, workers=2,sg=1)

# %%
model.wv.vocab.items()
# Out:
# [('foul', <gensim.models.keyedvectors.Vocab at 0x1160b0f90>),
#  ('four', <gensim.models.keyedvectors.Vocab at 0x1160ca090>),
#  ('hanging', <gensim.models.keyedvectors.Vocab at 0x1162cef50>),
#  ('marching', <gensim.models.keyedvectors.Vocab at 0x1162cec90>),
#  (u'increase', <gensim.models.keyedvectors.Vocab at 0x117a3ad10>),
#  ('midafternoon', <gensim.models.keyedvectors.Vocab at 0x117849050>),
#  ('mutinied', <gensim.models.keyedvectors.Vocab at 0x117849090>),
#  ('lord', <gensim.models.keyedvectors.Vocab at 0x1178490d0>),
#  (u'sinking', <gensim.models.keyedvectors.Vocab at 0x117849110>),
#  ('leisurely', <gensim.models.keyedvectors.Vocab at 0x117849150>),
#  (u'politician', <gensim.models.keyedvectors.Vocab at 0x117849190>),
#  ('stabbed', <gensim.models.keyedvectors.Vocab at 0x1178491d0>),
#  ('bringing', <gensim.models.keyedvectors.Vocab at 0x11784e9d0>),
#  ('disturb', <gensim.models.keyedvectors.Vocab at 0x117849250>),
#  ('prize', <gensim.models.keyedvectors.Vocab at 0x117849290>),
#  ('wooden', <gensim.models.keyedvectors.Vocab at 0x1178492d0>),
#  (u'clientele', <gensim.models.keyedvectors.Vocab at 0x117849310>),
#  ('succession', <gensim.models.keyedvectors.Vocab at 0x117849350>),
#  ('straight', <gensim.models.keyedvectors.Vocab at 0x1178ae390>),
#  ('tired', <gensim.models.keyedvectors.Vocab at 0x1178493d0>),
#  (u'lefford', <gensim.models.keyedvectors.Vocab at 0x117849410>),
#  ('bacon', <gensim.models.keyedvectors.Vocab at 0x117849450>),
#  ('elegant', <gensim.models.keyedvectors.Vocab at 0x117849490>),
#  ('second', <gensim.models.keyedvectors.Vocab at 0x1178494d0>),
#  ('sailed', <gensim.models.keyedvectors.Vocab at 0x117854f50>),
#  (u'ruthless', <gensim.models.keyedvectors.Vocab at 0x117849550>),
#  ('thunder', <gensim.models.keyedvectors.Vocab at 0x117849590>),
#  ('cooking', <gensim.models.keyedvectors.Vocab at 0x1178495d0>),
#  ('contributed', <gensim.models.keyedvectors.Vocab at 0x117849610>),
#  ('resilient', <gensim.models.keyedvectors.Vocab at 0x117849650>),
#  ('succumb', <gensim.models.keyedvectors.Vocab at 0x117849690>),
#  ('hero', <gensim.models.keyedvectors.Vocab at 0x1178496d0>),
#  ('interrupting', <gensim.models.keyedvectors.Vocab at 0x117849710>),
#  (u'here', <gensim.models.keyedvectors.Vocab at 0x117849750>),
#  ('substance', <gensim.models.keyedvectors.Vocab at 0x117849790>),
#  (u'k', <gensim.models.keyedvectors.Vocab at 0x1178497d0>),
#  ('climbed', <gensim.models.keyedvectors.Vocab at 0x117849810>),
#  ('military', <gensim.models.keyedvectors.Vocab at 0x117849850>),
#  (u'climber', <gensim.models.keyedvectors.Vocab at 0x117849890>),
#  ('diplomat', <gensim.models.keyedvectors.Vocab at 0x117b62690>),
#  ('appropriately', <gensim.models.keyedvectors.Vocab at 0x117866090>),
#  ('divide', <gensim.models.keyedvectors.Vocab at 0x117849910>),
#  ('explained', <gensim.models.keyedvectors.Vocab at 0x117849950>),
#  ('replace', <gensim.models.keyedvectors.Vocab at 0x117849990>),
#  ('brought', <gensim.models.keyedvectors.Vocab at 0x1178499d0>),
#  ('stern', <gensim.models.keyedvectors.Vocab at 0x117849a10>),
#  ('cheating', <gensim.models.keyedvectors.Vocab at 0x117849a50>),
#  ('spoke', <gensim.models.keyedvectors.Vocab at 0x117849a90>),
#  (u'cannibal', <gensim.models.keyedvectors.Vocab at 0x117849ad0>),
#  ('occupying', <gensim.models.keyedvectors.Vocab at 0x117849b10>),
#  ('untie', <gensim.models.keyedvectors.Vocab at 0x117849b50>),
#  ('strike', <gensim.models.keyedvectors.Vocab at 0x117849b90>),
#  ('sideface', <gensim.models.keyedvectors.Vocab at 0x117849bd0>),
#  ('holy', <gensim.models.keyedvectors.Vocab at 0x117849c10>),
#  ('relax', <gensim.models.keyedvectors.Vocab at 0x117849c50>),
#  ('successful', <gensim.models.keyedvectors.Vocab at 0x117849c90>),
#  ('brings', <gensim.models.keyedvectors.Vocab at 0x117849cd0>),
#  ('hereby', <gensim.models.keyedvectors.Vocab at 0x117849d10>),
#  ('hurt', <gensim.models.keyedvectors.Vocab at 0x117849d50>),
#  (u'glass', <gensim.models.keyedvectors.Vocab at 0x117849d90>),
#  (u'hole', <gensim.models.keyedvectors.Vocab at 0x11786ce10>),
#  ('hold', <gensim.models.keyedvectors.Vocab at 0x117849e10>),
#  (u'simper', <gensim.models.keyedvectors.Vocab at 0x11786cf50>),
#  (u'benjens', <gensim.models.keyedvectors.Vocab at 0x117849e90>),
#  ('pursue', <gensim.models.keyedvectors.Vocab at 0x117849ed0>),
#  ('zhoan', <gensim.models.keyedvectors.Vocab at 0x117849f10>),
#  ('blade', <gensim.models.keyedvectors.Vocab at 0x117871250>),
#  ('plunged', <gensim.models.keyedvectors.Vocab at 0x117849f90>),
#  ('sweeter', <gensim.models.keyedvectors.Vocab at 0x117849fd0>),
#  ('rework', <gensim.models.keyedvectors.Vocab at 0x11784e050>),
#  ('example', <gensim.models.keyedvectors.Vocab at 0x11784e090>),
#  ('triple', <gensim.models.keyedvectors.Vocab at 0x1178ae750>),
#  ('organized', <gensim.models.keyedvectors.Vocab at 0x11784e110>),
#  (u'caution', <gensim.models.keyedvectors.Vocab at 0x11784e190>),
#  ('want', <gensim.models.keyedvectors.Vocab at 0x11784e1d0>),
#  ('counseling', <gensim.models.keyedvectors.Vocab at 0x11784e210>),
#  ('mymother', <gensim.models.keyedvectors.Vocab at 0x11784e250>),
#  (u'cocksucker', <gensim.models.keyedvectors.Vocab at 0x11784e290>),
#  ('absolute', <gensim.models.keyedvectors.Vocab at 0x11784e2d0>),
#  ('hog', <gensim.models.keyedvectors.Vocab at 0x11784e310>),
#  ('complaining', <gensim.models.keyedvectors.Vocab at 0x11784e350>),
#  (u'travel', <gensim.models.keyedvectors.Vocab at 0x11784e390>),
#  ('copious', <gensim.models.keyedvectors.Vocab at 0x11784e3d0>),
#  ('undying', <gensim.models.keyedvectors.Vocab at 0x117b41650>),
#  ('hot', <gensim.models.keyedvectors.Vocab at 0x11784e410>),
#  ('retreating', <gensim.models.keyedvectors.Vocab at 0x117aff890>),
#  ('beauty', <gensim.models.keyedvectors.Vocab at 0x11784e490>),
#  ('swing', <gensim.models.keyedvectors.Vocab at 0x117aff8d0>),
#  (u'despondent', <gensim.models.keyedvectors.Vocab at 0x11784e510>),
#  ('outlawed', <gensim.models.keyedvectors.Vocab at 0x11784e550>),
#  ('wrong', <gensim.models.keyedvectors.Vocab at 0x11784e590>),
#  ('barristan', <gensim.models.keyedvectors.Vocab at 0x11784e5d0>),
#  (u'huhuh', <gensim.models.keyedvectors.Vocab at 0x11784e610>),
#  (u'attracts', <gensim.models.keyedvectors.Vocab at 0x11784e650>),
#  (u'revolt', <gensim.models.keyedvectors.Vocab at 0x11784e690>),
#  ('sickening', <gensim.models.keyedvectors.Vocab at 0x11784e6d0>),
#  ('tulip', <gensim.models.keyedvectors.Vocab at 0x11784e710>),
#  ('viserys', <gensim.models.keyedvectors.Vocab at 0x11784e750>),
#  (u'wing', <gensim.models.keyedvectors.Vocab at 0x11784e790>),
#  ('wind', <gensim.models.keyedvectors.Vocab at 0x11784e7d0>),
#  ('wine', <gensim.models.keyedvectors.Vocab at 0x11784e810>),
#  ('dreamed', <gensim.models.keyedvectors.Vocab at 0x11784e850>),
#  ('patricide', <gensim.models.keyedvectors.Vocab at 0x11784e890>),
#  (u'profaned', <gensim.models.keyedvectors.Vocab at 0x11784e8d0>),
#  ('rewarded', <gensim.models.keyedvectors.Vocab at 0x11784e910>),
#  ('fit', <gensim.models.keyedvectors.Vocab at 0x11784e950>),
#  ('allisers', <gensim.models.keyedvectors.Vocab at 0x11784e990>),
#  ('screaming', <gensim.models.keyedvectors.Vocab at 0x117849210>),
#  (u'fix', <gensim.models.keyedvectors.Vocab at 0x11784ea10>),
#  (u'dedicate', <gensim.models.keyedvectors.Vocab at 0x11784ea50>),
#  (u'fig', <gensim.models.keyedvectors.Vocab at 0x11784ea90>),
#  ('mewling', <gensim.models.keyedvectors.Vocab at 0x11784ead0>),
#  ('hidden', <gensim.models.keyedvectors.Vocab at 0x11784eb10>),
#  ('admirable', <gensim.models.keyedvectors.Vocab at 0x11784eb50>),
#  ('easier', <gensim.models.keyedvectors.Vocab at 0x11784eb90>),
#  ('hghar', <gensim.models.keyedvectors.Vocab at 0x11784ebd0>),
#  ('commemorate', <gensim.models.keyedvectors.Vocab at 0x11784ec10>),
#  ('educating', <gensim.models.keyedvectors.Vocab at 0x11784ec50>),
#  ('interrupt', <gensim.models.keyedvectors.Vocab at 0x11784ec90>),
#  ('blink', <gensim.models.keyedvectors.Vocab at 0x11784ecd0>),
#  ('silver', <gensim.models.keyedvectors.Vocab at 0x11784ed10>),
#  ('structural', <gensim.models.keyedvectors.Vocab at 0x11784ed50>),
#  (u'represents', <gensim.models.keyedvectors.Vocab at 0x11784ed90>),
#  ('jaehaerys', <gensim.models.keyedvectors.Vocab at 0x11784edd0>),
#  ('theons', <gensim.models.keyedvectors.Vocab at 0x11784ee10>),
#  (u'arrow', <gensim.models.keyedvectors.Vocab at 0x11784ee50>),
#  (u'armourer', <gensim.models.keyedvectors.Vocab at 0x11784ee90>),
#  ('burial', <gensim.models.keyedvectors.Vocab at 0x11784eed0>),
#  (u'whim', <gensim.models.keyedvectors.Vocab at 0x11784ef10>),
#  ('financial', <gensim.models.keyedvectors.Vocab at 0x11784ef50>),
#  (u'spider', <gensim.models.keyedvectors.Vocab at 0x11784ef90>),
#  (u'longclaw', <gensim.models.keyedvectors.Vocab at 0x11784efd0>),
#  (u'turnip', <gensim.models.keyedvectors.Vocab at 0x117854050>),
#  ('fortnight', <gensim.models.keyedvectors.Vocab at 0x117854090>),
#  (u'mutineer', <gensim.models.keyedvectors.Vocab at 0x1178540d0>),
#  (u'wyllis', <gensim.models.keyedvectors.Vocab at 0x117854110>),
#  ('message', <gensim.models.keyedvectors.Vocab at 0x117854150>),
#  ('whip', <gensim.models.keyedvectors.Vocab at 0x117854190>),
#  ('misfortune', <gensim.models.keyedvectors.Vocab at 0x1178541d0>),
#  ('whoosh', <gensim.models.keyedvectors.Vocab at 0x117854210>),
#  (u'mason', <gensim.models.keyedvectors.Vocab at 0x117854250>),
#  (u'rd', <gensim.models.keyedvectors.Vocab at 0x117854290>),
#  ('archmaester', <gensim.models.keyedvectors.Vocab at 0x1178542d0>),
#  (u'ro', <gensim.models.keyedvectors.Vocab at 0x117854310>),
#  (u'outburst', <gensim.models.keyedvectors.Vocab at 0x117854350>),
#  (u'foundation', <gensim.models.keyedvectors.Vocab at 0x117854390>),
#  ('assured', <gensim.models.keyedvectors.Vocab at 0x1178543d0>),
#  ('waddle', <gensim.models.keyedvectors.Vocab at 0x117854410>),
#  ('threatened', <gensim.models.keyedvectors.Vocab at 0x117854450>),
#  ('assures', <gensim.models.keyedvectors.Vocab at 0x117898410>),
#  ('aggar', <gensim.models.keyedvectors.Vocab at 0x1178544d0>),
#  ('crowned', <gensim.models.keyedvectors.Vocab at 0x117854510>),
#  ('tobho', <gensim.models.keyedvectors.Vocab at 0x117854550>),
#  ('ate', <gensim.models.keyedvectors.Vocab at 0x117854590>),
#  ('ath', <gensim.models.keyedvectors.Vocab at 0x1178545d0>),
#  ('shipped', <gensim.models.keyedvectors.Vocab at 0x117854610>),
#  (u'disturbed', <gensim.models.keyedvectors.Vocab at 0x117854650>),
#  ('tempting', <gensim.models.keyedvectors.Vocab at 0x117854690>),
#  ('minge', <gensim.models.keyedvectors.Vocab at 0x1178546d0>),
#  (u'subtlety', <gensim.models.keyedvectors.Vocab at 0x117854710>),
#  ('wash', <gensim.models.keyedvectors.Vocab at 0x117854750>),
#  ('instruct', <gensim.models.keyedvectors.Vocab at 0x117854790>),
#  ('bitten', <gensim.models.keyedvectors.Vocab at 0x1178547d0>),
#  ('zala', <gensim.models.keyedvectors.Vocab at 0x117866810>),
#  ('whorehouse', <gensim.models.keyedvectors.Vocab at 0x117854850>),
#  ('timid', <gensim.models.keyedvectors.Vocab at 0x1179e2110>),
#  ('engagement', <gensim.models.keyedvectors.Vocab at 0x117854910>),
#  ('needed', <gensim.models.keyedvectors.Vocab at 0x117854950>),
#  ('master', <gensim.models.keyedvectors.Vocab at 0x117854990>),
#  ('bitter', <gensim.models.keyedvectors.Vocab at 0x1178549d0>),
#  ('ranging', <gensim.models.keyedvectors.Vocab at 0x117854a10>),
#  ('listen', <gensim.models.keyedvectors.Vocab at 0x117854a50>),
#  ('lorch', <gensim.models.keyedvectors.Vocab at 0x117854a90>),
#  (u'collapse', <gensim.models.keyedvectors.Vocab at 0x117854ad0>),
#  ('hows', <gensim.models.keyedvectors.Vocab at 0x117854b10>),
#  ('highgarden', <gensim.models.keyedvectors.Vocab at 0x117854b50>),
#  ('wisdom', <gensim.models.keyedvectors.Vocab at 0x117854b90>),
#  ('predictable', <gensim.models.keyedvectors.Vocab at 0x117854bd0>),
#  ('crawl', <gensim.models.keyedvectors.Vocab at 0x117854c10>),
#  ('positively', <gensim.models.keyedvectors.Vocab at 0x117854c50>),
#  ('showed', <gensim.models.keyedvectors.Vocab at 0x117854c90>),
#  (u'coward', <gensim.models.keyedvectors.Vocab at 0x117854cd0>),
#  ('tree', <gensim.models.keyedvectors.Vocab at 0x117854d10>),
#  (u'whinging', <gensim.models.keyedvectors.Vocab at 0x1178a85d0>),
#  ('shower', <gensim.models.keyedvectors.Vocab at 0x117854d90>),
#  ('idle', <gensim.models.keyedvectors.Vocab at 0x117854dd0>),
#  ('endure', <gensim.models.keyedvectors.Vocab at 0x117854e10>),
#  ('profitable', <gensim.models.keyedvectors.Vocab at 0x117b36590>),
#  ('feeling', <gensim.models.keyedvectors.Vocab at 0x117854e50>),
#  ('groaning', <gensim.models.keyedvectors.Vocab at 0x117854e90>),
#  ('longs', <gensim.models.keyedvectors.Vocab at 0x117854ed0>),
#  ('untrained', <gensim.models.keyedvectors.Vocab at 0x117854f10>),
#  ('tether', <gensim.models.keyedvectors.Vocab at 0x117849510>),
#  ('dozen', <gensim.models.keyedvectors.Vocab at 0x117854f90>),
#  ('responsible', <gensim.models.keyedvectors.Vocab at 0x117854fd0>),
#  (u'instructs', <gensim.models.keyedvectors.Vocab at 0x11785b090>),
#  ('amusing', <gensim.models.keyedvectors.Vocab at 0x11785b0d0>),
#  ('britches', <gensim.models.keyedvectors.Vocab at 0x11785b110>),
#  (u'season', <gensim.models.keyedvectors.Vocab at 0x117affdd0>),
#  ('eastwatch', <gensim.models.keyedvectors.Vocab at 0x117b2be90>),
#  (u'horselords', <gensim.models.keyedvectors.Vocab at 0x11785b190>),
#  ('howd', <gensim.models.keyedvectors.Vocab at 0x11785b1d0>),
#  ('shall', <gensim.models.keyedvectors.Vocab at 0x11785b210>),
#  ('huh', <gensim.models.keyedvectors.Vocab at 0x117affe10>),
#  ('aegons', <gensim.models.keyedvectors.Vocab at 0x11785b290>),
#  ('toil', <gensim.models.keyedvectors.Vocab at 0x1179e2290>),
#  ('mouth', <gensim.models.keyedvectors.Vocab at 0x11785b310>),
#  ('letter', <gensim.models.keyedvectors.Vocab at 0x11785b350>),
#  (u'singer', <gensim.models.keyedvectors.Vocab at 0x11785b390>),
#  (u'episode', <gensim.models.keyedvectors.Vocab at 0x11785b3d0>),
#  ('rayder', <gensim.models.keyedvectors.Vocab at 0x1178b3c90>),
#  ('consummate', <gensim.models.keyedvectors.Vocab at 0x11785b450>),
#  ('mating', <gensim.models.keyedvectors.Vocab at 0x11785b4d0>),
#  ('tirelessly', <gensim.models.keyedvectors.Vocab at 0x1179b6cd0>),
#  ('came', <gensim.models.keyedvectors.Vocab at 0x11785b550>),
#  ('saying', <gensim.models.keyedvectors.Vocab at 0x11785b590>),
#  ('fennel', <gensim.models.keyedvectors.Vocab at 0x11785b5d0>),
#  (u'tempted', <gensim.models.keyedvectors.Vocab at 0x11785b610>),
#  ('abreast', <gensim.models.keyedvectors.Vocab at 0x11785b650>),
#  ('busy', <gensim.models.keyedvectors.Vocab at 0x1178b9fd0>),
#  ('theme', <gensim.models.keyedvectors.Vocab at 0x11785b6d0>),
#  ('touched', <gensim.models.keyedvectors.Vocab at 0x11785b710>),
#  ('rich', <gensim.models.keyedvectors.Vocab at 0x11785b750>),
#  (u'plate', <gensim.models.keyedvectors.Vocab at 0x11785b790>),
#  ('petrified', <gensim.models.keyedvectors.Vocab at 0x117afff90>),
#  (u'foremost', <gensim.models.keyedvectors.Vocab at 0x11785b810>),
#  (u'pocket', <gensim.models.keyedvectors.Vocab at 0x11785b850>),
#  (u'reversal', <gensim.models.keyedvectors.Vocab at 0x11785b890>),
#  ('altogether', <gensim.models.keyedvectors.Vocab at 0x11785b8d0>),
#  ('blistered', <gensim.models.keyedvectors.Vocab at 0x11785b910>),
#  (u'spilling', <gensim.models.keyedvectors.Vocab at 0x11785b950>),
#  ('nicely', <gensim.models.keyedvectors.Vocab at 0x11785b990>),
#  ('dipping', <gensim.models.keyedvectors.Vocab at 0x11785b9d0>),
#  ('piggy', <gensim.models.keyedvectors.Vocab at 0x11785ba10>),
#  ('release', <gensim.models.keyedvectors.Vocab at 0x11785ba50>),
#  (u'respond', <gensim.models.keyedvectors.Vocab at 0x11785ba90>),
#  (u'blew', <gensim.models.keyedvectors.Vocab at 0x11785bad0>),
#  ('fair', <gensim.models.keyedvectors.Vocab at 0x11785bb10>),
#  ('bled', <gensim.models.keyedvectors.Vocab at 0x11785bb50>),
#  (u'result', <gensim.models.keyedvectors.Vocab at 0x11785bb90>),
#  ('fail', <gensim.models.keyedvectors.Vocab at 0x11785bbd0>),
#  ('nocturnal', <gensim.models.keyedvectors.Vocab at 0x11785bc10>),
#  (u'hammer', <gensim.models.keyedvectors.Vocab at 0x11785bc50>),
#  ('best', <gensim.models.keyedvectors.Vocab at 0x11785bc90>),
#  ('score', <gensim.models.keyedvectors.Vocab at 0x11785bcd0>),
#  ('pirate', <gensim.models.keyedvectors.Vocab at 0x11785bd10>),
#  (u'wage', <gensim.models.keyedvectors.Vocab at 0x11797f390>),
#  ('men', <gensim.models.keyedvectors.Vocab at 0x117974bd0>),
#  ('khaleesi', <gensim.models.keyedvectors.Vocab at 0x11785bdd0>),
#  ('extend', <gensim.models.keyedvectors.Vocab at 0x11785be10>),
#  ('nature', <gensim.models.keyedvectors.Vocab at 0x11785be50>),
#  ('rolled', <gensim.models.keyedvectors.Vocab at 0x11785be90>),
#  ('smelled', <gensim.models.keyedvectors.Vocab at 0x11785bed0>),
#  ('lapping', <gensim.models.keyedvectors.Vocab at 0x11785bf10>),
#  (u'souvenir', <gensim.models.keyedvectors.Vocab at 0x11785bf50>),
#  (u'extent', <gensim.models.keyedvectors.Vocab at 0x11785bfd0>),
#  ('tyrion', <gensim.models.keyedvectors.Vocab at 0x117861050>),
#  (u'debt', <gensim.models.keyedvectors.Vocab at 0x117861090>),
#  ('pity', <gensim.models.keyedvectors.Vocab at 0x1178610d0>),
#  ('accident', <gensim.models.keyedvectors.Vocab at 0x117861110>),
#  ('weirwood', <gensim.models.keyedvectors.Vocab at 0x117861150>),
#  ('country', <gensim.models.keyedvectors.Vocab at 0x117861190>),
#  (u'adventurer', <gensim.models.keyedvectors.Vocab at 0x1178611d0>),
#  ('demanded', <gensim.models.keyedvectors.Vocab at 0x117861210>),
#  ('planned', <gensim.models.keyedvectors.Vocab at 0x117861250>),
#  ('logic', <gensim.models.keyedvectors.Vocab at 0x117861290>),
#  ('argue', <gensim.models.keyedvectors.Vocab at 0x1178612d0>),
#  ('asked', <gensim.models.keyedvectors.Vocab at 0x117861310>),
#  (u'vain', <gensim.models.keyedvectors.Vocab at 0x117861350>),
#  ('blonde', <gensim.models.keyedvectors.Vocab at 0x117861390>),
#  ('shouting', <gensim.models.keyedvectors.Vocab at 0x1179e2750>),
#  ('union', <gensim.models.keyedvectors.Vocab at 0x117861410>),
#  ('slay', <gensim.models.keyedvectors.Vocab at 0x117861450>),
#  ('muck', <gensim.models.keyedvectors.Vocab at 0x117861490>),
#  ('much', <gensim.models.keyedvectors.Vocab at 0x1178614d0>),
#  ('privilege', <gensim.models.keyedvectors.Vocab at 0x117861510>),
#  ('tallest', <gensim.models.keyedvectors.Vocab at 0x117861550>),
#  ('life', <gensim.models.keyedvectors.Vocab at 0x117861590>),
#  (u'lodock', <gensim.models.keyedvectors.Vocab at 0x1178615d0>),
#  ('spit', <gensim.models.keyedvectors.Vocab at 0x117861610>),
#  (u'eastern', <gensim.models.keyedvectors.Vocab at 0x117861650>),
#  ('jeor', <gensim.models.keyedvectors.Vocab at 0x117861690>),
#  (u'davy', <gensim.models.keyedvectors.Vocab at 0x1178616d0>),
#  ('wish', <gensim.models.keyedvectors.Vocab at 0x117861710>),
#  ('lift', <gensim.models.keyedvectors.Vocab at 0x117861750>),
#  ('direwolf', <gensim.models.keyedvectors.Vocab at 0x117861790>),
#  ('child', <gensim.models.keyedvectors.Vocab at 0x1178617d0>),
#  ('worked', <gensim.models.keyedvectors.Vocab at 0x117861810>),
#  ('cunt', <gensim.models.keyedvectors.Vocab at 0x117861850>),
#  ('employ', <gensim.models.keyedvectors.Vocab at 0x117861890>),
#  ('contemplates', <gensim.models.keyedvectors.Vocab at 0x1178618d0>),
#  (u'flooding', <gensim.models.keyedvectors.Vocab at 0x117861910>),
#  ('picturing', <gensim.models.keyedvectors.Vocab at 0x117861950>),
#  ('remembering', <gensim.models.keyedvectors.Vocab at 0x117861990>),
#  (u'congratulation', <gensim.models.keyedvectors.Vocab at 0x1178619d0>),
#  ('played', <gensim.models.keyedvectors.Vocab at 0x117861a10>),
#  ('cersei', <gensim.models.keyedvectors.Vocab at 0x117861a50>),
#  (u'locksmith', <gensim.models.keyedvectors.Vocab at 0x117861a90>),
#  (u'obeying', <gensim.models.keyedvectors.Vocab at 0x117861ad0>),
#  (u'player', <gensim.models.keyedvectors.Vocab at 0x117861b10>),
#  ('trusted', <gensim.models.keyedvectors.Vocab at 0x117861b50>),
#  ('severity', <gensim.models.keyedvectors.Vocab at 0x117861b90>),
#  ('tarth', <gensim.models.keyedvectors.Vocab at 0x117b05350>),
#  ('yellow', <gensim.models.keyedvectors.Vocab at 0x117861c10>),
#  ('thievery', <gensim.models.keyedvectors.Vocab at 0x117861c50>),
#  ('rebellion', <gensim.models.keyedvectors.Vocab at 0x117861c90>),
#  ('clucking', <gensim.models.keyedvectors.Vocab at 0x117861cd0>),
#  (u'harmony', <gensim.models.keyedvectors.Vocab at 0x1178e5b50>),
#  ('fairly', <gensim.models.keyedvectors.Vocab at 0x117861d50>),
#  ('boiled', <gensim.models.keyedvectors.Vocab at 0x117861d90>),
#  ('marched', <gensim.models.keyedvectors.Vocab at 0x117861dd0>),
#  ('supper', <gensim.models.keyedvectors.Vocab at 0x117861e10>),
#  ('therell', <gensim.models.keyedvectors.Vocab at 0x117861e50>),
#  ('metalwork', <gensim.models.keyedvectors.Vocab at 0x117861e90>),
#  ('tune', <gensim.models.keyedvectors.Vocab at 0x117861ed0>),
#  (u'tarleys', <gensim.models.keyedvectors.Vocab at 0x117861f10>),
#  ('intrusion', <gensim.models.keyedvectors.Vocab at 0x117861f50>),
#  ('noblewoman', <gensim.models.keyedvectors.Vocab at 0x117861f90>),
#  ('eagle', <gensim.models.keyedvectors.Vocab at 0x117aff650>),
#  ('towheaded', <gensim.models.keyedvectors.Vocab at 0x117861fd0>),
#  (u'bellow', <gensim.models.keyedvectors.Vocab at 0x117866050>),
#  ('golden', <gensim.models.keyedvectors.Vocab at 0x1178498d0>),
#  ('forsaken', <gensim.models.keyedvectors.Vocab at 0x1178660d0>),
#  (u'plight', <gensim.models.keyedvectors.Vocab at 0x117866150>),
#  (u'hal', <gensim.models.keyedvectors.Vocab at 0x117866190>),
#  ('ham', <gensim.models.keyedvectors.Vocab at 0x1178661d0>),
#  ('ease', <gensim.models.keyedvectors.Vocab at 0x117866210>),
#  ('hay', <gensim.models.keyedvectors.Vocab at 0x117866250>),
#  ('innocent', <gensim.models.keyedvectors.Vocab at 0x117866290>),
#  ('prison', <gensim.models.keyedvectors.Vocab at 0x1178662d0>),
#  ('east', <gensim.models.keyedvectors.Vocab at 0x117866310>),
#  ('hat', <gensim.models.keyedvectors.Vocab at 0x117866350>),
#  (u'hightower', <gensim.models.keyedvectors.Vocab at 0x117866390>),
#  ('survival', <gensim.models.keyedvectors.Vocab at 0x1178663d0>),
#  ('possible', <gensim.models.keyedvectors.Vocab at 0x117866410>),
#  ('possibly', <gensim.models.keyedvectors.Vocab at 0x117866450>),
#  ('birth', <gensim.models.keyedvectors.Vocab at 0x117866490>),
#  ('shadow', <gensim.models.keyedvectors.Vocab at 0x1178664d0>),
#  ('unique', <gensim.models.keyedvectors.Vocab at 0x117866510>),
#  ('desire', <gensim.models.keyedvectors.Vocab at 0x117866550>),
#  ('remind', <gensim.models.keyedvectors.Vocab at 0x117866590>),
#  ('battlefield', <gensim.models.keyedvectors.Vocab at 0x1178665d0>),
#  ('right', <gensim.models.keyedvectors.Vocab at 0x117866610>),
#  ('old', <gensim.models.keyedvectors.Vocab at 0x117866650>),
#  ('crowd', <gensim.models.keyedvectors.Vocab at 0x117866690>),
#  ('people', <gensim.models.keyedvectors.Vocab at 0x1178666d0>),
#  ('macabre', <gensim.models.keyedvectors.Vocab at 0x117866710>),
#  ('crown', <gensim.models.keyedvectors.Vocab at 0x117866790>),
#  ('captive', <gensim.models.keyedvectors.Vocab at 0x1178667d0>),
#  ('warring', <gensim.models.keyedvectors.Vocab at 0x117866850>),
#  ('bottom', <gensim.models.keyedvectors.Vocab at 0x117866890>),
#  (u'rehearse', <gensim.models.keyedvectors.Vocab at 0x1178668d0>),
#  (u'fox', <gensim.models.keyedvectors.Vocab at 0x117866910>),
#  ('witty', <gensim.models.keyedvectors.Vocab at 0x117866950>),
#  (u'foe', <gensim.models.keyedvectors.Vocab at 0x117866990>),
#  (u'summoned', <gensim.models.keyedvectors.Vocab at 0x1178669d0>),
#  (u'umi', <gensim.models.keyedvectors.Vocab at 0x117866a10>),
#  ('pinched', <gensim.models.keyedvectors.Vocab at 0x117866a50>),
#  ('yoke', <gensim.models.keyedvectors.Vocab at 0x117866a90>),
#  (u'defensive', <gensim.models.keyedvectors.Vocab at 0x117866ad0>),
#  ('losing', <gensim.models.keyedvectors.Vocab at 0x117866b10>),
#  ('memorable', <gensim.models.keyedvectors.Vocab at 0x117866b50>),
#  ('bowing', <gensim.models.keyedvectors.Vocab at 0x117866b90>),
#  (u'grievously', <gensim.models.keyedvectors.Vocab at 0x117866bd0>),
#  (u'o', <gensim.models.keyedvectors.Vocab at 0x117866c10>),
#  ('despair', <gensim.models.keyedvectors.Vocab at 0x117866c50>),
#  (u'slightly', <gensim.models.keyedvectors.Vocab at 0x117866c90>),
#  ('match', <gensim.models.keyedvectors.Vocab at 0x117866cd0>),
#  ('lamprey', <gensim.models.keyedvectors.Vocab at 0x117866d10>),
#  ('raised', <gensim.models.keyedvectors.Vocab at 0x117866d50>),
#  ('watering', <gensim.models.keyedvectors.Vocab at 0x1179792d0>),
#  ('tyrell', <gensim.models.keyedvectors.Vocab at 0x117866dd0>),
#  ('son', <gensim.models.keyedvectors.Vocab at 0x117866e10>),
#  ('thankful', <gensim.models.keyedvectors.Vocab at 0x117866e50>),
#  ('consummated', <gensim.models.keyedvectors.Vocab at 0x117866e90>),
#  ('sow', <gensim.models.keyedvectors.Vocab at 0x117866ed0>),
#  ('wrap', <gensim.models.keyedvectors.Vocab at 0x117866f10>),
#  ('despised', <gensim.models.keyedvectors.Vocab at 0x117866f50>),
#  ('fabric', <gensim.models.keyedvectors.Vocab at 0x117866f90>),
#  ('suffice', <gensim.models.keyedvectors.Vocab at 0x117866fd0>),
#  ('tame', <gensim.models.keyedvectors.Vocab at 0x11786c050>),
#  ('grasping', <gensim.models.keyedvectors.Vocab at 0x11786c090>),
#  ('despises', <gensim.models.keyedvectors.Vocab at 0x11786c0d0>),
#  ('greatness', <gensim.models.keyedvectors.Vocab at 0x11786c110>),
#  ('music', <gensim.models.keyedvectors.Vocab at 0x1178a3e50>),
#  ('thoros', <gensim.models.keyedvectors.Vocab at 0x117911cd0>),
#  ('underestimated', <gensim.models.keyedvectors.Vocab at 0x11786c1d0>),
#  ('offer', <gensim.models.keyedvectors.Vocab at 0x11786c210>),
#  ('shireen', <gensim.models.keyedvectors.Vocab at 0x11786c250>),
#  ('perfumed', <gensim.models.keyedvectors.Vocab at 0x11786c290>),
#  ('matthos', <gensim.models.keyedvectors.Vocab at 0x11786c2d0>),
#  ('duel', <gensim.models.keyedvectors.Vocab at 0x11786c310>),
#  ('inside', <gensim.models.keyedvectors.Vocab at 0x11786c350>),
#  ('morning', <gensim.models.keyedvectors.Vocab at 0x1179a5dd0>),
#  ('vanguard', <gensim.models.keyedvectors.Vocab at 0x11786c390>),
#  ('pest', <gensim.models.keyedvectors.Vocab at 0x11786c3d0>),
#  ('torturing', <gensim.models.keyedvectors.Vocab at 0x11786c410>),
#  ('smashed', <gensim.models.keyedvectors.Vocab at 0x11786c450>),
#  ('juvenile', <gensim.models.keyedvectors.Vocab at 0x11786c490>),
#  ('later', <gensim.models.keyedvectors.Vocab at 0x117b05610>),
#  ('proved', <gensim.models.keyedvectors.Vocab at 0x11786c510>),
#  ('arwyen', <gensim.models.keyedvectors.Vocab at 0x11786c550>),
#  ('tournament', <gensim.models.keyedvectors.Vocab at 0x11786c590>),
#  ('proven', <gensim.models.keyedvectors.Vocab at 0x11786c5d0>),
#  ('meros', <gensim.models.keyedvectors.Vocab at 0x11786c610>),
#  ('soothe', <gensim.models.keyedvectors.Vocab at 0x11786c650>),
#  ('exist', <gensim.models.keyedvectors.Vocab at 0x11786c690>),
#  ('accounting', <gensim.models.keyedvectors.Vocab at 0x11786c6d0>),
#  ('floor', <gensim.models.keyedvectors.Vocab at 0x11786c710>),
#  (u'actor', <gensim.models.keyedvectors.Vocab at 0x11786c750>),
#  ('uttered', <gensim.models.keyedvectors.Vocab at 0x11786c790>),
#  ('flood', <gensim.models.keyedvectors.Vocab at 0x11786c7d0>),
#  ('underfed', <gensim.models.keyedvectors.Vocab at 0x11791cd90>),
#  ('role', <gensim.models.keyedvectors.Vocab at 0x11786c850>),
#  ('ambitious', <gensim.models.keyedvectors.Vocab at 0x11786c890>),
#  ('smell', <gensim.models.keyedvectors.Vocab at 0x11786c8d0>),
#  ('roll', <gensim.models.keyedvectors.Vocab at 0x11786c910>),
#  ('intend', <gensim.models.keyedvectors.Vocab at 0x11786c950>),
#  ('corbray', <gensim.models.keyedvectors.Vocab at 0x11786c990>),
#  (u'ointment', <gensim.models.keyedvectors.Vocab at 0x11786c9d0>),
#  ('scream', <gensim.models.keyedvectors.Vocab at 0x11785b510>),
#  ('acquaintance', <gensim.models.keyedvectors.Vocab at 0x11786ca10>),
#  ('giantsbane', <gensim.models.keyedvectors.Vocab at 0x11786ca50>),
#  ('cleaver', <gensim.models.keyedvectors.Vocab at 0x11786ca90>),
#  (u'daugters', <gensim.models.keyedvectors.Vocab at 0x11786cad0>),
#  ('warn', <gensim.models.keyedvectors.Vocab at 0x117979590>),
#  ('pycelle', <gensim.models.keyedvectors.Vocab at 0x11786cb50>),
#  ('sniffed', <gensim.models.keyedvectors.Vocab at 0x11786cb90>),
#  ('quandary', <gensim.models.keyedvectors.Vocab at 0x11786cbd0>),
#  ('time', <gensim.models.keyedvectors.Vocab at 0x11786cc10>),
#  ('push', <gensim.models.keyedvectors.Vocab at 0x11786cc50>),
#  ('someplace', <gensim.models.keyedvectors.Vocab at 0x117aff590>),
#  ('dotes', <gensim.models.keyedvectors.Vocab at 0x11786cc90>),
#  ('gown', <gensim.models.keyedvectors.Vocab at 0x11786ccd0>),
#  ('chain', <gensim.models.keyedvectors.Vocab at 0x11786cd10>),
#  ('whoever', <gensim.models.keyedvectors.Vocab at 0x11786cd50>),
#  ('warg', <gensim.models.keyedvectors.Vocab at 0x117979690>),
#  ('chair', <gensim.models.keyedvectors.Vocab at 0x11786cdd0>),
#  ('midst', <gensim.models.keyedvectors.Vocab at 0x117849dd0>),
#  ('quartered', <gensim.models.keyedvectors.Vocab at 0x11786ce50>),
#  (u'lothar', <gensim.models.keyedvectors.Vocab at 0x11786ce90>),
#  ('choice', <gensim.models.keyedvectors.Vocab at 0x11786ced0>),
#  ('mourn', <gensim.models.keyedvectors.Vocab at 0x11786cf10>),
#  ('locked', <gensim.models.keyedvectors.Vocab at 0x117849e50>),
#  (u'exact', <gensim.models.keyedvectors.Vocab at 0x11786cf90>),
#  ('minute', <gensim.models.keyedvectors.Vocab at 0x11786cfd0>),
#  ('tear', <gensim.models.keyedvectors.Vocab at 0x117871050>),
#  (u'teat', <gensim.models.keyedvectors.Vocab at 0x117871090>),
#  (u'pea', <gensim.models.keyedvectors.Vocab at 0x1178710d0>),
#  ('leave', <gensim.models.keyedvectors.Vocab at 0x117871110>),
#  ('settle', <gensim.models.keyedvectors.Vocab at 0x117871150>),
#  ('stockade', <gensim.models.keyedvectors.Vocab at 0x117871190>),
#  (u'team', <gensim.models.keyedvectors.Vocab at 0x1178711d0>),
#  ('bonfire', <gensim.models.keyedvectors.Vocab at 0x117871210>),
#  (u'accomplishment', <gensim.models.keyedvectors.Vocab at 0x117849f50>),
#  (u'sigh', <gensim.models.keyedvectors.Vocab at 0x117871290>),
#  ('sign', <gensim.models.keyedvectors.Vocab at 0x1178712d0>),
#  ('chopping', <gensim.models.keyedvectors.Vocab at 0x117871310>),
#  ('catelyn', <gensim.models.keyedvectors.Vocab at 0x117871350>),
#  (u'melt', <gensim.models.keyedvectors.Vocab at 0x117871390>),
#  ('current', <gensim.models.keyedvectors.Vocab at 0x1178713d0>),
#  ('axel', <gensim.models.keyedvectors.Vocab at 0x117871410>),
#  ('falling', <gensim.models.keyedvectors.Vocab at 0x117871450>),
#  ('crashing', <gensim.models.keyedvectors.Vocab at 0x117916610>),
#  ('badge', <gensim.models.keyedvectors.Vocab at 0x1178714d0>),
#  ('ramming', <gensim.models.keyedvectors.Vocab at 0x117871510>),
#  (u'funeral', <gensim.models.keyedvectors.Vocab at 0x117871550>),
#  ('understanding', <gensim.models.keyedvectors.Vocab at 0x117871590>),
#  ('contemplate', <gensim.models.keyedvectors.Vocab at 0x1178715d0>),
#  ('address', <gensim.models.keyedvectors.Vocab at 0x117871610>),
#  ('alone', <gensim.models.keyedvectors.Vocab at 0x117871650>),
#  ('along', <gensim.models.keyedvectors.Vocab at 0x117871690>),
#  ('crumbles', <gensim.models.keyedvectors.Vocab at 0x1178716d0>),
#  (u'summerwine', <gensim.models.keyedvectors.Vocab at 0x117871710>),
#  ('brilliant', <gensim.models.keyedvectors.Vocab at 0x117871750>),
#  ('studied', <gensim.models.keyedvectors.Vocab at 0x117871790>),
#  ('wherever', <gensim.models.keyedvectors.Vocab at 0x1178717d0>),
#  (u'commonly', <gensim.models.keyedvectors.Vocab at 0x117871810>),
#  ('accomplished', <gensim.models.keyedvectors.Vocab at 0x117871850>),
#  ('greizhen', <gensim.models.keyedvectors.Vocab at 0x117871890>),
#  (u'reclaim', <gensim.models.keyedvectors.Vocab at 0x1178718d0>),
#  ('nowhere', <gensim.models.keyedvectors.Vocab at 0x117871910>),
#  ('love', <gensim.models.keyedvectors.Vocab at 0x117871950>),
#  ('prefer', <gensim.models.keyedvectors.Vocab at 0x117871990>),
#  ('logical', <gensim.models.keyedvectors.Vocab at 0x1178719d0>),
#  ('bloody', <gensim.models.keyedvectors.Vocab at 0x117871a10>),
#  ('marvelous', <gensim.models.keyedvectors.Vocab at 0x117871a50>),
#  ('betraying', <gensim.models.keyedvectors.Vocab at 0x117871a90>),
#  (u'sky', <gensim.models.keyedvectors.Vocab at 0x117b57ed0>),
#  (u'capsized', <gensim.models.keyedvectors.Vocab at 0x117871ad0>),
#  ('working', <gensim.models.keyedvectors.Vocab at 0x117871b10>),
#  ('angry', <gensim.models.keyedvectors.Vocab at 0x117871b50>),
#  ('blackwater', <gensim.models.keyedvectors.Vocab at 0x117871b90>),
#  (u'cockfighting', <gensim.models.keyedvectors.Vocab at 0x117871bd0>),
#  ('wondering', <gensim.models.keyedvectors.Vocab at 0x117871c10>),
#  (u'halfbrother', <gensim.models.keyedvectors.Vocab at 0x117871c50>),
#  ('wicked', <gensim.models.keyedvectors.Vocab at 0x117871c90>),
#  (u'introducing', <gensim.models.keyedvectors.Vocab at 0x117871cd0>),
#  (u'guardsman', <gensim.models.keyedvectors.Vocab at 0x117871d10>),
#  ('afford', <gensim.models.keyedvectors.Vocab at 0x117871d50>),
#  ('xaros', <gensim.models.keyedvectors.Vocab at 0x117b15fd0>),
#  ('marbled', <gensim.models.keyedvectors.Vocab at 0x117871d90>),
#  ('everywhere', <gensim.models.keyedvectors.Vocab at 0x117871dd0>),
#  ('virtue', <gensim.models.keyedvectors.Vocab at 0x117871e10>),
#  ('behalf', <gensim.models.keyedvectors.Vocab at 0x117871e50>),
#  ('honey', <gensim.models.keyedvectors.Vocab at 0x117979910>),
#  ('valued', <gensim.models.keyedvectors.Vocab at 0x117871ed0>),
#  ('anything', <gensim.models.keyedvectors.Vocab at 0x1178b3390>),
#  ('originally', <gensim.models.keyedvectors.Vocab at 0x117871f50>),
#  (u'pretend', <gensim.models.keyedvectors.Vocab at 0x117871f90>),
#  ('privy', <gensim.models.keyedvectors.Vocab at 0x117871fd0>),
#  ('believer', <gensim.models.keyedvectors.Vocab at 0x117877050>),
#  (u'impasse', <gensim.models.keyedvectors.Vocab at 0x117877090>),
#  ('believed', <gensim.models.keyedvectors.Vocab at 0x1178770d0>),
#  ('admired', <gensim.models.keyedvectors.Vocab at 0x117877110>),
#  ('locke', <gensim.models.keyedvectors.Vocab at 0x117877150>),
#  (u'unconsummated', <gensim.models.keyedvectors.Vocab at 0x117877190>),
#  ('unveiled', <gensim.models.keyedvectors.Vocab at 0x1178771d0>),
#  ('allowed', <gensim.models.keyedvectors.Vocab at 0x117877210>),
#  ('offense', <gensim.models.keyedvectors.Vocab at 0x117877250>),
#  ('stole', <gensim.models.keyedvectors.Vocab at 0x117877290>),
#  ('evidently', <gensim.models.keyedvectors.Vocab at 0x1178772d0>),
#  ('listens', <gensim.models.keyedvectors.Vocab at 0x117877310>),
#  ('winter', <gensim.models.keyedvectors.Vocab at 0x117877350>),
#  (u'divided', <gensim.models.keyedvectors.Vocab at 0x117877390>),
#  ('thanking', <gensim.models.keyedvectors.Vocab at 0x1178773d0>),
#  ('immune', <gensim.models.keyedvectors.Vocab at 0x117877410>),
#  ('loathe', <gensim.models.keyedvectors.Vocab at 0x1179799d0>),
#  (u'encampment', <gensim.models.keyedvectors.Vocab at 0x117877490>),
#  (u'provincial', <gensim.models.keyedvectors.Vocab at 0x1178774d0>),
#  ('spot', <gensim.models.keyedvectors.Vocab at 0x117877510>),
#  ('suck', <gensim.models.keyedvectors.Vocab at 0x117877550>),
#  ('dove', <gensim.models.keyedvectors.Vocab at 0x117877590>),
#  (u'stress', <gensim.models.keyedvectors.Vocab at 0x1178775d0>),
#  ('natural', <gensim.models.keyedvectors.Vocab at 0x117877610>),
#  ('blackfish', <gensim.models.keyedvectors.Vocab at 0x117b05c10>),
#  ('st', <gensim.models.keyedvectors.Vocab at 0x117877690>),
#  ('swollen', <gensim.models.keyedvectors.Vocab at 0x1178776d0>),
#  ('truce', <gensim.models.keyedvectors.Vocab at 0x117877710>),
#  ('pulled', <gensim.models.keyedvectors.Vocab at 0x117877750>),
#  ('drunken', <gensim.models.keyedvectors.Vocab at 0x117877790>),
#  (u'footstep', <gensim.models.keyedvectors.Vocab at 0x1178777d0>),
#  ('unacceptable', <gensim.models.keyedvectors.Vocab at 0x117877810>),
#  ('damage', <gensim.models.keyedvectors.Vocab at 0x117877850>),
#  ('course', <gensim.models.keyedvectors.Vocab at 0x117877890>),
#  ('yearn', <gensim.models.keyedvectors.Vocab at 0x1178778d0>),
#  ('mishear', <gensim.models.keyedvectors.Vocab at 0x117877910>),
#  ('lovelier', <gensim.models.keyedvectors.Vocab at 0x117877950>),
#  (u'tendency', <gensim.models.keyedvectors.Vocab at 0x117877990>),
#  ('tore', <gensim.models.keyedvectors.Vocab at 0x1178779d0>),
#  ('milked', <gensim.models.keyedvectors.Vocab at 0x117877a10>),
#  ('torn', <gensim.models.keyedvectors.Vocab at 0x117877a50>),
#  ('stupidity', <gensim.models.keyedvectors.Vocab at 0x117979a50>),
#  ('aerion', <gensim.models.keyedvectors.Vocab at 0x117877ad0>),
#  ('celebrate', <gensim.models.keyedvectors.Vocab at 0x117877b10>),
#  ('troubled', <gensim.models.keyedvectors.Vocab at 0x117877b50>),
#  (u'deviant', <gensim.models.keyedvectors.Vocab at 0x117877b90>),
#  (u'chaining', <gensim.models.keyedvectors.Vocab at 0x117877bd0>),
#  ('smarter', <gensim.models.keyedvectors.Vocab at 0x117877c10>),
#  ('arriving', <gensim.models.keyedvectors.Vocab at 0x117877c50>),
#  ('reckoning', <gensim.models.keyedvectors.Vocab at 0x117877c90>),
#  (u'shhh', <gensim.models.keyedvectors.Vocab at 0x117877cd0>),
#  ('maintaining', <gensim.models.keyedvectors.Vocab at 0x117877d10>),
#  ('matched', <gensim.models.keyedvectors.Vocab at 0x117877d50>),
#  ('freya', <gensim.models.keyedvectors.Vocab at 0x117877d90>),
#  ('appropriate', <gensim.models.keyedvectors.Vocab at 0x1178b3510>),
#  ('stillborns', <gensim.models.keyedvectors.Vocab at 0x117877e10>),
#  ('fisherman', <gensim.models.keyedvectors.Vocab at 0x117877e50>),
#  ('amnesty', <gensim.models.keyedvectors.Vocab at 0x117877e90>),
#  (u'quarter', <gensim.models.keyedvectors.Vocab at 0x117877ed0>),
#  ('broodmare', <gensim.models.keyedvectors.Vocab at 0x117877f10>),
#  ('square', <gensim.models.keyedvectors.Vocab at 0x117877f50>),
#  ('beloved', <gensim.models.keyedvectors.Vocab at 0x117877f90>),
#  ('entering', <gensim.models.keyedvectors.Vocab at 0x117877fd0>),
#  (u'beetle', <gensim.models.keyedvectors.Vocab at 0x11787c050>),
#  ('troll', <gensim.models.keyedvectors.Vocab at 0x11787c090>),
#  (u'swordsman', <gensim.models.keyedvectors.Vocab at 0x11787c0d0>),
#  ('seriously', <gensim.models.keyedvectors.Vocab at 0x11787c110>),
#  ('investigation', <gensim.models.keyedvectors.Vocab at 0x11787c150>),
#  ('suggesting', <gensim.models.keyedvectors.Vocab at 0x11787c190>),
#  ('facedown', <gensim.models.keyedvectors.Vocab at 0x11787c210>),
#  ('siege', <gensim.models.keyedvectors.Vocab at 0x11787c250>),
#  ('million', <gensim.models.keyedvectors.Vocab at 0x11787c290>),
#  ('seventh', <gensim.models.keyedvectors.Vocab at 0x11787c2d0>),
#  (u'possibility', <gensim.models.keyedvectors.Vocab at 0x11787c310>),
#  ('quite', <gensim.models.keyedvectors.Vocab at 0x11787c350>),
#  ('complicated', <gensim.models.keyedvectors.Vocab at 0x11787c3d0>),
#  ('besides', <gensim.models.keyedvectors.Vocab at 0x11787c410>),
#  (u'grandma', <gensim.models.keyedvectors.Vocab at 0x11787c450>),
#  ('unnamed', <gensim.models.keyedvectors.Vocab at 0x11787c490>),
#  ('patronage', <gensim.models.keyedvectors.Vocab at 0x11787c4d0>),
#  ('training', <gensim.models.keyedvectors.Vocab at 0x11787c510>),
#  ('backside', <gensim.models.keyedvectors.Vocab at 0x11787c550>),
#  ('modest', <gensim.models.keyedvectors.Vocab at 0x11787c590>),
#  (u'nymeria', <gensim.models.keyedvectors.Vocab at 0x11787c5d0>),
#  ('saving', <gensim.models.keyedvectors.Vocab at 0x11787c610>),
#  ('spoken', <gensim.models.keyedvectors.Vocab at 0x11787c650>),
#  ('one', <gensim.models.keyedvectors.Vocab at 0x11787c690>),
#  (u'reopen', <gensim.models.keyedvectors.Vocab at 0x11787c6d0>),
#  ('punishable', <gensim.models.keyedvectors.Vocab at 0x11787c710>),
#  ('vote', <gensim.models.keyedvectors.Vocab at 0x11787c750>),
#  ('open', <gensim.models.keyedvectors.Vocab at 0x11787c790>),
#  ('ripping', <gensim.models.keyedvectors.Vocab at 0x11797f790>),
#  ('partook', <gensim.models.keyedvectors.Vocab at 0x11787c810>),
#  (u'city', <gensim.models.keyedvectors.Vocab at 0x11787c850>),
#  (u'wrath', <gensim.models.keyedvectors.Vocab at 0x11787c890>),
#  ('bite', <gensim.models.keyedvectors.Vocab at 0x11787c8d0>),
#  ('teacher', <gensim.models.keyedvectors.Vocab at 0x117b31810>),
#  (u'shiver', <gensim.models.keyedvectors.Vocab at 0x11787c910>),
#  ('prone', <gensim.models.keyedvectors.Vocab at 0x11787c950>),
#  ('shawl', <gensim.models.keyedvectors.Vocab at 0x11787c990>),
#  ('meddling', <gensim.models.keyedvectors.Vocab at 0x11787c9d0>),
#  (u'padding', <gensim.models.keyedvectors.Vocab at 0x11787ca10>),
#  ('prowling', <gensim.models.keyedvectors.Vocab at 0x1178b3710>),
#  ('ridiculous', <gensim.models.keyedvectors.Vocab at 0x11787ca90>),
#  (u'camello', <gensim.models.keyedvectors.Vocab at 0x11787cad0>),
#  ('third', <gensim.models.keyedvectors.Vocab at 0x117979c50>),
#  ('cower', <gensim.models.keyedvectors.Vocab at 0x11798a090>),
#  ('sandor', <gensim.models.keyedvectors.Vocab at 0x11787cb90>),
#  (u'counselor', <gensim.models.keyedvectors.Vocab at 0x11787cbd0>),
#  (u'wandering', <gensim.models.keyedvectors.Vocab at 0x11787cc10>),
#  ('damned', <gensim.models.keyedvectors.Vocab at 0x11787cc50>),
#  ('prospect', <gensim.models.keyedvectors.Vocab at 0x11787cc90>),
#  (u'addressing', <gensim.models.keyedvectors.Vocab at 0x11787ccd0>),
#  (u'illness', <gensim.models.keyedvectors.Vocab at 0x11787cd10>),
#  ('tasted', <gensim.models.keyedvectors.Vocab at 0x11787cd50>),
#  ('nicer', <gensim.models.keyedvectors.Vocab at 0x11787cd90>),
#  ('turned', <gensim.models.keyedvectors.Vocab at 0x11787cdd0>),
#  ('alley', <gensim.models.keyedvectors.Vocab at 0x11787ce10>),
#  ('sad', <gensim.models.keyedvectors.Vocab at 0x11787ce50>),
#  ('say', <gensim.models.keyedvectors.Vocab at 0x11787ce90>),
#  ('taster', <gensim.models.keyedvectors.Vocab at 0x11787ced0>),
#  ('buried', <gensim.models.keyedvectors.Vocab at 0x11787cf10>),
#  ('lurking', <gensim.models.keyedvectors.Vocab at 0x11787cf50>),
#  ('sap', <gensim.models.keyedvectors.Vocab at 0x11787cf90>),
#  ('saw', <gensim.models.keyedvectors.Vocab at 0x11787cfd0>),
#  ('sat', <gensim.models.keyedvectors.Vocab at 0x117882050>),
#  ('wink', <gensim.models.keyedvectors.Vocab at 0x117882090>),
#  (u'downwards', <gensim.models.keyedvectors.Vocab at 0x1178820d0>),
#  ('aside', <gensim.models.keyedvectors.Vocab at 0x11798fb10>),
#  ('instructed', <gensim.models.keyedvectors.Vocab at 0x117882150>),
#  ('note', <gensim.models.keyedvectors.Vocab at 0x117882190>),
#  ('take', <gensim.models.keyedvectors.Vocab at 0x1178821d0>),
#  (u'mazin', <gensim.models.keyedvectors.Vocab at 0x117882210>),
#  ('wanting', <gensim.models.keyedvectors.Vocab at 0x11798fed0>),
#  (u'opposite', <gensim.models.keyedvectors.Vocab at 0x117882290>),
#  ('squalor', <gensim.models.keyedvectors.Vocab at 0x1178822d0>),
#  ('knew', <gensim.models.keyedvectors.Vocab at 0x117882310>),
#  ('knee', <gensim.models.keyedvectors.Vocab at 0x117882350>),
#  ('average', <gensim.models.keyedvectors.Vocab at 0x117882390>),
#  (u'sale', <gensim.models.keyedvectors.Vocab at 0x117995d10>),
#  (u'defeating', <gensim.models.keyedvectors.Vocab at 0x117882410>),
#  ('crooked', <gensim.models.keyedvectors.Vocab at 0x117b05f50>),
#  ('gillyflower', <gensim.models.keyedvectors.Vocab at 0x117882490>),
#  ('squint', <gensim.models.keyedvectors.Vocab at 0x1178824d0>),
#  ('butchered', <gensim.models.keyedvectors.Vocab at 0x117882510>),
#  ('salt', <gensim.models.keyedvectors.Vocab at 0x117882550>),
#  ('walking', <gensim.models.keyedvectors.Vocab at 0x117882590>),
#  (u'merit', <gensim.models.keyedvectors.Vocab at 0x1178825d0>),
#  ('bright', <gensim.models.keyedvectors.Vocab at 0x117882610>),
#  ('imagined', <gensim.models.keyedvectors.Vocab at 0x117882650>),
#  ('slow', <gensim.models.keyedvectors.Vocab at 0x117882690>),
#  ('strangled', <gensim.models.keyedvectors.Vocab at 0x1179bb810>),
#  (u'cloak', <gensim.models.keyedvectors.Vocab at 0x1178826d0>),
#  ('liberation', <gensim.models.keyedvectors.Vocab at 0x117882710>),
#  ('betrothal', <gensim.models.keyedvectors.Vocab at 0x117882750>),
#  ('going', <gensim.models.keyedvectors.Vocab at 0x117882790>),
#  ('dancing', <gensim.models.keyedvectors.Vocab at 0x117b36210>),
#  ('outrage', <gensim.models.keyedvectors.Vocab at 0x1178827d0>),
#  ('robe', <gensim.models.keyedvectors.Vocab at 0x117882810>),
#  ('clawing', <gensim.models.keyedvectors.Vocab at 0x117882850>),
#  ('robb', <gensim.models.keyedvectors.Vocab at 0x117882890>),
#  (u'dispute', <gensim.models.keyedvectors.Vocab at 0x1178828d0>),
#  ('graceless', <gensim.models.keyedvectors.Vocab at 0x117882910>),
#  ('guarded', <gensim.models.keyedvectors.Vocab at 0x117882950>),
#  ('freezing', <gensim.models.keyedvectors.Vocab at 0x117882990>),
#  (u'clang', <gensim.models.keyedvectors.Vocab at 0x1178829d0>),
#  ('awaiting', <gensim.models.keyedvectors.Vocab at 0x117882a10>),
#  ('vhag', <gensim.models.keyedvectors.Vocab at 0x117882a50>),
#  ('prime', <gensim.models.keyedvectors.Vocab at 0x117882a90>),
#  (u'resource', <gensim.models.keyedvectors.Vocab at 0x117882ad0>),
#  (u'artist', <gensim.models.keyedvectors.Vocab at 0x117882b10>),
#  ('absurdly', <gensim.models.keyedvectors.Vocab at 0x117882b50>),
#  ('worried', <gensim.models.keyedvectors.Vocab at 0x117882b90>),
#  ('carrion', <gensim.models.keyedvectors.Vocab at 0x117882bd0>),
#  ('priest', <gensim.models.keyedvectors.Vocab at 0x117882c10>),
#  (u'primp', <gensim.models.keyedvectors.Vocab at 0x117882c50>),
#  (u'vision', <gensim.models.keyedvectors.Vocab at 0x117882c90>),
#  ('gout', <gensim.models.keyedvectors.Vocab at 0x117882cd0>),
#  ('raged', <gensim.models.keyedvectors.Vocab at 0x117882d10>),
#  ('notice', <gensim.models.keyedvectors.Vocab at 0x117882d50>),
#  ('purest', <gensim.models.keyedvectors.Vocab at 0x117882d90>),
#  ('stannis', <gensim.models.keyedvectors.Vocab at 0x117882dd0>),
#  ('mutton', <gensim.models.keyedvectors.Vocab at 0x117882e10>),
#  ('jumped', <gensim.models.keyedvectors.Vocab at 0x1179b00d0>),
#  ('enjoys', <gensim.models.keyedvectors.Vocab at 0x117882e90>),
#  ('amory', <gensim.models.keyedvectors.Vocab at 0x117882ed0>),
#  ('spare', <gensim.models.keyedvectors.Vocab at 0x117882f10>),
#  ('umber', <gensim.models.keyedvectors.Vocab at 0x117882f50>),
#  ('undermine', <gensim.models.keyedvectors.Vocab at 0x117882f90>),
#  ('mant', <gensim.models.keyedvectors.Vocab at 0x117882fd0>),
#  ('many', <gensim.models.keyedvectors.Vocab at 0x117887050>),
#  ('loudly', <gensim.models.keyedvectors.Vocab at 0x117887090>),
#  (u'riddle', <gensim.models.keyedvectors.Vocab at 0x1178870d0>),
#  ('drogo', <gensim.models.keyedvectors.Vocab at 0x117887110>),
#  (u'compels', <gensim.models.keyedvectors.Vocab at 0x117887150>),
#  (u'twin', <gensim.models.keyedvectors.Vocab at 0x117887190>),
#  ('boar', <gensim.models.keyedvectors.Vocab at 0x1178871d0>),
#  (u'considers', <gensim.models.keyedvectors.Vocab at 0x1179bb550>),
#  ('boat', <gensim.models.keyedvectors.Vocab at 0x117887250>),
#  (u'stretch', <gensim.models.keyedvectors.Vocab at 0x117887290>),
#  ('west', <gensim.models.keyedvectors.Vocab at 0x1178872d0>),
#  (u'expedition', <gensim.models.keyedvectors.Vocab at 0x117887310>),
#  ('breath', <gensim.models.keyedvectors.Vocab at 0x117887350>),
#  ('combined', <gensim.models.keyedvectors.Vocab at 0x117887390>),
#  ('stripped', <gensim.models.keyedvectors.Vocab at 0x1178873d0>),
#  ('coughing', <gensim.models.keyedvectors.Vocab at 0x1179c1590>),
#  ('centerpiece', <gensim.models.keyedvectors.Vocab at 0x117887450>),
#  ('observe', <gensim.models.keyedvectors.Vocab at 0x117887490>),
#  (u'extant', <gensim.models.keyedvectors.Vocab at 0x1178874d0>),
#  ('former', <gensim.models.keyedvectors.Vocab at 0x117887510>),
#  ('wherewithal', <gensim.models.keyedvectors.Vocab at 0x117887550>),
#  (u'fin', <gensim.models.keyedvectors.Vocab at 0x117887590>),
#  ('straighten', <gensim.models.keyedvectors.Vocab at 0x1179c6110>),
#  ('whatevers', <gensim.models.keyedvectors.Vocab at 0x117b0a250>),
#  ('squeezed', <gensim.models.keyedvectors.Vocab at 0x117887650>),
#  (u'situation', <gensim.models.keyedvectors.Vocab at 0x117887690>),
#  ('endured', <gensim.models.keyedvectors.Vocab at 0x1178876d0>),
#  ('ive', <gensim.models.keyedvectors.Vocab at 0x117887710>),
#  ('thatll', <gensim.models.keyedvectors.Vocab at 0x117887750>),
#  ('purse', <gensim.models.keyedvectors.Vocab at 0x117887790>),
#  ('shevelathin', <gensim.models.keyedvectors.Vocab at 0x1178877d0>),
#  ('spooked', <gensim.models.keyedvectors.Vocab at 0x117887810>),
#  ('burbling', <gensim.models.keyedvectors.Vocab at 0x117887850>),
#  ('threatens', <gensim.models.keyedvectors.Vocab at 0x117887890>),
#  ('damon', <gensim.models.keyedvectors.Vocab at 0x1178878d0>),
#  ('edged', <gensim.models.keyedvectors.Vocab at 0x117887910>),
#  ('sickness', <gensim.models.keyedvectors.Vocab at 0x1179d1350>),
#  ('defy', <gensim.models.keyedvectors.Vocab at 0x117887990>),
# ...
#  ('dark', <gensim.models.keyedvectors.Vocab at 0x117887d50>),
#  ('preference', <gensim.models.keyedvectors.Vocab at 0x117887d90>),
#  ('fringed', <gensim.models.keyedvectors.Vocab at 0x11798f710>),
#  ('vague', <gensim.models.keyedvectors.Vocab at 0x117887e10>),
#  ('bravery', <gensim.models.keyedvectors.Vocab at 0x117887e50>),
#  (u'clan', <gensim.models.keyedvectors.Vocab at 0x117887e90>),
#  (u'clam', <gensim.models.keyedvectors.Vocab at 0x117887ed0>),
#  ('stranger', <gensim.models.keyedvectors.Vocab at 0x117887f10>),
#  ('discarded', <gensim.models.keyedvectors.Vocab at 0x117887f50>),
#  ('superiority', <gensim.models.keyedvectors.Vocab at 0x117887f90>),
#  (u'claw', <gensim.models.keyedvectors.Vocab at 0x117887fd0>),
#  ('sorcerer', <gensim.models.keyedvectors.Vocab at 0x1178b3f90>),
#  (u'kennel', <gensim.models.keyedvectors.Vocab at 0x11788d090>),
#  (u'clap', <gensim.models.keyedvectors.Vocab at 0x11788d0d0>),
#  ('grub', <gensim.models.keyedvectors.Vocab at 0x11788d110>),
#  (u'lobster', <gensim.models.keyedvectors.Vocab at 0x11788d150>),
#  (u'divine', <gensim.models.keyedvectors.Vocab at 0x11788d190>),
#  ('crabber', <gensim.models.keyedvectors.Vocab at 0x11788d1d0>),
#  ('dimpled', <gensim.models.keyedvectors.Vocab at 0x11788d210>),
#  ('refer', <gensim.models.keyedvectors.Vocab at 0x11788d250>),
#  (u'clarenzo', <gensim.models.keyedvectors.Vocab at 0x11788d290>),
#  ('averse', <gensim.models.keyedvectors.Vocab at 0x11788d2d0>),
#  ('power', <gensim.models.keyedvectors.Vocab at 0x11788d310>),
#  ('intimate', <gensim.models.keyedvectors.Vocab at 0x11788d350>),
#  ('hayseed', <gensim.models.keyedvectors.Vocab at 0x11788d390>),
#  ('leadership', <gensim.models.keyedvectors.Vocab at 0x11788d3d0>),
#  (u'stone', <gensim.models.keyedvectors.Vocab at 0x11788d410>),
#  ('yunkai', <gensim.models.keyedvectors.Vocab at 0x11788d450>),
#  ('favorite', <gensim.models.keyedvectors.Vocab at 0x11788d490>),
#  (u'side', <gensim.models.keyedvectors.Vocab at 0x11797f410>),
#  (u'apostate', <gensim.models.keyedvectors.Vocab at 0x11788d510>),
#  (u'neighbor', <gensim.models.keyedvectors.Vocab at 0x11788d550>),
#  ('act', <gensim.models.keyedvectors.Vocab at 0x11788d590>),
#  (u'mean', <gensim.models.keyedvectors.Vocab at 0x1179dc410>),
#  ('stony', <gensim.models.keyedvectors.Vocab at 0x11788d610>),
#  (u'widowed', <gensim.models.keyedvectors.Vocab at 0x11788d650>),
#  ('chivalry', <gensim.models.keyedvectors.Vocab at 0x11788d690>),
#  ('shapely', <gensim.models.keyedvectors.Vocab at 0x11788d6d0>),
#  ('burning', <gensim.models.keyedvectors.Vocab at 0x11788d710>),
#  ('interruption', <gensim.models.keyedvectors.Vocab at 0x11797f4d0>),
#  (u'antidote', <gensim.models.keyedvectors.Vocab at 0x11788d790>),
#  ('apologize', <gensim.models.keyedvectors.Vocab at 0x11788d7d0>),
#  (u'pivot', <gensim.models.keyedvectors.Vocab at 0x1179f8390>),
#  ('trussed', <gensim.models.keyedvectors.Vocab at 0x11788d850>),
#  ('hey', <gensim.models.keyedvectors.Vocab at 0x11788d890>),
#  ('hed', <gensim.models.keyedvectors.Vocab at 0x11788d8d0>),
#  (u'lhazareen', <gensim.models.keyedvectors.Vocab at 0x11788d910>),
#  ('mindless', <gensim.models.keyedvectors.Vocab at 0x11788d950>),
#  ('sealed', <gensim.models.keyedvectors.Vocab at 0x11788d990>),
#  (u'hen', <gensim.models.keyedvectors.Vocab at 0x11788d9d0>),
#  ('survives', <gensim.models.keyedvectors.Vocab at 0x11788da10>),
#  ('recommends', <gensim.models.keyedvectors.Vocab at 0x11788da50>),
#  ('complete', <gensim.models.keyedvectors.Vocab at 0x11788da90>),
#  ('survived', <gensim.models.keyedvectors.Vocab at 0x11788dad0>),
#  (u'whinny', <gensim.models.keyedvectors.Vocab at 0x11788db10>),
#  ('buying', <gensim.models.keyedvectors.Vocab at 0x11788db50>),
#  ('handsome', <gensim.models.keyedvectors.Vocab at 0x11788db90>),
#  ('abused', <gensim.models.keyedvectors.Vocab at 0x11788dbd0>),
#  ('pull', <gensim.models.keyedvectors.Vocab at 0x11788dc10>),
#  (u'rush', <gensim.models.keyedvectors.Vocab at 0x11788dc50>),
#  ('rage', <gensim.models.keyedvectors.Vocab at 0x11788dc90>),
#  ('browbeaten', <gensim.models.keyedvectors.Vocab at 0x11788dcd0>),
#  ('balons', <gensim.models.keyedvectors.Vocab at 0x11797f550>),
#  ('dirty', <gensim.models.keyedvectors.Vocab at 0x11788dd50>),
#  ('agree', <gensim.models.keyedvectors.Vocab at 0x11788dd90>),
#  ('darker', <gensim.models.keyedvectors.Vocab at 0x11788ddd0>),
#  (u'detailed', <gensim.models.keyedvectors.Vocab at 0x11788de10>),
#  ('gone', <gensim.models.keyedvectors.Vocab at 0x11788de50>),
#  ('fright', <gensim.models.keyedvectors.Vocab at 0x11788de90>),
#  (u'exhausted', <gensim.models.keyedvectors.Vocab at 0x11788ded0>),
#  ('ah', <gensim.models.keyedvectors.Vocab at 0x11788df10>),
#  ('stealing', <gensim.models.keyedvectors.Vocab at 0x11797f5d0>),
#  ('al', <gensim.models.keyedvectors.Vocab at 0x11788df90>),
#  ('wartime', <gensim.models.keyedvectors.Vocab at 0x11788dfd0>),
#  (u'watcher', <gensim.models.keyedvectors.Vocab at 0x117892050>),
#  ('behest', <gensim.models.keyedvectors.Vocab at 0x117892090>),
#  (u'as', <gensim.models.keyedvectors.Vocab at 0x1178920d0>),
#  ('carved', <gensim.models.keyedvectors.Vocab at 0x117892110>),
#  (u'midwife', <gensim.models.keyedvectors.Vocab at 0x117892150>),
#  ('laboratory', <gensim.models.keyedvectors.Vocab at 0x117892190>),
#  ('ax', <gensim.models.keyedvectors.Vocab at 0x1178921d0>),
#  (u'johnna', <gensim.models.keyedvectors.Vocab at 0x117892210>),
#  ('cream', <gensim.models.keyedvectors.Vocab at 0x117892250>),
#  (u'ideally', <gensim.models.keyedvectors.Vocab at 0x117892290>),
#  ('tight', <gensim.models.keyedvectors.Vocab at 0x1178922d0>),
#  ('httpsubttfreeorg', <gensim.models.keyedvectors.Vocab at 0x117892310>),
#  (u'puppy', <gensim.models.keyedvectors.Vocab at 0x117892350>),
#  ('disgraceful', <gensim.models.keyedvectors.Vocab at 0x1178923d0>),
#  (u'congress', <gensim.models.keyedvectors.Vocab at 0x117892410>),
#  ('waving', <gensim.models.keyedvectors.Vocab at 0x117892450>),
#  (u'middling', <gensim.models.keyedvectors.Vocab at 0x117892490>),
#  (u'midget', <gensim.models.keyedvectors.Vocab at 0x1178924d0>),
#  ('brotherhood', <gensim.models.keyedvectors.Vocab at 0x117892510>),
#  ('tricky', <gensim.models.keyedvectors.Vocab at 0x117892550>),
#  ('disdained', <gensim.models.keyedvectors.Vocab at 0x117892590>),
#  ('infanticide', <gensim.models.keyedvectors.Vocab at 0x1178925d0>),
#  ('sobbing', <gensim.models.keyedvectors.Vocab at 0x117892610>),
#  (u'thorn', <gensim.models.keyedvectors.Vocab at 0x117892650>),
#  ('groom', <gensim.models.keyedvectors.Vocab at 0x117892690>),
#  (u'mask', <gensim.models.keyedvectors.Vocab at 0x1178926d0>),
#  (u'dyed', <gensim.models.keyedvectors.Vocab at 0x117892710>),
#  (u'mast', <gensim.models.keyedvectors.Vocab at 0x117892750>),
#  (u'mass', <gensim.models.keyedvectors.Vocab at 0x117892790>),
#  ('sawing', <gensim.models.keyedvectors.Vocab at 0x1178927d0>),
#  (u'dyer', <gensim.models.keyedvectors.Vocab at 0x117892810>),
#  ('original', <gensim.models.keyedvectors.Vocab at 0x117892850>),
#  ('consider', <gensim.models.keyedvectors.Vocab at 0x117892890>),
#  ('beware', <gensim.models.keyedvectors.Vocab at 0x1178928d0>),
#  (u'neigh', <gensim.models.keyedvectors.Vocab at 0x117892910>),
#  ('welfare', <gensim.models.keyedvectors.Vocab at 0x117892950>),
#  ('hunting', <gensim.models.keyedvectors.Vocab at 0x117892990>),
#  ('tail', <gensim.models.keyedvectors.Vocab at 0x1178929d0>),
#  ('chewing', <gensim.models.keyedvectors.Vocab at 0x117892a10>),
#  ('dockworker', <gensim.models.keyedvectors.Vocab at 0x117892a50>),
#  ('th', <gensim.models.keyedvectors.Vocab at 0x117892a90>),
#  (u'ti', <gensim.models.keyedvectors.Vocab at 0x117892ad0>),
#  ('smile', <gensim.models.keyedvectors.Vocab at 0x117892b10>),
#  (u'shipload', <gensim.models.keyedvectors.Vocab at 0x117892b50>),
#  ('paying', <gensim.models.keyedvectors.Vocab at 0x117b0a910>),
#  ('appointment', <gensim.models.keyedvectors.Vocab at 0x117892bd0>),
#  ('returned', <gensim.models.keyedvectors.Vocab at 0x117892c10>),
#  ('squiring', <gensim.models.keyedvectors.Vocab at 0x117892c50>),
#  ('eyrie', <gensim.models.keyedvectors.Vocab at 0x117892c90>),
#  ('condition', <gensim.models.keyedvectors.Vocab at 0x117892cd0>),
#  ('harrenhal', <gensim.models.keyedvectors.Vocab at 0x117892d10>),
#  ('overprotective', <gensim.models.keyedvectors.Vocab at 0x117892d50>),
#  (u'laying', <gensim.models.keyedvectors.Vocab at 0x117892d90>),
#  ('joined', <gensim.models.keyedvectors.Vocab at 0x117892dd0>),
#  ('underclothes', <gensim.models.keyedvectors.Vocab at 0x117892e10>),
#  ('large', <gensim.models.keyedvectors.Vocab at 0x117892e50>),
#  ('sang', <gensim.models.keyedvectors.Vocab at 0x117892e90>),
#  ('sand', <gensim.models.keyedvectors.Vocab at 0x117892ed0>),
#  (u'adjust', <gensim.models.keyedvectors.Vocab at 0x117892f10>),
#  ('small', <gensim.models.keyedvectors.Vocab at 0x117892f50>),
#  ('quicker', <gensim.models.keyedvectors.Vocab at 0x117892f90>),
#  (u'healed', <gensim.models.keyedvectors.Vocab at 0x117892fd0>),
#  ('past', <gensim.models.keyedvectors.Vocab at 0x117898050>),
#  ('podrick', <gensim.models.keyedvectors.Vocab at 0x11797f890>),
#  (u'pass', <gensim.models.keyedvectors.Vocab at 0x1178980d0>),
#  ('turning', <gensim.models.keyedvectors.Vocab at 0x11797f8d0>),
#  (u'investment', <gensim.models.keyedvectors.Vocab at 0x117898150>),
#  ('poisonous', <gensim.models.keyedvectors.Vocab at 0x117898190>),
#  ('prevailed', <gensim.models.keyedvectors.Vocab at 0x1178981d0>),
#  ('nurse', <gensim.models.keyedvectors.Vocab at 0x117898210>),
#  ('full', <gensim.models.keyedvectors.Vocab at 0x117898250>),
#  ('escaping', <gensim.models.keyedvectors.Vocab at 0x117898290>),
#  ('vomiting', <gensim.models.keyedvectors.Vocab at 0x1178982d0>),
#  ('smartest', <gensim.models.keyedvectors.Vocab at 0x117898310>),
#  ('buzzing', <gensim.models.keyedvectors.Vocab at 0x117898350>),
#  ('legend', <gensim.models.keyedvectors.Vocab at 0x117898390>),
#  ('slynt', <gensim.models.keyedvectors.Vocab at 0x1178983d0>),
#  ('kayla', <gensim.models.keyedvectors.Vocab at 0x117854490>),
#  ('experience', <gensim.models.keyedvectors.Vocab at 0x117898450>),
#  ('pick', <gensim.models.keyedvectors.Vocab at 0x117898490>),
#  (u'action', <gensim.models.keyedvectors.Vocab at 0x1178984d0>),
#  ('murdering', <gensim.models.keyedvectors.Vocab at 0x117898510>),
#  ('luck', <gensim.models.keyedvectors.Vocab at 0x11797f490>),
#  ('smuggle', <gensim.models.keyedvectors.Vocab at 0x117898550>),
#  ('gawking', <gensim.models.keyedvectors.Vocab at 0x117898590>),
#  ('followed', <gensim.models.keyedvectors.Vocab at 0x1178985d0>),
#  (u'follower', <gensim.models.keyedvectors.Vocab at 0x117898610>),
#  (u'indoors', <gensim.models.keyedvectors.Vocab at 0x117898650>),
#  (u'captor', <gensim.models.keyedvectors.Vocab at 0x117898690>),
#  ('darkens', <gensim.models.keyedvectors.Vocab at 0x1178986d0>),
#  (u'moro', <gensim.models.keyedvectors.Vocab at 0x117898710>),
#  (u'gorgeous', <gensim.models.keyedvectors.Vocab at 0x117898750>),
#  (u'mord', <gensim.models.keyedvectors.Vocab at 0x117898790>),
#  ('restraint', <gensim.models.keyedvectors.Vocab at 0x117b31ed0>),
#  ('door', <gensim.models.keyedvectors.Vocab at 0x1178987d0>),
#  ('company', <gensim.models.keyedvectors.Vocab at 0x117898810>),
#  ('tested', <gensim.models.keyedvectors.Vocab at 0x117898850>),
#  ('doom', <gensim.models.keyedvectors.Vocab at 0x117898890>),
#  ('riverbank', <gensim.models.keyedvectors.Vocab at 0x1178988d0>),
#  ('cunning', <gensim.models.keyedvectors.Vocab at 0x117898910>),
#  ('keeping', <gensim.models.keyedvectors.Vocab at 0x117898950>),
#  ('pleasing', <gensim.models.keyedvectors.Vocab at 0x117898990>),
#  ('farted', <gensim.models.keyedvectors.Vocab at 0x1178989d0>),
#  ('thickest', <gensim.models.keyedvectors.Vocab at 0x117898a10>),
#  ('learn', <gensim.models.keyedvectors.Vocab at 0x117898a50>),
#  ('knocked', <gensim.models.keyedvectors.Vocab at 0x117898a90>),
#  ('sunspear', <gensim.models.keyedvectors.Vocab at 0x117898ad0>),
#  (u'seagull', <gensim.models.keyedvectors.Vocab at 0x117898b10>),
#  (u'male', <gensim.models.keyedvectors.Vocab at 0x117898b50>),
#  ('beautiful', <gensim.models.keyedvectors.Vocab at 0x117898b90>),
#  ('brightflame', <gensim.models.keyedvectors.Vocab at 0x117898bd0>),
#  ('accept', <gensim.models.keyedvectors.Vocab at 0x117898c10>),
#  ('fiercely', <gensim.models.keyedvectors.Vocab at 0x117898c50>),
#  ('sense', <gensim.models.keyedvectors.Vocab at 0x117898c90>),
#  ('scar', <gensim.models.keyedvectors.Vocab at 0x117898d10>),
#  ('dress', <gensim.models.keyedvectors.Vocab at 0x117898d50>),
#  ('condemn', <gensim.models.keyedvectors.Vocab at 0x117898d90>),
#  ('information', <gensim.models.keyedvectors.Vocab at 0x117898dd0>),
#  ('impulse', <gensim.models.keyedvectors.Vocab at 0x11792c710>),
#  ('imminent', <gensim.models.keyedvectors.Vocab at 0x117898e10>),
#  (u'hugh', <gensim.models.keyedvectors.Vocab at 0x117898e50>),
#  ('dismissed', <gensim.models.keyedvectors.Vocab at 0x117898e90>),
#  (u'glowing', <gensim.models.keyedvectors.Vocab at 0x117898ed0>),
#  ('freshly', <gensim.models.keyedvectors.Vocab at 0x117898f10>),
#  (u'clink', <gensim.models.keyedvectors.Vocab at 0x117898f50>),
#  ('unattended', <gensim.models.keyedvectors.Vocab at 0x117898f90>),
#  ('creature', <gensim.models.keyedvectors.Vocab at 0x117898fd0>),
#  ('sprinkle', <gensim.models.keyedvectors.Vocab at 0x11789d050>),
#  ('intended', <gensim.models.keyedvectors.Vocab at 0x11789d090>),
#  ('countryside', <gensim.models.keyedvectors.Vocab at 0x11789d0d0>),
#  ('disgraced', <gensim.models.keyedvectors.Vocab at 0x11789d110>),
#  ('sympathize', <gensim.models.keyedvectors.Vocab at 0x11789d150>),
#  ('zuriff', <gensim.models.keyedvectors.Vocab at 0x11789d190>),
#  (u'pleaded', <gensim.models.keyedvectors.Vocab at 0x11789d1d0>),
#  ('plank', <gensim.models.keyedvectors.Vocab at 0x11789d210>),
#  ('refuse', <gensim.models.keyedvectors.Vocab at 0x11789d250>),
#  ('replied', <gensim.models.keyedvectors.Vocab at 0x11789d290>),
#  ('eddark', <gensim.models.keyedvectors.Vocab at 0x11789d2d0>),
#  (u'pant', <gensim.models.keyedvectors.Vocab at 0x11789d310>),
#  ('reminded', <gensim.models.keyedvectors.Vocab at 0x117b0ac50>),
#  ('eddard', <gensim.models.keyedvectors.Vocab at 0x11789d390>),
#  ('installed', <gensim.models.keyedvectors.Vocab at 0x11789d3d0>),
#  (u'paper', <gensim.models.keyedvectors.Vocab at 0x11789d410>),
#  (u'brim', <gensim.models.keyedvectors.Vocab at 0x11789d450>),
#  ('smiling', <gensim.models.keyedvectors.Vocab at 0x11789d490>),
#  ('aemon', <gensim.models.keyedvectors.Vocab at 0x11789d4d0>),
#  ('mistreated', <gensim.models.keyedvectors.Vocab at 0x11789d510>),
#  (u'mummer', <gensim.models.keyedvectors.Vocab at 0x11789d550>),
#  ('ruining', <gensim.models.keyedvectors.Vocab at 0x11789d590>),
#  (u'travelling', <gensim.models.keyedvectors.Vocab at 0x11789d5d0>),
#  ('ally', <gensim.models.keyedvectors.Vocab at 0x11789d610>),
#  ('colleague', <gensim.models.keyedvectors.Vocab at 0x11789d650>),
#  ('lowell', <gensim.models.keyedvectors.Vocab at 0x11789d690>),
#  ('propose', <gensim.models.keyedvectors.Vocab at 0x11789d6d0>),
#  ('martells', <gensim.models.keyedvectors.Vocab at 0x11789d710>),
#  (u'easterner', <gensim.models.keyedvectors.Vocab at 0x11789d750>),
#  (u'qyburns', <gensim.models.keyedvectors.Vocab at 0x11789d790>),
#  ('always', <gensim.models.keyedvectors.Vocab at 0x11789d7d0>),
#  ('repayment', <gensim.models.keyedvectors.Vocab at 0x11789d810>),
#  ('found', <gensim.models.keyedvectors.Vocab at 0x11789d850>),
#  ('shocking', <gensim.models.keyedvectors.Vocab at 0x11789d890>),
#  ('begged', <gensim.models.keyedvectors.Vocab at 0x11789d8d0>),
#  (u'stevron', <gensim.models.keyedvectors.Vocab at 0x11789d910>),
#  ('varys', <gensim.models.keyedvectors.Vocab at 0x1178b9b10>),
#  (u'measurement', <gensim.models.keyedvectors.Vocab at 0x11789d990>),
#  ('bluer', <gensim.models.keyedvectors.Vocab at 0x11789d9d0>),
#  ('really', <gensim.models.keyedvectors.Vocab at 0x11789da10>),
#  ('missed', <gensim.models.keyedvectors.Vocab at 0x11789da50>),
#  (u'research', <gensim.models.keyedvectors.Vocab at 0x11789da90>),
#  ('hood', <gensim.models.keyedvectors.Vocab at 0x11797fd10>),
#  ('darling', <gensim.models.keyedvectors.Vocab at 0x11789db10>),
#  ('nastiness', <gensim.models.keyedvectors.Vocab at 0x11797fd50>),
#  ...]

# %%
keys = model.wv.vocab.keys()

# %%
keys[:1000]
# Out:
# ['foul',
#  'four',
#  'hanging',
#  'marching',
#  u'increase',
#  'midafternoon',
#  'mutinied',
#  'lord',
#  u'sinking',
#  'leisurely',
#  u'politician',
#  'stabbed',
#  'bringing',
#  'disturb',
#  'prize',
#  'wooden',
#  u'clientele',
#  'succession',
#  'straight',
#  'tired',
#  u'lefford',
#  'bacon',
#  'elegant',
#  'second',
#  'sailed',
#  u'ruthless',
#  'thunder',
#  'cooking',
#  'contributed',
#  'resilient',
#  'succumb',
#  'hero',
#  'interrupting',
#  u'here',
#  'substance',
#  u'k',
#  'climbed',
#  'military',
#  u'climber',
#  'diplomat',
#  'appropriately',
#  'divide',
#  'explained',
#  'replace',
#  'brought',
#  'stern',
#  'cheating',
#  'spoke',
#  u'cannibal',
#  'occupying',
#  'untie',
#  'strike',
#  'sideface',
#  'holy',
#  'relax',
#  'successful',
#  'brings',
#  'hereby',
#  'hurt',
#  u'glass',
#  u'hole',
#  'hold',
#  u'simper',
#  u'benjens',
#  'pursue',
#  'zhoan',
#  'blade',
#  'plunged',
#  'sweeter',
#  'rework',
#  'example',
#  'triple',
#  'organized',
#  u'caution',
#  'want',
#  'counseling',
#  'mymother',
#  u'cocksucker',
#  'absolute',
#  'hog',
#  'complaining',
#  u'travel',
#  'copious',
#  'undying',
#  'hot',
#  'retreating',
#  'beauty',
#  'swing',
#  u'despondent',
#  'outlawed',
#  'wrong',
#  'barristan',
#  u'huhuh',
#  u'attracts',
#  u'revolt',
#  'sickening',
#  'tulip',
#  'viserys',
#  u'wing',
#  'wind',
#  'wine',
#  'dreamed',
#  'patricide',
#  u'profaned',
#  'rewarded',
#  'fit',
#  'allisers',
#  'screaming',
#  u'fix',
#  u'dedicate',
#  u'fig',
#  'mewling',
#  'hidden',
#  'admirable',
#  'easier',
#  'hghar',
#  'commemorate',
#  'educating',
#  'interrupt',
#  'blink',
#  'silver',
#  'structural',
#  u'represents',
#  'jaehaerys',
#  'theons',
#  u'arrow',
#  u'armourer',
#  'burial',
#  u'whim',
#  'financial',
#  u'spider',
#  u'longclaw',
#  u'turnip',
#  'fortnight',
#  u'mutineer',
#  u'wyllis',
#  'message',
#  'whip',
#  'misfortune',
#  'whoosh',
#  u'mason',
#  u'rd',
#  'archmaester',
#  u'ro',
#  u'outburst',
#  u'foundation',
#  'assured',
#  'waddle',
#  'threatened',
#  'assures',
#  'aggar',
#  'crowned',
#  'tobho',
#  'ate',
#  'ath',
#  'shipped',
#  u'disturbed',
#  'tempting',
#  'minge',
#  u'subtlety',
#  'wash',
#  'instruct',
#  'bitten',
#  'zala',
#  'whorehouse',
#  'timid',
#  'engagement',
#  'needed',
#  'master',
#  'bitter',
#  'ranging',
#  'listen',
#  'lorch',
#  u'collapse',
#  'hows',
#  'highgarden',
#  'wisdom',
#  'predictable',
#  'crawl',
#  'positively',
#  'showed',
#  u'coward',
#  'tree',
#  u'whinging',
#  'shower',
#  'idle',
#  'endure',
#  'profitable',
#  'feeling',
#  'groaning',
#  'longs',
#  'untrained',
#  'tether',
#  'dozen',
#  'responsible',
#  u'instructs',
#  'amusing',
#  'britches',
#  u'season',
#  'eastwatch',
#  u'horselords',
#  'howd',
#  'shall',
#  'huh',
#  'aegons',
#  'toil',
#  'mouth',
#  'letter',
#  u'singer',
#  u'episode',
#  'rayder',
#  'consummate',
#  'mating',
#  'tirelessly',
#  'came',
#  'saying',
#  'fennel',
#  u'tempted',
#  'abreast',
#  'busy',
#  'theme',
#  'touched',
#  'rich',
#  u'plate',
#  'petrified',
#  u'foremost',
#  u'pocket',
#  u'reversal',
#  'altogether',
#  'blistered',
#  u'spilling',
#  'nicely',
#  'dipping',
#  'piggy',
#  'release',
#  u'respond',
#  u'blew',
#  'fair',
#  'bled',
#  u'result',
#  'fail',
#  'nocturnal',
#  u'hammer',
#  'best',
#  'score',
#  'pirate',
#  u'wage',
#  'men',
#  'khaleesi',
#  'extend',
#  'nature',
#  'rolled',
#  'smelled',
#  'lapping',
#  u'souvenir',
#  u'extent',
#  'tyrion',
#  u'debt',
#  'pity',
#  'accident',
#  'weirwood',
#  'country',
#  u'adventurer',
#  'demanded',
#  'planned',
#  'logic',
#  'argue',
#  'asked',
#  u'vain',
#  'blonde',
#  'shouting',
#  'union',
#  'slay',
#  'muck',
#  'much',
#  'privilege',
#  'tallest',
#  'life',
#  u'lodock',
#  'spit',
#  u'eastern',
#  'jeor',
#  u'davy',
#  'wish',
#  'lift',
#  'direwolf',
#  'child',
#  'worked',
#  'cunt',
#  'employ',
#  'contemplates',
#  u'flooding',
#  'picturing',
#  'remembering',
#  u'congratulation',
#  'played',
#  'cersei',
#  u'locksmith',
#  u'obeying',
#  u'player',
#  'trusted',
#  'severity',
#  'tarth',
#  'yellow',
#  'thievery',
#  'rebellion',
#  'clucking',
#  u'harmony',
#  'fairly',
#  'boiled',
#  'marched',
#  'supper',
#  'therell',
#  'metalwork',
#  'tune',
#  u'tarleys',
#  'intrusion',
#  'noblewoman',
#  'eagle',
#  'towheaded',
#  u'bellow',
#  'golden',
#  'forsaken',
#  u'plight',
#  u'hal',
#  'ham',
#  'ease',
#  'hay',
#  'innocent',
#  'prison',
#  'east',
#  'hat',
#  u'hightower',
#  'survival',
#  'possible',
#  'possibly',
#  'birth',
#  'shadow',
#  'unique',
#  'desire',
#  'remind',
#  'battlefield',
#  'right',
#  'old',
#  'crowd',
#  'people',
#  'macabre',
#  'crown',
#  'captive',
#  'warring',
#  'bottom',
#  u'rehearse',
#  u'fox',
#  'witty',
#  u'foe',
#  u'summoned',
#  u'umi',
#  'pinched',
#  'yoke',
#  u'defensive',
#  'losing',
#  'memorable',
#  'bowing',
#  u'grievously',
#  u'o',
#  'despair',
#  u'slightly',
#  'match',
#  'lamprey',
#  'raised',
#  'watering',
#  'tyrell',
#  'son',
#  'thankful',
#  'consummated',
#  'sow',
#  'wrap',
#  'despised',
#  'fabric',
#  'suffice',
#  'tame',
#  'grasping',
#  'despises',
#  'greatness',
#  'music',
#  'thoros',
#  'underestimated',
#  'offer',
#  'shireen',
#  'perfumed',
#  'matthos',
#  'duel',
#  'inside',
#  'morning',
#  'vanguard',
#  'pest',
#  'torturing',
#  'smashed',
#  'juvenile',
#  'later',
#  'proved',
#  'arwyen',
#  'tournament',
#  'proven',
#  'meros',
#  'soothe',
#  'exist',
#  'accounting',
#  'floor',
#  u'actor',
#  'uttered',
#  'flood',
#  'underfed',
#  'role',
#  'ambitious',
#  'smell',
#  'roll',
#  'intend',
#  'corbray',
#  u'ointment',
#  'scream',
#  'acquaintance',
#  'giantsbane',
#  'cleaver',
#  u'daugters',
#  'warn',
#  'pycelle',
#  'sniffed',
#  'quandary',
#  'time',
#  'push',
#  'someplace',
#  'dotes',
#  'gown',
#  'chain',
#  'whoever',
#  'warg',
#  'chair',
#  'midst',
#  'quartered',
#  u'lothar',
#  'choice',
#  'mourn',
#  'locked',
#  u'exact',
#  'minute',
#  'tear',
#  u'teat',
#  u'pea',
#  'leave',
#  'settle',
#  'stockade',
#  u'team',
#  'bonfire',
#  u'accomplishment',
#  u'sigh',
#  'sign',
#  'chopping',
#  'catelyn',
#  u'melt',
#  'current',
#  'axel',
#  'falling',
#  'crashing',
#  'badge',
#  'ramming',
#  u'funeral',
#  'understanding',
#  'contemplate',
#  'address',
#  'alone',
#  'along',
#  'crumbles',
#  u'summerwine',
#  'brilliant',
#  'studied',
#  'wherever',
#  u'commonly',
#  'accomplished',
#  'greizhen',
#  u'reclaim',
#  'nowhere',
#  'love',
#  'prefer',
#  'logical',
#  'bloody',
#  'marvelous',
#  'betraying',
#  u'sky',
#  u'capsized',
#  'working',
#  'angry',
#  'blackwater',
#  u'cockfighting',
#  'wondering',
#  u'halfbrother',
#  'wicked',
#  u'introducing',
#  u'guardsman',
#  'afford',
#  'xaros',
#  'marbled',
#  'everywhere',
#  'virtue',
#  'behalf',
#  'honey',
#  'valued',
#  'anything',
#  'originally',
#  u'pretend',
#  'privy',
#  'believer',
#  u'impasse',
#  'believed',
#  'admired',
#  'locke',
#  u'unconsummated',
#  'unveiled',
#  'allowed',
#  'offense',
#  'stole',
#  'evidently',
#  'listens',
#  'winter',
#  u'divided',
#  'thanking',
#  'immune',
#  'loathe',
#  u'encampment',
#  u'provincial',
#  'spot',
#  'suck',
#  'dove',
#  u'stress',
#  'natural',
#  'blackfish',
#  'st',
#  'swollen',
#  'truce',
#  'pulled',
#  'drunken',
#  u'footstep',
#  'unacceptable',
#  'damage',
#  'course',
#  'yearn',
#  'mishear',
#  'lovelier',
#  u'tendency',
#  'tore',
#  'milked',
#  'torn',
#  'stupidity',
#  'aerion',
#  'celebrate',
#  'troubled',
#  u'deviant',
#  u'chaining',
#  'smarter',
#  'arriving',
#  'reckoning',
#  u'shhh',
#  'maintaining',
#  'matched',
#  'freya',
#  'appropriate',
#  'stillborns',
#  'fisherman',
#  'amnesty',
#  u'quarter',
#  'broodmare',
#  'square',
#  'beloved',
#  'entering',
#  u'beetle',
#  'troll',
#  u'swordsman',
#  'seriously',
#  'investigation',
#  'suggesting',
#  'facedown',
#  'siege',
#  'million',
#  'seventh',
#  u'possibility',
#  'quite',
#  'complicated',
#  'besides',
#  u'grandma',
#  'unnamed',
#  'patronage',
#  'training',
#  'backside',
#  'modest',
#  u'nymeria',
#  'saving',
#  'spoken',
#  'one',
#  u'reopen',
#  'punishable',
#  'vote',
#  'open',
#  'ripping',
#  'partook',
#  u'city',
#  u'wrath',
#  'bite',
#  'teacher',
#  u'shiver',
#  'prone',
#  'shawl',
#  'meddling',
#  u'padding',
#  'prowling',
#  'ridiculous',
#  u'camello',
#  'third',
#  'cower',
#  'sandor',
#  u'counselor',
#  u'wandering',
#  'damned',
#  'prospect',
#  u'addressing',
#  u'illness',
#  'tasted',
#  'nicer',
#  'turned',
#  'alley',
#  'sad',
#  'say',
#  'taster',
#  'buried',
#  'lurking',
#  'sap',
#  'saw',
#  'sat',
#  'wink',
#  u'downwards',
#  'aside',
#  'instructed',
#  'note',
#  'take',
#  u'mazin',
#  'wanting',
#  u'opposite',
#  'squalor',
#  'knew',
#  'knee',
#  'average',
#  u'sale',
#  u'defeating',
#  'crooked',
#  'gillyflower',
#  'squint',
#  'butchered',
#  'salt',
#  'walking',
#  u'merit',
#  'bright',
#  'imagined',
#  'slow',
#  'strangled',
#  u'cloak',
#  'liberation',
#  'betrothal',
#  'going',
#  'dancing',
#  'outrage',
#  'robe',
#  'clawing',
#  'robb',
#  u'dispute',
#  'graceless',
#  'guarded',
#  'freezing',
#  u'clang',
#  'awaiting',
#  'vhag',
#  'prime',
#  u'resource',
#  u'artist',
#  'absurdly',
#  'worried',
#  'carrion',
#  'priest',
#  u'primp',
#  u'vision',
#  'gout',
#  'raged',
#  'notice',
#  'purest',
#  'stannis',
#  'mutton',
#  'jumped',
#  'enjoys',
#  'amory',
#  'spare',
#  'umber',
#  'undermine',
#  'mant',
#  'many',
#  'loudly',
#  u'riddle',
#  'drogo',
#  u'compels',
#  u'twin',
#  'boar',
#  u'considers',
#  'boat',
#  u'stretch',
#  'west',
#  u'expedition',
#  'breath',
#  'combined',
#  'stripped',
#  'coughing',
#  'centerpiece',
#  'observe',
#  u'extant',
#  'former',
#  'wherewithal',
#  u'fin',
#  'straighten',
#  'whatevers',
#  'squeezed',
#  u'situation',
#  'endured',
#  'ive',
#  'thatll',
#  'purse',
#  'shevelathin',
#  'spooked',
#  'burbling',
#  'threatens',
#  'damon',
#  'edged',
#  'sickness',
#  'defy',
#  'disown',
#  'recapture',
#  'polliver',
#  'summer',
#  u'being',
#  'rest',
#  u'overconfident',
#  'afterwards',
#  u'khalar',
#  u'sixteen',
#  'befalling',
#  'overthrow',
#  'haystack',
#  'starving',
#  'around',
#  'dark',
#  'preference',
#  'fringed',
#  'vague',
#  'bravery',
#  u'clan',
#  u'clam',
#  'stranger',
#  'discarded',
#  'superiority',
#  u'claw',
#  'sorcerer',
#  u'kennel',
#  u'clap',
#  'grub',
#  u'lobster',
#  u'divine',
#  'crabber',
#  'dimpled',
#  'refer',
#  u'clarenzo',
#  'averse',
#  'power',
#  'intimate',
#  'hayseed',
#  'leadership',
#  u'stone',
#  'yunkai',
#  'favorite',
#  u'side',
#  u'apostate',
#  u'neighbor',
#  'act',
#  u'mean',
#  'stony',
#  u'widowed',
#  'chivalry',
#  'shapely',
#  'burning',
#  'interruption',
#  u'antidote',
#  'apologize',
#  u'pivot',
#  'trussed',
#  'hey',
#  'hed',
#  u'lhazareen',
#  'mindless',
#  'sealed',
#  u'hen',
#  'survives',
#  'recommends',
#  'complete',
#  'survived',
#  u'whinny',
#  'buying',
#  'handsome',
#  'abused',
#  'pull',
#  u'rush',
#  'rage',
#  'browbeaten',
#  'balons',
#  'dirty',
#  'agree',
#  'darker',
#  u'detailed',
#  'gone',
#  'fright',
#  u'exhausted',
#  'ah',
#  'stealing',
#  'al',
#  'wartime',
#  u'watcher',
#  'behest',
#  u'as',
#  'carved',
#  u'midwife',
#  'laboratory',
#  'ax',
#  u'johnna',
#  'cream',
#  u'ideally',
#  'tight',
#  'httpsubttfreeorg',
#  u'puppy',
#  'disgraceful',
#  u'congress',
#  'waving',
#  u'middling',
#  u'midget',
#  'brotherhood',
#  'tricky',
#  'disdained',
#  'infanticide',
#  'sobbing',
#  u'thorn',
#  'groom',
#  u'mask',
#  u'dyed',
#  u'mast',
#  u'mass',
#  'sawing',
#  u'dyer',
#  'original',
#  'consider',
#  'beware',
#  u'neigh',
#  'welfare',
#  'hunting',
#  'tail',
#  'chewing',
#  'dockworker',
#  'th',
#  u'ti',
#  'smile',
#  u'shipload',
#  'paying',
#  'appointment',
#  'returned',
#  'squiring',
#  'eyrie',
#  'condition',
#  'harrenhal',
#  'overprotective',
#  u'laying',
#  'joined',
#  'underclothes',
#  'large',
#  'sang',
#  'sand',
#  u'adjust',
#  'small',
#  'quicker',
#  u'healed',
#  'past',
#  'podrick',
#  u'pass',
#  'turning',
#  u'investment',
#  'poisonous',
#  'prevailed',
#  'nurse',
#  'full',
#  'escaping',
#  'vomiting',
#  'smartest',
#  'buzzing',
#  'legend',
#  'slynt',
#  'kayla',
#  'experience',
#  'pick',
#  u'action',
#  'murdering',
#  'luck',
#  'smuggle',
#  'gawking',
#  'followed',
#  u'follower',
#  u'indoors',
#  u'captor',
#  'darkens',
#  u'moro',
#  u'gorgeous',
#  u'mord',
#  'restraint',
#  'door',
#  'company',
#  'tested',
#  'doom',
#  'riverbank',
#  'cunning',
#  'keeping',
#  'pleasing',
#  'farted',
#  'thickest',
#  'learn',
#  'knocked',
#  'sunspear',
#  u'seagull',
#  u'male',
#  'beautiful',
#  'brightflame',
#  'accept',
#  'fiercely',
#  'sense',
#  'scar',
#  'dress',
#  'condemn',
#  'information',
#  'impulse',
#  'imminent',
#  u'hugh',
#  'dismissed',
#  u'glowing',
#  'freshly',
#  u'clink',
#  'unattended',
#  'creature',
#  'sprinkle',
#  'intended',
#  'countryside',
#  'disgraced',
#  'sympathize',
#  'zuriff',
#  u'pleaded',
#  'plank',
#  'refuse',
#  'replied',
#  'eddark',
#  u'pant',
#  'reminded',
#  'eddard',
#  'installed',
#  u'paper',
#  u'brim',
#  'smiling',
#  'aemon',
#  'mistreated',
#  u'mummer',
#  'ruining',
#  u'travelling',
#  'ally',
#  'colleague',
#  'lowell',
#  'propose',
#  'martells',
#  u'easterner',
#  u'qyburns',
#  'always',
#  'repayment',
#  'found',
#  'shocking',
#  'begged',
#  u'stevron',
#  'varys',
#  u'measurement',
#  'bluer',
#  'really',
#  'missed',
#  u'research',
#  'hood',
#  'darling',
#  'nastiness']

# %%
len(keys)
# Out:
# 6913

# %%
model_list = []

for i in model.wv.vocab.keys():
    model_list.append(model.wv[i])

# %%
model_list
# Out:
# [array([-0.21877286, -0.02853961, -0.02474029, -0.12855585, -0.11584654,
#         -0.08351734, -0.11349874, -0.1724204 , -0.0140408 , -0.1649981 ,
#          0.02489975, -0.09795569,  0.13566226, -0.11897743, -0.00369049,
#          0.1779529 ,  0.07569137, -0.08160688, -0.11426732, -0.01388025,
#         -0.23619609, -0.16719042,  0.02982032,  0.18533717,  0.17044915,
#         -0.1429655 , -0.01335798, -0.08758686, -0.07532321, -0.09236957,
#         -0.29045349,  0.03977234, -0.00835635, -0.10338014,  0.04341156,
#         -0.04404353, -0.18488596, -0.07119227,  0.07570332,  0.16742414,
#         -0.11363398,  0.01263127, -0.03097916, -0.12738472,  0.12379432,
#         -0.21968937,  0.12332289,  0.00126533, -0.01782854,  0.17088203,
#          0.21176919,  0.0704245 , -0.12840658, -0.05003917, -0.12585773,
#         -0.14999209,  0.00713243,  0.06050042, -0.17780551, -0.16413291,
#          0.09690674, -0.08441948,  0.15892735, -0.14787956,  0.03212822,
#         -0.10297637, -0.03006342,  0.03597519,  0.09452621, -0.02450023,
#          0.02061686, -0.13640073,  0.05696212, -0.23212899, -0.05899995,
#         -0.0997465 , -0.1724464 ,  0.08124618,  0.1504734 ,  0.07639517,
#         -0.06574141, -0.01506795,  0.09271132, -0.00454499, -0.10944855,
#         -0.10064089,  0.00277771,  0.06021151,  0.1396386 ,  0.14225017,
#          0.05522216,  0.02516889, -0.18859841, -0.14168967, -0.06133564,
#          0.09642241, -0.21184127,  0.00589161, -0.14560595,  0.01815002], dtype=float32),
#  array([-0.2937884 , -0.03832825, -0.03319588, -0.18046667, -0.14489907,
#         -0.10545817, -0.16054998, -0.23653726, -0.03044694, -0.21690717,
#          0.03611741, -0.13036081,  0.18118225, -0.14496411, -0.00723809,
#          0.23672472,  0.10152151, -0.1018736 , -0.15149669, -0.01873494,
#         -0.31262085, -0.23668891,  0.03971453,  0.24177076,  0.22741145,
#         -0.19727373, -0.02473976, -0.10861686, -0.10435802, -0.1189585 ,
#         -0.37923741,  0.05166516, -0.0204257 , -0.13273536,  0.06303079,
#         -0.06543618, -0.23323299, -0.09347316,  0.09016001,  0.21771987,
#         -0.14300402,  0.00599666, -0.02682993, -0.17486414,  0.16010061,
#         -0.0299606 , -0.02049874,  0.00053077,  0.0257033 ,  0.02611546,
#         -0.01677015, -0.00521737, -0.01653172, -0.0162965 , -0.01659119,
#         -0.03932956,  0.00519875, -0.00191435, -0.0183144 ,  0.0087506 ,
#         -0.00088752, -0.03040731, -0.00695889,  0.01358823,  0.02733129,
#         -0.01762288,  0.00328839, -0.00148777, -0.02342932,  0.01801041,
#         -0.03487606,  0.01794997,  0.00418001, -0.00808457,  0.02138684,
#          0.02807212,  0.00476274, -0.0145932 , -0.00791564, -0.01518717,
#         -0.02441527,  0.00309641,  0.01111535, -0.02294842, -0.01917817,
#          0.01594261, -0.00987616,  0.02168583, -0.02090677,  0.00442106,
#         -0.01695795, -0.00453919,  0.00386473,  0.01503103, -0.00720017,
#          0.00708671, -0.02099489,  0.01276337, -0.03308433, -0.00628668,
#         -0.01795464, -0.02642157,  0.00864207,  0.02664142,  0.01079586,
#         -0.00879337,  0.00091611,  0.01495276, -0.00586385, -0.01075564,
#         -0.01366222, -0.00265425,  0.00310275,  0.01497496,  0.01614116,
#          0.00456668,  0.00671542, -0.02302176, -0.01527703, -0.00932675,
#          0.01467397, -0.03433457,  0.00490974, -0.02288998,  0.00628707], dtype=float32),
#  ...]

# %%
type(model_list)
# Out:
# list

# %%
model_vectors = pd.DataFrame(model_list)
model_vectors.shape
# Out:
# (6913, 100)

# %%
model_vectors = model_vectors.reset_index()

# %%
model_vectors['index'] = model.wv.vocab.keys()

# %%
model_vectors = model_vectors.set_index('index')

# %%
model_vectors.head()
# Out:
#                 0         1         2         3         4         5   \
# index
# foul     -0.218773 -0.028540 -0.024740 -0.128556 -0.115847 -0.083517
# four     -0.293788 -0.038328 -0.033196 -0.180467 -0.144899 -0.105458
# hanging  -0.148177 -0.024665 -0.018045 -0.088360 -0.071674 -0.057964
# marching -0.275025 -0.028442 -0.030839 -0.161171 -0.140488 -0.102039
# increase -0.052370 -0.002105 -0.009632 -0.032556 -0.026578 -0.019316
#
#                 6         7         8         9     ...           90  \
# index                                               ...
# foul     -0.113499 -0.172420 -0.014041 -0.164998    ...     0.055222
# four     -0.160550 -0.236537 -0.030447 -0.216907    ...     0.074241
# hanging  -0.082549 -0.116133 -0.015068 -0.103439    ...     0.040535
# marching -0.151209 -0.233250 -0.031696 -0.203133    ...     0.070952
# increase -0.031026 -0.049798 -0.007598 -0.040674    ...     0.017680
#
#                 91        92        93        94        95        96  \
# index
# foul      0.025169 -0.188598 -0.141690 -0.061336  0.096422 -0.211841
# four      0.029705 -0.255473 -0.186566 -0.079701  0.132974 -0.290556
# hanging   0.018657 -0.131001 -0.091669 -0.048540  0.069461 -0.149599
# marching  0.034321 -0.235274 -0.180951 -0.085345  0.123444 -0.272405
# increase  0.002328 -0.042928 -0.038143 -0.019898  0.021543 -0.050448
#
#                 97        98        99
# index
# foul      0.005892 -0.145606  0.018150
# four      0.017854 -0.187144  0.018871
# hanging   0.005697 -0.092177  0.005766
# marching  0.007784 -0.177194  0.019764
# increase  0.006485 -0.039083  0.004686
#
# [5 rows x 100 columns]

# %%
model_vectors.index
# Out:
# Index([        u'foul',         u'four',      u'hanging',     u'marching',
#            u'increase', u'midafternoon',     u'mutinied',         u'lord',
#             u'sinking',    u'leisurely',
#        ...
#               u'lance',       u'risked',       u'squeak',       u'oberyn',
#               u'cliff',    u'auxiliary',        u'wylla',    u'firestorm',
#          u'baratheons',  u'furthermore'],
#       dtype='object', name=u'index', length=6913)

# %%
pca20 = PCA(n_components=20)

pca_results20 = pca20.fit_transform(model_vectors)

# %%
pca_results_20 = pd.DataFrame(pca_results20)

# %%
pca_results_20 = pca_results_20.reset_index()

# %%
pca_results_20['index'] = model.wv.vocab.keys()

# %%
pca_results_20 = pca_results_20.set_index('index')

# %%
pca_results_20.head()
# Out:
#                 0         1         2         3         4         5   \
# index
# foul      0.468324 -0.019241 -0.024037  0.000936  0.008204 -0.007582
# four      0.853085 -0.021888 -0.012209  0.027157  0.007965 -0.001718
# hanging   0.085235 -0.008563 -0.008990  0.008882 -0.000374  0.000650
# marching  0.773685 -0.003108 -0.005615  0.029420 -0.006672 -0.008579
# increase -0.412796  0.003127  0.001489 -0.001361 -0.001598  0.007518
#
#                 6         7         8         9         10        11  \
# index
# foul      0.003561  0.002837 -0.000168 -0.002984 -0.000876 -0.004124
# four      0.000441  0.014372 -0.001811  0.007532 -0.008531 -0.003400
# hanging   0.005402 -0.003396 -0.005292 -0.002697 -0.006446  0.001100
# marching -0.014072 -0.004678 -0.007958 -0.002192  0.000162  0.001800
# increase  0.000832  0.001953 -0.003724 -0.000629 -0.000723  0.001580
#
#                 12        13        14        15        16        17  \
# index
# foul     -0.006430  0.005364 -0.001906 -0.002012 -0.002145 -0.001540
# four     -0.001945  0.002346  0.002663  0.002746  0.000298  0.004339
# hanging  -0.004973  0.001897 -0.001566 -0.004083  0.004231  0.000801
# marching -0.001444 -0.008358  0.003401  0.002189 -0.001757 -0.002351
# increase  0.005212  0.000230 -0.003263  0.001769 -0.006923  0.003131
#
#                 18        19
# index
# foul      0.002032 -0.001536
# four     -0.002599  0.005517
# hanging  -0.003032 -0.004095
# marching  0.002144  0.007456
# increase  0.000432  0.002479

# %%
tsne = TSNE(n_components=2)

tsne_pca_results20 = tsne.fit_transform(pca_results20)

# %%
tsne_pca_results_20 = pd.DataFrame(tsne_pca_results20)

# %%
tsne_pca_results_20.head()
# Out:
#               0             1
# 0  1.140893e+16 -4.036794e+16
# 1  3.652000e+17  1.241167e+17
# 2 -2.839058e+17  2.526081e+17
# 3  1.544317e+17 -1.191202e+17
# 4 -1.707429e+17  9.913663e+16

# %%
tsne_pca_results_20 = tsne_pca_results_20.reset_index()

# %%
tsne_pca_results_20['index'] = model.wv.vocab.keys()

# %%
tsne_pca_results_20 = tsne_pca_results_20.set_index('index')

# %%
tsne_pca_results_20.shape
# Out:
# (6913, 2)

# %%
tsne_pca_results_20.head(10)
# Out:
#                          0             1
# index
# foul          1.140893e+16 -4.036794e+16
# four          3.652000e+17  1.241167e+17
# hanging      -2.839058e+17  2.526081e+17
# marching      1.544317e+17 -1.191202e+17
# increase     -1.707429e+17  9.913663e+16
# midafternoon -3.009895e+17  1.837077e+17
# mutinied      1.718593e+17 -1.295193e+16
# lord          1.149295e+17 -1.746230e+16
# sinking       4.536238e+17 -9.015096e+16
# leisurely    -1.117354e+17  9.650376e+16

# %%
topwords_index = tsne_pca_results_20.loc[:'nastiness']
print topwords_index.shape
topwords_index.head()
# Out:
# (1000, 2)
#                      0             1
# index
# foul      1.140893e+16 -4.036794e+16
# four      3.652000e+17  1.241167e+17
# hanging  -2.839058e+17  2.526081e+17
# marching  1.544317e+17 -1.191202e+17
# increase -1.707429e+17  9.913663e+16

# %%
topwords_index.to_csv('tsne2.csv', index=False)

# %%
tsne_pca_results_20 = tsne_pca_results_20.reset_index()

# %%
tsne_pca_results_20.head()
# Out:
#       index             0             1
# 0      foul  1.140893e+16 -4.036794e+16
# 1      four  3.652000e+17  1.241167e+17
# 2   hanging -2.839058e+17  2.526081e+17
# 3  marching  1.544317e+17 -1.191202e+17
# 4  increase -1.707429e+17  9.913663e+16

# %%
json_data = pd.DataFrame(tsne_pca_results_20['index'])
json_data['null'] = np.NaN

# %%
json_data.set_index('index', inplace=True)

# %%
json_data
# Out:
#               null
# index
# foul           NaN
# four           NaN
# hanging        NaN
# marching       NaN
# increase       NaN
# midafternoon   NaN
# mutinied       NaN
# lord           NaN
# sinking        NaN
# leisurely      NaN
# politician     NaN
# stabbed        NaN
# bringing       NaN
# disturb        NaN
# prize          NaN
# wooden         NaN
# clientele      NaN
# succession     NaN
# straight       NaN
# tired          NaN
# lefford        NaN
# bacon          NaN
# elegant        NaN
# second         NaN
# sailed         NaN
# ruthless       NaN
# thunder        NaN
# cooking        NaN
# contributed    NaN
# resilient      NaN
# ...            ...
# shant          NaN
# squeeze        NaN
# made           NaN
# whether        NaN
# lve            NaN
# record         NaN
# ruling         NaN
# cake           NaN
# ritsas         NaN
# myr            NaN
# meaningless    NaN
# maidenpool     NaN
# happen         NaN
# sobriety       NaN
# mutual         NaN
# theon          NaN
# boot           NaN
# book           NaN
# branch         NaN
# cutthroat      NaN
# lance          NaN
# risked         NaN
# squeak         NaN
# oberyn         NaN
# cliff          NaN
# auxiliary      NaN
# wylla          NaN
# firestorm      NaN
# baratheons     NaN
# furthermore    NaN
#
# [6913 rows x 1 columns]

# %%
json_data.to_json('D3_json_Data', orient="index")

# %%
tsne_pca_results_20.shape
# Out:
# (6913, 3)

# %%
tsne_pca_results_20.to_csv('D3_TSNE.csv', index=False)

# %%
topwords = tsne_pca_results_20.loc[:999]
topwords
# Out:
#             index             0             1
# 0            foul -1.958355e+16 -3.112271e+16
# 1            four -4.521269e+16 -8.393925e+16
# 2         hanging -3.421171e+17 -7.978076e+17
# 3        marching -3.323213e+17 -6.320489e+16
# 4        increase -3.611474e+16 -1.353899e+16
# 5    midafternoon -2.185056e+16  1.846430e+16
# 6        mutinied -2.449268e+16  6.781202e+16
# 7            lord  2.515238e+16 -1.159677e+17
# 8         sinking -5.184457e+16  1.471378e+15
# 9       leisurely -4.560146e+15  2.151922e+15
# 10     politician -1.329426e+16  1.428550e+16
# 11        stabbed -4.833293e+16 -1.316452e+17
# 12       bringing  9.491544e+16 -2.916512e+16
# 13        disturb  3.743087e+16 -1.576941e+17
# 14          prize -2.791746e+16 -1.185237e+15
# 15         wooden -1.522807e+16  1.289034e+16
# 16      clientele  8.998447e+16 -1.334251e+17
# 17     succession -2.751965e+16 -5.699688e+16
# 18       straight -5.237522e+16 -2.109478e+16
# 19          tired -5.885783e+16 -6.546230e+15
# 20        lefford -3.085194e+16  4.084977e+16
# 21          bacon  7.698842e+16  1.053384e+17
# 22        elegant -2.354035e+16 -3.141847e+16
# 23         second -1.945505e+16 -2.914936e+16
# 24         sailed -2.263601e+16  1.044975e+16
# 25       ruthless -4.211729e+16 -1.534722e+17
# 26        thunder -6.523176e+15 -4.611017e+16
# 27        cooking -4.305341e+16  1.381592e+16
# 28    contributed  3.887327e+16  3.026353e+16
# 29      resilient -4.325145e+16 -5.343151e+16
# ..            ...           ...           ...
# 970         paper -3.361875e+16 -4.130606e+16
# 971          brim -3.942655e+16  5.282453e+15
# 972       smiling -5.864918e+16  5.061606e+16
# 973         aemon -2.540948e+16 -3.450196e+16
# 974    mistreated  5.005231e+16  1.711976e+17
# 975        mummer -1.621059e+16  6.161309e+15
# 976       ruining -2.478433e+15 -6.815572e+15
# 977    travelling -1.813943e+16  2.308997e+17
# 978          ally -2.760720e+16 -6.478607e+16
# 979     colleague -7.510594e+16 -7.550794e+16
# 980        lowell -2.769154e+16  2.356358e+16
# 981       propose -4.751519e+16 -2.109697e+16
# 982      martells -1.015525e+16 -1.139802e+17
# 983     easterner  9.054362e+16 -1.389078e+17
# 984       qyburns -4.420915e+16 -7.323301e+15
# 985        always -6.598023e+15 -3.080108e+16
# 986     repayment  2.954336e+16 -2.517732e+16
# 987         found -2.853653e+16 -4.004813e+16
# 988      shocking  2.717087e+18  9.042949e+16
# 989        begged -1.209028e+16 -7.538122e+16
# 990       stevron -6.681303e+16 -5.279421e+16
# 991         varys -8.456975e+15  1.180191e+16
# 992   measurement -2.313446e+16 -2.641308e+15
# 993         bluer -1.225466e+17 -1.730948e+17
# 994        really -4.112011e+16 -1.312180e+15
# 995        missed -2.049783e+16 -5.115310e+16
# 996      research -3.072759e+16  4.485848e+15
# 997          hood -5.377519e+16 -1.288971e+17
# 998       darling -4.518682e+17 -6.362689e+16
# 999     nastiness  4.424233e+16  6.138126e+16
#
# [1000 rows x 3 columns]

# %%
topwords.to_csv('tsne3.csv', index=False)

# %%
tsne_pca_results_20.shape
# Out:
# (6913, 3)

# %%
tsne_pca_results_20 = tsne_pca_results_20.set_index('index')

# %%
tsne_pca_results20
# Out:
# array([[ -1.95835465e+16,  -3.11227096e+16],
#        [ -4.52126917e+16,  -8.39392542e+16],
#        [ -3.42117077e+17,  -7.97807643e+17],
#        ...,
#        [ -6.20007662e+16,  -4.03341523e+16],
#        [  1.01370193e+16,  -1.48371850e+16],
#        [  1.88590122e+16,  -5.50922484e+16]])

# %%
tsne_pca_results_20.index
# Out:
# Index([        u'foul',         u'four',      u'hanging',     u'marching',
#            u'increase', u'midafternoon',     u'mutinied',         u'lord',
#             u'sinking',    u'leisurely',
#        ...
#               u'lance',       u'risked',       u'squeak',       u'oberyn',
#               u'cliff',    u'auxiliary',        u'wylla',    u'firestorm',
#          u'baratheons',  u'furthermore'],
#       dtype='object', name=u'index', length=6913)

# %%
tsne_pca_results_20.head()
# Out:
#                      0             1
# index
# foul     -1.958355e+16 -3.112271e+16
# four     -4.521269e+16 -8.393925e+16
# hanging  -3.421171e+17 -7.978076e+17
# marching -3.323213e+17 -6.320489e+16
# increase -3.611474e+16 -1.353899e+16

# %%
tsne_pca_results_20.shape
# Out:
# (6913, 2)

# %%
tsne_pca_results_20.head(100)
# Out:
#                          0             1
# index
# foul         -1.958355e+16 -3.112271e+16
# four         -4.521269e+16 -8.393925e+16
# hanging      -3.421171e+17 -7.978076e+17
# marching     -3.323213e+17 -6.320489e+16
# increase     -3.611474e+16 -1.353899e+16
# midafternoon -2.185056e+16  1.846430e+16
# mutinied     -2.449268e+16  6.781202e+16
# lord          2.515238e+16 -1.159677e+17
# sinking      -5.184457e+16  1.471378e+15
# leisurely    -4.560146e+15  2.151922e+15
# politician   -1.329426e+16  1.428550e+16
# stabbed      -4.833293e+16 -1.316452e+17
# bringing      9.491544e+16 -2.916512e+16
# disturb       3.743087e+16 -1.576941e+17
# prize        -2.791746e+16 -1.185237e+15
# wooden       -1.522807e+16  1.289034e+16
# clientele     8.998447e+16 -1.334251e+17
# succession   -2.751965e+16 -5.699688e+16
# straight     -5.237522e+16 -2.109478e+16
# tired        -5.885783e+16 -6.546230e+15
# lefford      -3.085194e+16  4.084977e+16
# bacon         7.698842e+16  1.053384e+17
# elegant      -2.354035e+16 -3.141847e+16
# second       -1.945505e+16 -2.914936e+16
# sailed       -2.263601e+16  1.044975e+16
# ruthless     -4.211729e+16 -1.534722e+17
# thunder      -6.523176e+15 -4.611017e+16
# cooking      -4.305341e+16  1.381592e+16
# contributed   3.887327e+16  3.026353e+16
# resilient    -4.325145e+16 -5.343151e+16
# ...                    ...           ...
# example      -3.547576e+16  1.514211e+16
# triple       -6.525063e+16  7.374923e+17
# organized     2.392499e+16  9.235499e+15
# caution      -1.891377e+16 -2.865912e+16
# want         -3.897466e+16 -2.195253e+16
# counseling   -3.389838e+16  3.083304e+16
# mymother     -3.375363e+16  9.114536e+15
# cocksucker   -3.944212e+16 -1.838304e+17
# absolute     -1.330621e+16 -1.573388e+16
# hog          -5.644626e+14  3.561895e+15
# complaining  -6.135947e+16 -3.579724e+16
# travel       -6.059156e+17  1.761723e+18
# copious       3.938348e+17  9.543290e+16
# undying       1.360309e+17 -7.180075e+15
# hot          -1.605666e+16 -1.684839e+16
# retreating   -4.085591e+16  3.221725e+16
# beauty       -2.628954e+16 -3.591782e+16
# swing        -2.262939e+16  4.375425e+16
# despondent   -8.093310e+16  1.588894e+17
# outlawed     -1.391102e+15 -5.544007e+15
# wrong        -1.617471e+17  1.543056e+17
# barristan     1.468721e+16 -3.746972e+15
# huhuh         3.725487e+16 -3.071284e+15
# attracts      6.925827e+16  1.836218e+17
# revolt       -5.401883e+15  6.081112e+16
# sickening    -5.524163e+16 -1.587222e+16
# tulip        -2.139874e+17  1.281135e+17
# viserys      -2.712602e+16  1.424324e+16
# wing          1.714847e+16  3.208543e+16
# wind         -6.360485e+16 -1.409322e+16
#
# [100 rows x 2 columns]

# %%
import numpy as Math
import pylab as Plot
import matplotlib.pyplot as plt

rows = tsne_pca_results_20.index
# %matplotlib notebook
plt.ion()

Plot.figure(figsize=(20, 10))
max_x = Math.amax(tsne_pca_results20, axis=0)[0]
max_y = Math.amax(tsne_pca_results20, axis=0)[1]
#Plot.xlim((-.125e+20,.25e+20))
#Plot.ylim((-.125+e20,.1e20))

Plot.scatter(tsne_pca_results20[:, 0], tsne_pca_results20[:, 1], 20);

for row_id in range(0, len(rows)):
    target_word = rows[row_id]
    x = tsne_pca_results20[row_id, 0]
    y = tsne_pca_results20[row_id, 1]
    Plot.annotate(target_word, (x,y))

Plot.savefig("tsne_200.png");
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %%
tsne_pca_results_20.loc['problem']
# Out:
# 0   -8.681460e+16
# 1   -6.612014e+16
# Name: problem, dtype: float64

# %%
tsne_pca_results_20.loc['serve']
# Out:
# 0   -4.205786e+17
# 1    1.402973e+17
# Name: serve, dtype: float64

# %%
tsne_pca_results_20.loc['troubled']
# Out:
# 0    4.946416e+16
# 1    1.104972e+17
# Name: troubled, dtype: float64

# %%
tsne_pca_results_20.loc['amuse']
# Out:
# 0   -1.374064e+18
# 1   -1.240065e+18
# Name: amuse, dtype: float64

# %%
# X and Y Limits
# X Min: -5.011046e+17
# X Max: 3.689624e+17
# Y Min: -9.293477e+17
# Y Max: 9.785711e+17

# %%
import numpy as Math
import pylab as Plot
import matplotlib.pyplot as plt

rows = tsne_pca_results_20.index
# %matplotlib notebook
plt.ion()

Plot.figure(figsize=(20, 10))
max_x = Math.amax(tsne_pca_results20, axis=0)[0]
max_y = Math.amax(tsne_pca_results20, axis=0)[1]
Plot.xlim((-3.011046e+17,3.689624e+17))
Plot.ylim((-9.293477e+17,9.785711e+17))

Plot.scatter(tsne_pca_results20[:, 0], tsne_pca_results20[:, 1], 20);

for row_id in range(0, len(rows)):
    target_word = rows[row_id]
    x = tsne_pca_results20[row_id, 0]
    y = tsne_pca_results20[row_id, 1]
    Plot.annotate(target_word, (x,y))

Plot.savefig("tsne_2000.png");
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %%
tsne_pca_results_20.loc['fortnight']
# Out:
# 0   -6.786583e+16
# 1    3.766130e+16
# Name: fortnight, dtype: float64

# %%
tsne_pca_results_20.loc['grenns']
# Out:
# 0   -2.210166e+16
# 1    2.585055e+16
# Name: grenns, dtype: float64

# %%
tsne_pca_results_20.loc['text']
# Out:
# 0    7.222634e+15
# 1   -1.208166e+15
# Name: text, dtype: float64

# %%
# X and Y Limits (Part 2)
# X Min: -1.005918e+17
# X Max: 1.005918e+17
# Y Min: -3.319169e+17
# Y Max: 3.319169e+17

# %%
import numpy as Math
import pylab as Plot
import matplotlib.pyplot as plt

rows = tsne_pca_results_20.index
# %matplotlib notebook
plt.ion()

Plot.figure(figsize=(20, 10))
max_x = Math.amax(tsne_pca_results20, axis=0)[0]
max_y = Math.amax(tsne_pca_results20, axis=0)[1]
Plot.xlim((-1.005918e+17,2.005918e+17))
Plot.ylim((-3.319169e+17,3.319169e+17))

Plot.scatter(tsne_pca_results20[:, 0], tsne_pca_results20[:, 1], 20);

for row_id in range(0, len(rows)):
    target_word = rows[row_id]
    x = tsne_pca_results20[row_id, 0]
    y = tsne_pca_results20[row_id, 1]
    Plot.annotate(target_word, (x,y))

Plot.savefig("tsne_2002.png");
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %%
tsne_pca_results20
# Out:
# array([[ -1.95835465e+16,  -3.11227096e+16],
#        [ -4.52126917e+16,  -8.39392542e+16],
#        [ -3.42117077e+17,  -7.97807643e+17],
#        ...,
#        [ -6.20007662e+16,  -4.03341523e+16],
#        [  1.01370193e+16,  -1.48371850e+16],
#        [  1.88590122e+16,  -5.50922484e+16]])

# %%
topwords_matrix = topwords.as_matrix(columns=(0,1))
topwords_matrix
# Out:
# array([[ -1.95835465e+16,  -3.11227096e+16],
#        [ -4.52126917e+16,  -8.39392542e+16],
#        [ -3.42117077e+17,  -7.97807643e+17],
#        ...,
#        [ -5.37751885e+16,  -1.28897109e+17],
#        [ -4.51868165e+17,  -6.36268917e+16],
#        [  4.42423287e+16,   6.13812599e+16]])

# %%
len(topwords_matrix)
# Out:
# 1000

# %%
topwords_index.head()
# Out:
#                      0             1
# index
# foul     -1.958355e+16 -3.112271e+16
# four     -4.521269e+16 -8.393925e+16
# hanging  -3.421171e+17 -7.978076e+17
# marching -3.323213e+17 -6.320489e+16
# increase -3.611474e+16 -1.353899e+16

# %%
topwords_index.describe()
# Out:
#                   0             1
# count  1.000000e+03  1.000000e+03
# mean  -1.337890e+16 -4.132166e+16
# std    4.289667e+17  1.253636e+18
# min   -8.355307e+18 -3.230846e+19
# 25%   -4.629632e+16 -4.012133e+16
# 50%   -2.183248e+16 -8.255354e+15
# 75%    4.300217e+14  1.839039e+16
# max    8.545671e+18  1.096630e+19

# %%
import numpy as Math
import pylab as Plot
import matplotlib.pyplot as plt

rows = topwords_index.index
# %matplotlib notebook
plt.ion()

Plot.figure(figsize=(20, 10))
max_x = Math.amax(topwords_matrix, axis=0)[0]
max_y = Math.amax(topwords_matrix, axis=0)[1]
#Plot.xlim((-.125e+20,.25e+20))
#Plot.ylim((-.125+e20,.1e20))

Plot.scatter(topwords_matrix[:, 0], topwords_matrix[:, 1], 20);

for row_id in range(0, len(rows)):
    target_word = rows[row_id]
    x = topwords_matrix[row_id, 0]
    y = topwords_matrix[row_id, 1]
    Plot.annotate(target_word, (x,y))

Plot.savefig("tsne_top.png");
# Out:
# <img src="data:image/png;base64,..." width="1440">
