# %% [markdown]
# # Project Five
# # Game of Thrones - TSNE

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from textblob import TextBlob
from nltk.corpus import stopwords
import spacy
from nltk import Tree
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph
from nltk.parse import ProjectiveDependencyParser
from nltk.parse import NonprojectiveDependencyParser
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import gensim
from gensim.models import Word2Vec
from nltk.tag import pos_tag
import re
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline
# Out:
# Using Theano backend.

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import scale

from sklearn.datasets import fetch_mldata
from sklearn.cluster import KMeans
from sklearn.utils import shuffle

# %%
import pickle

with open('/Users/zoemarkovits/Metis/project_five_got/total_corpus_texts2.pkl', 'rb') as f:
    total_corpus_texts = pickle.load(f)

# %%
total_corpus_texts
# Out:
# [['well', 'struck'],
#  ['well', 'struck', 'dog'],
#  ['like'],
#  ['well', 'struck', 'grace'],
#  ['already', 'said', 'well', 'struck'],
#  ['yes', 'grace'],
#  ['ser', 'dontos', 'red', 'house', 'hollard'],
#  ['ser', 'dontos', 'red', 'house', 'hollard'],
#  [],
#  ['sorry', 'grace'],
#  ['deepest', u'apology'],
#  ['drunk'],
#  [],
#  ['uh'],
#  ['grace'],
#  ['two', u'cup', 'wine'],
#  ['two', u'cup'],
#  ['thats', 'much'],
#  ['please', 'another', 'cup'],
#  ['sure', 'grace'],
#  ['two'],
#  ['much', 'like'],
#  ['would', 'honored', 'grace'],
#  ['ser', 'meryn', 'help', 'ser', 'dontos', 'celebrate', 'name', 'day'],
#  ['see', u'drink', 'fill'],
#  ['cant'],
#  ['say'],
#  ['say', 'cant'],
#  ['meant', 'would', 'bad', 'luck', 'kill', 'man', 'name', 'day'],
#  ['kind', 'stupid', u'peasant', 'superstition', 'take', 'away'],
#  ['ill', 'killed', 'tomorrow', 'fool'],
#  [],
#  ['fool', 'youre', 'clever', 'see'],
#  ['hell', 'make', 'much', 'better', 'fool', 'knight'],
#  ['doesnt', 'deserve', 'mercy', 'quick', 'death'],
#  ['hear', 'lady', 'ser', 'dontos'],
#  ['day', 'youll', 'new', 'fool'],
#  ['thank', 'grace'],
#  ['lady', 'thank'],
#  ['looked', 'battlefield'],
#  ['nowhere', 'found'],
#  ['ive', 'ruling', u'kingdom'],
#  ['fine', 'job', 'youve', 'done'],
#  ['look'],
#  ['beautiful', 'ever'],
#  [],
#  ['youre', 'going', 'bigger', 'hound', 'much', 'better', 'looking'],
#  ['one', 'doesnt', 'like'],
#  ['cant', 'imagine'],
#  ['heard', 'dead'],
#  ['im', 'glad', 'youre', 'dead'],
#  ['dear'],
#  ['death', 'boring', 'especially', 'much', 'excitement', 'world'],
#  ['lady', 'im', 'sorry', 'loss'],
#  ['loss'],
#  ['father', 'confessed', 'traitor'],
#  ['still', 'father'],
#  ['surely', 'recently', 'lost', 'beloved', 'father', 'sympathize'],
#  ['father', 'traitor'],
#  ['mother', 'brother', u'traitor'],
#  ['loyal', 'beloved', 'joffrey'],
#  ['course'],
#  ['well', 'enjoy', 'name', 'day', 'grace'],
#  ['wish', 'could', 'stay', 'celebrate', 'work', 'done'],
#  ['work'],
#  [],
#  ['raven', 'arrived', 'citadel', 'morning', 'grace'],
#  ['conclave',
#   'met',
#   'considered',
#   u'report',
#   'maesters',
#   'seven',
#   u'kingdom',
#   'done',
#   'last'],
#  ['longest', 'summer', 'living', 'memory'],
#  [u'peasant',
#   'say',
#   'long',
#   'summer',
#   u'mean',
#   u'last',
#   'longer',
#   'well',
#   'fewer',
#   u'peasant'],
#  [u'city', 'drowning', u'refugee', 'grace', 'fleeing', 'war'],
#  ['nowhere', 'house'],
#  ['winter', 'coming', 'itll', 'get', 'worse'],
#  ['command', 'city', 'watch', 'lord', 'slynt'],
#  ['lord', 'command'],
#  ['owe', 'title', u'land', 'generosity', 'grace'],
#  ['job'],
#  ['shut', u'gate', u'peasant'],
#  ['belong', 'field', 'capital'],
#  ['yes', 'grace'],
#  ['dont', 'get'],
#  ['ravishing', 'ever', 'big', 'sister'],
#  ['war', 'agrees'],
#  ['forgive', 'interruption'],
#  ['carry'],
#  [],
#  ['ah', 'remarkable', 'journey'],
#  ['pissed',
#   'edge',
#   'wall',
#   'fought',
#   'hill',
#   u'tribe',
#   'many',
#   u'adventure',
#   'much',
#   'thankful'],
#  [],
#  ['small', 'council'],
#  ['yes'],
#  ['well',
#   'believe',
#   'hand',
#   'king',
#   'welcome',
#   'small',
#   'council',
#   u'meeting'],
#  ['father', 'hand', 'king'],
#  ['yes', 'absence', 'serve', 'hand', 'stead', u'fight'],
#  [],
#  [],
#  ['would', 'like', 'know', 'tricked', 'father'],
#  ['capable', 'tricking', 'father', 'id', 'emperor', 'world'],
#  ['brought'],
#  ['ive', 'done', 'nothing'],
#  ['quite', 'right', 'nothing', 'son', 'called', 'ned', 'starks', 'head'],
#  ['entire', 'north', 'risen', u'u'],
#  ['tried', 'stop'],
#  [],
#  ['failed'],
#  ['bit', 'theater', 'haunt', 'family', 'generation'],
#  ['robb', 'stark', 'child'],
#  [u'who', 'every', 'battle', u'he', 'fought'],
#  ['understand', 'losing', 'war'],
#  ['know', 'warfare'],
#  ['nothing'],
#  ['know', 'people'],
#  ['know', u'enemy', 'hate', 'almost', 'much', 'hate', u'u'],
#  ['joffrey', 'king'],
#  ['joffrey', 'king'],
#  ['advise'],
#  ['im', 'advise'],
#  ['king', 'listens', 'say', 'king', 'might', 'get', 'uncle', 'jaime', 'back'],
#  [],
#  ['love', u'child'],
#  ['one', 'redeeming', 'quality'],
#  [u'cheekbone'],
#  ['starks', 'love', u'child', 'well'],
#  ['two'],
#  ['one'],
#  ['one'],
#  ['arya', 'little', 'animal', 'disappeared'],
#  ['disappeared'],
#  ['puff', 'smoke'],
#  ['three', 'starks', 'trade'],
#  ['chopped', u'one', 'head', 'let', 'another', 'escape'],
#  ['father', 'furious'],
#  ['must', 'odd', 'disappointing', 'child'],
#  ['lord', 'may', 'old', u'god', 'watch', 'brother', 'northern', u'son'],
#  [u'wall', 'holdfast', 'stand', 'winter'],
#  [u'stone',
#   'last',
#   'mortared',
#   'time',
#   'king',
#   u'aery',
#   'im',
#   'afraid',
#   u'mason',
#   'today',
#   'fit',
#   'carry',
#   u'father',
#   u'hammer'],
#  ['boy',
#   'remember',
#   'seeing',
#   'put',
#   'new',
#   'tower',
#   'torrhens',
#   'square',
#   'summer'],
#  ['men', 'worked', 'back'],
#  ['today', 'holdfast', u'look', 'like', 'built', 'drunk', u'child'],
#  ['night', 'hear', 'wind', 'howling', u'gap'],
#  [u'god', 'forbid', u'rain'],
#  ['might', 'well', 'sleep', 'beneath', 'waterfall'],
#  ['maintenance', 'holdfast', 'generally', u'fall', 'lord', 'holdfast'],
#  ['generally',
#   'yes',
#   'ive',
#   'sent',
#   'young',
#   'men',
#   'fight',
#   'robb',
#   'starks',
#   'war'],
#  ['king', 'robb'],
#  ['war'],
#  ['didnt', 'choose'],
#  ['maybe', 'lord', 'called', u'banner', 'took', 'men'],
#  ['joffrey', 'killed', 'father', 'liege', 'lord'],
#  ['remember', u'vow', 'ser'],
#  ['course', 'remember'],
#  ['spare', 'four', u'mason', 'week', 'lord'],
#  ['sufficient', 'repair', u'wall'],
#  ['believe'],
#  ['didnt', 'want', 'day'],
#  ['didnt', 'like', 'way', 'talking', 'robb'],
#  ['listening',
#   'people',
#   'youd',
#   'rather',
#   'listen',
#   'one',
#   u'responsibility',
#   'lord',
#   'winterfell'],
#  ['lord', 'portan'],
#  ['lord', 'may', 'old', u'god', 'watch', 'brother', 'northern', u'son'],
#  ['boil', 'hour', 'drink', 'tea'],
#  [u'make', 'pain', 'go', 'away'],
#  ['dont', 'pain'],
#  ['lucky'],
#  ['way'],
#  ['youve', u'dream'],
#  ['dont', 'dream'],
#  ['everyone', u'dream'],
#  ['dont'],
#  ['heard', 'men', 'talking', 'comet'],
#  ['say', 'omen'],
#  ['say', u'mean', 'robb', 'win', 'great', 'victory', 'south'],
#  [],
#  ['heard', u'fool', 'say', 'lannister', 'red'],
#  [u'mean', 'lannisters', 'rule', 'seven', u'kingdom', 'long'],
#  ['heard', 'stableboy', 'say', 'color', 'blood', 'mark', 'death', 'father'],
#  [u'star', 'dont', 'fall', 'men'],
#  ['red', 'comet', u'mean', 'one', 'thing', 'boy', u'dragon'],
#  [u'dragon', 'dead'],
#  ['theyve', 'dead', u'century'],
#  ['mmm'],
#  ['mmm'],
#  ['mmm'],
#  ['brother', 'say', 'khaleesi'],
#  ['said', 'ate', 'meat'],
#  ['didnt', 'tell', 'kind', 'meat'],
#  ['brother', 'didnt', 'know', 'anything', u'dragon'],
#  ['didnt', 'know', 'anything', 'anything'],
#  ['eh'],
#  ['drogos', 'first', 'gift'],
#  ['remember'],
#  ['promised', 'protect'],
#  ['promised', u'enemy', 'would', 'die', 'screaming'],
#  ['make', 'starvation', 'scream'],
#  ['trick', 'never', 'learned', 'im', 'afraid'],
#  ['ever', 'end'],
#  ['farther', 'east', 'ive', 'ever'],
#  ['yes', 'khaleesi', 'everything', u'end', 'even', 'red', 'waste'],
#  ['youre', 'sure', u'there', 'way'],
#  ['go',
#   'south',
#   'land',
#   'lazarheen',
#   'lamb',
#   'men',
#   'kill',
#   u'u',
#   'take',
#   u'dragon'],
#  ['go',
#   'west',
#   'dothraki',
#   'sea',
#   'first',
#   'khalasar',
#   'meet',
#   'kill',
#   u'u',
#   'take',
#   u'dragon'],
#  ['one', 'take', u'dragon'],
#  ['weak', 'fight', 'people'],
#  ['must', 'strength'],
#  ['mine'],
#  ['rakharo', 'never'],
#  ['bad', 'time', 'start'],
#  ['rough', 'time'],
#  [u'nothing', 'killed', 'yet'],
#  [u'as', 'killed', 'sledge'],
#  ['offered', 'ride'],
#  ['wanted', 'shut', 'damn', u'blister'],
#  ['born', 'place', 'like'],
#  ['later', 'fell', 'hard', u'time'],
#  [u'girl'],
#  ['crasters', u'daughter'],
#  ['havent', 'seen', 'girl', 'six', u'month'],
#  ['id', 'keep', 'seeing'],
#  ['dont', 'like', 'people', 'messing', u'daughter'],
#  ['dont', 'like', 'people', 'messing', u'wife'],
#  ['marries', u'daughter', 'give', u'daughter'],
#  [u'go'],
#  ['thats', 'foul'],
#  ['beyond', 'foul'],
#  ['wildlings', 'hundred', u'league', 'disappeared'],
#  ['crasters', 'still'],
#  ['must', 'something', 'right'],
#  ['happens', u'boy'],
#  ['hmm'],
#  ['marries', u'daughter'],
#  [u'son'],
#  ['said', 'planned', 'stop', 'way', 'frostfangs'],
#  ['people', 'make', u'sort', u'plan'],
#  ['havent', 'seen', 'benjen', 'stark', 'three', u'year'],
#  ['havent', 'missed'],
#  ['always', 'treated', 'like', 'scum'],
#  ['havent', 'good', 'wine', 'long', 'time'],
#  [u'southerner', 'make', 'good', 'wine', 'ill', 'give'],
#  [u'southerner'],
#  [u'who', 'little', 'girl'],
#  ['youre', 'prettier', 'half', u'daughter'],
#  ['got', 'nice', 'wet', 'twat', u'leg'],
#  ['whats', 'name'],
#  ['jon', 'snow'],
#  ['snow', 'eh'],
#  ['listen', 'bastard'],
#  ['lot', 'south', 'wall', 'youre', u'southerner'],
#  ['youre', 'north', 'real', 'north'],
#  ['lad', 'meant', 'harm'],
#  ['catch',
#   'pretty',
#   'little',
#   'bastard',
#   'talking',
#   u'daughter',
#   'one',
#   'talk',
#   u'daughter',
#   'word'],
#  ['sit', 'shut', 'mouth'],
#  ['bring', 'good', 'wine'],
#  [],
#  ['passed', 'six', u'village', 'way'],
#  ['six', 'abandoned'],
#  ['wildlings', 'gone'],
#  ['could', 'tell', 'im', 'thirsty'],
#  [u'there', 'barrel', 'dornish', 'wine', 'sledge'],
#  ['bring'],
#  ['yes', 'commander'],
#  ['want', 'know', 'theyve', 'gone'],
#  ['north', 'join', 'mance', 'rayder', 'old', 'friend'],
#  [u'he', 'friend', 'mine'],
#  ['broke', u'vow', 'betrayed', u'brother'],
#  ['oh', 'aye'],
#  ['poor', 'black', 'crow'],
#  [u'he', 'king', 'beyond', 'wall'],
#  [u'he', 'calling', u'year'],
#  ['whats', 'king'],
#  ['frozen', 'lake', 'somewhere'],
#  ['thats', 'good', 'looking', 'axe'],
#  ['fresh', 'forged'],
#  ['give'],
#  ['youll', 'another', 'one', 'made', 'castle', 'black'],
#  [],
#  ['oh', 'thats', 'lovely', 'steel'],
#  ['want', 'know', 'mance', 'rayder'],
#  ['gathering', 'army'],
#  ['hear', u'he', 'already', 'got', 'men', 'southern', u'king'],
#  ['plan', 'marching', 'army'],
#  ['youre', 'way', 'north', u'there', 'one', 'direction', 'go'],
#  ['bad', u'time', 'living', 'alone', 'wild'],
#  ['cold', u'wind', 'rising'],
#  ['let', 'come'],
#  [u'root', 'sunk', 'deep'],
#  ['wife', 'tell', 'lord', 'crow', 'content'],
#  ['place'],
#  ['husband', u'keep', u'u', 'safe'],
#  ['better', 'live', 'free', 'die', 'slave'],
#  ['dont',
#   'make',
#   'jealous',
#   'old',
#   'man',
#   'see',
#   'young',
#   u'wife',
#   'one',
#   'warm',
#   'bed'],
#  ['chose', 'different', u'path'],
#  ['oh', 'aye', 'chose', 'path', 'one', u'boy'],
#  ['youll', 'wanting', 'sleep', 'beneath', 'roof', 'suppose', 'eat', u'pig'],
#  ['roof', 'would', 'welcome'],
#  ['hard', 'riding'],
#  ['weve', 'brought', 'food', 'good', 'steel'],
#  ['man', u'lay', 'hand', 'one', u'wife', 'loses', 'hand'],
#  ['see', 'one', 'staring', 'long', 'might', 'gouge', u'eye'],
#  ['roof', u'rule'],
#  [],
#  [],
#  ['lord', 'commander'],
#  [],
#  ['jon', 'snow'],
#  [],
#  ['steward'],
#  ['want', 'lead', 'one', 'day'],
#  ['learn', 'follow'],
#  ['lord', 'light', 'come', u'u', 'darkness'],
#  ['offer', 'false', u'god'],
#  ['take', 'cast', 'light', 'upon', u'u', 'night', 'dark', 'full', u'terror'],
#  ['night', 'dark', 'full', u'terror'],
#  ['long', 'summer', 'darkness', 'fall', 'heavy', 'world'],
#  [u'star', 'bleed'],
#  ['need', 'stop'],
#  ['cold', 'breath', 'winter', 'freeze', u'sea'],
#  ['dead', 'shall', 'rise', 'north'],
#  ['men', 'named', 'light', 'seven'],
#  ['treat', u'god', u'father'],
#  ['eager', 'spit', u'ancestor'],
#  ['smell', 'fear', 'fear', 'piss', 'old', u'bone'],
#  ['want', 'stop'],
#  ['stop'],
#  ['ancient',
#   u'book',
#   'written',
#   'warrior',
#   'draw',
#   'burning',
#   'sword',
#   'fire'],
#  ['sword', 'shall', 'lightbringer'],
#  ['stannis', 'baratheon', 'warrior', 'light', 'sword', 'awaits'],
#  ['lord', 'cast', 'light', 'upon', u'u'],
#  ['night', 'dark', 'full', u'terror'],
#  ['night', 'dark', 'full', 'terror'],
#  ['woman', 'lead', 'war', 'cannot', 'win'],
#  ['stannis', 'king'],
#  ['follow', u'lead', 'even', 'dont', 'like', 'path'],
#  ['king'],
#  ['since',
#   'boar',
#   'killed',
#   'brother',
#   'every',
#   'lord',
#   u'want',
#   'coronation'],
#  ['dont', 'serve', 'others'],
#  ['serve', 'stannis'],
#  ['loyal', 'service', u'mean', 'telling', 'hard', u'truth'],
#  [u'he', 'surrounded', u'fool', u'fanatic', u'trust', 'davos'],
#  ['tell', 'truth', 'whats', 'truth'],
#  ['declare',
#   'upon',
#   'honor',
#   'house',
#   'beloved',
#   'brother',
#   'robert',
#   'wasnt',
#   'beloved',
#   'brother'],
#  ['didnt', 'love'],
#  ['didnt', 'love'],
#  ['harmless', 'courtesy', 'grace'],
#  ['lie'],
#  ['take'],
#  ['brother',
#   'robert',
#   'left',
#   'trueborn',
#   u'heir',
#   'boy',
#   'joffrey',
#   'boy',
#   'tommen',
#   'girl',
#   'myrcella',
#   'born',
#   'incest',
#   'cersei',
#   'lannister',
#   'brother',
#   'jaime',
#   'lannister'],
#  ['right', 'birth', 'jaime', 'lannister', 'kingslayer'],
#  ['call'],
#  ['brother', 'jaime', 'lannister', 'kingslayer'],
#  ['right',
#   'birth',
#   'blood',
#   'day',
#   'lay',
#   'claim',
#   'make',
#   'ser',
#   'jaime',
#   'lannister',
#   'kingslayer'],
#  ['whatever', 'else', u'man', 'still', 'knight'],
#  ['ser', 'jaime', 'lannister', 'kingslayer'],
#  ['right',
#   'birth',
#   'blood',
#   'day',
#   'lay',
#   'claim',
#   'iron',
#   'throne',
#   'westeros'],
#  ['let', 'true', 'men', 'declare', 'loyalty'],
#  ['eddard', 'stark', 'learned', 'truth', 'told'],
#  ['ill', 'make', 'mistake'],
#  ['send', u'copy', 'letter', 'every', 'corner', 'realm', 'arbor', 'wall'],
#  ['time', 'come', 'choose'],
#  ['let', 'man', 'claim', 'ignorance', 'excuse'],
#  ['gracethe', 'lannisters', 'true', 'enemy'],
#  ['time',
#   'could',
#   'make',
#   'peace',
#   'brother',
#   'ill',
#   'make',
#   'peace',
#   'renly',
#   u'call',
#   'king'],
#  ['well', 'many', 'already', 'declared', 'mace', 'tyrell', 'randyll', 'tarly'],
#  ['stannis', 'need', 'beg', 'lord', 'lord', 'support'],
#  ['lord', 'light', u'stand', 'behind'],
#  ['many', u'ship', 'lord', 'light', 'got', 'fleet'],
#  ['need', u'ship'],
#  ['im', 'sure', 'doesnt', 'going', 'war'],
#  ['renly', 'grace', 'join', u'force', 'robb', 'stark'],
#  ['would', 'steal', 'northern', 'half', 'kingdom'],
#  ['ive',
#   'always',
#   'served',
#   u'thief',
#   'according',
#   u'dessert',
#   'well',
#   'know',
#   'ser',
#   'davos'],
#  ['joffrey', 'renly', 'robb', 'stark', 'theyre', u'thief'],
#  ['theyll', 'bend', 'knee', 'ill', 'destroy'],
#  ['owe', 'apology', 'king'],
#  ['duty', 'serve'],
#  ['chosen', 'new', 'god', 'old', u'god'],
#  ['may', 'lord', 'light', 'watch', u'u'],
#  ['shall', 'drink', 'together'],
#  ['dont'],
#  ['cup', 'wine', 'honor', 'one', 'true', 'god'],
#  ['night', 'dark', 'full', u'terror', 'old', 'man', 'fire', u'burn', 'away'],
#  ['grace'],
#  ['king', 'north'],
#  ['keep',
#   'expecting',
#   'leave',
#   'one',
#   'castle',
#   'another',
#   'safekeeping',
#   'drag',
#   'along',
#   'camp',
#   'camp'],
#  ['grown', 'fond', 'stark'],
#  [],
#  ['ive', 'never', 'seen', 'girl'],
#  ['left',
#   'one',
#   'bannermen',
#   'father',
#   'would',
#   'know',
#   'within',
#   'fortnight',
#   'bannerman',
#   'would',
#   'receive',
#   'raven',
#   'message',
#   'release',
#   'son',
#   'youll',
#   'rich',
#   'beyond',
#   u'dream'],
#  ['refuse', 'house', 'destroyed', 'root', 'stem'],
#  ['dont', 'trust', 'loyalty', 'men', 'following', 'battle'],
#  ['oh', 'trust', 'life'],
#  ['smart', 'boy'],
#  ['whats', 'wrong'],
#  ['dont', 'like', 'called', 'boy'],
#  ['insulted'],
#  ['insult', 'kingslayer'],
#  ['youve', 'defeated', 'boy'],
#  ['youre', 'held', 'captive', 'boy'],
#  ['perhaps', 'youll', 'killed', 'boy'],
#  ['stannis', 'baratheon', 'sent', u'raven', 'high', u'lord', 'westeros'],
#  ['king',
#   'joffrey',
#   'baratheon',
#   'neither',
#   'true',
#   'king',
#   'true',
#   'baratheon'],
#  [u'he', 'bastard', 'son'],
#  ['thats', 'true', 'stannis', 'rightful', 'king'],
#  ['convenient'],
#  ['father', 'learned', 'truth'],
#  ['thats', 'executed'],
#  ['prisoner', 'ned', 'stark', 'lost', 'head'],
#  ['son', 'killed', 'world', 'wouldnt', 'learn', 'fathered'],
#  ['pushed', 'brother', 'window', 'saw', 'queen'],
#  ['proof'],
#  ['want', 'trade', 'gossip', 'like', 'couple', u'fishwife'],
#  ['im', 'sending', 'one', u'cousin', u'king', 'landing', 'peace', u'term'],
#  ['think', u'father', 'going', 'negotiate'],
#  ['dont', 'know', 'well'],
#  [u'he', 'starting', 'know'],
#  ['three', u'victory', 'dont', 'make', 'conqueror'],
#  ['better', 'three', u'defeat'],
#  ['city', u'stink', 'like', 'dead', u'body'],
#  ['bit', 'corpsey', 'yes'],
#  ['shit'],
#  ['thought', 'wanted', 'come'],
#  ['love'],
#  ['love', 'smell', 'dead', u'body', 'shit'],
#  ['cum', 'garlic', 'rum'],
#  ['smell', 'cum', 'balcony'],
#  ['love', 'stink'],
#  ['love', 'noise'],
#  [u'city', 'make', 'want', 'fuck'],
#  ['country'],
#  ['belong'],
#  ['yes', 'well', 'need', 'careful'],
#  ['one', 'know', 'youre'],
#  ['one', 'know'],
#  ['cant', 'trust', 'anyone', u'king', 'landing'],
#  ['theyre',
#   u'liar',
#   'good',
#   u'liar',
#   'bad',
#   u'liar',
#   'one',
#   'two',
#   'great',
#   u'liar'],
#  [],
#  [],
#  ['im'],
#  ['im', 'slave', 'truth'],
#  ['truth'],
#  ['biggest', 'little', 'liar', 'ever', 'met'],
#  ['think', 'little'],
#  ['im', 'crushed', 'beneath', 'weight', 'truth'],
#  ['oh'],
#  ['ned', 'stark', 'actually', 'slept'],
#  ['poor', 'man', 'didnt', 'suffer', 'enough'],
#  ['one', 'many', u'change', 'well', 'make', 'around'],
#  ['lord', 'baelish'],
#  ['grace'],
#  ['wonder', 'might', 'ask', 'favor'],
#  ['course', 'grace'],
#  ['ned', 'starks', 'youngest', 'daughter', 'arya', 'cant', 'seem', 'locate'],
#  ['shes',
#   'escaped',
#   'capital',
#   'winterfell',
#   'seems',
#   'logical',
#   'destination'],
#  ['yet', u'friend', 'north', 'report', 'sign'],
#  ['curious'],
#  ['choose', 'negotiate', 'starks', 'girl', 'value'],
#  ['whoever', u'find', 'well', 'know', 'say', 'lannisters', u'debt'],
#  ['well', 'could', 'ask', 'varys'],
#  ['hell', 'answer'],
#  ['whether', 'believe', 'always', 'hard', 'time', 'trusting', u'eunuch'],
#  [u'know', 'want'],
#  ['mockingbird'],
#  ['created', 'sigil', 'didnt'],
#  ['yes'],
#  ['appropriate', 'self', 'made', 'man', 'many', u'song', 'sing'],
#  ['im', 'glad', 'like'],
#  ['people', 'fortunate', 'enough', 'born', 'right', 'family'],
#  ['others', 'find', 'way'],
#  ['heard',
#   'song',
#   'boy',
#   'modest',
#   u'mean',
#   'found',
#   'way',
#   'home',
#   'prominent',
#   'family'],
#  ['loved', 'eldest', 'daughter'],
#  ['sadly', u'eye', 'another'],
#  [u'boy', u'girl', 'live', 'home', 'awkward', u'situation', 'arise'],
#  ['sometimes',
#   'ive',
#   'heard',
#   'even',
#   u'brother',
#   u'sister',
#   'develop',
#   'certain',
#   u'affection'],
#  [u'affection',
#   'become',
#   'common',
#   'knowledge',
#   'well',
#   'awkward',
#   'situation',
#   'indeed',
#   'especially',
#   'prominent',
#   'family'],
#  ['prominent',
#   u'family',
#   'often',
#   'forget',
#   'simple',
#   'truth',
#   'ive',
#   'found'],
#  ['truth'],
#  ['knowledge', 'power'],
#  ['seize'],
#  ['cut', 'throat'],
#  ['stop'],
#  ['wait'],
#  ['ive', 'changed', 'mind'],
#  ['let', 'go'],
#  ['step', 'back', 'three', u'pace'],
#  ['turn', 'around'],
#  ['close', u'eye'],
#  ['power', 'power'],
#  ['see', 'take', 'time', 'away', u'coin', u'whore', 'locate', 'stark', 'girl'],
#  ['would', 'much', 'appreciate'],
#  ['youre', 'ser', 'alton', 'lannister'],
#  ['grace'],
#  ['offer', u'cousin', 'peace', 'meet', u'term'],
#  ['first', 'family', 'must', 'release', u'sister'],
#  ['second',
#   u'father',
#   u'bone',
#   'must',
#   'returned',
#   u'u',
#   'may',
#   'rest',
#   'beside',
#   'brother',
#   'sister',
#   u'crypt',
#   'beneath',
#   'winterfell'],
#  ['remains', 'died', 'service', 'must', 'also', 'returned'],
#  [u'family', 'honor', 'proper', u'funeral'],
#  ['honorable', 'request', 'grace'],
#  ['third',
#   'joffrey',
#   'queen',
#   'regent',
#   'must',
#   'renounce',
#   'claim',
#   'dominion',
#   'north'],
#  ['time', 'till', 'end', 'time', 'free', 'independent', 'kingdom'],
#  ['king', 'north'],
#  ['king', 'north'],
#  ['neither', 'joffrey', 'men', 'shall', 'set', 'foot', u'land'],
#  [u'disregard',
#   'command',
#   'shall',
#   'suffer',
#   'fate',
#   'father',
#   'dont',
#   'need',
#   'servant',
#   'beheading'],
#  ['grace', u'term'],
#  ['queen', 'regent', 'son', 'meet', 'ill', 'give', 'peace'],
#  ['litter', 'south', 'lannister', 'dead'],
#  ['king', 'joffrey', 'baratheon', 'grace'],
#  ['oh'],
#  ['youll', 'ride', 'daybreak', 'ser', 'alton'],
#  ['tonight'],
#  ['word', 'grace'],
#  ['dont', 'call', 'grace', u'one', 'around'],
#  ['bad', 'get', 'used'],
#  ['im', 'glad', u'someone', 'gotten', 'used'],
#  ['lannisters', 'going', 'reject', u'term', 'know'],
#  ['course'],
#  ['fight',
#   u'field',
#   'long',
#   'like',
#   'wont',
#   'beat',
#   'take',
#   u'king',
#   'landing'],
#  ['cant', 'take', u'king', 'landing', 'without', u'ship'],
#  ['father', u'ship', 'men', 'know', 'sail'],
#  ['men', 'fought', 'father'],
#  ['men', 'fought', 'king', 'robert', 'free', 'yoke', 'south', 'like', 'youre'],
#  ['im', 'living', 'son'],
#  ['hell', 'listen'],
#  ['know'],
#  ['im', 'stark'],
#  ['know'],
#  ['father', 'raised', 'honorable', 'man'],
#  ['avenge', 'together'],
#  ['dont', 'want', 'balon', 'greyjoy', 'ally'],
#  ['need', u'ship'],
#  ['say'],
#  ['say', 'million', u'rat', 'live', u'sewer', u'king', 'landing'],
#  ['shall', 'rally', 'fight', u'u'],
#  ['understand', 'dont', 'trust', 'lord', 'greyjoy'],
#  ['dont', 'trust', 'lord', 'greyjoy', 'trustworthy'],
#  ['father', 'go', 'war', 'end', 'rebellion'],
#  ['yes'],
#  ['im', 'one', 'rebelling', 'throne'],
#  ['father'],
#  ['married', 'one', 'rebel', 'mothered', 'another'],
#  ['mothered', u'rebel', 'fact', 'seem', 'forgotten'],
#  ['trade', 'kingslayer', 'two', u'girl', 'bannermen', 'string', u'foot'],
#  ['want', 'leave', 'sansa', u'queen', u'hand'],
#  ['arya', 'havent', 'heard', 'word', 'arya'],
#  ['fighting'],
#  ['complicated'],
#  ['know'],
#  ['time', 'go', 'home'],
#  ['havent', 'seen', 'bran', 'rickon', u'month'],
#  ['cant', 'go', 'winterfell'],
#  ['beg', 'pardon'],
#  ['ill',
#   'send',
#   'rodrik',
#   'watch',
#   u'boy',
#   'tomorrow',
#   'youll',
#   'ride',
#   'south',
#   'stormlands'],
#  ['name', u'god', 'need', 'negotiate', 'renly', 'baratheon'],
#  [u'he', 'rallied', 'army'],
#  ['know'],
#  ['know', 'family'],
#  ['havent', 'seen', 'renly', 'baratheon', 'since', 'boy'],
#  ['hundred', u'lord', u'lord', 'trust'],
#  ['renly', u'side', u'u', 'well', 'outnumber', 'two', 'one'],
#  ['feel', u'jaw', 'beginning', 'shut', 'theyll', 'sue', 'peace'],
#  ['well', 'get', u'girl', 'back'],
#  ['well', 'go', 'home', 'good'],
#  ['ride', 'first', 'light'],
#  ['together', 'soon', 'promise'],
#  ['youve', 'done', 'well'],
#  ['father', 'would', 'proud'],
#  ['give', 'lord', 'renly', u'regard'],
#  ['king', 'renly'],
#  [u'there', 'king', 'every', 'corner'],
#  [],
#  ['returning', 'room', 'proper', 'appearance'],
#  ['say', 'targaryens', u'conqueror'],
#  ['seat', 'conqueror'],
#  [u'need', 'room', 'match', u'vine', u'flower'],
#  ['cant', 'find', 'arya', 'stark'],
#  ['luck', 'shes', 'dead', 'ditch', 'somewhere'],
#  ['perhaps'],
#  ['need'],
#  ['theyll', 'never', 'give', 'jaime', 'back', u'u', 'sansa', 'alone'],
#  ['think', 'might'],
#  ['theyre', 'weak'],
#  ['put', 'much', 'value', u'woman'],
#  ['need', 'set', u'army', 'task', 'finding'],
#  ['send', 'many', 'men'],
#  ['im', 'sure', 'asked', 'grandfather', 'king', 'ask', u'command'],
#  [u'grandfather',
#   'stupidity',
#   'field',
#   'battle',
#   'reason',
#   'robb',
#   'stark',
#   'uncle',
#   'jaime',
#   'first',
#   'place'],
#  ['life', 'danger'],
#  ['war'],
#  [u'life', 'danger'],
#  ['heard', 'disgusting', 'lie', 'uncle', 'jaime'],
#  [],
#  [u'enemy', 'say', 'anything', 'weaken', 'claim', 'throne'],
#  ['claim'],
#  ['throne', 'mine'],
#  ['course'],
#  ['one', u'belief', 'foul', 'gossip'],
#  ['someone', u'belief'],
#  ['father', u'child'],
#  ['besides', 'tommen', 'myrcella'],
#  ['asking'],
#  ['im', 'asking', 'fucked', u'woman', 'grew', 'tired'],
#  ['many', u'bastard', 'running', 'punishable', 'death'],
#  ['never'],
#  ['never'],
#  ['mother'],
#  [],
#  ['idea', 'ridiculous', 'sound'],
#  ['ease'],
#  ['slowly', 'passion'],
#  ['oh', 'yeah'],
#  ['go', 'wash'],
#  ['put', 'clothes'],
#  ['working', 'tonight'],
#  [u'thing', 'differently', 'daisy'],
#  ['isnt', 'five', 'copper', 'bawdy', 'house', 'hayseed', 'hall'],
#  ['haystack', 'hall'],
#  ['wherever', 'youre'],
#  ['establishment', 'doesnt', 'cater', u'plowman', 'goat', u'herder'],
#  ['lord', 'olsen'],
#  ['taste', 'everything'],
#  ['littlefingers', 'fancy', 'man'],
#  ['dont', 'call', 'littlefinger'],
#  ['doesnt', 'like'],
#  ['lord', 'baelish'],
#  [u'pretend',
#   'doesnt',
#   'speak',
#   'common',
#   'tongue',
#   'people',
#   'think',
#   'shes',
#   'exotic'],
#  ['grew', 'road', 'flea', 'bottom'],
#  ['shes', 'beautiful'],
#  ['shes', 'dumb', 'slut', 'really', 'lid', 'every', 'pot'],
#  ['lord', 'commander'],
#  ['good', 'see'],
#  ['realize',
#   'establishment',
#   'owned',
#   'lord',
#   'petyr',
#   'baelish',
#   u'king',
#   'master',
#   'coin',
#   'coin',
#   u'go',
#   'many',
#   u'pocket'],
#  [u'order'],
#  ['whose', u'order'],
#  ['someone', 'doesnt', 'care', 'littlefinger', u'think'],
#  ['cant'],
#  [],
#  ['please'],
#  [],
#  ['barra'],
#  ['please'],
#  ['please'],
#  ['enough'],
#  ['get', 'done'],
#  ['kill', 'bastard'],
#  [],
#  ['please'],
#  ['give'],
#  ['please'],
#  ['spread'],
#  ['search', 'every', 'house'],
#  ['every', 'room'],
#  ['look', 'every', 'room'],
#  ['people', 'shouting', 'gendry'],
#  ['name', 'gendry'],
#  ['bastard'],
#  [u'night', 'watch'],
#  ['please', 'stop'],
#  [],
#  ['took', 'kingsroad', 'heading', 'north'],
#  ['know'],
#  [u'he', 'got', u'bull', 'head', 'helmet'],
#  ['made'],
#  ['find'],
#  ['boy'],
#  ['lovely', 'boy'],
#  ['want'],
#  ['man', 'thirst'],
#  ['man', 'drink', 'day', 'night'],
#  ['boy', 'could', 'make', 'friend'],
#  [u'friend'],
#  ['give', u'u', 'beer', 'skin'],
#  ['man', 'choose', u'companion'],
#  ['two', 'courtesy'],
#  ['man', 'must', 'ask', 'forgiveness'],
#  ['youre', 'called', 'arry'],
#  ['man', 'honor', 'jaqen', 'hghar', 'free', 'city', 'beer', 'little', 'shit'],
#  ['get', u'u', 'beer'],
#  ['asked', 'nicely'],
#  ['aah'],
#  ['come', 'closer', 'ill', 'shove', 'stick', 'bunghole', 'fuck', 'bloody'],
#  ['boy', 'courage', 'sense'],
#  ['come'],
#  ['yoren', 'said', 'none', u'u', 'go', 'near', 'three'],
#  ['come'],
#  ['dont', 'scare'],
#  ['hmm'],
#  ['youre', 'stupid'],
#  ['scare'],
#  ['gold', u'cloak', 'far', u'king', 'landing'],
#  [],
#  ['theyre', 'looking'],
#  ['command'],
#  ['youre', 'long', 'way', 'home'],
#  ['asked', 'question'],
#  ['aye'],
#  ['asked', 'without', u'manner', 'chose', 'answer'],
#  ['royal', 'warrant', 'one', 'gutter', u'rat', 'youre', 'transporting'],
#  ['well', 'thing', 'gutter', u'rat', 'belong', u'night', 'watch'],
#  [u'put', 'beyond', 'reach', u'king', u'queen'],
#  [],
#  ['funny',
#   'thing',
#   'people',
#   'worry',
#   'much',
#   u'throat',
#   'forget',
#   'whats',
#   'low'],
#  ['sharpened', 'blade', 'breakfast'],
#  ['could',
#   'shave',
#   u'spider',
#   'arse',
#   'wanted',
#   'could',
#   'nick',
#   'artery',
#   'leg'],
#  ['nicked', u'there', 'one', 'around', u'know', 'unnick'],
#  ['well', 'keep'],
#  ['good', 'steel', 'always', 'needed', 'wall'],
#  ['seems',
#   'choice',
#   'die',
#   u'crossroad',
#   'long',
#   'way',
#   'home',
#   'go',
#   'back',
#   'city',
#   'tell',
#   u'master',
#   'didnt',
#   'find',
#   'looking'],
#  ['looking', 'boy', 'named', 'gendry'],
#  [u'carry', u'bull', 'head', 'helmet'],
#  ['anyone', 'turning', 'earn', u'king', 'reward'],
#  ['well',
#   'back',
#   'men',
#   'ill',
#   'taking',
#   'head',
#   'home',
#   'along',
#   'bastard',
#   'boy'],
#  ['distant', u'seagull', 'lord'],
#  ['make', 'wait', 'long', 'time', 'friend', u'keep', 'company'],
#  ['speaking', 'bravery', 'victory', 'stark', 'auxiliary', u'force'],
#  ['quite', 'battle'],
#  ['heard', 'suffered', 'terrible', 'head', 'wound'],
#  [u'northerner', 'fearsome', u'warrior'],
#  ['tell', 'story', 'meet'],
#  ['find',
#   'lovely',
#   'creature',
#   'working',
#   u'father',
#   u'kitchen',
#   'almost',
#   u'beggar',
#   'belief'],
#  ['strange', u'thing', 'happen'],
#  ['taste', 'fish', 'pie'],
#  ['dont', 'think', 'lord', 'varys', u'like', 'fish', 'pie'],
#  ['tell'],
#  ['always', 'tell'],
#  ['men',
#   'like',
#   'lord',
#   'varys',
#   'cant',
#   'let',
#   u'disadvantage',
#   'get',
#   'best',
#   u'u'],
#  ['well', 'make', 'fisherman', 'yet'],
#  ['glad', 'new', 'friend', 'able', 'accompany', 'capital'],
#  [u'friend', 'important', 'part', 'life'],
#  ['unfortunate', 'father', 'didnt', 'want', 'come'],
#  ['rest', 'easy', 'lord'],
#  ['good', 'keeping', u'secret', 'good', u'friend'],
#  ['discretion', 'legendary', u'friend', 'concerned'],
#  ['unspeakable', 'go', 'want', 'rest'],
#  ['leave'],
#  ['welcome', u'king', 'landing', 'dear'],
#  ['city', 'made', 'brighter', 'presence'],
#  ['council', 'meeting', 'lord'],
#  ['dont', 'like', u'threat'],
#  ['threatened'],
#  ['im', 'ned', 'stark'],
#  ['understand', 'way', 'game', 'played'],
#  ['ned', 'stark', 'man', 'honor'],
#  [],
#  ['threaten', 'ill', 'thrown', 'sea'],
#  ['might', 'disappointed', u'result'],
#  [u'storm',
#   'come',
#   'go',
#   'big',
#   'fish',
#   'eat',
#   'little',
#   'fish',
#   'keep',
#   'paddling'],
#  ['come', 'lord'],
#  ['shouldnt', 'keep', 'queen', 'waiting'],
#  ['time',
#   'end',
#   'time',
#   'part',
#   'realm',
#   'free',
#   'independent',
#   'kingdom',
#   'north'],
#  ['spirit', 'father', 'ill', 'give'],
#  ['youve', 'perfected', 'art', 'tearing', u'paper'],
#  ['give', u'father', u'bone', 'back', 'least', 'gesture', 'good', 'faith'],
#  ['youll', 'give', 'starks', 'reply', 'cousin'],
#  ['grace'],
#  ['see', 'brother', 'starks', 'guest'],
#  [],
#  ['broken', 'spirit', 'grace'],
#  ['speak', 'tell', u'he', 'forgotten'],
#  ['grace'],
#  ['safe', u'travel', 'cousin'],
#  ['deft', 'hand', 'diplomacy'],
#  ['thats', 'everything', 'raven', 'flew', 'morning', 'castle', 'black'],
#  ['trouble', 'wildlings'],
#  ['thats', 'theyre', 'called', 'wildlings'],
#  ['somewhat', u'le', 'wild', u'day'],
#  ['seems',
#   'theyve',
#   'stopped',
#   'killing',
#   'started',
#   'following',
#   'king',
#   'beyond',
#   'wall'],
#  ['another', 'king'],
#  ['many', 'five'],
#  ['ive', 'lost', 'count'],
#  ['lord', 'commander', 'asks', 'send', 'men', 'man', 'wall'],
#  ['perhaps', u'he', 'forgotten', 'fighting', 'war'],
#  ['men', 'spare'],
#  ['cold', u'wind', 'rising', 'dead', 'rise'],
#  [u'northerner', 'superstitious', 'people'],
#  ['according', 'commander', 'one', 'dead', 'men', 'attacked', u'chamber'],
#  ['mormont', 'doesnt', 'lie'],
#  ['kill', 'dead', 'man'],
#  ['apparently', 'burn'],
#  ['one', 'trip', 'wall', 'come', 'back', 'believing', 'grumpkins', 'snarks'],
#  ['dont',
#   'know',
#   'believe',
#   u'here',
#   'fact',
#   u'night',
#   'watch',
#   'thing',
#   u'separate',
#   u'u',
#   u'lie',
#   'beyond',
#   'wall'],
#  ['every', 'confidence', 'brave', 'men', u'night', 'watch', 'protect', u'u'],
#  ['said',
#   u'god',
#   'wanted',
#   u'u',
#   'dignity',
#   'wouldnt',
#   'make',
#   u'u',
#   'fart',
#   'died'],
#  ['fart', 'die'],
#  ['blessed', 'mother', 'holding', 'hand', 'left', 'world'],
#  ['farted', 'hard', 'whole', 'bed', 'shook'],
#  ['seems', 'bit', 'greedy', 'one', 'man', 'many', u'wife'],
#  ['wouldnt', 'two', 'three', 'enough'],
#  ['serious', 'discussion'],
#  ['would', 'look'],
#  ['nothing', 'like', 'sight', 'woman', 'walking', 'away'],
#  ['prefer', 'watching', 'come', 'towards'],
#  ['im', 'sure', 'thats', 'nice'],
#  ['yeah', 'well', 'milkmaid', 'named', 'violet', 'next', 'farm', 'grew'],
#  ['wrestling', 'together', 'time', 'six', u'year', 'old'],
#  ['got', 'older', 'wrestling', 'uh', 'changed'],
#  [],
#  ['many', u'time'],
#  ['well', 'many', u'time', 'could'],
#  ['wish', 'grew', 'farm'],
#  ['need', u'potato'],
#  ['get', 'another', 'sack', 'sledge'],
#  ['get', u'turnip'],
#  [],
#  ['ghost'],
#  [],
#  ['ghost', 'away'],
#  ['shoo', 'shoo'],
#  ['right'],
#  ['frighten'],
#  ['shouldnt', 'touch'],
#  ['oh'],
#  ['oh', 'right'],
#  ['im', 'sorry'],
#  ['wanted', 'make', 'sure', 'werent', 'hurt'],
#  ['youre', 'brave'],
#  [],
#  ['gilly'],
#  ['shes', 'one', 'crasters', u'daughter'],
#  ['hello', 'gilly'],
#  [],
#  ['sam', 'said', 'could', 'help'],
#  ['im', 'sorry', 'sam', u'know', 'supposed', 'shes', 'pregnant'],
#  ['take', u'u', 'leave'],
#  [],
#  ['would', 'know', u'sound', 'bit', 'mad'],
#  ['doesnt', 'sound', 'bit', 'mad', 'impossible'],
#  ['lord', 'commander', 'ordered', u'u', 'sworn', 'protect'],
#  ['sam', 'cant', 'take', 'please', 'ser', 'please'],
#  ['still', 'run'],
#  ['possible'],
#  ['im', 'going', 'baby'],
#  ['boy', 'boy'],
#  ['want', u'u', 'risk', u'life', 'wont', 'even', 'tell', u'u'],
#  ['whyd'],
#  [],
#  ['ask', 'question'],
#  ['cruel'],
#  ['cruel'],
#  ['sam', 'hurry', 'lose', 'hand'],
#  ['didnt', 'touch'],
#  ['want', 'steal'],
#  ['think', 'craster', u'cut'],
#  ['cant', 'steal'],
#  ['shes', 'person', 'goat'],
#  ['heading', 'deeper', 'deeper', 'wildling', 'territory'],
#  ['cant', 'take', 'girl', u'u'],
#  ['mormont', 'wouldnt'],
#  ['even', 'would', 'would'],
#  [u'who', 'going', 'deliver', 'baby'],
#  ['could', 'try'],
#  [],
#  ['ive', 'read'],
#  ['bit'],
#  ['im', 'sorry', 'sam'],
#  ['cant', 'help'],
#  ['khaleesi'],
#  ['dont', 'need', 'see'],
#  ['blood', 'blood'],
#  [],
#  ['khal', 'pono', 'perhaps'],
#  ['khal', 'jhaqo'],
#  ['dont', 'like', 'idea', 'woman', 'leading', 'khalasar'],
#  ['like', 'far', u'le', 'done'],
#  ['remember', 'lord'],
#  [u'look', 'smaller'],
#  ['everything', u'look', 'bigger', 'youre', 'child'],
#  ['remember', u'father', 'cabin', 'felt', 'like', 'palace', 'little'],
#  ['look'],
#  ['theyll', 'waiting', u'dock'],
#  [],
#  ['anyone', u'matter'],
#  ['big', 'day'],
#  ['havent', 'much', 'get', 'excited', 'since', 'left'],
#  ['hard', 'place', 'iron', u'island'],
#  ['always'],
#  ['cold', 'wet'],
#  ['oh', 'love', 'cold', 'wet'],
#  ['say', 'hard', u'place', 'breed', 'hard', 'men'],
#  ['hard', 'men', 'rule', 'world'],
#  ['youll', 'king', 'long'],
#  ['try', 'smiling', u'lip', 'closed'],
#  ['better'],
#  ['father', 'doesnt', 'trust', 'iron', u'islander'],
#  ['dont', 'blame'],
#  [u'say',
#   'youre',
#   'reavers',
#   u'raper',
#   'matter',
#   'many',
#   u'woman',
#   'youll',
#   'never',
#   'sat',
#   'uh'],
#  ['quit', 'talking', 'father'],
#  [u'he', 'right', u'u'],
#  [u'wife', 'iron', u'island', 'theyre', 'breeding'],
#  ['thats', 'enough', u'u'],
#  ['thats', 'take', 'salt', u'wife', u'woman', 'capture'],
#  ['capture'],
#  ['take', 'go', 'ashore'],
#  ['make', 'salt', 'wife'],
#  ['place', 'ship'],
#  ['leave'],
#  ['father', 'punish'],
#  ['hell', 'call', 'whore'],
#  ['havent', 'paid'],
#  ['oh', 'yeah'],
#  ['paid', 'good', 'money', 'im', 'going', 'stand'],
#  ['barely', 'touched'],
#  ['charge', 'twice', 'much', 'every', 'brothel', 'get', u'cry'],
#  ['one', 'moment', 'friend'],
#  ['moment'],
#  ['please', 'accept', 'sincerest', u'apology'],
#  ['aremca', 'take', 'good', 'care'],
#  ['im', 'sorry', 'lord'],
#  ['shh', 'shh'],
#  ['hurt'],
#  ['lord'],
#  ['mhaegen'],
#  [],
#  [u'work'],
#  ['shes', 'one', 'gold', u'cloak', 'killed', 'baby'],
#  ['ah', 'yes'],
#  ['poorly', 'handled'],
#  ['sometimes', 'power', 'least', 'grace'],
#  ['cant', 'stop', 'thinking'],
#  ['cant', 'sleep'],
#  ['poor', 'little', 'baby'],
#  ['know',
#   'remind',
#   'another',
#   'girl',
#   'lovely',
#   'thing',
#   'acquired',
#   'lysene',
#   'pleasure',
#   'house',
#   'beautiful',
#   'like',
#   'intelligent',
#   'like'],
#  ['wasnt', 'happy'],
#  ['cried', 'often'],
#  ['asked', 'didnt', 'kind', 'rapport'],
#  ['yes', 'quite', 'sad'],
#  [u'girl',
#   'lysene',
#   'pleasure',
#   u'house',
#   'expensive',
#   'extremely',
#   'expensive'],
#  ['one', 'wasnt', 'making', 'money'],
#  ['hate', 'bad', u'investment'],
#  ['really'],
#  ['haunt'],
#  ['idea', 'make', 'happy', 'idea', 'mitigate', u'loss'],
#  ['wealthy',
#   'patron',
#   'offered',
#   'tremendous',
#   'amount',
#   'money',
#   'let',
#   'transform',
#   'lovely',
#   'sad',
#   'girl'],
#  ['use', u'way', 'would', 'never', 'occur', 'men'],
#  ['know', 'occurs', 'men'],
#  ['would',
#   'say',
#   'succeeded',
#   'making',
#   'happy',
#   u'loss',
#   'definitely',
#   'mitigated'],
#  ['take', 'tonight', 'mourn', 'mhaegens', 'child'],
#  ['ill', 'see', 'tomorrow'],
#  ['youll', 'happy'],
#  [u'make', 'happy'],
#  ['wine'],
#  ['damn', 'boy'],
#  [u'apology', 'lord'],
#  ['leave', u'u', 'podrick'],
#  ['believe', 'know', 'pour', 'wine'],
#  ['thats', 'new', 'squire'],
#  ['couldve', 'found', 'proper', 'lad'],
#  ['prefer', 'improper', u'one'],
#  ['mm', 'thats', 'good', 'red'],
#  ['dornish'],
#  ['know', u'wine', 'lord'],
#  [],
#  ['fine', 'dinner', 'lord'],
#  ['call', 'tyrion', 'please'],
#  ['im',
#   'sure',
#   'youre',
#   'getting',
#   'used',
#   'fine',
#   u'dinner',
#   'youre',
#   'lord'],
#  ['maybe', 'ill', 'hire', 'cook'],
#  [u'war', 'started', u'le'],
#  ['heard', 'trouble', 'littlefingers', 'brothel', 'night'],
#  ['mm', 'nasty', 'business'],
#  ['done'],
#  ['yes', 'course'],
#  ['city',
#   'watch',
#   'must',
#   'keep',
#   'peace',
#   'hadnt',
#   'realized',
#   'peace',
#   'depended',
#   'killing',
#   u'baby'],
#  [u'order', u'order'],
#  ['quite', 'right'],
#  ['especially', u'queen', u'order'],
#  ['never', 'said', u'queen', u'order'],
#  ['else', 'would', 'want', 'murder', 'king', u'robert', u'bastard'],
#  ['shes', 'always', 'jealous', 'woman'],
#  ['know', 'sister', 'better'],
#  ['youve', 'heard', 'awful', u'rumor', 'brother', 'sister'],
#  ['dont', 'listen', 'filth'],
#  ['thats', 'good', 'heard'],
#  ['suppose',
#   'people',
#   'believe',
#   'filth',
#   'consider',
#   u'robert',
#   u'bastard',
#   'better',
#   u'claimant',
#   'throne',
#   'cerseis',
#   u'child'],
#  ['joffrey', 'king'],
#  ['rest', 'doesnt', 'interest'],
#  ['appreciate', 'loyalty'],
#  ['tell',
#   'men',
#   'slaughtered',
#   'ned',
#   'starks',
#   'men',
#   'throne',
#   'room',
#   'give',
#   'order'],
#  [],
#  ['would'],
#  ['man', 'traitor'],
#  ['tried', 'buy', 'loyalty'],
#  ['fool'],
#  ['idea', 'already', 'bought'],
#  ['drunk'],
#  ['ill', 'honor', 'questioned', 'imp'],
#  ['im', 'questioning', 'honor', 'lord', 'janos'],
#  ['im', 'denying', 'existence'],
#  ['think', 'ill', 'stand', 'take', 'dwarf', 'dwarf'],
#  ['mm', 'stopped', 'imp'],
#  ['yes', 'stand', 'take', 'unless', 'youd', 'like', 'take', 'friend'],
#  ['intend', 'serve', 'hand', 'king', 'father', u'return', 'war'],
#  ['seeing',
#   'betrayed',
#   'last',
#   'hand',
#   'king',
#   'well',
#   'wouldnt',
#   'feel',
#   'safe',
#   'lurking'],
#  [u'friend', 'court', 'allow'],
#  ['queen', 'granted', 'queen', 'regent'],
#  ['youre', 'fool', 'believe', 'friend'],
#  ['shall', 'hear', 'joffrey', 'say'],
#  ['shant'],
#  [u'there', 'ship', 'leaving', 'eastwatch', 'sea', 'tonight'],
#  ['im', 'afraid', 'rather', 'long', 'walk', 'castle', 'black'],
#  ['hope', 'enjoy', 'wall'],
#  ['found',
#   'surprisingly',
#   'beautiful',
#   'brutal',
#   'horribly',
#   'uncomfortable',
#   'sort',
#   'way'],
#  [u'lad', 'escort'],
#  [u'street', 'arent', 'safe', 'night', 'lord'],
#  ...]

# %%
import gensim  
model = gensim.models.Word2Vec(total_corpus_texts, size=100, window=5, min_count=1, workers=2,sg=1)

# %%
model.wv.vocab.items()
# Out:
# [('foul', <gensim.models.keyedvectors.Vocab at 0x10e9376d0>),
#  ('four', <gensim.models.keyedvectors.Vocab at 0x11ecadb10>),
#  ('hanging', <gensim.models.keyedvectors.Vocab at 0x11ecad550>),
#  ('marching', <gensim.models.keyedvectors.Vocab at 0x11ecada50>),
#  (u'increase', <gensim.models.keyedvectors.Vocab at 0x12041c8d0>),
#  ('midafternoon', <gensim.models.keyedvectors.Vocab at 0x11ecadc10>),
#  ('mutinied', <gensim.models.keyedvectors.Vocab at 0x11ecadad0>),
#  ('lord', <gensim.models.keyedvectors.Vocab at 0x11ecadd90>),
#  (u'sinking', <gensim.models.keyedvectors.Vocab at 0x11ecada90>),
#  ('leisurely', <gensim.models.keyedvectors.Vocab at 0x11ecadb50>),
#  (u'politician', <gensim.models.keyedvectors.Vocab at 0x11ecad8d0>),
#  ('stabbed', <gensim.models.keyedvectors.Vocab at 0x11ecad990>),
#  ('bringing', <gensim.models.keyedvectors.Vocab at 0x120230590>),
#  ('disturb', <gensim.models.keyedvectors.Vocab at 0x11ecade50>),
#  ('prize', <gensim.models.keyedvectors.Vocab at 0x11ecaddd0>),
#  ('wooden', <gensim.models.keyedvectors.Vocab at 0x11ecad910>),
#  (u'clientele', <gensim.models.keyedvectors.Vocab at 0x11ecad890>),
#  ('succession', <gensim.models.keyedvectors.Vocab at 0x11ecaded0>),
#  ('straight', <gensim.models.keyedvectors.Vocab at 0x12028af10>),
#  ('tired', <gensim.models.keyedvectors.Vocab at 0x11ecadf50>),
#  (u'lefford', <gensim.models.keyedvectors.Vocab at 0x11ecadf90>),
#  ('bacon', <gensim.models.keyedvectors.Vocab at 0x11ecadfd0>),
#  ('elegant', <gensim.models.keyedvectors.Vocab at 0x12022c050>),
#  ('second', <gensim.models.keyedvectors.Vocab at 0x12022c090>),
#  ('sailed', <gensim.models.keyedvectors.Vocab at 0x120237b10>),
#  (u'ruthless', <gensim.models.keyedvectors.Vocab at 0x12022c110>),
#  ('thunder', <gensim.models.keyedvectors.Vocab at 0x12022c150>),
#  ('cooking', <gensim.models.keyedvectors.Vocab at 0x12022c190>),
#  ('contributed', <gensim.models.keyedvectors.Vocab at 0x12022c1d0>),
#  ('resilient', <gensim.models.keyedvectors.Vocab at 0x12022c210>),
#  ('succumb', <gensim.models.keyedvectors.Vocab at 0x12022c250>),
#  ('hero', <gensim.models.keyedvectors.Vocab at 0x12022c290>),
#  ('interrupting', <gensim.models.keyedvectors.Vocab at 0x12022c2d0>),
#  (u'here', <gensim.models.keyedvectors.Vocab at 0x12022c310>),
#  ('substance', <gensim.models.keyedvectors.Vocab at 0x12022c350>),
#  (u'k', <gensim.models.keyedvectors.Vocab at 0x12022c390>),
#  ('climbed', <gensim.models.keyedvectors.Vocab at 0x12022c3d0>),
#  ('military', <gensim.models.keyedvectors.Vocab at 0x12022c410>),
#  (u'climber', <gensim.models.keyedvectors.Vocab at 0x12022c450>),
#  ('diplomat', <gensim.models.keyedvectors.Vocab at 0x120544250>),
#  ('appropriately', <gensim.models.keyedvectors.Vocab at 0x120243c10>),
#  ('divide', <gensim.models.keyedvectors.Vocab at 0x12022c4d0>),
#  ('explained', <gensim.models.keyedvectors.Vocab at 0x12022c510>),
#  ('replace', <gensim.models.keyedvectors.Vocab at 0x12022c550>),
#  ('brought', <gensim.models.keyedvectors.Vocab at 0x12022c590>),
#  ('stern', <gensim.models.keyedvectors.Vocab at 0x12022c5d0>),
#  ('cheating', <gensim.models.keyedvectors.Vocab at 0x12022c610>),
#  ('spoke', <gensim.models.keyedvectors.Vocab at 0x12022c650>),
#  (u'cannibal', <gensim.models.keyedvectors.Vocab at 0x12022c690>),
#  ('occupying', <gensim.models.keyedvectors.Vocab at 0x12022c6d0>),
#  ('untie', <gensim.models.keyedvectors.Vocab at 0x12022c710>),
#  ('strike', <gensim.models.keyedvectors.Vocab at 0x12022c750>),
#  ('sideface', <gensim.models.keyedvectors.Vocab at 0x12022c790>),
#  ('holy', <gensim.models.keyedvectors.Vocab at 0x12022c7d0>),
#  ('relax', <gensim.models.keyedvectors.Vocab at 0x12022c810>),
#  ('successful', <gensim.models.keyedvectors.Vocab at 0x12022c850>),
#  ('brings', <gensim.models.keyedvectors.Vocab at 0x12022c890>),
#  ('hereby', <gensim.models.keyedvectors.Vocab at 0x12022c8d0>),
#  ('hurt', <gensim.models.keyedvectors.Vocab at 0x12022c910>),
#  (u'glass', <gensim.models.keyedvectors.Vocab at 0x12022c950>),
#  (u'hole', <gensim.models.keyedvectors.Vocab at 0x12024e9d0>),
#  ('hold', <gensim.models.keyedvectors.Vocab at 0x12022c9d0>),
#  (u'simper', <gensim.models.keyedvectors.Vocab at 0x12024eb10>),
#  (u'benjens', <gensim.models.keyedvectors.Vocab at 0x12022ca50>),
#  ('pursue', <gensim.models.keyedvectors.Vocab at 0x12022ca90>),
#  ('zhoan', <gensim.models.keyedvectors.Vocab at 0x12022cad0>),
#  ('blade', <gensim.models.keyedvectors.Vocab at 0x12024edd0>),
#  ('plunged', <gensim.models.keyedvectors.Vocab at 0x12022cb50>),
#  ('sweeter', <gensim.models.keyedvectors.Vocab at 0x12022cb90>),
#  ('rework', <gensim.models.keyedvectors.Vocab at 0x12022cbd0>),
#  ('example', <gensim.models.keyedvectors.Vocab at 0x12022cc10>),
#  ('triple', <gensim.models.keyedvectors.Vocab at 0x120290310>),
#  ('organized', <gensim.models.keyedvectors.Vocab at 0x12022cc90>),
#  (u'caution', <gensim.models.keyedvectors.Vocab at 0x12022cd10>),
#  ('want', <gensim.models.keyedvectors.Vocab at 0x12022cd50>),
#  ('counseling', <gensim.models.keyedvectors.Vocab at 0x12022cd90>),
#  ('mymother', <gensim.models.keyedvectors.Vocab at 0x12022cdd0>),
#  (u'cocksucker', <gensim.models.keyedvectors.Vocab at 0x12022ce10>),
#  ('absolute', <gensim.models.keyedvectors.Vocab at 0x12022ce50>),
#  ('hog', <gensim.models.keyedvectors.Vocab at 0x12022ce90>),
#  ('complaining', <gensim.models.keyedvectors.Vocab at 0x12022ced0>),
#  (u'travel', <gensim.models.keyedvectors.Vocab at 0x12022cf10>),
#  ('copious', <gensim.models.keyedvectors.Vocab at 0x12022cf50>),
#  ('undying', <gensim.models.keyedvectors.Vocab at 0x120523210>),
#  ('hot', <gensim.models.keyedvectors.Vocab at 0x12022cf90>),
#  ('retreating', <gensim.models.keyedvectors.Vocab at 0x1204e1450>),
#  ('beauty', <gensim.models.keyedvectors.Vocab at 0x120230050>),
#  ('swing', <gensim.models.keyedvectors.Vocab at 0x1204e1490>),
#  (u'despondent', <gensim.models.keyedvectors.Vocab at 0x1202300d0>),
#  ('outlawed', <gensim.models.keyedvectors.Vocab at 0x120230110>),
#  ('wrong', <gensim.models.keyedvectors.Vocab at 0x120230150>),
#  ('barristan', <gensim.models.keyedvectors.Vocab at 0x120230190>),
#  (u'huhuh', <gensim.models.keyedvectors.Vocab at 0x1202301d0>),
#  (u'attracts', <gensim.models.keyedvectors.Vocab at 0x120230210>),
#  (u'revolt', <gensim.models.keyedvectors.Vocab at 0x120230250>),
#  ('sickening', <gensim.models.keyedvectors.Vocab at 0x120230290>),
#  ('tulip', <gensim.models.keyedvectors.Vocab at 0x1202302d0>),
#  ('viserys', <gensim.models.keyedvectors.Vocab at 0x120230310>),
#  (u'wing', <gensim.models.keyedvectors.Vocab at 0x120230350>),
#  ('wind', <gensim.models.keyedvectors.Vocab at 0x120230390>),
#  ('wine', <gensim.models.keyedvectors.Vocab at 0x1202303d0>),
#  ('dreamed', <gensim.models.keyedvectors.Vocab at 0x120230410>),
#  ('patricide', <gensim.models.keyedvectors.Vocab at 0x120230450>),
#  (u'profaned', <gensim.models.keyedvectors.Vocab at 0x120230490>),
#  ('rewarded', <gensim.models.keyedvectors.Vocab at 0x1202304d0>),
#  ('fit', <gensim.models.keyedvectors.Vocab at 0x120230510>),
#  ('allisers', <gensim.models.keyedvectors.Vocab at 0x120230550>),
#  ('screaming', <gensim.models.keyedvectors.Vocab at 0x11ecadb90>),
#  (u'fix', <gensim.models.keyedvectors.Vocab at 0x1202305d0>),
#  (u'dedicate', <gensim.models.keyedvectors.Vocab at 0x120230610>),
#  (u'fig', <gensim.models.keyedvectors.Vocab at 0x120230650>),
#  ('mewling', <gensim.models.keyedvectors.Vocab at 0x120230690>),
#  ('hidden', <gensim.models.keyedvectors.Vocab at 0x1202306d0>),
#  ('admirable', <gensim.models.keyedvectors.Vocab at 0x120230710>),
#  ('easier', <gensim.models.keyedvectors.Vocab at 0x120230750>),
#  ('hghar', <gensim.models.keyedvectors.Vocab at 0x120230790>),
#  ('commemorate', <gensim.models.keyedvectors.Vocab at 0x1202307d0>),
#  ('educating', <gensim.models.keyedvectors.Vocab at 0x120230810>),
#  ('interrupt', <gensim.models.keyedvectors.Vocab at 0x120230850>),
#  ('blink', <gensim.models.keyedvectors.Vocab at 0x120230890>),
#  ('silver', <gensim.models.keyedvectors.Vocab at 0x1202308d0>),
#  ('structural', <gensim.models.keyedvectors.Vocab at 0x120230910>),
#  (u'represents', <gensim.models.keyedvectors.Vocab at 0x120230950>),
#  ('jaehaerys', <gensim.models.keyedvectors.Vocab at 0x120230990>),
#  ('theons', <gensim.models.keyedvectors.Vocab at 0x1202309d0>),
#  (u'arrow', <gensim.models.keyedvectors.Vocab at 0x120230a10>),
#  (u'armourer', <gensim.models.keyedvectors.Vocab at 0x120230a50>),
#  ('burial', <gensim.models.keyedvectors.Vocab at 0x120230a90>),
#  (u'whim', <gensim.models.keyedvectors.Vocab at 0x120230ad0>),
#  ('financial', <gensim.models.keyedvectors.Vocab at 0x120230b10>),
#  (u'spider', <gensim.models.keyedvectors.Vocab at 0x120230b50>),
#  (u'longclaw', <gensim.models.keyedvectors.Vocab at 0x120230b90>),
#  (u'turnip', <gensim.models.keyedvectors.Vocab at 0x120230bd0>),
#  ('fortnight', <gensim.models.keyedvectors.Vocab at 0x120230c10>),
#  (u'mutineer', <gensim.models.keyedvectors.Vocab at 0x120230c50>),
#  (u'wyllis', <gensim.models.keyedvectors.Vocab at 0x120230c90>),
#  ('message', <gensim.models.keyedvectors.Vocab at 0x120230cd0>),
#  ('whip', <gensim.models.keyedvectors.Vocab at 0x120230d10>),
#  ('misfortune', <gensim.models.keyedvectors.Vocab at 0x120230d50>),
#  ('whoosh', <gensim.models.keyedvectors.Vocab at 0x120230d90>),
#  (u'mason', <gensim.models.keyedvectors.Vocab at 0x120230dd0>),
#  (u'rd', <gensim.models.keyedvectors.Vocab at 0x120230e10>),
#  ('archmaester', <gensim.models.keyedvectors.Vocab at 0x120230e50>),
#  (u'ro', <gensim.models.keyedvectors.Vocab at 0x120230e90>),
#  (u'outburst', <gensim.models.keyedvectors.Vocab at 0x120230ed0>),
#  (u'foundation', <gensim.models.keyedvectors.Vocab at 0x120230f10>),
#  ('assured', <gensim.models.keyedvectors.Vocab at 0x120230f50>),
#  ('waddle', <gensim.models.keyedvectors.Vocab at 0x120230f90>),
#  ('threatened', <gensim.models.keyedvectors.Vocab at 0x120230fd0>),
#  ('assures', <gensim.models.keyedvectors.Vocab at 0x120274f90>),
#  ('aggar', <gensim.models.keyedvectors.Vocab at 0x120237090>),
#  ('crowned', <gensim.models.keyedvectors.Vocab at 0x1202370d0>),
#  ('tobho', <gensim.models.keyedvectors.Vocab at 0x120237110>),
#  ('ate', <gensim.models.keyedvectors.Vocab at 0x120237150>),
#  ('ath', <gensim.models.keyedvectors.Vocab at 0x120237190>),
#  ('shipped', <gensim.models.keyedvectors.Vocab at 0x1202371d0>),
#  (u'disturbed', <gensim.models.keyedvectors.Vocab at 0x120237210>),
#  ('tempting', <gensim.models.keyedvectors.Vocab at 0x120237250>),
#  ('minge', <gensim.models.keyedvectors.Vocab at 0x120237290>),
#  (u'subtlety', <gensim.models.keyedvectors.Vocab at 0x1202372d0>),
#  ('wash', <gensim.models.keyedvectors.Vocab at 0x120237310>),
#  ('instruct', <gensim.models.keyedvectors.Vocab at 0x120237350>),
#  ('bitten', <gensim.models.keyedvectors.Vocab at 0x120237390>),
#  ('zala', <gensim.models.keyedvectors.Vocab at 0x1202483d0>),
#  ('whorehouse', <gensim.models.keyedvectors.Vocab at 0x120237410>),
#  ('timid', <gensim.models.keyedvectors.Vocab at 0x1203bec90>),
#  ('engagement', <gensim.models.keyedvectors.Vocab at 0x1202374d0>),
#  ('needed', <gensim.models.keyedvectors.Vocab at 0x120237510>),
#  ('master', <gensim.models.keyedvectors.Vocab at 0x120237550>),
#  ('bitter', <gensim.models.keyedvectors.Vocab at 0x120237590>),
#  ('ranging', <gensim.models.keyedvectors.Vocab at 0x1202375d0>),
#  ('listen', <gensim.models.keyedvectors.Vocab at 0x120237610>),
#  ('lorch', <gensim.models.keyedvectors.Vocab at 0x120237650>),
#  (u'collapse', <gensim.models.keyedvectors.Vocab at 0x120237690>),
#  ('hows', <gensim.models.keyedvectors.Vocab at 0x1202376d0>),
#  ('highgarden', <gensim.models.keyedvectors.Vocab at 0x120237710>),
#  ('wisdom', <gensim.models.keyedvectors.Vocab at 0x120237750>),
#  ('predictable', <gensim.models.keyedvectors.Vocab at 0x120237790>),
#  ('crawl', <gensim.models.keyedvectors.Vocab at 0x1202377d0>),
#  ('positively', <gensim.models.keyedvectors.Vocab at 0x120237810>),
#  ('showed', <gensim.models.keyedvectors.Vocab at 0x120237850>),
#  (u'coward', <gensim.models.keyedvectors.Vocab at 0x120237890>),
#  ('tree', <gensim.models.keyedvectors.Vocab at 0x1202378d0>),
#  (u'whinging', <gensim.models.keyedvectors.Vocab at 0x12028a190>),
#  ('shower', <gensim.models.keyedvectors.Vocab at 0x120237950>),
#  ('idle', <gensim.models.keyedvectors.Vocab at 0x120237990>),
#  ('endure', <gensim.models.keyedvectors.Vocab at 0x1202379d0>),
#  ('profitable', <gensim.models.keyedvectors.Vocab at 0x120518150>),
#  ('feeling', <gensim.models.keyedvectors.Vocab at 0x120237a10>),
#  ('groaning', <gensim.models.keyedvectors.Vocab at 0x120237a50>),
#  ('longs', <gensim.models.keyedvectors.Vocab at 0x120237a90>),
#  ('untrained', <gensim.models.keyedvectors.Vocab at 0x120237ad0>),
#  ('tether', <gensim.models.keyedvectors.Vocab at 0x12022c0d0>),
#  ('dozen', <gensim.models.keyedvectors.Vocab at 0x120237b50>),
#  ('responsible', <gensim.models.keyedvectors.Vocab at 0x120237b90>),
#  (u'instructs', <gensim.models.keyedvectors.Vocab at 0x120237c10>),
#  ('amusing', <gensim.models.keyedvectors.Vocab at 0x120237c50>),
#  ('britches', <gensim.models.keyedvectors.Vocab at 0x120237c90>),
#  (u'season', <gensim.models.keyedvectors.Vocab at 0x1204e1990>),
#  ('eastwatch', <gensim.models.keyedvectors.Vocab at 0x12050da50>),
#  (u'horselords', <gensim.models.keyedvectors.Vocab at 0x120237d10>),
#  ('howd', <gensim.models.keyedvectors.Vocab at 0x120237d50>),
#  ('shall', <gensim.models.keyedvectors.Vocab at 0x120237d90>),
#  ('huh', <gensim.models.keyedvectors.Vocab at 0x1204e19d0>),
#  ('aegons', <gensim.models.keyedvectors.Vocab at 0x120237e10>),
#  ('toil', <gensim.models.keyedvectors.Vocab at 0x1203bee10>),
#  ('mouth', <gensim.models.keyedvectors.Vocab at 0x120237e90>),
#  ('letter', <gensim.models.keyedvectors.Vocab at 0x120237ed0>),
#  (u'singer', <gensim.models.keyedvectors.Vocab at 0x120237f10>),
#  (u'episode', <gensim.models.keyedvectors.Vocab at 0x120237f50>),
#  ('rayder', <gensim.models.keyedvectors.Vocab at 0x120295850>),
#  ('consummate', <gensim.models.keyedvectors.Vocab at 0x120237fd0>),
#  ('mating', <gensim.models.keyedvectors.Vocab at 0x12023d090>),
#  ('tirelessly', <gensim.models.keyedvectors.Vocab at 0x120398890>),
#  ('came', <gensim.models.keyedvectors.Vocab at 0x12023d110>),
#  ('saying', <gensim.models.keyedvectors.Vocab at 0x12023d150>),
#  ('fennel', <gensim.models.keyedvectors.Vocab at 0x12023d190>),
#  (u'tempted', <gensim.models.keyedvectors.Vocab at 0x12023d1d0>),
#  ('abreast', <gensim.models.keyedvectors.Vocab at 0x12023d210>),
#  ('busy', <gensim.models.keyedvectors.Vocab at 0x12029bb90>),
#  ('theme', <gensim.models.keyedvectors.Vocab at 0x12023d290>),
#  ('touched', <gensim.models.keyedvectors.Vocab at 0x12023d2d0>),
#  ('rich', <gensim.models.keyedvectors.Vocab at 0x12023d310>),
#  (u'plate', <gensim.models.keyedvectors.Vocab at 0x12023d350>),
#  ('petrified', <gensim.models.keyedvectors.Vocab at 0x1204e1b50>),
#  (u'foremost', <gensim.models.keyedvectors.Vocab at 0x12023d3d0>),
#  (u'pocket', <gensim.models.keyedvectors.Vocab at 0x12023d410>),
#  (u'reversal', <gensim.models.keyedvectors.Vocab at 0x12023d450>),
#  ('altogether', <gensim.models.keyedvectors.Vocab at 0x12023d490>),
#  ('blistered', <gensim.models.keyedvectors.Vocab at 0x12023d4d0>),
#  (u'spilling', <gensim.models.keyedvectors.Vocab at 0x12023d510>),
#  ('nicely', <gensim.models.keyedvectors.Vocab at 0x12023d550>),
#  ('dipping', <gensim.models.keyedvectors.Vocab at 0x12023d590>),
#  ('piggy', <gensim.models.keyedvectors.Vocab at 0x12023d5d0>),
#  ('release', <gensim.models.keyedvectors.Vocab at 0x12023d610>),
#  (u'respond', <gensim.models.keyedvectors.Vocab at 0x12023d650>),
#  (u'blew', <gensim.models.keyedvectors.Vocab at 0x12023d690>),
#  ('fair', <gensim.models.keyedvectors.Vocab at 0x12023d6d0>),
#  ('bled', <gensim.models.keyedvectors.Vocab at 0x12023d710>),
#  (u'result', <gensim.models.keyedvectors.Vocab at 0x12023d750>),
#  ('fail', <gensim.models.keyedvectors.Vocab at 0x12023d790>),
#  ('nocturnal', <gensim.models.keyedvectors.Vocab at 0x12023d7d0>),
#  (u'hammer', <gensim.models.keyedvectors.Vocab at 0x12023d810>),
#  ('best', <gensim.models.keyedvectors.Vocab at 0x12023d850>),
#  ('score', <gensim.models.keyedvectors.Vocab at 0x12023d890>),
#  ('pirate', <gensim.models.keyedvectors.Vocab at 0x12023d8d0>),
#  (u'wage', <gensim.models.keyedvectors.Vocab at 0x12035bf10>),
#  ('men', <gensim.models.keyedvectors.Vocab at 0x120356790>),
#  ('khaleesi', <gensim.models.keyedvectors.Vocab at 0x12023d990>),
#  ('extend', <gensim.models.keyedvectors.Vocab at 0x12023d9d0>),
#  ('nature', <gensim.models.keyedvectors.Vocab at 0x12023da10>),
#  ('rolled', <gensim.models.keyedvectors.Vocab at 0x12023da50>),
#  ('smelled', <gensim.models.keyedvectors.Vocab at 0x12023da90>),
#  ('lapping', <gensim.models.keyedvectors.Vocab at 0x12023dad0>),
#  (u'souvenir', <gensim.models.keyedvectors.Vocab at 0x12023db10>),
#  (u'extent', <gensim.models.keyedvectors.Vocab at 0x12023db90>),
#  ('tyrion', <gensim.models.keyedvectors.Vocab at 0x12023dbd0>),
#  (u'debt', <gensim.models.keyedvectors.Vocab at 0x12023dc10>),
#  ('pity', <gensim.models.keyedvectors.Vocab at 0x12023dc50>),
#  ('accident', <gensim.models.keyedvectors.Vocab at 0x12023dc90>),
#  ('weirwood', <gensim.models.keyedvectors.Vocab at 0x12023dcd0>),
#  ('country', <gensim.models.keyedvectors.Vocab at 0x12023dd10>),
#  (u'adventurer', <gensim.models.keyedvectors.Vocab at 0x12023dd50>),
#  ('demanded', <gensim.models.keyedvectors.Vocab at 0x12023dd90>),
#  ('planned', <gensim.models.keyedvectors.Vocab at 0x12023ddd0>),
#  ('logic', <gensim.models.keyedvectors.Vocab at 0x12023de10>),
#  ('argue', <gensim.models.keyedvectors.Vocab at 0x12023de50>),
#  ('asked', <gensim.models.keyedvectors.Vocab at 0x12023de90>),
#  (u'vain', <gensim.models.keyedvectors.Vocab at 0x12023ded0>),
#  ('blonde', <gensim.models.keyedvectors.Vocab at 0x12023df10>),
#  ('shouting', <gensim.models.keyedvectors.Vocab at 0x1203c4310>),
#  ('union', <gensim.models.keyedvectors.Vocab at 0x12023df90>),
#  ('slay', <gensim.models.keyedvectors.Vocab at 0x12023dfd0>),
#  ('muck', <gensim.models.keyedvectors.Vocab at 0x120243050>),
#  ('much', <gensim.models.keyedvectors.Vocab at 0x120243090>),
#  ('privilege', <gensim.models.keyedvectors.Vocab at 0x1202430d0>),
#  ('tallest', <gensim.models.keyedvectors.Vocab at 0x120243110>),
#  ('life', <gensim.models.keyedvectors.Vocab at 0x120243150>),
#  (u'lodock', <gensim.models.keyedvectors.Vocab at 0x120243190>),
#  ('spit', <gensim.models.keyedvectors.Vocab at 0x1202431d0>),
#  (u'eastern', <gensim.models.keyedvectors.Vocab at 0x120243210>),
#  ('jeor', <gensim.models.keyedvectors.Vocab at 0x120243250>),
#  (u'davy', <gensim.models.keyedvectors.Vocab at 0x120243290>),
#  ('wish', <gensim.models.keyedvectors.Vocab at 0x1202432d0>),
#  ('lift', <gensim.models.keyedvectors.Vocab at 0x120243310>),
#  ('direwolf', <gensim.models.keyedvectors.Vocab at 0x120243350>),
#  ('child', <gensim.models.keyedvectors.Vocab at 0x120243390>),
#  ('worked', <gensim.models.keyedvectors.Vocab at 0x1202433d0>),
#  ('cunt', <gensim.models.keyedvectors.Vocab at 0x120243410>),
#  ('employ', <gensim.models.keyedvectors.Vocab at 0x120243450>),
#  ('contemplates', <gensim.models.keyedvectors.Vocab at 0x120243490>),
#  (u'flooding', <gensim.models.keyedvectors.Vocab at 0x1202434d0>),
#  ('picturing', <gensim.models.keyedvectors.Vocab at 0x120243510>),
#  ('remembering', <gensim.models.keyedvectors.Vocab at 0x120243550>),
#  (u'congratulation', <gensim.models.keyedvectors.Vocab at 0x120243590>),
#  ('played', <gensim.models.keyedvectors.Vocab at 0x1202435d0>),
#  ('cersei', <gensim.models.keyedvectors.Vocab at 0x120243610>),
#  (u'locksmith', <gensim.models.keyedvectors.Vocab at 0x120243650>),
#  (u'obeying', <gensim.models.keyedvectors.Vocab at 0x120243690>),
#  (u'player', <gensim.models.keyedvectors.Vocab at 0x1202436d0>),
#  ('trusted', <gensim.models.keyedvectors.Vocab at 0x120243710>),
#  ('severity', <gensim.models.keyedvectors.Vocab at 0x120243750>),
#  ('tarth', <gensim.models.keyedvectors.Vocab at 0x1204e1ed0>),
#  ('yellow', <gensim.models.keyedvectors.Vocab at 0x1202437d0>),
#  ('thievery', <gensim.models.keyedvectors.Vocab at 0x120243810>),
#  ('rebellion', <gensim.models.keyedvectors.Vocab at 0x120243850>),
#  ('clucking', <gensim.models.keyedvectors.Vocab at 0x120243890>),
#  (u'harmony', <gensim.models.keyedvectors.Vocab at 0x1202c7710>),
#  ('fairly', <gensim.models.keyedvectors.Vocab at 0x120243910>),
#  ('boiled', <gensim.models.keyedvectors.Vocab at 0x120243950>),
#  ('marched', <gensim.models.keyedvectors.Vocab at 0x120243990>),
#  ('supper', <gensim.models.keyedvectors.Vocab at 0x1202439d0>),
#  ('therell', <gensim.models.keyedvectors.Vocab at 0x120243a10>),
#  ('metalwork', <gensim.models.keyedvectors.Vocab at 0x120243a50>),
#  ('tune', <gensim.models.keyedvectors.Vocab at 0x120243a90>),
#  (u'tarleys', <gensim.models.keyedvectors.Vocab at 0x120243ad0>),
#  ('intrusion', <gensim.models.keyedvectors.Vocab at 0x120243b10>),
#  ('noblewoman', <gensim.models.keyedvectors.Vocab at 0x120243b50>),
#  ('eagle', <gensim.models.keyedvectors.Vocab at 0x1204e1210>),
#  ('towheaded', <gensim.models.keyedvectors.Vocab at 0x120243b90>),
#  (u'bellow', <gensim.models.keyedvectors.Vocab at 0x120243bd0>),
#  ('golden', <gensim.models.keyedvectors.Vocab at 0x12022c490>),
#  ('forsaken', <gensim.models.keyedvectors.Vocab at 0x120243c50>),
#  (u'plight', <gensim.models.keyedvectors.Vocab at 0x120243cd0>),
#  (u'hal', <gensim.models.keyedvectors.Vocab at 0x120243d10>),
#  ('ham', <gensim.models.keyedvectors.Vocab at 0x120243d50>),
#  ('ease', <gensim.models.keyedvectors.Vocab at 0x120243d90>),
#  ('hay', <gensim.models.keyedvectors.Vocab at 0x120243dd0>),
#  ('innocent', <gensim.models.keyedvectors.Vocab at 0x120243e10>),
#  ('prison', <gensim.models.keyedvectors.Vocab at 0x120243e50>),
#  ('east', <gensim.models.keyedvectors.Vocab at 0x120243e90>),
#  ('hat', <gensim.models.keyedvectors.Vocab at 0x120243ed0>),
#  (u'hightower', <gensim.models.keyedvectors.Vocab at 0x120243f10>),
#  ('survival', <gensim.models.keyedvectors.Vocab at 0x120243f50>),
#  ('possible', <gensim.models.keyedvectors.Vocab at 0x120243f90>),
#  ('possibly', <gensim.models.keyedvectors.Vocab at 0x120243fd0>),
#  ('birth', <gensim.models.keyedvectors.Vocab at 0x120248050>),
#  ('shadow', <gensim.models.keyedvectors.Vocab at 0x120248090>),
#  ('unique', <gensim.models.keyedvectors.Vocab at 0x1202480d0>),
#  ('desire', <gensim.models.keyedvectors.Vocab at 0x120248110>),
#  ('remind', <gensim.models.keyedvectors.Vocab at 0x120248150>),
#  ('battlefield', <gensim.models.keyedvectors.Vocab at 0x120248190>),
#  ('right', <gensim.models.keyedvectors.Vocab at 0x1202481d0>),
#  ('old', <gensim.models.keyedvectors.Vocab at 0x120248210>),
#  ('crowd', <gensim.models.keyedvectors.Vocab at 0x120248250>),
#  ('people', <gensim.models.keyedvectors.Vocab at 0x120248290>),
#  ('macabre', <gensim.models.keyedvectors.Vocab at 0x1202482d0>),
#  ('crown', <gensim.models.keyedvectors.Vocab at 0x120248350>),
#  ('captive', <gensim.models.keyedvectors.Vocab at 0x120248390>),
#  ('warring', <gensim.models.keyedvectors.Vocab at 0x120248410>),
#  ('bottom', <gensim.models.keyedvectors.Vocab at 0x120248450>),
#  (u'rehearse', <gensim.models.keyedvectors.Vocab at 0x120248490>),
#  (u'fox', <gensim.models.keyedvectors.Vocab at 0x1202484d0>),
#  ('witty', <gensim.models.keyedvectors.Vocab at 0x120248510>),
#  (u'foe', <gensim.models.keyedvectors.Vocab at 0x120248550>),
#  (u'summoned', <gensim.models.keyedvectors.Vocab at 0x120248590>),
#  (u'umi', <gensim.models.keyedvectors.Vocab at 0x1202485d0>),
#  ('pinched', <gensim.models.keyedvectors.Vocab at 0x120248610>),
#  ('yoke', <gensim.models.keyedvectors.Vocab at 0x120248650>),
#  (u'defensive', <gensim.models.keyedvectors.Vocab at 0x120248690>),
#  ('losing', <gensim.models.keyedvectors.Vocab at 0x1202486d0>),
#  ('memorable', <gensim.models.keyedvectors.Vocab at 0x120248710>),
#  ('bowing', <gensim.models.keyedvectors.Vocab at 0x120248750>),
#  (u'grievously', <gensim.models.keyedvectors.Vocab at 0x120248790>),
#  (u'o', <gensim.models.keyedvectors.Vocab at 0x1202487d0>),
#  ('despair', <gensim.models.keyedvectors.Vocab at 0x120248810>),
#  (u'slightly', <gensim.models.keyedvectors.Vocab at 0x120248850>),
#  ('match', <gensim.models.keyedvectors.Vocab at 0x120248890>),
#  ('lamprey', <gensim.models.keyedvectors.Vocab at 0x1202488d0>),
#  ('raised', <gensim.models.keyedvectors.Vocab at 0x120248910>),
#  ('watering', <gensim.models.keyedvectors.Vocab at 0x120356e50>),
#  ('tyrell', <gensim.models.keyedvectors.Vocab at 0x120248990>),
#  ('son', <gensim.models.keyedvectors.Vocab at 0x1202489d0>),
#  ('thankful', <gensim.models.keyedvectors.Vocab at 0x120248a10>),
#  ('consummated', <gensim.models.keyedvectors.Vocab at 0x120248a50>),
#  ('sow', <gensim.models.keyedvectors.Vocab at 0x120248a90>),
#  ('wrap', <gensim.models.keyedvectors.Vocab at 0x120248ad0>),
#  ('despised', <gensim.models.keyedvectors.Vocab at 0x120248b10>),
#  ('fabric', <gensim.models.keyedvectors.Vocab at 0x120248b50>),
#  ('suffice', <gensim.models.keyedvectors.Vocab at 0x120248b90>),
#  ('tame', <gensim.models.keyedvectors.Vocab at 0x120248bd0>),
#  ('grasping', <gensim.models.keyedvectors.Vocab at 0x120248c10>),
#  ('despises', <gensim.models.keyedvectors.Vocab at 0x120248c50>),
#  ('greatness', <gensim.models.keyedvectors.Vocab at 0x120248c90>),
#  ('music', <gensim.models.keyedvectors.Vocab at 0x120285a10>),
#  ('thoros', <gensim.models.keyedvectors.Vocab at 0x1202f3890>),
#  ('underestimated', <gensim.models.keyedvectors.Vocab at 0x120248d50>),
#  ('offer', <gensim.models.keyedvectors.Vocab at 0x120248d90>),
#  ('shireen', <gensim.models.keyedvectors.Vocab at 0x120248dd0>),
#  ('perfumed', <gensim.models.keyedvectors.Vocab at 0x120248e10>),
#  ('matthos', <gensim.models.keyedvectors.Vocab at 0x120248e50>),
#  ('duel', <gensim.models.keyedvectors.Vocab at 0x120248e90>),
#  ('inside', <gensim.models.keyedvectors.Vocab at 0x120248ed0>),
#  ('morning', <gensim.models.keyedvectors.Vocab at 0x120387990>),
#  ('vanguard', <gensim.models.keyedvectors.Vocab at 0x120248f10>),
#  ('pest', <gensim.models.keyedvectors.Vocab at 0x120248f50>),
#  ('torturing', <gensim.models.keyedvectors.Vocab at 0x120248f90>),
#  ('smashed', <gensim.models.keyedvectors.Vocab at 0x120248fd0>),
#  ('juvenile', <gensim.models.keyedvectors.Vocab at 0x12024e050>),
#  ('later', <gensim.models.keyedvectors.Vocab at 0x1204e71d0>),
#  ('proved', <gensim.models.keyedvectors.Vocab at 0x12024e0d0>),
#  ('arwyen', <gensim.models.keyedvectors.Vocab at 0x12024e110>),
#  ('tournament', <gensim.models.keyedvectors.Vocab at 0x12024e150>),
#  ('proven', <gensim.models.keyedvectors.Vocab at 0x12024e190>),
#  ('meros', <gensim.models.keyedvectors.Vocab at 0x12024e1d0>),
#  ('soothe', <gensim.models.keyedvectors.Vocab at 0x12024e210>),
#  ('exist', <gensim.models.keyedvectors.Vocab at 0x12024e250>),
#  ('accounting', <gensim.models.keyedvectors.Vocab at 0x12024e290>),
#  ('floor', <gensim.models.keyedvectors.Vocab at 0x12024e2d0>),
#  (u'actor', <gensim.models.keyedvectors.Vocab at 0x12024e310>),
#  ('uttered', <gensim.models.keyedvectors.Vocab at 0x12024e350>),
#  ('flood', <gensim.models.keyedvectors.Vocab at 0x12024e390>),
#  ('underfed', <gensim.models.keyedvectors.Vocab at 0x1202fe950>),
#  ('role', <gensim.models.keyedvectors.Vocab at 0x12024e410>),
#  ('ambitious', <gensim.models.keyedvectors.Vocab at 0x12024e450>),
#  ('smell', <gensim.models.keyedvectors.Vocab at 0x12024e490>),
#  ('roll', <gensim.models.keyedvectors.Vocab at 0x12024e4d0>),
#  ('intend', <gensim.models.keyedvectors.Vocab at 0x12024e510>),
#  ('corbray', <gensim.models.keyedvectors.Vocab at 0x12024e550>),
#  (u'ointment', <gensim.models.keyedvectors.Vocab at 0x12024e590>),
#  ('scream', <gensim.models.keyedvectors.Vocab at 0x12023d0d0>),
#  ('acquaintance', <gensim.models.keyedvectors.Vocab at 0x12024e5d0>),
#  ('giantsbane', <gensim.models.keyedvectors.Vocab at 0x12024e610>),
#  ('cleaver', <gensim.models.keyedvectors.Vocab at 0x12024e650>),
#  (u'daugters', <gensim.models.keyedvectors.Vocab at 0x12024e690>),
#  ('warn', <gensim.models.keyedvectors.Vocab at 0x12035b150>),
#  ('pycelle', <gensim.models.keyedvectors.Vocab at 0x12024e710>),
#  ('sniffed', <gensim.models.keyedvectors.Vocab at 0x12024e750>),
#  ('quandary', <gensim.models.keyedvectors.Vocab at 0x12024e790>),
#  ('time', <gensim.models.keyedvectors.Vocab at 0x12024e7d0>),
#  ('push', <gensim.models.keyedvectors.Vocab at 0x12024e810>),
#  ('someplace', <gensim.models.keyedvectors.Vocab at 0x1204e1150>),
#  ('dotes', <gensim.models.keyedvectors.Vocab at 0x12024e850>),
#  ('gown', <gensim.models.keyedvectors.Vocab at 0x12024e890>),
#  ('chain', <gensim.models.keyedvectors.Vocab at 0x12024e8d0>),
#  ('whoever', <gensim.models.keyedvectors.Vocab at 0x12024e910>),
#  ('warg', <gensim.models.keyedvectors.Vocab at 0x12035b250>),
#  ('chair', <gensim.models.keyedvectors.Vocab at 0x12024e990>),
#  ('midst', <gensim.models.keyedvectors.Vocab at 0x12022c990>),
#  ('quartered', <gensim.models.keyedvectors.Vocab at 0x12024ea10>),
#  (u'lothar', <gensim.models.keyedvectors.Vocab at 0x12024ea50>),
#  ('choice', <gensim.models.keyedvectors.Vocab at 0x12024ea90>),
#  ('mourn', <gensim.models.keyedvectors.Vocab at 0x12024ead0>),
#  ('locked', <gensim.models.keyedvectors.Vocab at 0x12022ca10>),
#  (u'exact', <gensim.models.keyedvectors.Vocab at 0x12024eb50>),
#  ('minute', <gensim.models.keyedvectors.Vocab at 0x12024eb90>),
#  ('tear', <gensim.models.keyedvectors.Vocab at 0x12024ebd0>),
#  (u'teat', <gensim.models.keyedvectors.Vocab at 0x12024ec10>),
#  (u'pea', <gensim.models.keyedvectors.Vocab at 0x12024ec50>),
#  ('leave', <gensim.models.keyedvectors.Vocab at 0x12024ec90>),
#  ('settle', <gensim.models.keyedvectors.Vocab at 0x12024ecd0>),
#  ('stockade', <gensim.models.keyedvectors.Vocab at 0x12024ed10>),
#  (u'team', <gensim.models.keyedvectors.Vocab at 0x12024ed50>),
#  ('bonfire', <gensim.models.keyedvectors.Vocab at 0x12024ed90>),
#  (u'accomplishment', <gensim.models.keyedvectors.Vocab at 0x12022cb10>),
#  (u'sigh', <gensim.models.keyedvectors.Vocab at 0x12024ee10>),
#  ('sign', <gensim.models.keyedvectors.Vocab at 0x12024ee50>),
#  ('chopping', <gensim.models.keyedvectors.Vocab at 0x12024ee90>),
#  ('catelyn', <gensim.models.keyedvectors.Vocab at 0x12024eed0>),
#  (u'melt', <gensim.models.keyedvectors.Vocab at 0x12024ef10>),
#  ('current', <gensim.models.keyedvectors.Vocab at 0x12024ef50>),
#  ('axel', <gensim.models.keyedvectors.Vocab at 0x12024ef90>),
#  ('falling', <gensim.models.keyedvectors.Vocab at 0x12024efd0>),
#  ('crashing', <gensim.models.keyedvectors.Vocab at 0x1202f81d0>),
#  ('badge', <gensim.models.keyedvectors.Vocab at 0x120253090>),
#  ('ramming', <gensim.models.keyedvectors.Vocab at 0x1202530d0>),
#  (u'funeral', <gensim.models.keyedvectors.Vocab at 0x120253110>),
#  ('understanding', <gensim.models.keyedvectors.Vocab at 0x120253150>),
#  ('contemplate', <gensim.models.keyedvectors.Vocab at 0x120253190>),
#  ('address', <gensim.models.keyedvectors.Vocab at 0x1202531d0>),
#  ('alone', <gensim.models.keyedvectors.Vocab at 0x120253210>),
#  ('along', <gensim.models.keyedvectors.Vocab at 0x120253250>),
#  ('crumbles', <gensim.models.keyedvectors.Vocab at 0x120253290>),
#  (u'summerwine', <gensim.models.keyedvectors.Vocab at 0x1202532d0>),
#  ('brilliant', <gensim.models.keyedvectors.Vocab at 0x120253310>),
#  ('studied', <gensim.models.keyedvectors.Vocab at 0x120253350>),
#  ('wherever', <gensim.models.keyedvectors.Vocab at 0x120253390>),
#  (u'commonly', <gensim.models.keyedvectors.Vocab at 0x1202533d0>),
#  ('accomplished', <gensim.models.keyedvectors.Vocab at 0x120253410>),
#  ('greizhen', <gensim.models.keyedvectors.Vocab at 0x120253450>),
#  (u'reclaim', <gensim.models.keyedvectors.Vocab at 0x120253490>),
#  ('nowhere', <gensim.models.keyedvectors.Vocab at 0x1202534d0>),
#  ('love', <gensim.models.keyedvectors.Vocab at 0x120253510>),
#  ('prefer', <gensim.models.keyedvectors.Vocab at 0x120253550>),
#  ('logical', <gensim.models.keyedvectors.Vocab at 0x120253590>),
#  ('bloody', <gensim.models.keyedvectors.Vocab at 0x1202535d0>),
#  ('marvelous', <gensim.models.keyedvectors.Vocab at 0x120253610>),
#  ('betraying', <gensim.models.keyedvectors.Vocab at 0x120253650>),
#  (u'sky', <gensim.models.keyedvectors.Vocab at 0x120539a90>),
#  (u'capsized', <gensim.models.keyedvectors.Vocab at 0x120253690>),
#  ('working', <gensim.models.keyedvectors.Vocab at 0x1202536d0>),
#  ('angry', <gensim.models.keyedvectors.Vocab at 0x120253710>),
#  ('blackwater', <gensim.models.keyedvectors.Vocab at 0x120253750>),
#  (u'cockfighting', <gensim.models.keyedvectors.Vocab at 0x120253790>),
#  ('wondering', <gensim.models.keyedvectors.Vocab at 0x1202537d0>),
#  (u'halfbrother', <gensim.models.keyedvectors.Vocab at 0x120253810>),
#  ('wicked', <gensim.models.keyedvectors.Vocab at 0x120253850>),
#  (u'introducing', <gensim.models.keyedvectors.Vocab at 0x120253890>),
#  (u'guardsman', <gensim.models.keyedvectors.Vocab at 0x1202538d0>),
#  ('afford', <gensim.models.keyedvectors.Vocab at 0x120253910>),
#  ('xaros', <gensim.models.keyedvectors.Vocab at 0x1204f7b90>),
#  ('marbled', <gensim.models.keyedvectors.Vocab at 0x120253950>),
#  ('everywhere', <gensim.models.keyedvectors.Vocab at 0x120253990>),
#  ('virtue', <gensim.models.keyedvectors.Vocab at 0x1202539d0>),
#  ('behalf', <gensim.models.keyedvectors.Vocab at 0x120253a10>),
#  ('honey', <gensim.models.keyedvectors.Vocab at 0x12035b4d0>),
#  ('valued', <gensim.models.keyedvectors.Vocab at 0x120253a90>),
#  ('anything', <gensim.models.keyedvectors.Vocab at 0x120290f10>),
#  ('originally', <gensim.models.keyedvectors.Vocab at 0x120253b10>),
#  (u'pretend', <gensim.models.keyedvectors.Vocab at 0x120253b50>),
#  ('privy', <gensim.models.keyedvectors.Vocab at 0x120253b90>),
#  ('believer', <gensim.models.keyedvectors.Vocab at 0x120253bd0>),
#  (u'impasse', <gensim.models.keyedvectors.Vocab at 0x120253c10>),
#  ('believed', <gensim.models.keyedvectors.Vocab at 0x120253c50>),
#  ('admired', <gensim.models.keyedvectors.Vocab at 0x120253c90>),
#  ('locke', <gensim.models.keyedvectors.Vocab at 0x120253cd0>),
#  (u'unconsummated', <gensim.models.keyedvectors.Vocab at 0x120253d10>),
#  ('unveiled', <gensim.models.keyedvectors.Vocab at 0x120253d50>),
#  ('allowed', <gensim.models.keyedvectors.Vocab at 0x120253d90>),
#  ('offense', <gensim.models.keyedvectors.Vocab at 0x120253dd0>),
#  ('stole', <gensim.models.keyedvectors.Vocab at 0x120253e10>),
#  ('evidently', <gensim.models.keyedvectors.Vocab at 0x120253e50>),
#  ('listens', <gensim.models.keyedvectors.Vocab at 0x120253e90>),
#  ('winter', <gensim.models.keyedvectors.Vocab at 0x120253ed0>),
#  (u'divided', <gensim.models.keyedvectors.Vocab at 0x120253f10>),
#  ('thanking', <gensim.models.keyedvectors.Vocab at 0x120253f50>),
#  ('immune', <gensim.models.keyedvectors.Vocab at 0x120253f90>),
#  ('loathe', <gensim.models.keyedvectors.Vocab at 0x12035b590>),
#  (u'encampment', <gensim.models.keyedvectors.Vocab at 0x120259050>),
#  (u'provincial', <gensim.models.keyedvectors.Vocab at 0x120259090>),
#  ('spot', <gensim.models.keyedvectors.Vocab at 0x1202590d0>),
#  ('suck', <gensim.models.keyedvectors.Vocab at 0x120259110>),
#  ('dove', <gensim.models.keyedvectors.Vocab at 0x120259150>),
#  (u'stress', <gensim.models.keyedvectors.Vocab at 0x120259190>),
#  ('natural', <gensim.models.keyedvectors.Vocab at 0x1202591d0>),
#  ('blackfish', <gensim.models.keyedvectors.Vocab at 0x1204e77d0>),
#  ('st', <gensim.models.keyedvectors.Vocab at 0x120259250>),
#  ('swollen', <gensim.models.keyedvectors.Vocab at 0x120259290>),
#  ('truce', <gensim.models.keyedvectors.Vocab at 0x1202592d0>),
#  ('pulled', <gensim.models.keyedvectors.Vocab at 0x120259310>),
#  ('drunken', <gensim.models.keyedvectors.Vocab at 0x120259350>),
#  (u'footstep', <gensim.models.keyedvectors.Vocab at 0x120259390>),
#  ('unacceptable', <gensim.models.keyedvectors.Vocab at 0x1202593d0>),
#  ('damage', <gensim.models.keyedvectors.Vocab at 0x120259410>),
#  ('course', <gensim.models.keyedvectors.Vocab at 0x120259450>),
#  ('yearn', <gensim.models.keyedvectors.Vocab at 0x120259490>),
#  ('mishear', <gensim.models.keyedvectors.Vocab at 0x1202594d0>),
#  ('lovelier', <gensim.models.keyedvectors.Vocab at 0x120259510>),
#  (u'tendency', <gensim.models.keyedvectors.Vocab at 0x120259550>),
#  ('tore', <gensim.models.keyedvectors.Vocab at 0x120259590>),
#  ('milked', <gensim.models.keyedvectors.Vocab at 0x1202595d0>),
#  ('torn', <gensim.models.keyedvectors.Vocab at 0x120259610>),
#  ('stupidity', <gensim.models.keyedvectors.Vocab at 0x12035b610>),
#  ('aerion', <gensim.models.keyedvectors.Vocab at 0x120259690>),
#  ('celebrate', <gensim.models.keyedvectors.Vocab at 0x1202596d0>),
#  ('troubled', <gensim.models.keyedvectors.Vocab at 0x120259710>),
#  (u'deviant', <gensim.models.keyedvectors.Vocab at 0x120259750>),
#  (u'chaining', <gensim.models.keyedvectors.Vocab at 0x120259790>),
#  ('smarter', <gensim.models.keyedvectors.Vocab at 0x1202597d0>),
#  ('arriving', <gensim.models.keyedvectors.Vocab at 0x120259810>),
#  ('reckoning', <gensim.models.keyedvectors.Vocab at 0x120259850>),
#  (u'shhh', <gensim.models.keyedvectors.Vocab at 0x120259890>),
#  ('maintaining', <gensim.models.keyedvectors.Vocab at 0x1202598d0>),
#  ('matched', <gensim.models.keyedvectors.Vocab at 0x120259910>),
#  ('freya', <gensim.models.keyedvectors.Vocab at 0x120259950>),
#  ('appropriate', <gensim.models.keyedvectors.Vocab at 0x1202950d0>),
#  ('stillborns', <gensim.models.keyedvectors.Vocab at 0x1202599d0>),
#  ('fisherman', <gensim.models.keyedvectors.Vocab at 0x120259a10>),
#  ('amnesty', <gensim.models.keyedvectors.Vocab at 0x120259a50>),
#  (u'quarter', <gensim.models.keyedvectors.Vocab at 0x120259a90>),
#  ('broodmare', <gensim.models.keyedvectors.Vocab at 0x120259ad0>),
#  ('square', <gensim.models.keyedvectors.Vocab at 0x120259b10>),
#  ('beloved', <gensim.models.keyedvectors.Vocab at 0x120259b50>),
#  ('entering', <gensim.models.keyedvectors.Vocab at 0x120259b90>),
#  (u'beetle', <gensim.models.keyedvectors.Vocab at 0x120259bd0>),
#  ('troll', <gensim.models.keyedvectors.Vocab at 0x120259c10>),
#  (u'swordsman', <gensim.models.keyedvectors.Vocab at 0x120259c50>),
#  ('seriously', <gensim.models.keyedvectors.Vocab at 0x120259c90>),
#  ('investigation', <gensim.models.keyedvectors.Vocab at 0x120259cd0>),
#  ('suggesting', <gensim.models.keyedvectors.Vocab at 0x120259d10>),
#  ('facedown', <gensim.models.keyedvectors.Vocab at 0x120259d90>),
#  ('siege', <gensim.models.keyedvectors.Vocab at 0x120259dd0>),
#  ('million', <gensim.models.keyedvectors.Vocab at 0x120259e10>),
#  ('seventh', <gensim.models.keyedvectors.Vocab at 0x120259e50>),
#  (u'possibility', <gensim.models.keyedvectors.Vocab at 0x120259e90>),
#  ('quite', <gensim.models.keyedvectors.Vocab at 0x120259ed0>),
#  ('complicated', <gensim.models.keyedvectors.Vocab at 0x120259f50>),
#  ('besides', <gensim.models.keyedvectors.Vocab at 0x120259f90>),
#  (u'grandma', <gensim.models.keyedvectors.Vocab at 0x120259fd0>),
#  ('unnamed', <gensim.models.keyedvectors.Vocab at 0x12025e050>),
#  ('patronage', <gensim.models.keyedvectors.Vocab at 0x12025e090>),
#  ('training', <gensim.models.keyedvectors.Vocab at 0x12025e0d0>),
#  ('backside', <gensim.models.keyedvectors.Vocab at 0x12025e110>),
#  ('modest', <gensim.models.keyedvectors.Vocab at 0x12025e150>),
#  (u'nymeria', <gensim.models.keyedvectors.Vocab at 0x12025e190>),
#  ('saving', <gensim.models.keyedvectors.Vocab at 0x12025e1d0>),
#  ('spoken', <gensim.models.keyedvectors.Vocab at 0x12025e210>),
#  ('one', <gensim.models.keyedvectors.Vocab at 0x12025e250>),
#  (u'reopen', <gensim.models.keyedvectors.Vocab at 0x12025e290>),
#  ('punishable', <gensim.models.keyedvectors.Vocab at 0x12025e2d0>),
#  ('vote', <gensim.models.keyedvectors.Vocab at 0x12025e310>),
#  ('open', <gensim.models.keyedvectors.Vocab at 0x12025e350>),
#  ('ripping', <gensim.models.keyedvectors.Vocab at 0x120361350>),
#  ('partook', <gensim.models.keyedvectors.Vocab at 0x12025e3d0>),
#  (u'city', <gensim.models.keyedvectors.Vocab at 0x12025e410>),
#  (u'wrath', <gensim.models.keyedvectors.Vocab at 0x12025e450>),
#  ('bite', <gensim.models.keyedvectors.Vocab at 0x12025e490>),
#  ('teacher', <gensim.models.keyedvectors.Vocab at 0x1205133d0>),
#  (u'shiver', <gensim.models.keyedvectors.Vocab at 0x12025e4d0>),
#  ('prone', <gensim.models.keyedvectors.Vocab at 0x12025e510>),
#  ('shawl', <gensim.models.keyedvectors.Vocab at 0x12025e550>),
#  ('meddling', <gensim.models.keyedvectors.Vocab at 0x12025e590>),
#  (u'padding', <gensim.models.keyedvectors.Vocab at 0x12025e5d0>),
#  ('prowling', <gensim.models.keyedvectors.Vocab at 0x1202952d0>),
#  ('ridiculous', <gensim.models.keyedvectors.Vocab at 0x12025e650>),
#  (u'camello', <gensim.models.keyedvectors.Vocab at 0x12025e690>),
#  ('third', <gensim.models.keyedvectors.Vocab at 0x12035b810>),
#  ('cower', <gensim.models.keyedvectors.Vocab at 0x120366c10>),
#  ('sandor', <gensim.models.keyedvectors.Vocab at 0x12025e750>),
#  (u'counselor', <gensim.models.keyedvectors.Vocab at 0x12025e790>),
#  (u'wandering', <gensim.models.keyedvectors.Vocab at 0x12025e7d0>),
#  ('damned', <gensim.models.keyedvectors.Vocab at 0x12025e810>),
#  ('prospect', <gensim.models.keyedvectors.Vocab at 0x12025e850>),
#  (u'addressing', <gensim.models.keyedvectors.Vocab at 0x12025e890>),
#  (u'illness', <gensim.models.keyedvectors.Vocab at 0x12025e8d0>),
#  ('tasted', <gensim.models.keyedvectors.Vocab at 0x12025e910>),
#  ('nicer', <gensim.models.keyedvectors.Vocab at 0x12025e950>),
#  ('turned', <gensim.models.keyedvectors.Vocab at 0x12025e990>),
#  ('alley', <gensim.models.keyedvectors.Vocab at 0x12025e9d0>),
#  ('sad', <gensim.models.keyedvectors.Vocab at 0x12025ea10>),
#  ('say', <gensim.models.keyedvectors.Vocab at 0x12025ea50>),
#  ('taster', <gensim.models.keyedvectors.Vocab at 0x12025ea90>),
#  ('buried', <gensim.models.keyedvectors.Vocab at 0x12025ead0>),
#  ('lurking', <gensim.models.keyedvectors.Vocab at 0x12025eb10>),
#  ('sap', <gensim.models.keyedvectors.Vocab at 0x12025eb50>),
#  ('saw', <gensim.models.keyedvectors.Vocab at 0x12025eb90>),
#  ('sat', <gensim.models.keyedvectors.Vocab at 0x12025ebd0>),
#  ('wink', <gensim.models.keyedvectors.Vocab at 0x12025ec10>),
#  (u'downwards', <gensim.models.keyedvectors.Vocab at 0x12025ec50>),
#  ('aside', <gensim.models.keyedvectors.Vocab at 0x1203716d0>),
#  ('instructed', <gensim.models.keyedvectors.Vocab at 0x12025ecd0>),
#  ('note', <gensim.models.keyedvectors.Vocab at 0x12025ed10>),
#  ('take', <gensim.models.keyedvectors.Vocab at 0x12025ed50>),
#  (u'mazin', <gensim.models.keyedvectors.Vocab at 0x12025ed90>),
#  ('wanting', <gensim.models.keyedvectors.Vocab at 0x120371a90>),
#  (u'opposite', <gensim.models.keyedvectors.Vocab at 0x12025ee10>),
#  ('squalor', <gensim.models.keyedvectors.Vocab at 0x12025ee50>),
#  ('knew', <gensim.models.keyedvectors.Vocab at 0x12025ee90>),
#  ('knee', <gensim.models.keyedvectors.Vocab at 0x12025eed0>),
#  ('average', <gensim.models.keyedvectors.Vocab at 0x12025ef10>),
#  (u'sale', <gensim.models.keyedvectors.Vocab at 0x1203778d0>),
#  (u'defeating', <gensim.models.keyedvectors.Vocab at 0x12025ef90>),
#  ('crooked', <gensim.models.keyedvectors.Vocab at 0x1204e7b10>),
#  ('gillyflower', <gensim.models.keyedvectors.Vocab at 0x120264050>),
#  ('squint', <gensim.models.keyedvectors.Vocab at 0x120264090>),
#  ('butchered', <gensim.models.keyedvectors.Vocab at 0x1202640d0>),
#  ('salt', <gensim.models.keyedvectors.Vocab at 0x120264110>),
#  ('walking', <gensim.models.keyedvectors.Vocab at 0x120264150>),
#  (u'merit', <gensim.models.keyedvectors.Vocab at 0x120264190>),
#  ('bright', <gensim.models.keyedvectors.Vocab at 0x1202641d0>),
#  ('imagined', <gensim.models.keyedvectors.Vocab at 0x120264210>),
#  ('slow', <gensim.models.keyedvectors.Vocab at 0x120264250>),
#  ('strangled', <gensim.models.keyedvectors.Vocab at 0x12039d3d0>),
#  (u'cloak', <gensim.models.keyedvectors.Vocab at 0x120264290>),
#  ('liberation', <gensim.models.keyedvectors.Vocab at 0x1202642d0>),
#  ('betrothal', <gensim.models.keyedvectors.Vocab at 0x120264310>),
#  ('going', <gensim.models.keyedvectors.Vocab at 0x120264350>),
#  ('dancing', <gensim.models.keyedvectors.Vocab at 0x120513d90>),
#  ('outrage', <gensim.models.keyedvectors.Vocab at 0x120264390>),
#  ('robe', <gensim.models.keyedvectors.Vocab at 0x1202643d0>),
#  ('clawing', <gensim.models.keyedvectors.Vocab at 0x120264410>),
#  ('robb', <gensim.models.keyedvectors.Vocab at 0x120264450>),
#  (u'dispute', <gensim.models.keyedvectors.Vocab at 0x120264490>),
#  ('graceless', <gensim.models.keyedvectors.Vocab at 0x1202644d0>),
#  ('guarded', <gensim.models.keyedvectors.Vocab at 0x120264510>),
#  ('freezing', <gensim.models.keyedvectors.Vocab at 0x120264550>),
#  (u'clang', <gensim.models.keyedvectors.Vocab at 0x120264590>),
#  ('awaiting', <gensim.models.keyedvectors.Vocab at 0x1202645d0>),
#  ('vhag', <gensim.models.keyedvectors.Vocab at 0x120264610>),
#  ('prime', <gensim.models.keyedvectors.Vocab at 0x120264650>),
#  (u'resource', <gensim.models.keyedvectors.Vocab at 0x120264690>),
#  (u'artist', <gensim.models.keyedvectors.Vocab at 0x1202646d0>),
#  ('absurdly', <gensim.models.keyedvectors.Vocab at 0x120264710>),
#  ('worried', <gensim.models.keyedvectors.Vocab at 0x120264750>),
#  ('carrion', <gensim.models.keyedvectors.Vocab at 0x120264790>),
#  ('priest', <gensim.models.keyedvectors.Vocab at 0x1202647d0>),
#  (u'primp', <gensim.models.keyedvectors.Vocab at 0x120264810>),
#  (u'vision', <gensim.models.keyedvectors.Vocab at 0x120264850>),
#  ('gout', <gensim.models.keyedvectors.Vocab at 0x120264890>),
#  ('raged', <gensim.models.keyedvectors.Vocab at 0x1202648d0>),
#  ('notice', <gensim.models.keyedvectors.Vocab at 0x120264910>),
#  ('purest', <gensim.models.keyedvectors.Vocab at 0x120264950>),
#  ('stannis', <gensim.models.keyedvectors.Vocab at 0x120264990>),
#  ('mutton', <gensim.models.keyedvectors.Vocab at 0x1202649d0>),
#  ('jumped', <gensim.models.keyedvectors.Vocab at 0x12038dc50>),
#  ('enjoys', <gensim.models.keyedvectors.Vocab at 0x120264a50>),
#  ('amory', <gensim.models.keyedvectors.Vocab at 0x120264a90>),
#  ('spare', <gensim.models.keyedvectors.Vocab at 0x120264ad0>),
#  ('umber', <gensim.models.keyedvectors.Vocab at 0x120264b10>),
#  ('undermine', <gensim.models.keyedvectors.Vocab at 0x120264b50>),
#  ('mant', <gensim.models.keyedvectors.Vocab at 0x120264b90>),
#  ('many', <gensim.models.keyedvectors.Vocab at 0x120264bd0>),
#  ('loudly', <gensim.models.keyedvectors.Vocab at 0x120264c10>),
#  (u'riddle', <gensim.models.keyedvectors.Vocab at 0x120264c50>),
#  ('drogo', <gensim.models.keyedvectors.Vocab at 0x120264c90>),
#  (u'compels', <gensim.models.keyedvectors.Vocab at 0x120264cd0>),
#  (u'twin', <gensim.models.keyedvectors.Vocab at 0x120264d10>),
#  ('boar', <gensim.models.keyedvectors.Vocab at 0x120264d50>),
#  (u'considers', <gensim.models.keyedvectors.Vocab at 0x12039d110>),
#  ('boat', <gensim.models.keyedvectors.Vocab at 0x120264dd0>),
#  (u'stretch', <gensim.models.keyedvectors.Vocab at 0x120264e10>),
#  ('west', <gensim.models.keyedvectors.Vocab at 0x120264e50>),
#  (u'expedition', <gensim.models.keyedvectors.Vocab at 0x120264e90>),
#  ('breath', <gensim.models.keyedvectors.Vocab at 0x120264ed0>),
#  ('combined', <gensim.models.keyedvectors.Vocab at 0x120264f10>),
#  ('stripped', <gensim.models.keyedvectors.Vocab at 0x120264f50>),
#  ('coughing', <gensim.models.keyedvectors.Vocab at 0x1203a3150>),
#  ('centerpiece', <gensim.models.keyedvectors.Vocab at 0x120264fd0>),
#  ('observe', <gensim.models.keyedvectors.Vocab at 0x120269050>),
#  (u'extant', <gensim.models.keyedvectors.Vocab at 0x120269090>),
#  ('former', <gensim.models.keyedvectors.Vocab at 0x1202690d0>),
#  ('wherewithal', <gensim.models.keyedvectors.Vocab at 0x120269110>),
#  (u'fin', <gensim.models.keyedvectors.Vocab at 0x120269150>),
#  ('straighten', <gensim.models.keyedvectors.Vocab at 0x1203a3c90>),
#  ('whatevers', <gensim.models.keyedvectors.Vocab at 0x1204e7dd0>),
#  ('squeezed', <gensim.models.keyedvectors.Vocab at 0x120269210>),
#  (u'situation', <gensim.models.keyedvectors.Vocab at 0x120269250>),
#  ('endured', <gensim.models.keyedvectors.Vocab at 0x120269290>),
#  ('ive', <gensim.models.keyedvectors.Vocab at 0x1202692d0>),
#  ('thatll', <gensim.models.keyedvectors.Vocab at 0x120269310>),
#  ('purse', <gensim.models.keyedvectors.Vocab at 0x120269350>),
#  ('shevelathin', <gensim.models.keyedvectors.Vocab at 0x120269390>),
#  ('spooked', <gensim.models.keyedvectors.Vocab at 0x1202693d0>),
#  ('burbling', <gensim.models.keyedvectors.Vocab at 0x120269410>),
#  ('threatens', <gensim.models.keyedvectors.Vocab at 0x120269450>),
#  ('damon', <gensim.models.keyedvectors.Vocab at 0x120269490>),
#  ('edged', <gensim.models.keyedvectors.Vocab at 0x1202694d0>),
#  ('sickness', <gensim.models.keyedvectors.Vocab at 0x1203aeed0>),
#  ('defy', <gensim.models.keyedvectors.Vocab at 0x120269550>),
# ...
#  ('dark', <gensim.models.keyedvectors.Vocab at 0x120269910>),
#  ('preference', <gensim.models.keyedvectors.Vocab at 0x120269950>),
#  ('fringed', <gensim.models.keyedvectors.Vocab at 0x1203712d0>),
#  ('vague', <gensim.models.keyedvectors.Vocab at 0x1202699d0>),
#  ('bravery', <gensim.models.keyedvectors.Vocab at 0x120269a10>),
#  (u'clan', <gensim.models.keyedvectors.Vocab at 0x120269a50>),
#  (u'clam', <gensim.models.keyedvectors.Vocab at 0x120269a90>),
#  ('stranger', <gensim.models.keyedvectors.Vocab at 0x120269ad0>),
#  ('discarded', <gensim.models.keyedvectors.Vocab at 0x120269b10>),
#  ('superiority', <gensim.models.keyedvectors.Vocab at 0x120269b50>),
#  (u'claw', <gensim.models.keyedvectors.Vocab at 0x120269b90>),
#  ('sorcerer', <gensim.models.keyedvectors.Vocab at 0x120295b50>),
#  (u'kennel', <gensim.models.keyedvectors.Vocab at 0x120269c10>),
#  (u'clap', <gensim.models.keyedvectors.Vocab at 0x120269c50>),
#  ('grub', <gensim.models.keyedvectors.Vocab at 0x120269c90>),
#  (u'lobster', <gensim.models.keyedvectors.Vocab at 0x120269cd0>),
#  (u'divine', <gensim.models.keyedvectors.Vocab at 0x120269d10>),
#  ('crabber', <gensim.models.keyedvectors.Vocab at 0x120269d50>),
#  ('dimpled', <gensim.models.keyedvectors.Vocab at 0x120269d90>),
#  ('refer', <gensim.models.keyedvectors.Vocab at 0x120269dd0>),
#  (u'clarenzo', <gensim.models.keyedvectors.Vocab at 0x120269e10>),
#  ('averse', <gensim.models.keyedvectors.Vocab at 0x120269e50>),
#  ('power', <gensim.models.keyedvectors.Vocab at 0x120269e90>),
#  ('intimate', <gensim.models.keyedvectors.Vocab at 0x120269ed0>),
#  ('hayseed', <gensim.models.keyedvectors.Vocab at 0x120269f10>),
#  ('leadership', <gensim.models.keyedvectors.Vocab at 0x120269f50>),
#  (u'stone', <gensim.models.keyedvectors.Vocab at 0x120269f90>),
#  ('yunkai', <gensim.models.keyedvectors.Vocab at 0x120269fd0>),
#  ('favorite', <gensim.models.keyedvectors.Vocab at 0x12026f050>),
#  (u'side', <gensim.models.keyedvectors.Vocab at 0x12035bf90>),
#  (u'apostate', <gensim.models.keyedvectors.Vocab at 0x12026f0d0>),
#  (u'neighbor', <gensim.models.keyedvectors.Vocab at 0x12026f110>),
#  ('act', <gensim.models.keyedvectors.Vocab at 0x12026f150>),
#  (u'mean', <gensim.models.keyedvectors.Vocab at 0x1203b9f90>),
#  ('stony', <gensim.models.keyedvectors.Vocab at 0x12026f1d0>),
#  (u'widowed', <gensim.models.keyedvectors.Vocab at 0x12026f210>),
#  ('chivalry', <gensim.models.keyedvectors.Vocab at 0x12026f250>),
#  ('shapely', <gensim.models.keyedvectors.Vocab at 0x12026f290>),
#  ('burning', <gensim.models.keyedvectors.Vocab at 0x12026f2d0>),
#  ('interruption', <gensim.models.keyedvectors.Vocab at 0x120361090>),
#  (u'antidote', <gensim.models.keyedvectors.Vocab at 0x12026f350>),
#  ('apologize', <gensim.models.keyedvectors.Vocab at 0x12026f390>),
#  (u'pivot', <gensim.models.keyedvectors.Vocab at 0x1203d4f10>),
#  ('trussed', <gensim.models.keyedvectors.Vocab at 0x12026f410>),
#  ('hey', <gensim.models.keyedvectors.Vocab at 0x12026f450>),
#  ('hed', <gensim.models.keyedvectors.Vocab at 0x12026f490>),
#  (u'lhazareen', <gensim.models.keyedvectors.Vocab at 0x12026f4d0>),
#  ('mindless', <gensim.models.keyedvectors.Vocab at 0x12026f510>),
#  ('sealed', <gensim.models.keyedvectors.Vocab at 0x12026f550>),
#  (u'hen', <gensim.models.keyedvectors.Vocab at 0x12026f590>),
#  ('survives', <gensim.models.keyedvectors.Vocab at 0x12026f5d0>),
#  ('recommends', <gensim.models.keyedvectors.Vocab at 0x12026f610>),
#  ('complete', <gensim.models.keyedvectors.Vocab at 0x12026f650>),
#  ('survived', <gensim.models.keyedvectors.Vocab at 0x12026f690>),
#  (u'whinny', <gensim.models.keyedvectors.Vocab at 0x12026f6d0>),
#  ('buying', <gensim.models.keyedvectors.Vocab at 0x12026f710>),
#  ('handsome', <gensim.models.keyedvectors.Vocab at 0x12026f750>),
#  ('abused', <gensim.models.keyedvectors.Vocab at 0x12026f790>),
#  ('pull', <gensim.models.keyedvectors.Vocab at 0x12026f7d0>),
#  (u'rush', <gensim.models.keyedvectors.Vocab at 0x12026f810>),
#  ('rage', <gensim.models.keyedvectors.Vocab at 0x12026f850>),
#  ('browbeaten', <gensim.models.keyedvectors.Vocab at 0x12026f890>),
#  ('balons', <gensim.models.keyedvectors.Vocab at 0x120361110>),
#  ('dirty', <gensim.models.keyedvectors.Vocab at 0x12026f910>),
#  ('agree', <gensim.models.keyedvectors.Vocab at 0x12026f950>),
#  ('darker', <gensim.models.keyedvectors.Vocab at 0x12026f990>),
#  (u'detailed', <gensim.models.keyedvectors.Vocab at 0x12026f9d0>),
#  ('gone', <gensim.models.keyedvectors.Vocab at 0x12026fa10>),
#  ('fright', <gensim.models.keyedvectors.Vocab at 0x12026fa50>),
#  (u'exhausted', <gensim.models.keyedvectors.Vocab at 0x12026fa90>),
#  ('ah', <gensim.models.keyedvectors.Vocab at 0x12026fad0>),
#  ('stealing', <gensim.models.keyedvectors.Vocab at 0x120361190>),
#  ('al', <gensim.models.keyedvectors.Vocab at 0x12026fb50>),
#  ('wartime', <gensim.models.keyedvectors.Vocab at 0x12026fb90>),
#  (u'watcher', <gensim.models.keyedvectors.Vocab at 0x12026fbd0>),
#  ('behest', <gensim.models.keyedvectors.Vocab at 0x12026fc10>),
#  (u'as', <gensim.models.keyedvectors.Vocab at 0x12026fc50>),
#  ('carved', <gensim.models.keyedvectors.Vocab at 0x12026fc90>),
#  (u'midwife', <gensim.models.keyedvectors.Vocab at 0x12026fcd0>),
#  ('laboratory', <gensim.models.keyedvectors.Vocab at 0x12026fd10>),
#  ('ax', <gensim.models.keyedvectors.Vocab at 0x12026fd50>),
#  (u'johnna', <gensim.models.keyedvectors.Vocab at 0x12026fd90>),
#  ('cream', <gensim.models.keyedvectors.Vocab at 0x12026fdd0>),
#  (u'ideally', <gensim.models.keyedvectors.Vocab at 0x12026fe10>),
#  ('tight', <gensim.models.keyedvectors.Vocab at 0x12026fe50>),
#  ('httpsubttfreeorg', <gensim.models.keyedvectors.Vocab at 0x12026fe90>),
#  (u'puppy', <gensim.models.keyedvectors.Vocab at 0x12026fed0>),
#  ('disgraceful', <gensim.models.keyedvectors.Vocab at 0x12026ff50>),
#  (u'congress', <gensim.models.keyedvectors.Vocab at 0x12026ff90>),
#  ('waving', <gensim.models.keyedvectors.Vocab at 0x12026ffd0>),
#  (u'middling', <gensim.models.keyedvectors.Vocab at 0x120274050>),
#  (u'midget', <gensim.models.keyedvectors.Vocab at 0x120274090>),
#  ('brotherhood', <gensim.models.keyedvectors.Vocab at 0x1202740d0>),
#  ('tricky', <gensim.models.keyedvectors.Vocab at 0x120274110>),
#  ('disdained', <gensim.models.keyedvectors.Vocab at 0x120274150>),
#  ('infanticide', <gensim.models.keyedvectors.Vocab at 0x120274190>),
#  ('sobbing', <gensim.models.keyedvectors.Vocab at 0x1202741d0>),
#  (u'thorn', <gensim.models.keyedvectors.Vocab at 0x120274210>),
#  ('groom', <gensim.models.keyedvectors.Vocab at 0x120274250>),
#  (u'mask', <gensim.models.keyedvectors.Vocab at 0x120274290>),
#  (u'dyed', <gensim.models.keyedvectors.Vocab at 0x1202742d0>),
#  (u'mast', <gensim.models.keyedvectors.Vocab at 0x120274310>),
#  (u'mass', <gensim.models.keyedvectors.Vocab at 0x120274350>),
#  ('sawing', <gensim.models.keyedvectors.Vocab at 0x120274390>),
#  (u'dyer', <gensim.models.keyedvectors.Vocab at 0x1202743d0>),
#  ('original', <gensim.models.keyedvectors.Vocab at 0x120274410>),
#  ('consider', <gensim.models.keyedvectors.Vocab at 0x120274450>),
#  ('beware', <gensim.models.keyedvectors.Vocab at 0x120274490>),
#  (u'neigh', <gensim.models.keyedvectors.Vocab at 0x1202744d0>),
#  ('welfare', <gensim.models.keyedvectors.Vocab at 0x120274510>),
#  ('hunting', <gensim.models.keyedvectors.Vocab at 0x120274550>),
#  ('tail', <gensim.models.keyedvectors.Vocab at 0x120274590>),
#  ('chewing', <gensim.models.keyedvectors.Vocab at 0x1202745d0>),
#  ('dockworker', <gensim.models.keyedvectors.Vocab at 0x120274610>),
#  ('th', <gensim.models.keyedvectors.Vocab at 0x120274650>),
#  (u'ti', <gensim.models.keyedvectors.Vocab at 0x120274690>),
#  ('smile', <gensim.models.keyedvectors.Vocab at 0x1202746d0>),
#  (u'shipload', <gensim.models.keyedvectors.Vocab at 0x120274710>),
#  ('paying', <gensim.models.keyedvectors.Vocab at 0x1204ec4d0>),
#  ('appointment', <gensim.models.keyedvectors.Vocab at 0x120274790>),
#  ('returned', <gensim.models.keyedvectors.Vocab at 0x1202747d0>),
#  ('squiring', <gensim.models.keyedvectors.Vocab at 0x120274810>),
#  ('eyrie', <gensim.models.keyedvectors.Vocab at 0x120274850>),
#  ('condition', <gensim.models.keyedvectors.Vocab at 0x120274890>),
#  ('harrenhal', <gensim.models.keyedvectors.Vocab at 0x1202748d0>),
#  ('overprotective', <gensim.models.keyedvectors.Vocab at 0x120274910>),
#  (u'laying', <gensim.models.keyedvectors.Vocab at 0x120274950>),
#  ('joined', <gensim.models.keyedvectors.Vocab at 0x120274990>),
#  ('underclothes', <gensim.models.keyedvectors.Vocab at 0x1202749d0>),
#  ('large', <gensim.models.keyedvectors.Vocab at 0x120274a10>),
#  ('sang', <gensim.models.keyedvectors.Vocab at 0x120274a50>),
#  ('sand', <gensim.models.keyedvectors.Vocab at 0x120274a90>),
#  (u'adjust', <gensim.models.keyedvectors.Vocab at 0x120274ad0>),
#  ('small', <gensim.models.keyedvectors.Vocab at 0x120274b10>),
#  ('quicker', <gensim.models.keyedvectors.Vocab at 0x120274b50>),
#  (u'healed', <gensim.models.keyedvectors.Vocab at 0x120274b90>),
#  ('past', <gensim.models.keyedvectors.Vocab at 0x120274bd0>),
#  ('podrick', <gensim.models.keyedvectors.Vocab at 0x120361450>),
#  (u'pass', <gensim.models.keyedvectors.Vocab at 0x120274c50>),
#  ('turning', <gensim.models.keyedvectors.Vocab at 0x120361490>),
#  (u'investment', <gensim.models.keyedvectors.Vocab at 0x120274cd0>),
#  ('poisonous', <gensim.models.keyedvectors.Vocab at 0x120274d10>),
#  ('prevailed', <gensim.models.keyedvectors.Vocab at 0x120274d50>),
#  ('nurse', <gensim.models.keyedvectors.Vocab at 0x120274d90>),
#  ('full', <gensim.models.keyedvectors.Vocab at 0x120274dd0>),
#  ('escaping', <gensim.models.keyedvectors.Vocab at 0x120274e10>),
#  ('vomiting', <gensim.models.keyedvectors.Vocab at 0x120274e50>),
#  ('smartest', <gensim.models.keyedvectors.Vocab at 0x120274e90>),
#  ('buzzing', <gensim.models.keyedvectors.Vocab at 0x120274ed0>),
#  ('legend', <gensim.models.keyedvectors.Vocab at 0x120274f10>),
#  ('slynt', <gensim.models.keyedvectors.Vocab at 0x120274f50>),
#  ('kayla', <gensim.models.keyedvectors.Vocab at 0x120237050>),
#  ('experience', <gensim.models.keyedvectors.Vocab at 0x120274fd0>),
#  ('pick', <gensim.models.keyedvectors.Vocab at 0x12027a050>),
#  (u'action', <gensim.models.keyedvectors.Vocab at 0x12027a090>),
#  ('murdering', <gensim.models.keyedvectors.Vocab at 0x12027a0d0>),
#  ('luck', <gensim.models.keyedvectors.Vocab at 0x120361050>),
#  ('smuggle', <gensim.models.keyedvectors.Vocab at 0x12027a110>),
#  ('gawking', <gensim.models.keyedvectors.Vocab at 0x12027a150>),
#  ('followed', <gensim.models.keyedvectors.Vocab at 0x12027a190>),
#  (u'follower', <gensim.models.keyedvectors.Vocab at 0x12027a1d0>),
#  (u'indoors', <gensim.models.keyedvectors.Vocab at 0x12027a210>),
#  (u'captor', <gensim.models.keyedvectors.Vocab at 0x12027a250>),
#  ('darkens', <gensim.models.keyedvectors.Vocab at 0x12027a290>),
#  (u'moro', <gensim.models.keyedvectors.Vocab at 0x12027a2d0>),
#  (u'gorgeous', <gensim.models.keyedvectors.Vocab at 0x12027a310>),
#  (u'mord', <gensim.models.keyedvectors.Vocab at 0x12027a350>),
#  ('restraint', <gensim.models.keyedvectors.Vocab at 0x120513a90>),
#  ('door', <gensim.models.keyedvectors.Vocab at 0x12027a390>),
#  ('company', <gensim.models.keyedvectors.Vocab at 0x12027a3d0>),
#  ('tested', <gensim.models.keyedvectors.Vocab at 0x12027a410>),
#  ('doom', <gensim.models.keyedvectors.Vocab at 0x12027a450>),
#  ('riverbank', <gensim.models.keyedvectors.Vocab at 0x12027a490>),
#  ('cunning', <gensim.models.keyedvectors.Vocab at 0x12027a4d0>),
#  ('keeping', <gensim.models.keyedvectors.Vocab at 0x12027a510>),
#  ('pleasing', <gensim.models.keyedvectors.Vocab at 0x12027a550>),
#  ('farted', <gensim.models.keyedvectors.Vocab at 0x12027a590>),
#  ('thickest', <gensim.models.keyedvectors.Vocab at 0x12027a5d0>),
#  ('learn', <gensim.models.keyedvectors.Vocab at 0x12027a610>),
#  ('knocked', <gensim.models.keyedvectors.Vocab at 0x12027a650>),
#  ('sunspear', <gensim.models.keyedvectors.Vocab at 0x12027a690>),
#  (u'seagull', <gensim.models.keyedvectors.Vocab at 0x12027a6d0>),
#  (u'male', <gensim.models.keyedvectors.Vocab at 0x12027a710>),
#  ('beautiful', <gensim.models.keyedvectors.Vocab at 0x12027a750>),
#  ('brightflame', <gensim.models.keyedvectors.Vocab at 0x12027a790>),
#  ('accept', <gensim.models.keyedvectors.Vocab at 0x12027a7d0>),
#  ('fiercely', <gensim.models.keyedvectors.Vocab at 0x12027a810>),
#  ('sense', <gensim.models.keyedvectors.Vocab at 0x12027a850>),
#  ('scar', <gensim.models.keyedvectors.Vocab at 0x12027a8d0>),
#  ('dress', <gensim.models.keyedvectors.Vocab at 0x12027a910>),
#  ('condemn', <gensim.models.keyedvectors.Vocab at 0x12027a950>),
#  ('information', <gensim.models.keyedvectors.Vocab at 0x12027a990>),
#  ('impulse', <gensim.models.keyedvectors.Vocab at 0x12030e2d0>),
#  ('imminent', <gensim.models.keyedvectors.Vocab at 0x12027a9d0>),
#  (u'hugh', <gensim.models.keyedvectors.Vocab at 0x12027aa10>),
#  ('dismissed', <gensim.models.keyedvectors.Vocab at 0x12027aa50>),
#  (u'glowing', <gensim.models.keyedvectors.Vocab at 0x12027aa90>),
#  ('freshly', <gensim.models.keyedvectors.Vocab at 0x12027aad0>),
#  (u'clink', <gensim.models.keyedvectors.Vocab at 0x12027ab10>),
#  ('unattended', <gensim.models.keyedvectors.Vocab at 0x12027ab50>),
#  ('creature', <gensim.models.keyedvectors.Vocab at 0x12027ab90>),
#  ('sprinkle', <gensim.models.keyedvectors.Vocab at 0x12027abd0>),
#  ('intended', <gensim.models.keyedvectors.Vocab at 0x12027ac10>),
#  ('countryside', <gensim.models.keyedvectors.Vocab at 0x12027ac50>),
#  ('disgraced', <gensim.models.keyedvectors.Vocab at 0x12027ac90>),
#  ('sympathize', <gensim.models.keyedvectors.Vocab at 0x12027acd0>),
#  ('zuriff', <gensim.models.keyedvectors.Vocab at 0x12027ad10>),
#  (u'pleaded', <gensim.models.keyedvectors.Vocab at 0x12027ad50>),
#  ('plank', <gensim.models.keyedvectors.Vocab at 0x12027ad90>),
#  ('refuse', <gensim.models.keyedvectors.Vocab at 0x12027add0>),
#  ('replied', <gensim.models.keyedvectors.Vocab at 0x12027ae10>),
#  ('eddark', <gensim.models.keyedvectors.Vocab at 0x12027ae50>),
#  (u'pant', <gensim.models.keyedvectors.Vocab at 0x12027ae90>),
#  ('reminded', <gensim.models.keyedvectors.Vocab at 0x1204ec810>),
#  ('eddard', <gensim.models.keyedvectors.Vocab at 0x12027af10>),
#  ('installed', <gensim.models.keyedvectors.Vocab at 0x12027af50>),
#  (u'paper', <gensim.models.keyedvectors.Vocab at 0x12027af90>),
#  (u'brim', <gensim.models.keyedvectors.Vocab at 0x12027afd0>),
#  ('smiling', <gensim.models.keyedvectors.Vocab at 0x12027f050>),
#  ('aemon', <gensim.models.keyedvectors.Vocab at 0x12027f090>),
#  ('mistreated', <gensim.models.keyedvectors.Vocab at 0x12027f0d0>),
#  (u'mummer', <gensim.models.keyedvectors.Vocab at 0x12027f110>),
#  ('ruining', <gensim.models.keyedvectors.Vocab at 0x12027f150>),
#  (u'travelling', <gensim.models.keyedvectors.Vocab at 0x12027f190>),
#  ('ally', <gensim.models.keyedvectors.Vocab at 0x12027f1d0>),
#  ('colleague', <gensim.models.keyedvectors.Vocab at 0x12027f210>),
#  ('lowell', <gensim.models.keyedvectors.Vocab at 0x12027f250>),
#  ('propose', <gensim.models.keyedvectors.Vocab at 0x12027f290>),
#  ('martells', <gensim.models.keyedvectors.Vocab at 0x12027f2d0>),
#  (u'easterner', <gensim.models.keyedvectors.Vocab at 0x12027f310>),
#  (u'qyburns', <gensim.models.keyedvectors.Vocab at 0x12027f350>),
#  ('always', <gensim.models.keyedvectors.Vocab at 0x12027f390>),
#  ('repayment', <gensim.models.keyedvectors.Vocab at 0x12027f3d0>),
#  ('found', <gensim.models.keyedvectors.Vocab at 0x12027f410>),
#  ('shocking', <gensim.models.keyedvectors.Vocab at 0x12027f450>),
#  ('begged', <gensim.models.keyedvectors.Vocab at 0x12027f490>),
#  (u'stevron', <gensim.models.keyedvectors.Vocab at 0x12027f4d0>),
#  ('varys', <gensim.models.keyedvectors.Vocab at 0x12029b6d0>),
#  (u'measurement', <gensim.models.keyedvectors.Vocab at 0x12027f550>),
#  ('bluer', <gensim.models.keyedvectors.Vocab at 0x12027f590>),
#  ('really', <gensim.models.keyedvectors.Vocab at 0x12027f5d0>),
#  ('missed', <gensim.models.keyedvectors.Vocab at 0x12027f610>),
#  (u'research', <gensim.models.keyedvectors.Vocab at 0x12027f650>),
#  ('hood', <gensim.models.keyedvectors.Vocab at 0x1203618d0>),
#  ('darling', <gensim.models.keyedvectors.Vocab at 0x12027f6d0>),
#  ('nastiness', <gensim.models.keyedvectors.Vocab at 0x120361910>),
#  ...]

# %%
model.wv.vocab.keys()
# Out:
# ['foul',
#  'four',
#  'hanging',
#  'marching',
#  u'increase',
#  'midafternoon',
#  'mutinied',
#  'lord',
#  u'sinking',
#  'leisurely',
#  u'politician',
#  'stabbed',
#  'bringing',
#  'disturb',
#  'prize',
#  'wooden',
#  u'clientele',
#  'succession',
#  'straight',
#  'tired',
#  u'lefford',
#  'bacon',
#  'elegant',
#  'second',
#  'sailed',
#  u'ruthless',
#  'thunder',
#  'cooking',
#  'contributed',
#  'resilient',
#  'succumb',
#  'hero',
#  'interrupting',
#  u'here',
#  'substance',
#  u'k',
#  'climbed',
#  'military',
#  u'climber',
#  'diplomat',
#  'appropriately',
#  'divide',
#  'explained',
#  'replace',
#  'brought',
#  'stern',
#  'cheating',
#  'spoke',
#  u'cannibal',
#  'occupying',
#  'untie',
#  'strike',
#  'sideface',
#  'holy',
#  'relax',
#  'successful',
#  'brings',
#  'hereby',
#  'hurt',
#  u'glass',
#  u'hole',
#  'hold',
#  u'simper',
#  u'benjens',
#  'pursue',
#  'zhoan',
#  'blade',
#  'plunged',
#  'sweeter',
#  'rework',
#  'example',
#  'triple',
#  'organized',
#  u'caution',
#  'want',
#  'counseling',
#  'mymother',
#  u'cocksucker',
#  'absolute',
#  'hog',
#  'complaining',
#  u'travel',
#  'copious',
#  'undying',
#  'hot',
#  'retreating',
#  'beauty',
#  'swing',
#  u'despondent',
#  'outlawed',
#  'wrong',
#  'barristan',
#  u'huhuh',
#  u'attracts',
#  u'revolt',
#  'sickening',
#  'tulip',
#  'viserys',
#  u'wing',
#  'wind',
#  'wine',
#  'dreamed',
#  'patricide',
#  u'profaned',
#  'rewarded',
#  'fit',
#  'allisers',
#  'screaming',
#  u'fix',
#  u'dedicate',
#  u'fig',
#  'mewling',
#  'hidden',
#  'admirable',
#  'easier',
#  'hghar',
#  'commemorate',
#  'educating',
#  'interrupt',
#  'blink',
#  'silver',
#  'structural',
#  u'represents',
#  'jaehaerys',
#  'theons',
#  u'arrow',
#  u'armourer',
#  'burial',
#  u'whim',
#  'financial',
#  u'spider',
#  u'longclaw',
#  u'turnip',
#  'fortnight',
#  u'mutineer',
#  u'wyllis',
#  'message',
#  'whip',
#  'misfortune',
#  'whoosh',
#  u'mason',
#  u'rd',
#  'archmaester',
#  u'ro',
#  u'outburst',
#  u'foundation',
#  'assured',
#  'waddle',
#  'threatened',
#  'assures',
#  'aggar',
#  'crowned',
#  'tobho',
#  'ate',
#  'ath',
#  'shipped',
#  u'disturbed',
#  'tempting',
#  'minge',
#  u'subtlety',
#  'wash',
#  'instruct',
#  'bitten',
#  'zala',
#  'whorehouse',
#  'timid',
#  'engagement',
#  'needed',
#  'master',
#  'bitter',
#  'ranging',
#  'listen',
#  'lorch',
#  u'collapse',
#  'hows',
#  'highgarden',
#  'wisdom',
#  'predictable',
#  'crawl',
#  'positively',
#  'showed',
#  u'coward',
#  'tree',
#  u'whinging',
#  'shower',
#  'idle',
#  'endure',
#  'profitable',
#  'feeling',
#  'groaning',
#  'longs',
#  'untrained',
#  'tether',
#  'dozen',
#  'responsible',
#  u'instructs',
#  'amusing',
#  'britches',
#  u'season',
#  'eastwatch',
#  u'horselords',
#  'howd',
#  'shall',
#  'huh',
#  'aegons',
#  'toil',
#  'mouth',
#  'letter',
#  u'singer',
#  u'episode',
#  'rayder',
#  'consummate',
#  'mating',
#  'tirelessly',
#  'came',
#  'saying',
#  'fennel',
#  u'tempted',
#  'abreast',
#  'busy',
#  'theme',
#  'touched',
#  'rich',
#  u'plate',
#  'petrified',
#  u'foremost',
#  u'pocket',
#  u'reversal',
#  'altogether',
#  'blistered',
#  u'spilling',
#  'nicely',
#  'dipping',
#  'piggy',
#  'release',
#  u'respond',
#  u'blew',
#  'fair',
#  'bled',
#  u'result',
#  'fail',
#  'nocturnal',
#  u'hammer',
#  'best',
#  'score',
#  'pirate',
#  u'wage',
#  'men',
#  'khaleesi',
#  'extend',
#  'nature',
#  'rolled',
#  'smelled',
#  'lapping',
#  u'souvenir',
#  u'extent',
#  'tyrion',
#  u'debt',
#  'pity',
#  'accident',
#  'weirwood',
#  'country',
#  u'adventurer',
#  'demanded',
#  'planned',
#  'logic',
#  'argue',
#  'asked',
#  u'vain',
#  'blonde',
#  'shouting',
#  'union',
#  'slay',
#  'muck',
#  'much',
#  'privilege',
#  'tallest',
#  'life',
#  u'lodock',
#  'spit',
#  u'eastern',
#  'jeor',
#  u'davy',
#  'wish',
#  'lift',
#  'direwolf',
#  'child',
#  'worked',
#  'cunt',
#  'employ',
#  'contemplates',
#  u'flooding',
#  'picturing',
#  'remembering',
#  u'congratulation',
#  'played',
#  'cersei',
#  u'locksmith',
#  u'obeying',
#  u'player',
#  'trusted',
#  'severity',
#  'tarth',
#  'yellow',
#  'thievery',
#  'rebellion',
#  'clucking',
#  u'harmony',
#  'fairly',
#  'boiled',
#  'marched',
#  'supper',
#  'therell',
#  'metalwork',
#  'tune',
#  u'tarleys',
#  'intrusion',
#  'noblewoman',
#  'eagle',
#  'towheaded',
#  u'bellow',
#  'golden',
#  'forsaken',
#  u'plight',
#  u'hal',
#  'ham',
#  'ease',
#  'hay',
#  'innocent',
#  'prison',
#  'east',
#  'hat',
#  u'hightower',
#  'survival',
#  'possible',
#  'possibly',
#  'birth',
#  'shadow',
#  'unique',
#  'desire',
#  'remind',
#  'battlefield',
#  'right',
#  'old',
#  'crowd',
#  'people',
#  'macabre',
#  'crown',
#  'captive',
#  'warring',
#  'bottom',
#  u'rehearse',
#  u'fox',
#  'witty',
#  u'foe',
#  u'summoned',
#  u'umi',
#  'pinched',
#  'yoke',
#  u'defensive',
#  'losing',
#  'memorable',
#  'bowing',
#  u'grievously',
#  u'o',
#  'despair',
#  u'slightly',
#  'match',
#  'lamprey',
#  'raised',
#  'watering',
#  'tyrell',
#  'son',
#  'thankful',
#  'consummated',
#  'sow',
#  'wrap',
#  'despised',
#  'fabric',
#  'suffice',
#  'tame',
#  'grasping',
#  'despises',
#  'greatness',
#  'music',
#  'thoros',
#  'underestimated',
#  'offer',
#  'shireen',
#  'perfumed',
#  'matthos',
#  'duel',
#  'inside',
#  'morning',
#  'vanguard',
#  'pest',
#  'torturing',
#  'smashed',
#  'juvenile',
#  'later',
#  'proved',
#  'arwyen',
#  'tournament',
#  'proven',
#  'meros',
#  'soothe',
#  'exist',
#  'accounting',
#  'floor',
#  u'actor',
#  'uttered',
#  'flood',
#  'underfed',
#  'role',
#  'ambitious',
#  'smell',
#  'roll',
#  'intend',
#  'corbray',
#  u'ointment',
#  'scream',
#  'acquaintance',
#  'giantsbane',
#  'cleaver',
#  u'daugters',
#  'warn',
#  'pycelle',
#  'sniffed',
#  'quandary',
#  'time',
#  'push',
#  'someplace',
#  'dotes',
#  'gown',
#  'chain',
#  'whoever',
#  'warg',
#  'chair',
#  'midst',
#  'quartered',
#  u'lothar',
#  'choice',
#  'mourn',
#  'locked',
#  u'exact',
#  'minute',
#  'tear',
#  u'teat',
#  u'pea',
#  'leave',
#  'settle',
#  'stockade',
#  u'team',
#  'bonfire',
#  u'accomplishment',
#  u'sigh',
#  'sign',
#  'chopping',
#  'catelyn',
#  u'melt',
#  'current',
#  'axel',
#  'falling',
#  'crashing',
#  'badge',
#  'ramming',
#  u'funeral',
#  'understanding',
#  'contemplate',
#  'address',
#  'alone',
#  'along',
#  'crumbles',
#  u'summerwine',
#  'brilliant',
#  'studied',
#  'wherever',
#  u'commonly',
#  'accomplished',
#  'greizhen',
#  u'reclaim',
#  'nowhere',
#  'love',
#  'prefer',
#  'logical',
#  'bloody',
#  'marvelous',
#  'betraying',
#  u'sky',
#  u'capsized',
#  'working',
#  'angry',
#  'blackwater',
#  u'cockfighting',
#  'wondering',
#  u'halfbrother',
#  'wicked',
#  u'introducing',
#  u'guardsman',
#  'afford',
#  'xaros',
#  'marbled',
#  'everywhere',
#  'virtue',
#  'behalf',
#  'honey',
#  'valued',
#  'anything',
#  'originally',
#  u'pretend',
#  'privy',
#  'believer',
#  u'impasse',
#  'believed',
#  'admired',
#  'locke',
#  u'unconsummated',
#  'unveiled',
#  'allowed',
#  'offense',
#  'stole',
#  'evidently',
#  'listens',
#  'winter',
#  u'divided',
#  'thanking',
#  'immune',
#  'loathe',
#  u'encampment',
#  u'provincial',
#  'spot',
#  'suck',
#  'dove',
#  u'stress',
#  'natural',
#  'blackfish',
#  'st',
#  'swollen',
#  'truce',
#  'pulled',
#  'drunken',
#  u'footstep',
#  'unacceptable',
#  'damage',
#  'course',
#  'yearn',
#  'mishear',
#  'lovelier',
#  u'tendency',
#  'tore',
#  'milked',
#  'torn',
#  'stupidity',
#  'aerion',
#  'celebrate',
#  'troubled',
#  u'deviant',
#  u'chaining',
#  'smarter',
#  'arriving',
#  'reckoning',
#  u'shhh',
#  'maintaining',
#  'matched',
#  'freya',
#  'appropriate',
#  'stillborns',
#  'fisherman',
#  'amnesty',
#  u'quarter',
#  'broodmare',
#  'square',
#  'beloved',
#  'entering',
#  u'beetle',
#  'troll',
#  u'swordsman',
#  'seriously',
#  'investigation',
#  'suggesting',
#  'facedown',
#  'siege',
#  'million',
#  'seventh',
#  u'possibility',
#  'quite',
#  'complicated',
#  'besides',
#  u'grandma',
#  'unnamed',
#  'patronage',
#  'training',
#  'backside',
#  'modest',
#  u'nymeria',
#  'saving',
#  'spoken',
#  'one',
#  u'reopen',
#  'punishable',
#  'vote',
#  'open',
#  'ripping',
#  'partook',
#  u'city',
#  u'wrath',
#  'bite',
#  'teacher',
#  u'shiver',
#  'prone',
#  'shawl',
#  'meddling',
#  u'padding',
#  'prowling',
#  'ridiculous',
#  u'camello',
#  'third',
#  'cower',
#  'sandor',
#  u'counselor',
#  u'wandering',
#  'damned',
#  'prospect',
#  u'addressing',
#  u'illness',
#  'tasted',
#  'nicer',
#  'turned',
#  'alley',
#  'sad',
#  'say',
#  'taster',
#  'buried',
#  'lurking',
#  'sap',
#  'saw',
#  'sat',
#  'wink',
#  u'downwards',
#  'aside',
#  'instructed',
#  'note',
#  'take',
#  u'mazin',
#  'wanting',
#  u'opposite',
#  'squalor',
#  'knew',
#  'knee',
#  'average',
#  u'sale',
#  u'defeating',
#  'crooked',
#  'gillyflower',
#  'squint',
#  'butchered',
#  'salt',
#  'walking',
#  u'merit',
#  'bright',
#  'imagined',
#  'slow',
#  'strangled',
#  u'cloak',
#  'liberation',
#  'betrothal',
#  'going',
#  'dancing',
#  'outrage',
#  'robe',
#  'clawing',
#  'robb',
#  u'dispute',
#  'graceless',
#  'guarded',
#  'freezing',
#  u'clang',
#  'awaiting',
#  'vhag',
#  'prime',
#  u'resource',
#  u'artist',
#  'absurdly',
#  'worried',
#  'carrion',
#  'priest',
#  u'primp',
#  u'vision',
#  'gout',
#  'raged',
#  'notice',
#  'purest',
#  'stannis',
#  'mutton',
#  'jumped',
#  'enjoys',
#  'amory',
#  'spare',
#  'umber',
#  'undermine',
#  'mant',
#  'many',
#  'loudly',
#  u'riddle',
#  'drogo',
#  u'compels',
#  u'twin',
#  'boar',
#  u'considers',
#  'boat',
#  u'stretch',
#  'west',
#  u'expedition',
#  'breath',
#  'combined',
#  'stripped',
#  'coughing',
#  'centerpiece',
#  'observe',
#  u'extant',
#  'former',
#  'wherewithal',
#  u'fin',
#  'straighten',
#  'whatevers',
#  'squeezed',
#  u'situation',
#  'endured',
#  'ive',
#  'thatll',
#  'purse',
#  'shevelathin',
#  'spooked',
#  'burbling',
#  'threatens',
#  'damon',
#  'edged',
#  'sickness',
#  'defy',
#  'disown',
#  'recapture',
#  'polliver',
#  'summer',
#  u'being',
#  'rest',
#  u'overconfident',
#  'afterwards',
#  u'khalar',
#  u'sixteen',
#  'befalling',
#  'overthrow',
#  'haystack',
#  'starving',
#  'around',
#  'dark',
#  'preference',
#  'fringed',
#  'vague',
#  'bravery',
#  u'clan',
#  u'clam',
#  'stranger',
#  'discarded',
#  'superiority',
#  u'claw',
#  'sorcerer',
#  u'kennel',
#  u'clap',
#  'grub',
#  u'lobster',
#  u'divine',
#  'crabber',
#  'dimpled',
#  'refer',
#  u'clarenzo',
#  'averse',
#  'power',
#  'intimate',
#  'hayseed',
#  'leadership',
#  u'stone',
#  'yunkai',
#  'favorite',
#  u'side',
#  u'apostate',
#  u'neighbor',
#  'act',
#  u'mean',
#  'stony',
#  u'widowed',
#  'chivalry',
#  'shapely',
#  'burning',
#  'interruption',
#  u'antidote',
#  'apologize',
#  u'pivot',
#  'trussed',
#  'hey',
#  'hed',
#  u'lhazareen',
#  'mindless',
#  'sealed',
#  u'hen',
#  'survives',
#  'recommends',
#  'complete',
#  'survived',
#  u'whinny',
#  'buying',
#  'handsome',
#  'abused',
#  'pull',
#  u'rush',
#  'rage',
#  'browbeaten',
#  'balons',
#  'dirty',
#  'agree',
#  'darker',
#  u'detailed',
#  'gone',
#  'fright',
#  u'exhausted',
#  'ah',
#  'stealing',
#  'al',
#  'wartime',
#  u'watcher',
#  'behest',
#  u'as',
#  'carved',
#  u'midwife',
#  'laboratory',
#  'ax',
#  u'johnna',
#  'cream',
#  u'ideally',
#  'tight',
#  'httpsubttfreeorg',
#  u'puppy',
#  'disgraceful',
#  u'congress',
#  'waving',
#  u'middling',
#  u'midget',
#  'brotherhood',
#  'tricky',
#  'disdained',
#  'infanticide',
#  'sobbing',
#  u'thorn',
#  'groom',
#  u'mask',
#  u'dyed',
#  u'mast',
#  u'mass',
#  'sawing',
#  u'dyer',
#  'original',
#  'consider',
#  'beware',
#  u'neigh',
#  'welfare',
#  'hunting',
#  'tail',
#  'chewing',
#  'dockworker',
#  'th',
#  u'ti',
#  'smile',
#  u'shipload',
#  'paying',
#  'appointment',
#  'returned',
#  'squiring',
#  'eyrie',
#  'condition',
#  'harrenhal',
#  'overprotective',
#  u'laying',
#  'joined',
#  'underclothes',
#  'large',
#  'sang',
#  'sand',
#  u'adjust',
#  'small',
#  'quicker',
#  u'healed',
#  'past',
#  'podrick',
#  u'pass',
#  'turning',
#  u'investment',
#  'poisonous',
#  'prevailed',
#  'nurse',
#  'full',
#  'escaping',
#  'vomiting',
#  'smartest',
#  'buzzing',
#  'legend',
#  'slynt',
#  'kayla',
#  'experience',
#  'pick',
#  u'action',
#  'murdering',
#  'luck',
#  'smuggle',
#  'gawking',
#  'followed',
#  u'follower',
#  u'indoors',
#  u'captor',
#  'darkens',
#  u'moro',
#  u'gorgeous',
#  u'mord',
#  'restraint',
#  'door',
#  'company',
#  'tested',
#  'doom',
#  'riverbank',
#  'cunning',
#  'keeping',
#  'pleasing',
#  'farted',
#  'thickest',
#  'learn',
#  'knocked',
#  'sunspear',
#  u'seagull',
#  u'male',
#  'beautiful',
#  'brightflame',
#  'accept',
#  'fiercely',
#  'sense',
#  'scar',
#  'dress',
#  'condemn',
#  'information',
#  'impulse',
#  'imminent',
#  u'hugh',
#  'dismissed',
#  u'glowing',
#  'freshly',
#  u'clink',
#  'unattended',
#  'creature',
#  'sprinkle',
#  'intended',
#  'countryside',
#  'disgraced',
#  'sympathize',
#  'zuriff',
#  u'pleaded',
#  'plank',
#  'refuse',
#  'replied',
#  'eddark',
#  u'pant',
#  'reminded',
#  'eddard',
#  'installed',
#  u'paper',
#  u'brim',
#  'smiling',
#  'aemon',
#  'mistreated',
#  u'mummer',
#  'ruining',
#  u'travelling',
#  'ally',
#  'colleague',
#  'lowell',
#  'propose',
#  'martells',
#  u'easterner',
#  u'qyburns',
#  'always',
#  'repayment',
#  'found',
#  'shocking',
#  'begged',
#  u'stevron',
#  'varys',
#  u'measurement',
#  'bluer',
#  'really',
#  'missed',
#  u'research',
#  'hood',
#  'darling',
#  'nastiness',
#  ...]

# %%
model_list = []

for i in model.wv.vocab.keys():
    model_list.append(model.wv[i])

# %%
model_list
# Out:
# [array([-0.22734848, -0.02274841, -0.03192084, -0.13213485, -0.11684443,
#         -0.01594091, -0.00067989,  0.00274709,  0.01537378,  0.01290557,
#          0.00197759,  0.00244862, -0.02072038, -0.01562375, -0.00705851,
#          0.02012384, -0.03136397,  0.00280233, -0.02507024,  0.00966559], dtype=float32),
#  ...]

# %%
model_vectors = pd.DataFrame(model_list)
model_vectors.shape
# Out:
# (6913, 100)

# %%
model_vectors = model_vectors.reset_index()

# %%
model_vectors['index'] = model.wv.vocab.keys()

# %%
model_vectors = model_vectors.set_index('index')

# %%
model_vectors.head()
# Out:
#                 0         1         2         3         4         5   \
# index
# foul     -0.227348 -0.022748 -0.031921 -0.132135 -0.116844 -0.108855
# four     -0.308133 -0.030978 -0.043079 -0.187027 -0.147836 -0.140025
# hanging  -0.151221 -0.020682 -0.022413 -0.088994 -0.070946 -0.073776
# marching -0.287961 -0.021104 -0.040261 -0.167429 -0.143008 -0.134391
# increase -0.053263 -0.000538 -0.011278 -0.032747 -0.026203 -0.025140
#
#                 6         7         8         9     ...           90  \
# index                                               ...
# foul     -0.106332 -0.197335 -0.012054 -0.181412    ...     0.035260
# four     -0.152644 -0.272066 -0.028142 -0.240630    ...     0.047810
# hanging  -0.076421 -0.130453 -0.013585 -0.112496    ...     0.026866
# marching -0.143650 -0.266373 -0.029403 -0.225230    ...     0.046018
# increase -0.028630 -0.055006 -0.006999 -0.043935    ...     0.012420
#
#                 91        92        93        94        95        96  \
# index
# foul     -0.005630 -0.166717 -0.139884 -0.043533  0.131457 -0.184855
# four     -0.011332 -0.227886 -0.185361 -0.057243  0.180777 -0.257185
# hanging  -0.002189 -0.114250 -0.088434 -0.036014  0.091575 -0.129315
# marching -0.004155 -0.209439 -0.179424 -0.064052  0.168700 -0.240126
# increase -0.005476 -0.036459 -0.036896 -0.015185  0.029795 -0.042562
#
#                 97        98        99
# index
# foul     -0.008847 -0.156338  0.040658
# four     -0.001546 -0.203124  0.049584
# hanging  -0.003738 -0.097730  0.020513
# marching -0.010947 -0.192614  0.048529
# increase  0.002786 -0.040991  0.010211
#
# [5 rows x 100 columns]

# %%
pca20 = PCA(n_components=20)

pca_results20 = pca20.fit_transform(model_vectors)

# %%
pca_results_20 = pd.DataFrame(pca_results20)

# %%
pca_results_20 = pca_results_20.reset_index()

# %%
pca_results_20['index'] = model.wv.vocab.keys()

# %%
pca_results_20 = pca_results_20.set_index('index')

# %%
pca_results_20.head()
# Out:
#                 0         1         2         3         4         5   \
# index
# foul      0.466164 -0.004241 -0.029383  0.001997  0.007994 -0.007967
# four      0.862427 -0.013954 -0.018760  0.027812  0.007532 -0.000938
# hanging   0.069150 -0.003843 -0.011289  0.009442  0.000551  0.000982
# marching  0.782270 -0.000466 -0.002600  0.029265 -0.007757 -0.009118
# increase -0.419327  0.002046  0.002757 -0.001476 -0.000924  0.007497
#
#                 6         7         8         9         10        11  \
# index
# foul      0.004210  0.003179 -0.000068 -0.002277 -0.001553 -0.004802
# four      0.000772  0.013391 -0.003197  0.008574 -0.008752 -0.003175
# hanging   0.006007 -0.003604 -0.005626 -0.003291 -0.006278  0.000274
# marching -0.013787 -0.004805 -0.008338 -0.003497  0.000996  0.000482
# increase  0.000436  0.001080 -0.003947 -0.000035 -0.000257  0.002746
#
#                 12        13        14        15        16        17  \
# index
# foul     -0.004327 -0.006375 -0.001643 -0.000757 -0.001982 -0.001486
# four     -0.000368 -0.002060  0.001996  0.002979  0.001499  0.004406
# hanging  -0.004914 -0.002176 -0.002328 -0.002144  0.005001  0.000268
# marching -0.002337  0.007886  0.003716  0.000442 -0.002033 -0.001644
# increase  0.004778  0.001073 -0.002841  0.000658 -0.006676  0.003510
#
#                 18        19
# index
# foul      0.001804 -0.002266
# four     -0.002499  0.006589
# hanging  -0.003759 -0.005203
# marching  0.002644  0.006627
# increase  0.001087  0.001405

# %%
tsne = TSNE(n_components=2)

tsne_pca_results20 = tsne.fit_transform(pca_results20)

# %%
tsne_pca_results_20 = pd.DataFrame(tsne_pca_results20)

# %%
tsne_pca_results_20 = tsne_pca_results_20.reset_index()

# %%
tsne_pca_results_20['index'] = model.wv.vocab.keys()

# %%
tsne_pca_results_20 = tsne_pca_results_20.set_index('index')

# %%
tsne_pca_results_20.head(10)
# Out:
#                          0             1
# index
# foul          2.627026e+16 -5.088883e+15
# four         -3.905450e+16  7.740059e+16
# hanging       8.741687e+16 -1.574284e+17
# marching      2.508176e+16  6.711072e+15
# increase     -4.326863e+18 -1.717717e+18
# midafternoon  1.551103e+15  4.348303e+16
# mutinied      2.358794e+16  9.703822e+16
# lord          9.190351e+16 -3.390594e+16
# sinking       2.652186e+17 -2.008444e+18
# leisurely     2.096185e+17  3.249580e+17

# %%
tsne_pca_results20
# Out:
# array([[  2.62702626e+16,  -5.08888332e+15],
#        [ -3.90544953e+16,   7.74005897e+16],
#        [  8.74168683e+16,  -1.57428412e+17],
#        ...,
#        [  1.10337543e+16,  -3.97210187e+16],
#        [  1.95529753e+16,  -2.27440613e+16],
#        [  8.32042319e+15,   2.05273290e+16]])

# %%
tsne_pca_results_20.index
# Out:
# Index([        u'foul',         u'four',      u'hanging',     u'marching',
#            u'increase', u'midafternoon',     u'mutinied',         u'lord',
#             u'sinking',    u'leisurely',
#        ...
#               u'lance',       u'risked',       u'squeak',       u'oberyn',
#               u'cliff',    u'auxiliary',        u'wylla',    u'firestorm',
#          u'baratheons',  u'furthermore'],
#       dtype='object', name=u'index', length=6913)

# %%
import numpy as Math
import pylab as Plot
import matplotlib.pyplot as plt

rows = tsne_pca_results_20.index
# %matplotlib notebook
plt.ion()

Plot.figure(figsize=(20, 10))
max_x = Math.amax(tsne_pca_results20, axis=0)[0]
max_y = Math.amax(tsne_pca_results20, axis=0)[1]
#Plot.xlim((-.125e+20,.25e+20))
#Plot.ylim((-.125+e20,.1e20))

Plot.scatter(tsne_pca_results20[:, 0], tsne_pca_results20[:, 1], 20);

for row_id in range(0, len(rows)):
    target_word = rows[row_id]
    x = tsne_pca_results20[row_id, 0]
    y = tsne_pca_results20[row_id, 1]
    Plot.annotate(target_word, (x,y))

Plot.savefig("tsne_2002.png");
# Out:
# <img src="data:image/png;base64,..." width="1440">
